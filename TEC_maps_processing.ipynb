# %% [markdown]
# # Download datasets and software

# %%
# %cd '/content'
# Out:
# /content

# %%
#Download TF1_TF2_TEC_maps_without_interpolation_and_datetimes from https://doi.org/10.5281/zenodo.15453941

# %%
# !gdown '1U7GFAHllhd3EOumLdJjwi8PC3LEN1UJd'
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1U7GFAHllhd3EOumLdJjwi8PC3LEN1UJd
# From (redirected): https://drive.google.com/uc?id=1U7GFAHllhd3EOumLdJjwi8PC3LEN1UJd&confirm=t&uuid=2cf1d786-d46a-444d-a242-99c3f9253fa8
# To: /content/TF1_TF2_TEC_maps_without_interpolation_and_datetimes.zip
# 100% 511M/511M [00:06<00:00, 82.5MB/s]

# %%
#Download TEC_maps_seasonal_analysis.zip from https://doi.org/10.5281/zenodo.15453941

# %%
# !gdown '1VY1HgxOmO8zChHKwpxjfDHVmjDm4Mmbm'
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1VY1HgxOmO8zChHKwpxjfDHVmjDm4Mmbm
# To: /content/TEC_maps_seasonal_analysis.zip
# 100% 623k/623k [00:00<00:00, 126MB/s]

# %%
# !git clone 'https://github.com/marcocintra/Atmosphere.git'
# Out:
# Cloning into 'Atmosphere'...
# remote: Enumerating objects: 27939, done.
# remote: Counting objects: 100% (415/415), done.
# remote: Compressing objects: 100% (59/59), done.
# remote: Total 27939 (delta 397), reused 356 (delta 356), pack-reused 27524 (from 2)
# Receiving objects: 100% (27939/27939), 227.36 MiB | 23.02 MiB/s, done.
# Resolving deltas: 100% (3079/3079), done.
# Updating files: 100% (22398/22398), done.

# %%
# %cd Atmosphere
# Out:
# /content/Atmosphere

# %%
# !git pull origin master
# Out:
# From https://github.com/marcocintra/Atmosphere
#  * branch              master     -> FETCH_HEAD
# Already up to date.

# %%
# !unzip '/content/TF1_TF2_TEC_maps_without_interpolation_and_datetimes.zip' -d '/content/Atmosphere/data'
# Out:
# Archive:  /content/TF1_TF2_TEC_maps_without_interpolation_and_datetimes.zip
#   inflating: /content/Atmosphere/data/TF1_EMBRACE_TEC_maps_0800.npy
#   inflating: /content/Atmosphere/data/TF1_EMBRACE_TEC_maps_0800_datetimes.npy
#   inflating: /content/Atmosphere/data/TF1_EMBRACE_TEC_maps_1600.npy
#   inflating: /content/Atmosphere/data/TF1_EMBRACE_TEC_maps_1600_datetimes.npy
#   inflating: /content/Atmosphere/data/TF1_EMBRACE_TEC_maps_2000_0400.npy
#   inflating: /content/Atmosphere/data/TF1_EMBRACE_TEC_maps_2000_0400_datetimes.npy
#   inflating: /content/Atmosphere/data/TF1_IGS_TEC_maps_0800.npy
#   inflating: /content/Atmosphere/data/TF1_IGS_TEC_maps_0800_datetimes.npy
#   inflating: /content/Atmosphere/data/TF1_IGS_TEC_maps_1600.npy
#   inflating: /content/Atmosphere/data/TF1_IGS_TEC_maps_1600_datetimes.npy
#   inflating: /content/Atmosphere/data/TF1_IGS_TEC_maps_2000_0400.npy
#   inflating: /content/Atmosphere/data/TF1_IGS_TEC_maps_2000_0400_datetimes.npy
# ...

# %%
# !rm '/content/TF1_TF2_TEC_maps_without_interpolation_and_datetimes.zip'

# %%
# !unzip '/content/TEC_maps_seasonal_analysis.zip' -d '/content/Atmosphere/data'
# Out:
# Archive:  /content/TEC_maps_seasonal_analysis.zip
#   inflating: /content/Atmosphere/data/EMBRACE_TEC_maps.npy
#   inflating: /content/Atmosphere/data/EMBRACE_TEC_maps_datetimes.npy
#   inflating: /content/Atmosphere/data/IGS_TEC_maps.npy
#   inflating: /content/Atmosphere/data/IGS_TEC_maps_datetimes.npy
#   inflating: /content/Atmosphere/data/MAGGIA_TEC_maps.npy
#   inflating: /content/Atmosphere/data/MAGGIA_TEC_maps_datetimes.npy
#   inflating: /content/Atmosphere/data/Nagoya_TEC_maps.npy
#   inflating: /content/Atmosphere/data/Nagoya_TEC_maps_datetimes.npy

# %%
# !rm '/content/TEC_maps_seasonal_analysis.zip'

# %%
# %cd '/content/Atmosphere'
# Out:
# /content/Atmosphere

# %%
# !ls
# Out:
# 01_parallel_npy_plot.py
# 01_serial_npy_plot.py
# 02_parallel_npy_interpolation.py
# 02_serial_npy_interpolation.py
# 03_parallel_interpolated_npy_plot.py
# 03_serial_interpolated_npy_plot.py
# 04_metrics_pearson_seasonal.txt
# 04_metrics.py
# 04_metrics_ssim_seasonal_fisher.txt
# 04_metrics_ssim_seasonal.txt
# Case_study_EMBRACE_TEC_maps_2024.ipynb
# Case_study_MAGGIA_TEC_maps_2024.ipynb
# data
# EMBRACE_TEC_maps_2022_2024.ipynb
# F10_7_analysis.ipynb
# Filter_2024_TEC_maps_dataframes_Solstices_and_Equinoxes.ipynb
# Generate_datetimes_from_TEC_maps_dataframes.ipynb
# Gopi_TEC_Brasilia_analysis_09_27_2024.ipynb
# Gopi_TEC_Brasilia_analysis_Dec_2024.ipynb
# Gopi_TEC_Cuiaba_analysis_09_27_2024.ipynb
# Gopi_TEC_Cuiaba_analysis_Dec_2024.ipynb
# Gopi_TEC_Manaus_analysis_09_27_2024.ipynb
# Gopi_TEC_Manaus_analysis_Dec_2024.ipynb
# Gopi_TEC_Porto_Alegre_analysis_09_27_2024.ipynb
# Gopi_TEC_Porto_Alegre_analysis_Dec_2024.ipynb
# Gopi_TEC_Salvador_analysis_09_27_2024.ipynb
# ...

# %%
# %cd data
# Out:
# /content/Atmosphere/data

# %%
# !ls
# Out:
# EMBRACE_TEC_maps_datetimes.npy	MAGGIA_TEC_maps.npy
# EMBRACE_TEC_maps.npy		Nagoya_TEC_maps_datetimes.npy
# IGS_TEC_maps_datetimes.npy	Nagoya_TEC_maps.npy
# IGS_TEC_maps.npy		README.md
# MAGGIA_TEC_maps_datetimes.npy

# %%
# %cd '/content/Atmosphere'
# Out:
# /content/Atmosphere

# %% [markdown]
# # TF1

# %% [markdown]
# # Adjusts

# %%
# %pwd
# Out:
# '/content'

# %%
import sys
import os

sys.path.append(os.path.abspath('.'))

# %%
# !pip install -U "ray[default]"

# %%
# !pip install cartopy

# %% [markdown]
# # Process/plot TEC maps

# %% [markdown]
# ## Nagoya

# %%
# !./run_nagoya.sh

# %% [markdown]
# ## MAGGIA

# %%
# !./run_maggia.sh

# %% [markdown]
# ## IGS

# %%
# !./run_igs.sh

# %% [markdown]
# ## EMBRACE

# %%
# !./run_embrace.sh

# %% [markdown]
# # Zip folders after processings

# %% [markdown]
# ## All

# %%
# !zip -r 'outputs.zip' '/content/Atmosphere/output/'

# %% [markdown]
# ## Nagoya

# %%
# !zip -r 'TF1_Nagoya_TEC_maps_2022_2024_0800_plot.zip' '/content/Atmosphere/output/TF1_Nagoya_TEC_maps_2022_2024_0800_plot'

# %%
# !zip -r 'TF1_Nagoya_TEC_maps_2022_2024_0800_interp_plot.zip' '/content/Atmosphere/output/TF1_Nagoya_TEC_maps_2022_2024_0800_interp_plot'

# %%
# !zip -r 'TF1_Nagoya_TEC_maps_2022_2024_1600_plot.zip' '/content/Atmosphere/output/TF1_Nagoya_TEC_maps_2022_2024_1600_plot'

# %%
# !zip -r 'TF1_Nagoya_TEC_maps_2022_2024_1600_interp_plot.zip' '/content/Atmosphere/output/TF1_Nagoya_TEC_maps_2022_2024_1600_interp_plot'

# %%
# !zip -r 'TF1_Nagoya_TEC_maps_2022_2024_2000_2200_0000_0200_0400_plot.zip' '/content/Atmosphere/output/TF1_Nagoya_TEC_maps_2022_2024_2000_2200_0000_0200_0400_plot'

# %%
# !zip -r 'TF1_Nagoya_TEC_maps_2022_2024_2000_2200_0000_0200_0400_interp_plot.zip' '/content/Atmosphere/output/TF1_Nagoya_TEC_maps_2022_2024_2000_2200_0000_0200_0400_interp_plot'

# %%
# !zip -r 'TF2_Nagoya_TEC_maps_2022_2024_0800_plot.zip' '/content/Atmosphere/output/TF2_Nagoya_TEC_maps_2022_2024_0800_plot'

# %%
# !zip -r 'TF2_Nagoya_TEC_maps_2022_2024_0800_interp_plot.zip' '/content/Atmosphere/output/TF2_Nagoya_TEC_maps_2022_2024_0800_interp_plot'

# %%
# !zip -r 'TF2_Nagoya_TEC_maps_2022_2024_1600_plot.zip' '/content/Atmosphere/output/TF2_Nagoya_TEC_maps_2022_2024_1600_plot'

# %%
# !zip -r 'TF2_Nagoya_TEC_maps_2022_2024_1600_interp_plot.zip' '/content/Atmosphere/output/TF2_Nagoya_TEC_maps_2022_2024_1600_interp_plot'

# %%
# !zip -r 'TF2_Nagoya_TEC_maps_2022_2024_2000_2200_0000_0200_0400_plot.zip' '/content/Atmosphere/output/TF2_Nagoya_TEC_maps_2022_2024_2000_2200_0000_0200_0400_plot'

# %%
# !zip -r 'TF2_Nagoya_TEC_maps_2022_2024_2000_2200_0000_0200_0400_interp_plot.zip' '/content/Atmosphere/output/TF2_Nagoya_TEC_maps_2022_2024_2000_2200_0000_0200_0400_interp_plot'

# %% [markdown]
# ## MAGGIA

# %%
# !zip -r 'TF1_MAGGIA_TEC_maps_2022_2024_0800_plot.zip' '/content/Atmosphere/output/TF1_MAGGIA_TEC_maps_2022_2024_0800_plot'

# %%
# !zip -r 'TF1_MAGGIA_TEC_maps_2022_2024_0800_interp_plot.zip' '/content/Atmosphere/output/TF1_MAGGIA_TEC_maps_2022_2024_0800_interp_plot'

# %%
# !zip -r 'TF1_MAGGIA_TEC_maps_2022_2024_1600_plot.zip' '/content/Atmosphere/output/TF1_MAGGIA_TEC_maps_2022_2024_1600_plot'

# %%
# !zip -r 'TF1_MAGGIA_TEC_maps_2022_2024_1600_interp_plot.zip' '/content/Atmosphere/output/TF1_MAGGIA_TEC_maps_2022_2024_1600_interp_plot'

# %%
# !zip -r 'TF1_MAGGIA_TEC_maps_2022_2024_2000_2200_0000_0200_0400_plot.zip' '/content/Atmosphere/output/TF1_MAGGIA_TEC_maps_2022_2024_2000_2200_0000_0200_0400_plot'

# %%
# !zip -r 'TF1_MAGGIA_TEC_maps_2022_2024_2000_2200_0000_0200_0400_interp_plot.zip' '/content/Atmosphere/output/TF1_MAGGIA_TEC_maps_2022_2024_2000_2200_0000_0200_0400_interp_plot'

# %%
# !zip -r 'TF2_MAGGIA_TEC_maps_2022_2024_0800_plot.zip' '/content/Atmosphere/output/TF2_MAGGIA_TEC_maps_2022_2024_0800_plot'

# %%
# !zip -r 'TF2_MAGGIA_TEC_maps_2022_2024_0800_interp_plot.zip' '/content/Atmosphere/output/TF2_MAGGIA_TEC_maps_2022_2024_0800_interp_plot'

# %%
# !zip -r 'TF2_MAGGIA_TEC_maps_2022_2024_1600_plot.zip' '/content/Atmosphere/output/TF2_MAGGIA_TEC_maps_2022_2024_1600_plot'

# %%
# !zip -r 'TF2_MAGGIA_TEC_maps_2022_2024_1600_interp_plot.zip' '/content/Atmosphere/output/TF2_MAGGIA_TEC_maps_2022_2024_1600_interp_plot'

# %%
# !zip -r 'TF2_MAGGIA_TEC_maps_2022_2024_2000_2200_0000_0200_0400_plot.zip' '/content/Atmosphere/output/TF2_MAGGIA_TEC_maps_2022_2024_2000_2200_0000_0200_0400_plot'

# %%
# !zip -r 'TF2_MAGGIA_TEC_maps_2022_2024_2000_2200_0000_0200_0400_interp_plot.zip' '/content/Atmosphere/output/TF2_MAGGIA_TEC_maps_2022_2024_2000_2200_0000_0200_0400_interp_plot'

# %% [markdown]
# ## IGS

# %%
# !zip -r 'TF1_IGS_TEC_maps_2022_2024_0800_plot.zip' '/content/Atmosphere/output/TF1_IGS_TEC_maps_2022_2024_0800_plot'

# %%
# !zip -r 'TF1_IGS_TEC_maps_2022_2024_0800_interp_plot.zip' '/content/Atmosphere/output/TF1_IGS_TEC_maps_2022_2024_0800_interp_plot'

# %%
# !zip -r 'TF1_IGS_TEC_maps_2022_2024_1600_plot.zip' '/content/Atmosphere/output/TF1_IGS_TEC_maps_2022_2024_1600_plot'

# %%
# !zip -r 'TF1_IGS_TEC_maps_2022_2024_1600_interp_plot.zip' '/content/Atmosphere/output/TF1_IGS_TEC_maps_2022_2024_1600_interp_plot'

# %%
# !zip -r 'TF1_IGS_TEC_maps_2022_2024_2000_2200_0000_0200_0400_plot.zip' '/content/Atmosphere/output/TF1_IGS_TEC_maps_2022_2024_2000_2200_0000_0200_0400_plot'

# %%
# !zip -r 'TF1_IGS_TEC_maps_2022_2024_2000_2200_0000_0200_0400_interp_plot.zip' '/content/Atmosphere/output/TF1_IGS_TEC_maps_2022_2024_2000_2200_0000_0200_0400_interp_plot'

# %%
# !zip -r 'TF2_IGS_TEC_maps_2022_2024_0800_plot.zip' '/content/Atmosphere/output/TF2_IGS_TEC_maps_2022_2024_0800_plot'

# %%
# !zip -r 'TF2_IGS_TEC_maps_2022_2024_0800_interp_plot.zip' '/content/Atmosphere/output/TF2_IGS_TEC_maps_2022_2024_0800_interp_plot'

# %%
# !zip -r 'TF2_IGS_TEC_maps_2022_2024_1600_plot.zip' '/content/Atmosphere/output/TF2_IGS_TEC_maps_2022_2024_1600_plot'

# %%
# !zip -r 'TF2_IGS_TEC_maps_2022_2024_1600_interp_plot.zip' '/content/Atmosphere/output/TF2_IGS_TEC_maps_2022_2024_1600_interp_plot'

# %%
# !zip -r 'TF2_IGS_TEC_maps_2022_2024_2000_2200_0000_0200_0400_plot.zip' '/content/Atmosphere/output/TF2_IGS_TEC_maps_2022_2024_2000_2200_0000_0200_0400_plot'

# %%
# !zip -r 'TF2_IGS_TEC_maps_2022_2024_2000_2200_0000_0200_0400_interp_plot.zip' '/content/Atmosphere/output/TF2_IGS_TEC_maps_2022_2024_2000_2200_0000_0200_0400_interp_plot'

# %% [markdown]
# ## EMBRACE

# %%
# !zip -r 'TF1_EMBRACE_TEC_maps_2022_2024_0800_plot.zip' '/content/Atmosphere/output/TF1_EMBRACE_TEC_maps_2022_2024_0800_plot'

# %%
# !zip -r 'TF1_EMBRACE_TEC_maps_2022_2024_0800_interp_plot.zip' '/content/Atmosphere/output/TF1_EMBRACE_TEC_maps_2022_2024_0800_interp_plot'

# %%
# !zip -r 'TF1_EMBRACE_TEC_maps_2022_2024_1600_plot.zip' '/content/Atmosphere/output/TF1_EMBRACE_TEC_maps_2022_2024_1600_plot'

# %%
# !zip -r 'TF1_EMBRACE_TEC_maps_2022_2024_1600_interp_plot.zip' '/content/Atmosphere/output/TF1_EMBRACE_TEC_maps_2022_2024_1600_interp_plot'

# %%
# !zip -r 'TF1_EMBRACE_TEC_maps_2022_2024_2000_2200_0000_0200_0400_plot.zip' '/content/Atmosphere/output/TF1_EMBRACE_TEC_maps_2022_2024_2000_2200_0000_0200_0400_plot'

# %%
# !zip -r 'TF1_EMBRACE_TEC_maps_2022_2024_2000_2200_0000_0200_0400_interp_plot.zip' '/content/Atmosphere/output/TF1_EMBRACE_TEC_maps_2022_2024_2000_2200_0000_0200_0400_interp_plot'

# %%
# %cd /content/Atmosphere/output/

# %%
# !ls

# %% [markdown]
# # Metrics

# %% [markdown]
# ### Pearson

# %%
# !python 04_metrics.py --metric pearson > 04_metrics_pearson_TF1_Q3.txt

# %% [markdown]
# ### SSIM

# %%
# !python 04_metrics.py --metric ssim > 04_metrics_ssim_TF1_Q3.txt

# %%
from google.colab import files

# %%
files.download('04_metrics_ssim_TF1_Q3.txt')

# %%
# !python 04_metrics.py --metric ssim --ssim-use-fisher > 04_metrics_ssim_TF1_Q3_fisher.txt

# %%
files.download('04_metrics_ssim_TF1_Q3_fisher.txt')

# %% [markdown]
# # Download TEC maps plots/results

# %%
from google.colab import files

# %%
# !ls *.txt

# %%
# !zip resultados_txt.zip *.txt

# %% [markdown]
# ## All

# %%
# !ls -lh

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# %cp '/content/Atmosphere/outputs.zip' '/content/drive/MyDrive'

# %%
# files.download('outputs.zip')

# %% [markdown]
# ## Nagoya

# %%
# files.download('TF1_Nagoya_TEC_maps_2022_2024_0800_plot.zip')

# %%
# files.download('TF1_Nagoya_TEC_maps_2022_2024_0800_interp_plot.zip')

# %%
# files.download('TF1_Nagoya_TEC_maps_2022_2024_1600_plot.zip')

# %%
# files.download('TF1_Nagoya_TEC_maps_2022_2024_1600_interp_plot.zip')

# %%
# files.download('TF1_Nagoya_TEC_maps_2022_2024_2000_2200_0000_0200_0400_plot.zip')

# %%
# files.download('TF1_Nagoya_TEC_maps_2022_2024_2000_2200_0000_0200_0400_interp_plot.zip')

# %% [markdown]
# ## MAGGIA

# %%
files.download('TF1_MAGGIA_TEC_maps_2022_2024_0800_plot.zip')

# %%
files.download('TF1_MAGGIA_TEC_maps_2022_2024_0800_interp_plot.zip')

# %%
files.download('TF1_MAGGIA_TEC_maps_2022_2024_1600_plot.zip')

# %%
files.download('TF1_MAGGIA_TEC_maps_2022_2024_1600_interp_plot.zip')

# %%
files.download('TF1_MAGGIA_TEC_maps_2022_2024_2000_2200_0000_0200_0400_plot.zip')

# %%
files.download('TF1_MAGGIA_TEC_maps_2022_2024_2000_2200_0000_0200_0400_interp_plot.zip')

# %% [markdown]
# ## IGS

# %%
files.download('TF1_IGS_TEC_maps_2022_2024_0800_plot.zip')

# %%
files.download('TF1_IGS_TEC_maps_2022_2024_0800_interp_plot.zip')

# %%
files.download('TF1_IGS_TEC_maps_2022_2024_1600_plot.zip')

# %%
files.download('TF1_IGS_TEC_maps_2022_2024_1600_interp_plot.zip')

# %%
files.download('TF1_IGS_TEC_maps_2022_2024_2000_2200_0000_0200_0400_plot.zip')

# %%
files.download('TF1_IGS_TEC_maps_2022_2024_2000_2200_0000_0200_0400_interp_plot.zip')

# %% [markdown]
# ## EMBRACE

# %%
# %cd '/content/Atmosphere/'

# %%
# !ls

# %%
files.download('TF1_EMBRACE_TEC_maps_2022_2024_0800_plot.zip')

# %%
files.download('TF1_EMBRACE_TEC_maps_2022_2024_0800_interp_plot.zip')

# %%
files.download('TF1_EMBRACE_TEC_maps_2022_2024_1600_plot.zip')

# %%
files.download('TF1_EMBRACE_TEC_maps_2022_2024_1600_interp_plot.zip')

# %%
files.download('TF1_EMBRACE_TEC_maps_2022_2024_2000_2200_0000_0200_0400_plot.zip')

# %%
files.download('TF1_EMBRACE_TEC_maps_2022_2024_2000_2200_0000_0200_0400_interp_plot.zip')

# %% [markdown]
# # TF2

# %% [markdown]
# # Adjusts

# %%
# %pwd
# Out:
# '/content/Atmosphere'

# %%
import sys
import os

sys.path.append(os.path.abspath('.'))

# %%
# !pip install -U "ray[default]"

# %%
# !pip install cartopy

# %% [markdown]
# # Process/plot TEC maps

# %% [markdown]
# ## Nagoya

# %%
# !./run_nagoya.sh

# %% [markdown]
# ## MAGGIA

# %%
# !./run_maggia.sh

# %% [markdown]
# ## EMBRACE

# %%
# !./run_embrace.sh

# %% [markdown]
# # Zip folders after processings

# %% [markdown]
# ## All

# %%
# !zip -r 'outputs.zip' '/content/Atmosphere/output'

# %% [markdown]
# ## Nagoya

# %%
# !zip -r 'TF1_Nagoya_TEC_maps_2022_2024_0800_plot.zip' '/content/Atmosphere/output/TF1_Nagoya_TEC_maps_2022_2024_0800_plot'

# %%
TF1_EMBRACE_TEC_maps_

# %%
# !zip -r 'TF1_Nagoya_TEC_maps_2022_2024_0800_interp_plot.zip' '/content/Atmosphere/output/TF1_Nagoya_TEC_maps_2022_2024_0800_interp_plot'

# %%
# !zip -r 'TF1_Nagoya_TEC_maps_2022_2024_1600_plot.zip' '/content/Atmosphere/output/TF1_Nagoya_TEC_maps_2022_2024_1600_plot'

# %%
# !zip -r 'TF1_Nagoya_TEC_maps_2022_2024_1600_interp_plot.zip' '/content/Atmosphere/output/TF1_Nagoya_TEC_maps_2022_2024_1600_interp_plot'

# %%
# !zip -r 'TF1_Nagoya_TEC_maps_2022_2024_2000_2200_0000_0200_0400_plot.zip' '/content/Atmosphere/output/TF1_Nagoya_TEC_maps_2022_2024_2000_2200_0000_0200_0400_plot'

# %%
# !zip -r 'TF1_Nagoya_TEC_maps_2022_2024_2000_2200_0000_0200_0400_interp_plot.zip' '/content/Atmosphere/output/TF1_Nagoya_TEC_maps_2022_2024_2000_2200_0000_0200_0400_interp_plot'

# %%
# !zip -r 'TF2_Nagoya_TEC_maps_2022_2024_0800_plot.zip' '/content/Atmosphere/output/TF2_Nagoya_TEC_maps_2022_2024_0800_plot'

# %%
# !zip -r 'TF2_Nagoya_TEC_maps_2022_2024_0800_interp_plot.zip' '/content/Atmosphere/output/TF2_Nagoya_TEC_maps_2022_2024_0800_interp_plot'

# %%
# !zip -r 'TF2_Nagoya_TEC_maps_2022_2024_1600_plot.zip' '/content/Atmosphere/output/TF2_Nagoya_TEC_maps_2022_2024_1600_plot'

# %%
# !zip -r 'TF2_Nagoya_TEC_maps_2022_2024_1600_interp_plot.zip' '/content/Atmosphere/output/TF2_Nagoya_TEC_maps_2022_2024_1600_interp_plot'

# %%
# !zip -r 'TF2_Nagoya_TEC_maps_2022_2024_2000_2200_0000_0200_0400_plot.zip' '/content/Atmosphere/output/TF2_Nagoya_TEC_maps_2022_2024_2000_2200_0000_0200_0400_plot'

# %%
# !zip -r 'TF2_Nagoya_TEC_maps_2022_2024_2000_2200_0000_0200_0400_interp_plot.zip' '/content/Atmosphere/output/TF2_Nagoya_TEC_maps_2022_2024_2000_2200_0000_0200_0400_interp_plot'

# %% [markdown]
# ## MAGGIA

# %%
# !zip -r 'TF1_MAGGIA_TEC_maps_2022_2024_0800_plot.zip' '/content/Atmosphere/output/TF1_MAGGIA_TEC_maps_2022_2024_0800_plot'

# %%
# !zip -r 'TF1_MAGGIA_TEC_maps_2022_2024_0800_interp_plot.zip' '/content/Atmosphere/output/TF1_MAGGIA_TEC_maps_2022_2024_0800_interp_plot'

# %%
# !zip -r 'TF1_MAGGIA_TEC_maps_2022_2024_1600_plot.zip' '/content/Atmosphere/output/TF1_MAGGIA_TEC_maps_2022_2024_1600_plot'

# %%
# !zip -r 'TF1_MAGGIA_TEC_maps_2022_2024_1600_interp_plot.zip' '/content/Atmosphere/output/TF1_MAGGIA_TEC_maps_2022_2024_1600_interp_plot'

# %%
# !zip -r 'TF1_MAGGIA_TEC_maps_2022_2024_2000_2200_0000_0200_0400_plot.zip' '/content/Atmosphere/output/TF1_MAGGIA_TEC_maps_2022_2024_2000_2200_0000_0200_0400_plot'

# %%
# !zip -r 'TF1_MAGGIA_TEC_maps_2022_2024_2000_2200_0000_0200_0400_interp_plot.zip' '/content/Atmosphere/output/TF1_MAGGIA_TEC_maps_2022_2024_2000_2200_0000_0200_0400_interp_plot'

# %%
# !zip -r 'TF2_MAGGIA_TEC_maps_2022_2024_0800_plot.zip' '/content/Atmosphere/output/TF2_MAGGIA_TEC_maps_2022_2024_0800_plot'

# %%
# !zip -r 'TF2_MAGGIA_TEC_maps_2022_2024_0800_interp_plot.zip' '/content/Atmosphere/output/TF2_MAGGIA_TEC_maps_2022_2024_0800_interp_plot'

# %%
# !zip -r 'TF2_MAGGIA_TEC_maps_2022_2024_1600_plot.zip' '/content/Atmosphere/output/TF2_MAGGIA_TEC_maps_2022_2024_1600_plot'

# %%
# !zip -r 'TF2_MAGGIA_TEC_maps_2022_2024_1600_interp_plot.zip' '/content/Atmosphere/output/TF2_MAGGIA_TEC_maps_2022_2024_1600_interp_plot'

# %%
# !zip -r 'TF2_MAGGIA_TEC_maps_2022_2024_2000_2200_0000_0200_0400_plot.zip' '/content/Atmosphere/output/TF2_MAGGIA_TEC_maps_2022_2024_2000_2200_0000_0200_0400_plot'

# %%
# !zip -r 'TF2_MAGGIA_TEC_maps_2022_2024_2000_2200_0000_0200_0400_interp_plot.zip' '/content/Atmosphere/output/TF2_MAGGIA_TEC_maps_2022_2024_2000_2200_0000_0200_0400_interp_plot'

# %% [markdown]
# ## EMBRACE

# %%
# !zip -r 'TF1_EMBRACE_TEC_maps_2022_2024_0800_plot.zip' '/content/Atmosphere/output/TF1_EMBRACE_TEC_maps_2022_2024_0800_plot'

# %%
# !zip -r 'TF1_EMBRACE_TEC_maps_2022_2024_0800_interp_plot.zip' '/content/Atmosphere/output/TF1_EMBRACE_TEC_maps_2022_2024_0800_interp_plot'

# %%
# !zip -r 'TF1_EMBRACE_TEC_maps_2022_2024_1600_plot.zip' '/content/Atmosphere/output/TF1_EMBRACE_TEC_maps_2022_2024_1600_plot'

# %%
# !zip -r 'TF1_EMBRACE_TEC_maps_2022_2024_1600_interp_plot.zip' '/content/Atmosphere/output/TF1_EMBRACE_TEC_maps_2022_2024_1600_interp_plot'

# %%
# !zip -r 'TF1_EMBRACE_TEC_maps_2022_2024_2000_2200_0000_0200_0400_plot.zip' '/content/Atmosphere/output/TF1_EMBRACE_TEC_maps_2022_2024_2000_2200_0000_0200_0400_plot'

# %%
# !zip -r 'TF1_EMBRACE_TEC_maps_2022_2024_2000_2200_0000_0200_0400_interp_plot.zip' '/content/Atmosphere/output/TF1_EMBRACE_TEC_maps_2022_2024_2000_2200_0000_0200_0400_interp_plot'

# %%
# %cd /content/Atmosphere/output/

# %%
# !ls

# %% [markdown]
# # Metrics

# %% [markdown]
# ### Pearson

# %%
# !python 04_metrics.py --metric pearson > 04_metrics_pearson_TF2_Q3.txt

# %% [markdown]
# ### SSIM

# %%
# !python 04_metrics.py --metric ssim > 04_metrics_ssim_TF2_Q3.txt

# %%
from google.colab import files

# %%
files.download('04_metrics_ssim_TF2_Q3.txt')

# %%
# !python 04_metrics.py --metric ssim --ssim-use-fisher > 04_metrics_ssim_TF2_Q3_fisher.txt

# %%
files.download('04_metrics_ssim_TF2_Q3_fisher.txt')

# %% [markdown]
# # Download TEC maps plots/results

# %%
from google.colab import files

# %%
# !ls *.txt

# %%
# !zip resultados_txt.zip *.txt

# %% [markdown]
# ## All

# %%
# !ls -lh

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# %cp '/content/Atmosphere/outputs.zip' '/content/drive/MyDrive'

# %%
# files.download('outputs.zip')

# %% [markdown]
# ## Nagoya

# %%
# files.download('TF2_Nagoya_TEC_maps_2024_0800_plot.zip')

# %%
# files.download('TF2_Nagoya_TEC_maps_2024_0800_interp_plot.zip')

# %%
# files.download('TF2_Nagoya_TEC_maps_2024_1600_plot.zip')

# %%
# files.download('TF2_Nagoya_TEC_maps_2024_1600_interp_plot.zip')

# %%
# files.download('TF2_Nagoya_TEC_maps_2024_2000_0400_plot.zip')

# %%
# files.download('TF2_Nagoya_TEC_maps_2024_2000_0400_interp_plot.zip')

# %% [markdown]
# ## MAGGIA

# %%
files.download('TF2_MAGGIA_TEC_maps_2024_0800_plot.zip')

# %%
files.download('TF2_MAGGIA_TEC_maps_2024_0800_interp_plot.zip')

# %%
files.download('TF2_MAGGIA_TEC_maps_2024_1600_plot.zip')

# %%
files.download('TF2_MAGGIA_TEC_maps_2024_1600_interp_plot.zip')

# %%
files.download('TF2_MAGGIA_TEC_maps_2024_2000_0400_plot.zip')

# %%
files.download('TF2_MAGGIA_TEC_maps_2024_2000_0400_interp_plot.zip')

# %% [markdown]
# ## EMBRACE

# %%
# %cd '/content/Atmosphere/'

# %%
# !ls

# %%
files.download('TF2_EMBRACE_TEC_maps_2024_0800_plot.zip')

# %%
files.download('TF2_EMBRACE_TEC_maps_2024_0800_interp_plot.zip')

# %%
files.download('TF2_EMBRACE_TEC_maps_2024_1600_plot.zip')

# %%
files.download('TF2_EMBRACE_TEC_maps_2024_1600_interp_plot.zip')

# %%
files.download('TF2_EMBRACE_TEC_maps_2024_2000_0400_plot.zip')

# %%
files.download('TF2_EMBRACE_TEC_maps_2024_2000_0400_interp_plot.zip')

# %% [markdown]
# # Some TEC maps plots with original temporal resolution for case study searchs - 2024

# %% [markdown]
# # Nagoya

# %% [markdown]
# ## Download software

# %%
# !git clone 'https://github.com/marcocintra/Atmosphere.git'

# %%
# %cd Atmosphere

# %%
# !git pull origin master

# %%
# Download TF_Nagoya_TEC_maps_intersection_with_datetimes_case_study_Dec_2024.zip from https://doi.org/10.5281/zenodo.15453941

# %%
# !unzip 'TF_Nagoya_TEC_maps_intersection_with_datetimes_case_study_Dec_2024.zip' -d '/content/Atmosphere/data'

# %%
# !rm 'TF_Nagoya_TEC_maps_intersection_with_datetimes_case_study_Dec_2024.zip'

# %%
# %cd '/content/'

# %%
# !ls

# %%
# %cd '/content/Atmosphere'

# %%
# !ls

# %%
# %cd data

# %%
# !ls

# %%
# %cd '/content/Atmosphere'

# %% [markdown]
# ## Adjusts

# %%
# %pwd

# %%
import sys
import os

sys.path.append(os.path.abspath('.'))

# %%
# !pip install -U "ray[default]"

# %%
# !pip install cartopy

# %% [markdown]
# ## Process/plot TEC maps

# %%
# !./run_nagoya.sh

# %%
# %pwd

# %%
# %cd output

# %%
# %cd /content/Atmosphere/output/TF_Nagoya_TEC_maps_intersection_with_datetimes_case_study_Dec_2024_plot

# %%
# !ls

# %%
# %cd ..

# %%
# !zip -r 'TF_Nagoya_TEC_maps_intersection_with_datetimes_case_study_Dec_2024_plot.zip' '/content/Atmosphere/output/TF_Nagoya_TEC_maps_intersection_with_datetimes_case_study_Dec_2024_plot'

# %%
# %pwd

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# %cp /content/Atmosphere/output/TF_Nagoya_TEC_maps_intersection_with_datetimes_case_study_Dec_2024_plot.zip /content/drive/MyDrive/TF_Nagoya_TEC_maps_intersection_with_datetimes_case_study_Dec_2024_plot.zip

# %% [markdown]
# # IGS

# %% [markdown]
# ## Download software

# %%
# !git clone 'https://github.com/marcocintra/Atmosphere.git'

# %%
# %cd Atmosphere

# %%
# !git pull origin master

# %%
# Download TF_IGS_TEC_maps_intersection_with_datetimes_case_study_Dec_2024.zip from https://doi.org/10.5281/zenodo.15453941

# %%
# !unzip 'TF_IGS_TEC_maps_intersection_with_datetimes_case_study_Dec_2024.zip' -d '/content/Atmosphere/data'

# %%
# !rm 'TF_IGS_TEC_maps_intersection_with_datetimes_case_study_Dec_2024.zip'

# %%
# %cd '/content/'

# %%
# !ls

# %%
# %cd '/content/Atmosphere'

# %%
# !ls

# %%
# %cd data

# %%
# !ls

# %%
# %cd '/content/Atmosphere'

# %% [markdown]
# ## Adjusts

# %%
# %pwd

# %%
import sys
import os

sys.path.append(os.path.abspath('.'))

# %%
# !pip install -U "ray[default]"

# %%
# !pip install cartopy

# %% [markdown]
# ## Process/plot TEC maps

# %%
# !./run_igs.sh

# %%
# %pwd

# %%
# %cd /content/Atmosphere/output/TF_IGS_TEC_maps_intersection_with_datetimes_case_study_Dec_2024_plot

# %%
# !ls

# %%
# %cd ..

# %%
# !zip -r 'TF_IGS_TEC_maps_intersection_with_datetimes_case_study_Dec_2024_plot.zip' '/content/Atmosphere/output/TF_IGS_TEC_maps_intersection_with_datetimes_case_study_Dec_2024_plot'

# %%
# %pwd

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# %cp /content/Atmosphere/output/TF_IGS_TEC_maps_intersection_with_datetimes_case_study_Dec_2024_plot.zip /content/drive/MyDrive/TF_IGS_TEC_maps_intersection_with_datetimes_case_study_Dec_2024_plot.zip

# %% [markdown]
# # Seasonal analysis

# %% [markdown]
# # Adjusts

# %%
# %pwd
# Out:
# '/content/Atmosphere'

# %%
import sys
import os

sys.path.append(os.path.abspath('.'))

# %%
# !pip install -U "ray[default]"
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 120.0/120.0 kB 5.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.6/65.6 kB 8.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 201.6/201.6 kB 10.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 56.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.0/6.0 MB 96.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 201.5/201.5 kB 25.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 128.2/128.2 kB 16.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.5/72.5 kB 10.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.1/70.1 MB 12.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 469.0/469.0 kB 49.7 MB/s eta 0:00:00
# ...

# %%
# !pip install cartopy
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.8/11.8 MB 102.3 MB/s eta 0:00:00
# ...

# %% [markdown]
# # Process/plot TEC maps

# %%
# %cd '/content/Atmosphere'
# Out:
# /content/Atmosphere

# %% [markdown]
# ## Nagoya

# %%
# %pwd
# Out:
# '/content/Atmosphere'

# %%
# !./run_serial_nagoya.sh
# Out:
# Plotting original TEC maps for dataset: Nagoya_TEC_maps...
# (4, 242, 221)
# [[23.57547188 23.57547188 23.57547188 ...         nan         nan
#           nan]
#  [19.84235954 19.84235954 19.84235954 ...         nan         nan
#           nan]
#  [23.57547188 19.84235954 19.84235954 ...         nan         nan
#           nan]
#  ...
#  [17.22373009 17.03804398 16.88067055 ... 13.10881233 12.79760647
#   12.71374035]
#  [17.22604942 17.05638123 16.99543381 ... 12.98862362 12.73429298
#   12.68001461]
#  [17.41147041 17.24334335 17.28094482 ... 12.72864628 12.61390114
#   12.49296379]]
# (4,)
# 2024-03-20T04:00:00
# (242, 221)
# /usr/local/lib/python3.11/dist-packages/cartopy/io/__init__.py:242: DownloadWarning: Downloading: https://naturalearth.s3.amazonaws.com/50m_physical/ne_50m_land.zip
#   warnings.warn(f'Downloading: {url}', DownloadWarning)
# ...

# %% [markdown]
# ## MAGGIA

# %%
# !./run_serial_maggia.sh
# Out:
# Plotting original TEC maps for dataset: MAGGIA_TEC_maps...
# (4, 241, 221)
# [[        nan         nan         nan ...         nan         nan
#           nan]
#  [        nan         nan         nan ...         nan         nan
#           nan]
#  [        nan         nan         nan ...         nan         nan
#           nan]
#  ...
#  [15.23816872 15.1769371  15.10902786 ... 12.27402878 12.15724277
#   12.05804634]
#  [15.00026798 14.93837261 14.87103748 ... 11.70321941 11.58734322
#   11.48490238]
#  [14.75568581 14.69262505 14.62831497 ... 11.1546669  11.03664112
#   10.92925835]]
# (4,)
# 2024-03-20T04:00:00
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
#
#
#
# Interpolating TEC maps for dataset: MAGGIA_TEC_maps...
# (4, 241, 221)
# [[        nan         nan         nan ...         nan         nan
#           nan]
#  [        nan         nan         nan ...         nan         nan
#           nan]
#  [        nan         nan         nan ...         nan         nan
# ...

# %% [markdown]
# ## IGS

# %%
# !./run_serial_igs.sh
# Out:
# Plotting original TEC maps for dataset: IGS_TEC_maps...
# (4, 49, 23)
# [[19.2 18.3 17.6 ... 16.4 16.6 16.6]
#  [19.7 18.9 18.2 ... 18.8 18.3 17.9]
#  [20.4 19.6 19.1 ... 22.  20.6 19.4]
#  ...
#  [29.6 28.8 27.8 ... 16.6 17.2 17.8]
#  [29.9 29.2 28.5 ... 18.9 19.2 19.7]
#  [30.9 30.3 29.5 ... 21.5 21.5 21.7]]
# (4,)
# 2024-03-20T04:00:00
# (49, 23)
# (49, 23)
# (49, 23)
# (49, 23)
#
#
#
# Interpolating TEC maps for dataset: IGS_TEC_maps...
# (4, 49, 23)
# [[19.2 18.3 17.6 ... 16.4 16.6 16.6]
#  [19.7 18.9 18.2 ... 18.8 18.3 17.9]
#  [20.4 19.6 19.1 ... 22.  20.6 19.4]
#  ...
#  [29.6 28.8 27.8 ... 16.6 17.2 17.8]
#  [29.9 29.2 28.5 ... 18.9 19.2 19.7]
#  [30.9 30.3 29.5 ... 21.5 21.5 21.7]]
# (4,)
# 2024-03-20T04:00:00
# 2024-03-20T04:00:00
# (49, 23)
# (37, 19)
# 2024-06-21T00:00:00
# (49, 23)
# (37, 19)
# 2024-09-22T14:00:00
# (49, 23)
# (37, 19)
# 2024-12-21T10:00:00
# (49, 23)
# (37, 19)
#
#
#
# Plotting interpolated TEC maps for dataset: IGS_TEC_maps...
# ...

# %% [markdown]
# ## EMBRACE

# %%
# !./run_serial_embrace.sh
# Out:
# Plotting original TEC maps for dataset: EMBRACE_TEC_maps...
# (4, 41, 25)
# [[nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  ...
#  [nan 12. 12. ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]]
# (4,)
# 2024-03-20T04:00:00
# (41, 25)
# (41, 25)
# (41, 25)
# (41, 25)
#
#
#
# Interpolating TEC maps for dataset: EMBRACE_TEC_maps...
# (4, 41, 25)
# [[nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  ...
#  [nan 12. 12. ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]]
# (4,)
# 2024-03-20T04:00:00
# 2024-03-20T04:00:00
# (41, 25)
# (36, 25)
# 2024-06-21T00:00:00
# (41, 25)
# (36, 25)
# 2024-09-22T14:00:00
# (41, 25)
# (36, 25)
# 2024-12-21T10:00:00
# (41, 25)
# (36, 25)
#
#
#
# Plotting interpolated TEC maps for dataset: EMBRACE_TEC_maps...
# /content/Atmosphere/output/EMBRACE_TEC_maps_interp
# 2024-09-22T14.00.00
# ...

# %% [markdown]
# # Zip folders after processings

# %% [markdown]
# ## All

# %%
# !zip -r 'outputs.zip' '/content/Atmosphere/output/'
# Out:
# A saída de streaming foi truncada nas últimas 5000 linhas.
#   adding: content/Atmosphere/output/TF2_MAGGIA_TEC_maps_2000_0400_interp/2024-12-18T23.30.00.npy (deflated 55%)
#   adding: content/Atmosphere/output/TF2_MAGGIA_TEC_maps_2000_0400_interp/2024-06-08T04.00.00.npy (deflated 48%)
#   adding: content/Atmosphere/output/TF2_MAGGIA_TEC_maps_2000_0400_interp/2024-03-07T20.30.00.npy (deflated 52%)
#   adding: content/Atmosphere/output/TF2_MAGGIA_TEC_maps_2000_0400_interp/2024-03-21T03.00.00.npy (deflated 49%)
#   adding: content/Atmosphere/output/TF2_MAGGIA_TEC_maps_2000_0400_interp/2024-09-08T20.00.00.npy (deflated 58%)
#   adding: content/Atmosphere/output/TF2_MAGGIA_TEC_maps_2000_0400_interp/2024-06-08T01.00.00.npy (deflated 49%)
#   adding: content/Atmosphere/output/TF2_MAGGIA_TEC_maps_2000_0400_interp/2024-06-09T21.00.00.npy (deflated 50%)
#   adding: content/Atmosphere/output/TF2_MAGGIA_TEC_maps_2000_0400_interp/2024-09-08T22.30.00.npy (deflated 54%)
# ...

# %% [markdown]
# ## Nagoya

# %%
# !zip -r 'Nagoya_TEC_maps_plot.zip' '/content/Atmosphere/output/Nagoya_TEC_maps_plot'
# Out:
#   adding: content/Atmosphere/output/Nagoya_TEC_maps_plot/ (stored 0%)
#   adding: content/Atmosphere/output/Nagoya_TEC_maps_plot/2024-06-21T00.00.00.png (deflated 4%)
#   adding: content/Atmosphere/output/Nagoya_TEC_maps_plot/2024-09-22T14.00.00.png (deflated 3%)
#   adding: content/Atmosphere/output/Nagoya_TEC_maps_plot/2024-12-21T10.00.00.png (deflated 3%)
#   adding: content/Atmosphere/output/Nagoya_TEC_maps_plot/2024-03-20T04.00.00.png (deflated 4%)

# %%
# !zip -r 'Nagoya_TEC_maps_interp_plot.zip' '/content/Atmosphere/output/Nagoya_TEC_maps_interp_plot'
# Out:
#   adding: content/Atmosphere/output/Nagoya_TEC_maps_interp_plot/ (stored 0%)
#   adding: content/Atmosphere/output/Nagoya_TEC_maps_interp_plot/2024-06-21T00.00.00.png (deflated 2%)
#   adding: content/Atmosphere/output/Nagoya_TEC_maps_interp_plot/2024-09-22T14.00.00.png (deflated 1%)
#   adding: content/Atmosphere/output/Nagoya_TEC_maps_interp_plot/2024-12-21T10.00.00.png (deflated 2%)
#   adding: content/Atmosphere/output/Nagoya_TEC_maps_interp_plot/2024-03-20T04.00.00.png (deflated 2%)

# %% [markdown]
# ## MAGGIA

# %%
# !zip -r 'MAGGIA_TEC_maps_plot.zip' '/content/Atmosphere/output/MAGGIA_TEC_maps_plot'
# Out:
#   adding: content/Atmosphere/output/MAGGIA_TEC_maps_plot/ (stored 0%)
#   adding: content/Atmosphere/output/MAGGIA_TEC_maps_plot/2024-06-21T00.00.00.png (deflated 2%)
#   adding: content/Atmosphere/output/MAGGIA_TEC_maps_plot/2024-09-22T14.00.00.png (deflated 1%)
#   adding: content/Atmosphere/output/MAGGIA_TEC_maps_plot/2024-12-21T10.00.00.png (deflated 2%)
#   adding: content/Atmosphere/output/MAGGIA_TEC_maps_plot/2024-03-20T04.00.00.png (deflated 2%)

# %%
# !zip -r 'MAGGIA_TEC_maps_interp_plot.zip' '/content/Atmosphere/output/MAGGIA_TEC_maps_interp_plot'
# Out:
#   adding: content/Atmosphere/output/MAGGIA_TEC_maps_interp_plot/ (stored 0%)
#   adding: content/Atmosphere/output/MAGGIA_TEC_maps_interp_plot/2024-06-21T00.00.00.png (deflated 2%)
#   adding: content/Atmosphere/output/MAGGIA_TEC_maps_interp_plot/2024-09-22T14.00.00.png (deflated 1%)
#   adding: content/Atmosphere/output/MAGGIA_TEC_maps_interp_plot/2024-12-21T10.00.00.png (deflated 2%)
#   adding: content/Atmosphere/output/MAGGIA_TEC_maps_interp_plot/2024-03-20T04.00.00.png (deflated 2%)

# %% [markdown]
# ## IGS

# %%
# !zip -r 'IGS_TEC_maps_plot.zip' '/content/Atmosphere/output/IGS_TEC_maps_plot'
# Out:
#   adding: content/Atmosphere/output/IGS_TEC_maps_plot/ (stored 0%)
#   adding: content/Atmosphere/output/IGS_TEC_maps_plot/2024-06-21T00.00.00.png (deflated 2%)
#   adding: content/Atmosphere/output/IGS_TEC_maps_plot/2024-09-22T14.00.00.png (deflated 1%)
#   adding: content/Atmosphere/output/IGS_TEC_maps_plot/2024-12-21T10.00.00.png (deflated 2%)
#   adding: content/Atmosphere/output/IGS_TEC_maps_plot/2024-03-20T04.00.00.png (deflated 2%)

# %%
# !zip -r 'IGS_TEC_maps_interp_plot.zip' '/content/Atmosphere/output/IGS_TEC_maps_interp_plot'
# Out:
#   adding: content/Atmosphere/output/IGS_TEC_maps_interp_plot/ (stored 0%)
#   adding: content/Atmosphere/output/IGS_TEC_maps_interp_plot/2024-06-21T00.00.00.png (deflated 2%)
#   adding: content/Atmosphere/output/IGS_TEC_maps_interp_plot/2024-09-22T14.00.00.png (deflated 1%)
#   adding: content/Atmosphere/output/IGS_TEC_maps_interp_plot/2024-12-21T10.00.00.png (deflated 2%)
#   adding: content/Atmosphere/output/IGS_TEC_maps_interp_plot/2024-03-20T04.00.00.png (deflated 2%)

# %% [markdown]
# ## EMBRACE

# %%
# !zip -r 'EMBRACE_TEC_maps_plot.zip' '/content/Atmosphere/output/EMBRACE_TEC_maps_plot'
# Out:
#   adding: content/Atmosphere/output/EMBRACE_TEC_maps_plot/ (stored 0%)
#   adding: content/Atmosphere/output/EMBRACE_TEC_maps_plot/2024-06-21T00.00.00.png (deflated 3%)
#   adding: content/Atmosphere/output/EMBRACE_TEC_maps_plot/2024-09-22T14.00.00.png (deflated 3%)
#   adding: content/Atmosphere/output/EMBRACE_TEC_maps_plot/2024-12-21T10.00.00.png (deflated 5%)
#   adding: content/Atmosphere/output/EMBRACE_TEC_maps_plot/2024-03-20T04.00.00.png (deflated 3%)

# %%
# !zip -r 'EMBRACE_TEC_maps_interp_plot.zip' '/content/Atmosphere/output/EMBRACE_TEC_maps_interp_plot'
# Out:
#   adding: content/Atmosphere/output/EMBRACE_TEC_maps_interp_plot/ (stored 0%)
#   adding: content/Atmosphere/output/EMBRACE_TEC_maps_interp_plot/2024-06-21T00.00.00.png (deflated 2%)
#   adding: content/Atmosphere/output/EMBRACE_TEC_maps_interp_plot/2024-09-22T14.00.00.png (deflated 1%)
#   adding: content/Atmosphere/output/EMBRACE_TEC_maps_interp_plot/2024-12-21T10.00.00.png (deflated 2%)
#   adding: content/Atmosphere/output/EMBRACE_TEC_maps_interp_plot/2024-03-20T04.00.00.png (deflated 2%)

# %%
# %cd /content/Atmosphere/output/
# Out:
# /content/Atmosphere/output

# %%
# !ls
# Out:
# EMBRACE_TEC_maps_interp
# EMBRACE_TEC_maps_interp_plot
# EMBRACE_TEC_maps_interp_raster
# EMBRACE_TEC_maps_plot
# IGS_TEC_maps_interp
# IGS_TEC_maps_interp_plot
# IGS_TEC_maps_interp_raster
# IGS_TEC_maps_plot
# MAGGIA_TEC_maps_interp
# MAGGIA_TEC_maps_interp_plot
# MAGGIA_TEC_maps_interp_raster
# MAGGIA_TEC_maps_plot
# Nagoya_TEC_maps_interp
# Nagoya_TEC_maps_interp_plot
# Nagoya_TEC_maps_interp_raster
# Nagoya_TEC_maps_plot
# README.md
# TF1_EMBRACE_TEC_maps_0800_interp
# TF1_EMBRACE_TEC_maps_0800_interp_raster
# TF1_EMBRACE_TEC_maps_1600_interp
# TF1_EMBRACE_TEC_maps_1600_interp_raster
# TF1_EMBRACE_TEC_maps_2000_0400_interp
# TF1_EMBRACE_TEC_maps_2000_0400_interp_raster
# TF1_IGS_TEC_maps_0800_interp
# TF1_IGS_TEC_maps_0800_interp_raster
# TF1_IGS_TEC_maps_1600_interp
# TF1_IGS_TEC_maps_1600_interp_raster
# TF1_IGS_TEC_maps_2000_0400_interp
# TF1_IGS_TEC_maps_2000_0400_interp_raster
# TF1_MAGGIA_TEC_maps_0800_interp
# TF1_MAGGIA_TEC_maps_0800_interp_raster
# ...

# %% [markdown]
# # Metrics

# %% [markdown]
# ### Pearson

# %%
# !python 04_metrics.py --metric pearson > 04_metrics_pearson_seasonal.txt

# %% [markdown]
# ### SSIM

# %%
# !python 04_metrics.py --metric ssim > 04_metrics_ssim_seasonal.txt

# %%
# !python 04_metrics.py --metric ssim --ssim-use-fisher > 04_metrics_ssim_seasonal_fisher.txt

# %% [markdown]
# # Download TEC maps

# %%
from google.colab import files

# %% [markdown]
# ## All

# %%
files.download('outputs.zip')

# %% [markdown]
# ## Nagoya

# %%
# files.download('Nagoya_TEC_maps_plot.zip')

# %%
# files.download('Nagoya_TEC_maps_interp_plot.zip')

# %% [markdown]
# ## MAGGIA

# %%
# files.download('MAGGIA_TEC_maps_plot.zip')

# %%
# files.download('MAGGIA_TEC_maps_interp_plot.zip')

# %% [markdown]
# ## IGS

# %%
# files.download('IGS_TEC_maps_plot.zip')

# %%
# files.download('IGS_TEC_maps_interp_plot.zip')

# %% [markdown]
# ## EMBRACE

# %%
# %cd '/content/Atmosphere/'

# %%
# !ls

# %%
files.download('TF1_EMBRACE_TEC_maps_2022_2024_0800_plot.zip')

# %%
files.download('TF1_EMBRACE_TEC_maps_2022_2024_0800_interp_plot.zip')

# %%
files.download('TF1_EMBRACE_TEC_maps_2022_2024_1600_plot.zip')

# %%
files.download('TF1_EMBRACE_TEC_maps_2022_2024_1600_interp_plot.zip')

# %%
files.download('TF1_EMBRACE_TEC_maps_2022_2024_2000_2200_0000_0200_0400_plot.zip')

# %%
files.download('TF1_EMBRACE_TEC_maps_2022_2024_2000_2200_0000_0200_0400_interp_plot.zip')
