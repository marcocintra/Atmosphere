# %% [markdown]
# # Gopi TEC Brasília analysis - December/2024

# %%
#Download Gopi_TEC_BRAZ_09_27_2024_and_Dec_2024.zip from https://doi.org/10.5281/zenodo.15453941

# %%
# !gdown '1Dpt31SWcuPd9CGF6afPV1XkySQ7i0yTx'
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1Dpt31SWcuPd9CGF6afPV1XkySQ7i0yTx
# From (redirected): https://drive.google.com/uc?id=1Dpt31SWcuPd9CGF6afPV1XkySQ7i0yTx&confirm=t&uuid=f9378ad0-7267-4ebd-93a3-b5ce9202b9c6
# To: /content/Gopi_TEC_BRAZ_09_27_2024_and_Dec_2024.zip
# 100% 46.0M/46.0M [00:00<00:00, 56.6MB/s]

# %%
# %pwd
# Out:
# '/content'

# %%
# !ls
# Out:
# Gopi_TEC_BRAZ_09_27_2024_and_Dec_2024.zip  sample_data

# %%
# !unzip 'Gopi_TEC_BRAZ_09_27_2024_and_Dec_2024.zip'
# Out:
# Archive:  Gopi_TEC_BRAZ_09_27_2024_and_Dec_2024.zip
#   inflating: GPS_TEC Readme.pdf
#   inflating: braz271-2024-09-27.Std
#   inflating: braz336-2024-12-01.Std
#   inflating: braz337-2024-12-02.Std
#   inflating: braz338-2024-12-03.Std
#   inflating: braz339-2024-12-04.Std
#   inflating: braz340-2024-12-05.Std
#   inflating: braz341-2024-12-06.Std
#   inflating: braz342-2024-12-07.Std
#   inflating: braz343-2024-12-08.Std
#   inflating: braz344-2024-12-09.Std
#   inflating: braz345-2024-12-10.Std
#   inflating: braz346-2024-12-11.Std
#   inflating: braz347-2024-12-12.Std
#   inflating: braz348-2024-12-13.Std
#   inflating: braz349-2024-12-14.Std
#   inflating: braz350-2024-12-15.Std
#   inflating: braz351-2024-12-16.Std
#   inflating: braz352-2024-12-17.Std
#   inflating: braz353-2024-12-18.Std
#   inflating: braz354-2024-12-19.Std
#   inflating: braz355-2024-12-20.Std
#   inflating: braz356-2024-12-21.Std
#   inflating: braz357-2024-12-22.Std
#   inflating: braz358-2024-12-23.Std
#   inflating: braz359-2024-12-24.Std
#   inflating: braz361-2024-12-26.Std
#   inflating: braz362-2024-12-27.Std
#   inflating: braz363-2024-12-28.Std
#   inflating: braz364-2024-12-29.Std
#   inflating: braz365-2024-12-30.Std
#   inflating: braz366-2024-12-31.Std
#   inflating: braz271-2024-09-27_page0.png
#   inflating: braz271-2024-09-27-wbias.png
#   inflating: braz336-2024-12-01_page0.png
#   inflating: braz336-2024-12-01-wbias.png
#   inflating: braz337-2024-12-02_page0.png
#   inflating: braz337-2024-12-02-wbias.png
#   inflating: braz338-2024-12-03_page0.png
#   inflating: braz338-2024-12-03-wbias.png
#   inflating: braz339-2024-12-04_page0.png
#   inflating: braz339-2024-12-04-wbias.png
#   inflating: braz340-2024-12-05_page0.png
#   inflating: braz340-2024-12-05-wbias.png
#   inflating: braz341-2024-12-06_page0.png
#   inflating: braz341-2024-12-06-wbias.png
#   inflating: braz342-2024-12-07_page0.png
#   inflating: braz342-2024-12-07-wbias.png
#   inflating: braz343-2024-12-08_page0.png
#   inflating: braz343-2024-12-08-wbias.png
#   inflating: braz344-2024-12-09_page0.png
#   inflating: braz344-2024-12-09-wbias.png
#   inflating: braz345-2024-12-10_page0.png
#   inflating: braz345-2024-12-10-wbias.png
#   inflating: braz346-2024-12-11_page0.png
#   inflating: braz346-2024-12-11-wbias.png
#   inflating: braz347-2024-12-12_page0.png
#   inflating: braz347-2024-12-12-wbias.png
#   inflating: braz348-2024-12-13_page0.png
#   inflating: braz348-2024-12-13-wbias.png
#   inflating: braz349-2024-12-14_page0.png
#   inflating: braz349-2024-12-14-wbias.png
#   inflating: braz350-2024-12-15_page0.png
#   inflating: braz350-2024-12-15-wbias.png
#   inflating: braz351-2024-12-16_page0.png
#   inflating: braz351-2024-12-16-wbias.png
#   inflating: braz352-2024-12-17_page0.png
#   inflating: braz352-2024-12-17-wbias.png
#   inflating: braz353-2024-12-18_page0.png
#   inflating: braz353-2024-12-18-wbias.png
#   inflating: braz354-2024-12-19_page0.png
#   inflating: braz354-2024-12-19-wbias.png
#   inflating: braz355-2024-12-20_page0.png
#   inflating: braz355-2024-12-20-wbias.png
#   inflating: braz356-2024-12-21_page0.png
#   inflating: braz356-2024-12-21-wbias.png
#   inflating: braz357-2024-12-22_page0.png
#   inflating: braz357-2024-12-22-wbias.png
#   inflating: braz358-2024-12-23_page0.png
#   inflating: braz358-2024-12-23-wbias.png
#   inflating: braz359-2024-12-24_page0.png
#   inflating: braz359-2024-12-24-wbias.png
#   inflating: braz361-2024-12-26_page0.png
#   inflating: braz361-2024-12-26-wbias.png
#   inflating: braz362-2024-12-27_page0.png
#   inflating: braz362-2024-12-27-wbias.png
#   inflating: braz363-2024-12-28_page0.png
#   inflating: braz363-2024-12-28-wbias.png
#   inflating: braz364-2024-12-29_page0.png
#   inflating: braz364-2024-12-29-wbias.png
#   inflating: braz365-2024-12-30_page0.png
#   inflating: braz365-2024-12-30-wbias.png
#   inflating: braz366-2024-12-31_page0.png
#   inflating: braz366-2024-12-31-wbias.png
#   inflating: braz271-2024-09-27.Bias
#   inflating: braz271-2024-09-27.Cmn
#   inflating: braz336-2024-12-01.Bias
#   inflating: braz336-2024-12-01.Cmn
#   inflating: braz337-2024-12-02.Bias
#   inflating: braz337-2024-12-02.Cmn
#   inflating: braz338-2024-12-03.Bias
#   inflating: braz338-2024-12-03.Cmn
#   inflating: braz339-2024-12-04.Bias
#   inflating: braz339-2024-12-04.Cmn
#   inflating: braz340-2024-12-05.Bias
#   inflating: braz340-2024-12-05.Cmn
#   inflating: braz341-2024-12-06.Bias
#   inflating: braz341-2024-12-06.Cmn
#   inflating: braz342-2024-12-07.Bias
#   inflating: braz342-2024-12-07.Cmn
#   inflating: braz343-2024-12-08.Bias
#   inflating: braz343-2024-12-08.Cmn
#   inflating: braz344-2024-12-09.Bias
#   inflating: braz344-2024-12-09.Cmn
#   inflating: braz345-2024-12-10.Bias
#   inflating: braz345-2024-12-10.Cmn
#   inflating: braz346-2024-12-11.Bias
#   inflating: braz346-2024-12-11.Cmn
#   inflating: braz347-2024-12-12.Bias
#   inflating: braz347-2024-12-12.Cmn
#   inflating: braz348-2024-12-13.Bias
#   inflating: braz348-2024-12-13.Cmn
#   inflating: braz349-2024-12-14.Bias
#   inflating: braz349-2024-12-14.Cmn
#   inflating: braz350-2024-12-15.Bias
#   inflating: braz350-2024-12-15.Cmn
#   inflating: braz351-2024-12-16.Bias
#   inflating: braz351-2024-12-16.Cmn
#   inflating: braz352-2024-12-17.Bias
#   inflating: braz352-2024-12-17.Cmn
#   inflating: braz353-2024-12-18.Bias
#   inflating: braz353-2024-12-18.Cmn
#   inflating: braz354-2024-12-19.Bias
#   inflating: braz354-2024-12-19.Cmn
#   inflating: braz355-2024-12-20.Bias
#   inflating: braz355-2024-12-20.Cmn
#   inflating: braz356-2024-12-21.Bias
#   inflating: braz356-2024-12-21.Cmn
#   inflating: braz357-2024-12-22.Bias
#   inflating: braz357-2024-12-22.Cmn
#   inflating: braz358-2024-12-23.Bias
#   inflating: braz358-2024-12-23.Cmn
#   inflating: braz359-2024-12-24.Bias
#   inflating: braz359-2024-12-24.Cmn
#   inflating: braz361-2024-12-26.Bias
#   inflating: braz361-2024-12-26.Cmn
#   inflating: braz362-2024-12-27.Bias
#   inflating: braz362-2024-12-27.Cmn
#   inflating: braz363-2024-12-28.Bias
#   inflating: braz363-2024-12-28.Cmn
#   inflating: braz364-2024-12-29.Bias
#   inflating: braz364-2024-12-29.Cmn
#   inflating: braz365-2024-12-30.Bias
#   inflating: braz365-2024-12-30.Cmn
#   inflating: braz366-2024-12-31.Bias
#   inflating: braz366-2024-12-31.Cmn
#   inflating: missing_rbmc_files_2024.txt

# %%
import pandas as pd
import numpy as np
import os
from datetime import datetime, timedelta
import glob

data_dir = '.'

std_files = glob.glob(os.path.join(data_dir, 'braz3*-2024-12-*.Std'))

std_files.sort()

dfs = []

for file_path in std_files:
    try:

        filename = os.path.basename(file_path)
        print(f"Processing {filename}")

        date_parts = filename.replace('.Std', '').split('-')
        year = int(date_parts[1])
        month = int(date_parts[2])
        day = int(date_parts[3])
        base_date = datetime(year, month, day)

        df = pd.read_csv(file_path, sep='\s+', header=None)

        df.columns = ['time_ut', 'tec', 'tec_std', 'latitude']

        def decimal_to_time(decimal_hours):
            hours = int(decimal_hours)
            minutes = int((decimal_hours - hours) * 60)
            seconds = int(((decimal_hours - hours) * 60 - minutes) * 60)
            return base_date + timedelta(hours=hours, minutes=minutes, seconds=seconds)

        df['DATETIME'] = df['time_ut'].apply(decimal_to_time)

        df['tec'] = pd.to_numeric(df['tec'].replace('-', np.nan))
        df['tec_std'] = pd.to_numeric(df['tec_std'].replace('-', np.nan))

        df = df[['DATETIME', 'tec', 'tec_std', 'latitude']]
        df.columns = ['DATETIME', 'TEC', 'TEC_STD', 'LATITUDE']

        dfs.append(df)

    except Exception as e:
        print(f"Error processing file {file_path}: {e}")

if dfs:
    combined_df = pd.concat(dfs, ignore_index=True)

    combined_df = combined_df.sort_values('DATETIME')

    combined_df.to_pickle('braz_dec_2024_complete.pkl')

    print(f"Combined DataFrame created with {len(combined_df)} rows")
    print("First 5 lines:")
    print(combined_df.head())

    print("\nPeriod covered by data:")
    print(f"Start: {combined_df['DATETIME'].min()}")
    print(f"End: {combined_df['DATETIME'].max()}")
    print(f"Total days: {(combined_df['DATETIME'].max() - combined_df['DATETIME'].min()).days + 1}")

    days_present = combined_df['DATETIME'].dt.date.unique()
    print(f"\nTotal days with data: {len(days_present)}")
    print("Days present:", sorted(days_present))
else:
    print("Nenhum arquivo foi processado com sucesso.")
# Out:
# <>:27: SyntaxWarning: invalid escape sequence '\s'
# <>:27: SyntaxWarning: invalid escape sequence '\s'
# /tmp/ipython-input-838961953.py:27: SyntaxWarning: invalid escape sequence '\s'
#   df = pd.read_csv(file_path, sep='\s+', header=None)
# Processing braz336-2024-12-01.Std
# Processing braz337-2024-12-02.Std
# Processing braz338-2024-12-03.Std
# Processing braz339-2024-12-04.Std
# Processing braz340-2024-12-05.Std
# Processing braz341-2024-12-06.Std
# Processing braz342-2024-12-07.Std
# Processing braz343-2024-12-08.Std
# Processing braz344-2024-12-09.Std
# Processing braz345-2024-12-10.Std
# Processing braz346-2024-12-11.Std
# Processing braz347-2024-12-12.Std
# Processing braz348-2024-12-13.Std
# Processing braz349-2024-12-14.Std
# Processing braz350-2024-12-15.Std
# Processing braz351-2024-12-16.Std
# Processing braz352-2024-12-17.Std
# Processing braz353-2024-12-18.Std
# Processing braz354-2024-12-19.Std
# Processing braz355-2024-12-20.Std
# Processing braz356-2024-12-21.Std
# Processing braz357-2024-12-22.Std
# Processing braz358-2024-12-23.Std
# Processing braz359-2024-12-24.Std
# Processing braz361-2024-12-26.Std
# Processing braz362-2024-12-27.Std
# Processing braz363-2024-12-28.Std
# Processing braz364-2024-12-29.Std
# Processing braz365-2024-12-30.Std
# Processing braz366-2024-12-31.Std
# Combined DataFrame created with 42320 rows
# First 5 lines:
#              DATETIME    TEC  TEC_STD  LATITUDE
# 0 2024-12-01 00:00:00  88.02    11.61    -15.95
# 1 2024-12-01 00:01:01  88.05    11.11    -15.95
# 2 2024-12-01 00:01:58  88.07    11.13    -15.95
# 3 2024-12-01 00:03:00  88.10    10.34    -15.95
# 4 2024-12-01 00:04:01  88.12    10.02    -15.95
#
# Period covered by data:
# Start: 2024-12-01 00:00:00
# End: 2024-12-31 23:58:58
# Total days: 31
#
# Total days with data: 30
# Days present: [datetime.date(2024, 12, 1), datetime.date(2024, 12, 2), datetime.date(2024, 12, 3), datetime.date(2024, 12, 4), datetime.date(2024, 12, 5), datetime.date(2024, 12, 6), datetime.date(2024, 12, 7), datetime.date(2024, 12, 8), datetime.date(2024, 12, 9), datetime.date(2024, 12, 10), datetime.date(2024, 12, 11), datetime.date(2024, 12, 12), datetime.date(2024, 12, 13), datetime.date(2024, 12, 14), datetime.date(2024, 12, 15), datetime.date(2024, 12, 16), datetime.date(2024, 12, 17), datetime.date(2024, 12, 18), datetime.date(2024, 12, 19), datetime.date(2024, 12, 20), datetime.date(2024, 12, 21), datetime.date(2024, 12, 22), datetime.date(2024, 12, 23), datetime.date(2024, 12, 24), datetime.date(2024, 12, 26), datetime.date(2024, 12, 27), datetime.date(2024, 12, 28), datetime.date(2024, 12, 29), datetime.date(2024, 12, 30), datetime.date(2024, 12, 31)]

# %%
combined_df
# Out:
#                  DATETIME    TEC  TEC_STD  LATITUDE
# 0     2024-12-01 00:00:00  88.02    11.61    -15.95
# 1     2024-12-01 00:01:01  88.05    11.11    -15.95
# 2     2024-12-01 00:01:58  88.07    11.13    -15.95
# 3     2024-12-01 00:03:00  88.10    10.34    -15.95
# 4     2024-12-01 00:04:01  88.12    10.02    -15.95
# ...                   ...    ...      ...       ...
# 42315 2024-12-31 23:55:01  62.39     4.24    -15.95
# 42316 2024-12-31 23:55:58  62.46     4.17    -15.95
# 42317 2024-12-31 23:56:59  62.52     4.11    -15.95
# 42318 2024-12-31 23:58:01  62.58     4.39    -15.95
# 42319 2024-12-31 23:58:58  62.63     4.52    -15.95
#
# [42320 rows x 4 columns]

# %% [markdown]
# ## SPECIFIC TIMES FOR 12/18

# %%
import pandas as pd
import numpy as np
from datetime import timedelta, time, datetime

df = pd.read_pickle('braz_dec_2024_complete.pkl')
print(f"Data loaded: {len(df)} records of {df['DATETIME'].min().date()} until {df['DATETIME'].max().date()}")

print(f"Available columns in the DataFrame: {list(df.columns)}")

df = df.sort_values('DATETIME').reset_index(drop=True)

df_clean = df.dropna(subset=['TEC', 'TEC_STD']).copy()
print(f"Analysing {len(df_clean)} points after removing missing values")

def check_consecutive_highs(df, peak_datetime, threshold_percent=90):
    peak_idx = df[df['DATETIME'] == peak_datetime].index[0]
    peak_value = df.loc[peak_idx, 'TEC']
    threshold = peak_value * (threshold_percent / 100)

    idx_before = peak_idx - 1
    idx_after = peak_idx + 1

    valid_before = idx_before >= 0
    valid_after = idx_after < len(df)

    if valid_before and valid_after:
        values = [df.loc[idx_before, 'TEC'], peak_value, df.loc[idx_after, 'TEC']]
        stds = [df.loc[idx_before, 'TEC_STD'], df.loc[peak_idx, 'TEC_STD'], df.loc[idx_after, 'TEC_STD']]
        datetimes = [df.loc[idx_before, 'DATETIME'], peak_datetime, df.loc[idx_after, 'DATETIME']]
        all_high = all(value >= threshold for value in values)

        if all_high:
            return {'indices': [idx_before, peak_idx, idx_after],
                   'values': values,
                   'stds': stds,
                   'datetimes': datetimes}

    if valid_before and idx_before > 0:
        values = [df.loc[idx_before-1, 'TEC'], df.loc[idx_before, 'TEC'], peak_value]
        stds = [df.loc[idx_before-1, 'TEC_STD'], df.loc[idx_before, 'TEC_STD'], df.loc[peak_idx, 'TEC_STD']]
        datetimes = [df.loc[idx_before-1, 'DATETIME'], df.loc[idx_before, 'DATETIME'], peak_datetime]
        all_high = all(value >= threshold for value in values)

        if all_high:
            return {'indices': [idx_before-1, idx_before, peak_idx],
                   'values': values,
                   'stds': stds,
                   'datetimes': datetimes}

    if valid_after and idx_after < len(df) - 1:
        values = [peak_value, df.loc[idx_after, 'TEC'], df.loc[idx_after+1, 'TEC']]
        stds = [df.loc[peak_idx, 'TEC_STD'], df.loc[idx_after, 'TEC_STD'], df.loc[idx_after+1, 'TEC_STD']]
        datetimes = [peak_datetime, df.loc[idx_after, 'DATETIME'], df.loc[idx_after+1, 'DATETIME']]
        all_high = all(value >= threshold for value in values)

        if all_high:
            return {'indices': [peak_idx, idx_after, idx_after+1],
                   'values': values,
                   'stds': stds,
                   'datetimes': datetimes}

    return None

def find_closest_value_to_datetime(df, target_datetime, max_minutes_diff=2):

    if isinstance(target_datetime, str):
        target_datetime = pd.to_datetime(target_datetime)
    elif isinstance(target_datetime, datetime):
        target_datetime = pd.Timestamp(target_datetime)

    time_diff = abs((df['DATETIME'] - target_datetime).dt.total_seconds() / 60)

    within_range = time_diff <= max_minutes_diff

    if not within_range.any():
        return None, None

    closest_idx = time_diff[within_range].idxmin()
    closest_diff = time_diff[closest_idx]

    return df.loc[closest_idx], closest_diff

def get_available_location_info(row):

    location_info = {}

    location_columns = ['LATITUDE', 'LONGITUDE', 'LAT', 'LON', 'STATION', 'SITE']

    for col in location_columns:
        if col in row.index:
            location_info[col] = row[col]

    return location_info

def analyze_specific_datetimes(target_datetimes, max_minutes_diff=2):

    print(f"\n{'='*100}")
    print(f"ANALYSIS OF TEC VALUES CLOSE TO SPECIFIC TIMES")
    print(f"(Maximum allowed difference: {max_minutes_diff} minutes)")
    print(f"{'='*100}")

    results = []

    for i, target_dt in enumerate(target_datetimes):
        print(f"\n{'-'*60}")
        print(f"LOOKING FOR VALUES NEAR: {target_dt}")
        print(f"{'-'*60}")

        closest_row, time_diff = find_closest_value_to_datetime(df_clean, target_dt, max_minutes_diff)

        if closest_row is not None:
            print(f" VALUE FOUND:")
            print(f" Actual Date/Time: {closest_row['DATETIME']}")
            print(f" Target Date/Time: {target_dt}")
            print(f" Difference: {time_diff:.2f} minutes")
            print(f" TEC: {closest_row['TEC']:.2f} ± {closest_row['TEC_STD']:.2f} TECU")

            location_info = get_available_location_info(closest_row)
            for key, value in location_info.items():
                print(f"  {key}: {value}")

            sequence = check_consecutive_highs(df_clean, closest_row['DATETIME'], threshold_percent=90)

            if sequence:
                print(f" HAS a sequence of 3 high values ​​(≥90% of the peak):")
                for j, (dt, val, std) in enumerate(zip(sequence['datetimes'], sequence['values'], sequence['stds'])):
                    print(f"    {j+1}. {dt}: {val:.2f} ± {std:.2f} TECU ({val/closest_row['TEC']*100:.1f}% of the value)")
            else:
                print(f" does NOT have a sequence of 3 consecutive high values")

            result = {
                'target_datetime': target_dt,
                'found_datetime': closest_row['DATETIME'],
                'time_diff_minutes': time_diff,
                'TEC': closest_row['TEC'],
                'TEC_STD': closest_row['TEC_STD'],
                'has_sequence': sequence is not None,
                'sequence': sequence,
                'location_info': location_info
            }

            results.append(result)

        else:
            print(f" NO VALUE FOUND within {max_minutes_diff} minutes of target time")
            results.append({
                'target_datetime': target_dt,
                'found_datetime': None,
                'time_diff_minutes': None,
                'TEC': None,
                'TEC_STD': None,
                'has_sequence': False,
                'sequence': None,
                'location_info': {}
            })

    print(f"\n{'='*120}")
    print(f"RESULTS SUMMARY TABLE")
    print(f"{'='*120}")

    header = f"{'#':<3}{'Target Time':<20}{'Found Time':<20}{'Diff(min)':<10}{'TEC':<10}{'TEC_STD':<10}{'Sequence':<12}"

    location_cols = set()
    for result in results:
        if result['location_info']:
            location_cols.update(result['location_info'].keys())

    for col in sorted(location_cols):
        header += f"{col:<12}"

    print(header)
    print(f"{'-'*len(header)}")

    for i, result in enumerate(results):
        if result['found_datetime'] is not None:
            seq_info = "Sim" if result['has_sequence'] else "Não"
            row = f"{i+1:<3}{str(result['target_datetime']):<20}{str(result['found_datetime']):<20}"
            row += f"{result['time_diff_minutes']:.2f}    {result['TEC']:.2f}    "
            row += f"{result['TEC_STD']:.2f}    {seq_info:<12}"

            for col in sorted(location_cols):
                value = result['location_info'].get(col, 'N/A')
                if isinstance(value, float):
                    row += f"{value:.2f}      "
                else:
                    row += f"{str(value):<12}"

            print(row)
        else:
            row = f"{i+1:<3}{str(result['target_datetime']):<20}{'NÃO ENCONTRADO':<20}"
            row += f"{'N/A':<10}{'N/A':<10}{'N/A':<10}{'N/A':<12}"

            for col in sorted(location_cols):
                row += f"{'N/A':<12}"

            print(row)

    print(f"{'-'*len(header)}")

    return results

target_datetimes = [
    "2024-12-18 18:20:00",
    "2024-12-18 18:10:00",
    "2024-12-18 18:30:00",
    "2024-12-18 18:00:00"
]

print("\n\n" + "*"*50 + " ANALYSIS OF SPECIFIC TIMES " + "*"*50)
results = analyze_specific_datetimes(target_datetimes, max_minutes_diff=2)

print("\nAnalysis complete!")

found_results = [r for r in results if r['found_datetime'] is not None]
if found_results:
    print(f"\n{'='*80}")
    print(f"STATISTICS OF THE RESULTS FOUND")
    print(f"{'='*80}")

    tec_values = [r['TEC'] for r in found_results]
    print(f"TEC values ​​found:")
    print(f" Minimum: {min(tec_values):.2f} TECU")
    print(f" Maximum: {max(tec_values):.2f} TECU")
    print(f" Mean: {np.mean(tec_values):.2f} TECU")
    print(f" Standard deviation: {np.std(tec_values):.2f} TECU")

    sequences_found = sum(1 for r in found_results if r['has_sequence'])
    print(f"\nHigh value sequences found: {sequences_found} out of {len(found_results)} ({sequences_found/len(found_results)*100:.1f}%)")
# Out:
# Data loaded: 42320 records of 2024-12-01 until 2024-12-31
# Available columns in the DataFrame: ['DATETIME', 'TEC', 'TEC_STD', 'LATITUDE']
# Analysing 41633 points after removing missing values
#
#
# ************************************************** ANALYSIS OF SPECIFIC TIMES **************************************************
#
# ====================================================================================================
# ANALYSIS OF TEC VALUES CLOSE TO SPECIFIC TIMES
# (Maximum allowed difference: 2 minutes)
# ====================================================================================================
#
# ------------------------------------------------------------
# LOOKING FOR VALUES NEAR: 2024-12-18 18:20:00
# ------------------------------------------------------------
#  VALUE FOUND:
#  Actual Date/Time: 2024-12-18 18:19:58
#  Target Date/Time: 2024-12-18 18:20:00
#  Difference: 0.03 minutes
#  TEC: 81.52 ± 4.94 TECU
#   LATITUDE: -15.95
#  HAS a sequence of 3 high values ​​(≥90% of the peak):
#     1. 2024-12-18 18:19:01: 81.48 ± 5.04 TECU (100.0% of the value)
#     2. 2024-12-18 18:19:58: 81.52 ± 4.94 TECU (100.0% of the value)
#     3. 2024-12-18 18:21:00: 81.55 ± 4.92 TECU (100.0% of the value)
#
# ------------------------------------------------------------
# LOOKING FOR VALUES NEAR: 2024-12-18 18:10:00
# ------------------------------------------------------------
#  VALUE FOUND:
#  Actual Date/Time: 2024-12-18 18:10:01
#  Target Date/Time: 2024-12-18 18:10:00
#  Difference: 0.02 minutes
#  TEC: 80.90 ± 5.24 TECU
#   LATITUDE: -15.95
#  HAS a sequence of 3 high values ​​(≥90% of the peak):
#     1. 2024-12-18 18:08:59: 80.81 ± 5.28 TECU (99.9% of the value)
#     2. 2024-12-18 18:10:01: 80.90 ± 5.24 TECU (100.0% of the value)
#     3. 2024-12-18 18:10:58: 80.99 ± 5.23 TECU (100.1% of the value)
#
# ------------------------------------------------------------
# LOOKING FOR VALUES NEAR: 2024-12-18 18:30:00
# ------------------------------------------------------------
#  VALUE FOUND:
#  Actual Date/Time: 2024-12-18 18:30:00
#  Target Date/Time: 2024-12-18 18:30:00
#  Difference: 0.00 minutes
#  TEC: 81.67 ± 4.82 TECU
#   LATITUDE: -15.95
#  HAS a sequence of 3 high values ​​(≥90% of the peak):
#     1. 2024-12-18 18:28:58: 81.67 ± 4.93 TECU (100.0% of the value)
#     2. 2024-12-18 18:30:00: 81.67 ± 4.82 TECU (100.0% of the value)
#     3. 2024-12-18 18:31:01: 81.66 ± 4.84 TECU (100.0% of the value)
#
# ------------------------------------------------------------
# LOOKING FOR VALUES NEAR: 2024-12-18 18:00:00
# ------------------------------------------------------------
#  VALUE FOUND:
#  Actual Date/Time: 2024-12-18 18:00:00
#  Target Date/Time: 2024-12-18 18:00:00
#  Difference: 0.00 minutes
#  TEC: 79.74 ± 5.18 TECU
#   LATITUDE: -15.95
#  HAS a sequence of 3 high values ​​(≥90% of the peak):
#     1. 2024-12-18 17:58:58: 79.59 ± 4.62 TECU (99.8% of the value)
#     2. 2024-12-18 18:00:00: 79.74 ± 5.18 TECU (100.0% of the value)
#     3. 2024-12-18 18:01:01: 79.87 ± 5.20 TECU (100.2% of the value)
#
# ========================================================================================================================
# RESULTS SUMMARY TABLE
# ========================================================================================================================
# #  Target Time         Found Time          Diff(min) TEC       TEC_STD   Sequence    LATITUDE
# -------------------------------------------------------------------------------------------------
# 1  2024-12-18 18:20:00 2024-12-18 18:19:58 0.03    81.52    4.94    Sim         -15.95
# 2  2024-12-18 18:10:00 2024-12-18 18:10:01 0.02    80.90    5.24    Sim         -15.95
# 3  2024-12-18 18:30:00 2024-12-18 18:30:00 0.00    81.67    4.82    Sim         -15.95
# 4  2024-12-18 18:00:00 2024-12-18 18:00:00 0.00    79.74    5.18    Sim         -15.95
# -------------------------------------------------------------------------------------------------
#
# Analysis complete!
#
# ================================================================================
# STATISTICS OF THE RESULTS FOUND
# ================================================================================
# TEC values ​​found:
#  Minimum: 79.74 TECU
#  Maximum: 81.67 TECU
#  Mean: 80.96 TECU
#  Standard deviation: 0.76 TECU
#
# High value sequences found: 4 out of 4 (100.0%)

# %% [markdown]
# ## 12/01 - 18:00

# %%
import pandas as pd
import numpy as np
from datetime import timedelta, time, datetime

df = pd.read_pickle('braz_dec_2024_complete.pkl')
print(f"Data loaded: {len(df)} records of {df['DATETIME'].min().date()} until {df['DATETIME'].max().date()}")

print(f"Available columns in the DataFrame: {list(df.columns)}")

df = df.sort_values('DATETIME').reset_index(drop=True)

df_clean = df.dropna(subset=['TEC', 'TEC_STD']).copy()
print(f"Analysing {len(df_clean)} points after removing missing values")

def check_consecutive_highs(df, peak_datetime, threshold_percent=90):
    peak_idx = df[df['DATETIME'] == peak_datetime].index[0]
    peak_value = df.loc[peak_idx, 'TEC']
    threshold = peak_value * (threshold_percent / 100)

    idx_before = peak_idx - 1
    idx_after = peak_idx + 1

    valid_before = idx_before >= 0
    valid_after = idx_after < len(df)

    if valid_before and valid_after:
        values = [df.loc[idx_before, 'TEC'], peak_value, df.loc[idx_after, 'TEC']]
        stds = [df.loc[idx_before, 'TEC_STD'], df.loc[peak_idx, 'TEC_STD'], df.loc[idx_after, 'TEC_STD']]
        datetimes = [df.loc[idx_before, 'DATETIME'], peak_datetime, df.loc[idx_after, 'DATETIME']]
        all_high = all(value >= threshold for value in values)

        if all_high:
            return {'indices': [idx_before, peak_idx, idx_after],
                   'values': values,
                   'stds': stds,
                   'datetimes': datetimes}

    if valid_before and idx_before > 0:
        values = [df.loc[idx_before-1, 'TEC'], df.loc[idx_before, 'TEC'], peak_value]
        stds = [df.loc[idx_before-1, 'TEC_STD'], df.loc[idx_before, 'TEC_STD'], df.loc[peak_idx, 'TEC_STD']]
        datetimes = [df.loc[idx_before-1, 'DATETIME'], df.loc[idx_before, 'DATETIME'], peak_datetime]
        all_high = all(value >= threshold for value in values)

        if all_high:
            return {'indices': [idx_before-1, idx_before, peak_idx],
                   'values': values,
                   'stds': stds,
                   'datetimes': datetimes}

    if valid_after and idx_after < len(df) - 1:
        values = [peak_value, df.loc[idx_after, 'TEC'], df.loc[idx_after+1, 'TEC']]
        stds = [df.loc[peak_idx, 'TEC_STD'], df.loc[idx_after, 'TEC_STD'], df.loc[idx_after+1, 'TEC_STD']]
        datetimes = [peak_datetime, df.loc[idx_after, 'DATETIME'], df.loc[idx_after+1, 'DATETIME']]
        all_high = all(value >= threshold for value in values)

        if all_high:
            return {'indices': [peak_idx, idx_after, idx_after+1],
                   'values': values,
                   'stds': stds,
                   'datetimes': datetimes}

    return None

def find_closest_value_to_datetime(df, target_datetime, max_minutes_diff=2):

    if isinstance(target_datetime, str):
        target_datetime = pd.to_datetime(target_datetime)
    elif isinstance(target_datetime, datetime):
        target_datetime = pd.Timestamp(target_datetime)

    time_diff = abs((df['DATETIME'] - target_datetime).dt.total_seconds() / 60)

    within_range = time_diff <= max_minutes_diff

    if not within_range.any():
        return None, None

    closest_idx = time_diff[within_range].idxmin()
    closest_diff = time_diff[closest_idx]

    return df.loc[closest_idx], closest_diff

def get_available_location_info(row):

    location_info = {}

    location_columns = ['LATITUDE', 'LONGITUDE', 'LAT', 'LON', 'STATION', 'SITE']

    for col in location_columns:
        if col in row.index:
            location_info[col] = row[col]

    return location_info

def analyze_specific_datetimes(target_datetimes, max_minutes_diff=2):

    print(f"\n{'='*100}")
    print(f"ANALYSIS OF TEC VALUES CLOSE TO SPECIFIC TIMES")
    print(f"(Maximum allowed difference: {max_minutes_diff} minutes)")
    print(f"{'='*100}")

    results = []

    for i, target_dt in enumerate(target_datetimes):
        print(f"\n{'-'*60}")
        print(f"LOOKING FOR VALUES NEAR: {target_dt}")
        print(f"{'-'*60}")

        closest_row, time_diff = find_closest_value_to_datetime(df_clean, target_dt, max_minutes_diff)

        if closest_row is not None:
            print(f" VALUE FOUND:")
            print(f" Actual Date/Time: {closest_row['DATETIME']}")
            print(f" Target Date/Time: {target_dt}")
            print(f" Difference: {time_diff:.2f} minutes")
            print(f"  TEC: {closest_row['TEC']:.2f} ± {closest_row['TEC_STD']:.2f} TECU")

            location_info = get_available_location_info(closest_row)
            for key, value in location_info.items():
                print(f"  {key}: {value}")

            sequence = check_consecutive_highs(df_clean, closest_row['DATETIME'], threshold_percent=90)

            if sequence:
                print(f" HAS a sequence of 3 high values ​​(≥90% of the peak):")
                for j, (dt, val, std) in enumerate(zip(sequence['datetimes'], sequence['values'], sequence['stds'])):
                    print(f"    {j+1}. {dt}: {val:.2f} ± {std:.2f} TECU ({val/closest_row['TEC']*100:.1f}% of the value)")
            else:
                print(f" does NOT have a sequence of 3 consecutive high values")

            result = {
                'target_datetime': target_dt,
                'found_datetime': closest_row['DATETIME'],
                'time_diff_minutes': time_diff,
                'TEC': closest_row['TEC'],
                'TEC_STD': closest_row['TEC_STD'],
                'has_sequence': sequence is not None,
                'sequence': sequence,
                'location_info': location_info
            }

            results.append(result)

        else:
            print(f"NO VALUE FOUND within {max_minutes_diff} minutes of target time")
            results.append({
                'target_datetime': target_dt,
                'found_datetime': None,
                'time_diff_minutes': None,
                'TEC': None,
                'TEC_STD': None,
                'has_sequence': False,
                'sequence': None,
                'location_info': {}
            })

    print(f"\n{'='*120}")
    print(f"RESULTS SUMMARY TABLE")
    print(f"{'='*120}")

    header = f"{'#':<3}{'Target Time':<20}{'Found Time':<20}{'Diff(min)':<10}{'TEC':<10}{'TEC_STD':<10}{'Sequence':<12}"

    location_cols = set()
    for result in results:
        if result['location_info']:
            location_cols.update(result['location_info'].keys())

    for col in sorted(location_cols):
        header += f"{col:<12}"

    print(header)
    print(f"{'-'*len(header)}")

    for i, result in enumerate(results):
        if result['found_datetime'] is not None:
            seq_info = "Yes" if result['has_sequence'] else "No"
            row = f"{i+1:<3}{str(result['target_datetime']):<20}{str(result['found_datetime']):<20}"
            row += f"{result['time_diff_minutes']:.2f}    {result['TEC']:.2f}    "
            row += f"{result['TEC_STD']:.2f}    {seq_info:<12}"

            for col in sorted(location_cols):
                value = result['location_info'].get(col, 'N/A')
                if isinstance(value, float):
                    row += f"{value:.2f}      "
                else:
                    row += f"{str(value):<12}"

            print(row)
        else:
            row = f"{i+1:<3}{str(result['target_datetime']):<20}{'NOT FOUND':<20}"
            row += f"{'N/A':<10}{'N/A':<10}{'N/A':<10}{'N/A':<12}"

            for col in sorted(location_cols):
                row += f"{'N/A':<12}"

            print(row)

    print(f"{'-'*len(header)}")

    return results

target_datetimes = [
    "2024-12-01 18:00:00"
]

print("\n\n" + "*"*50 + " ANALYSIS OF SPECIFIC TIMES " + "*"*50)
results = analyze_specific_datetimes(target_datetimes, max_minutes_diff=2)

print("\nAnalysis complete!")

found_results = [r for r in results if r['found_datetime'] is not None]
if found_results:
    print(f"\n{'='*80}")
    print(f"STATISTICS OF THE RESULTS FOUND")
    print(f"{'='*80}")

    tec_values = [r['TEC'] for r in found_results]
    print(f"TEC values ​​found:")
    print(f" Minimum: {min(tec_values):.2f} TECU")
    print(f" Maximum: {max(tec_values):.2f} TECU")
    print(f" Mean: {np.mean(tec_values):.2f} TECU")
    print(f" Standard deviation: {np.std(tec_values):.2f} TECU")

    sequences_found = sum(1 for r in found_results if r['has_sequence'])
    print(f"\nHigh value sequences found: {sequences_found} out of {len(found_results)} ({sequences_found/len(found_results)*100:.1f}%)")
# Out:
# Data loaded: 42320 records of 2024-12-01 until 2024-12-31
# Available columns in the DataFrame: ['DATETIME', 'TEC', 'TEC_STD', 'LATITUDE']
# Analysing 41633 points after removing missing values
#
#
# ************************************************** ANALYSIS OF SPECIFIC TIMES **************************************************
#
# ====================================================================================================
# ANALYSIS OF TEC VALUES CLOSE TO SPECIFIC TIMES
# (Maximum allowed difference: 2 minutes)
# ====================================================================================================
#
# ------------------------------------------------------------
# LOOKING FOR VALUES NEAR: 2024-12-01 18:00:00
# ------------------------------------------------------------
#  VALUE FOUND:
#  Actual Date/Time: 2024-12-01 18:00:00
#  Target Date/Time: 2024-12-01 18:00:00
#  Difference: 0.00 minutes
#   TEC: 71.17 ± 3.19 TECU
#   LATITUDE: -15.95
#  HAS a sequence of 3 high values ​​(≥90% of the peak):
#     1. 2024-12-01 17:58:58: 71.24 ± 3.18 TECU (100.1% of the value)
#     2. 2024-12-01 18:00:00: 71.17 ± 3.19 TECU (100.0% of the value)
#     3. 2024-12-01 18:01:01: 71.11 ± 3.21 TECU (99.9% of the value)
#
# ========================================================================================================================
# RESULTS SUMMARY TABLE
# ========================================================================================================================
# #  Target Time         Found Time          Diff(min) TEC       TEC_STD   Sequence    LATITUDE
# -------------------------------------------------------------------------------------------------
# 1  2024-12-01 18:00:00 2024-12-01 18:00:00 0.00    71.17    3.19    Yes         -15.95
# -------------------------------------------------------------------------------------------------
#
# Analysis complete!
#
# ================================================================================
# STATISTICS OF THE RESULTS FOUND
# ================================================================================
# TEC values ​​found:
#  Minimum: 71.17 TECU
#  Maximum: 71.17 TECU
#  Mean: 71.17 TECU
#  Standard deviation: 0.00 TECU
#
# High value sequences found: 1 out of 1 (100.0%)

# %% [markdown]
# ## 12/18 - 18:00

# %%
import pandas as pd
import numpy as np
from datetime import timedelta, time, datetime

df = pd.read_pickle('braz_dec_2024_complete.pkl')
print(f"Data loaded: {len(df)} records of {df['DATETIME'].min().date()} until {df['DATETIME'].max().date()}")

print(f"Available columns in the DataFrame: {list(df.columns)}")

df = df.sort_values('DATETIME').reset_index(drop=True)

df_clean = df.dropna(subset=['TEC', 'TEC_STD']).copy()
print(f"Analysing {len(df_clean)} points after removing missing values")

def check_consecutive_highs(df, peak_datetime, threshold_percent=90):
    peak_idx = df[df['DATETIME'] == peak_datetime].index[0]
    peak_value = df.loc[peak_idx, 'TEC']
    threshold = peak_value * (threshold_percent / 100)

    idx_before = peak_idx - 1
    idx_after = peak_idx + 1

    valid_before = idx_before >= 0
    valid_after = idx_after < len(df)

    if valid_before and valid_after:
        values = [df.loc[idx_before, 'TEC'], peak_value, df.loc[idx_after, 'TEC']]
        stds = [df.loc[idx_before, 'TEC_STD'], df.loc[peak_idx, 'TEC_STD'], df.loc[idx_after, 'TEC_STD']]
        datetimes = [df.loc[idx_before, 'DATETIME'], peak_datetime, df.loc[idx_after, 'DATETIME']]
        all_high = all(value >= threshold for value in values)

        if all_high:
            return {'indices': [idx_before, peak_idx, idx_after],
                   'values': values,
                   'stds': stds,
                   'datetimes': datetimes}

    if valid_before and idx_before > 0:
        values = [df.loc[idx_before-1, 'TEC'], df.loc[idx_before, 'TEC'], peak_value]
        stds = [df.loc[idx_before-1, 'TEC_STD'], df.loc[idx_before, 'TEC_STD'], df.loc[peak_idx, 'TEC_STD']]
        datetimes = [df.loc[idx_before-1, 'DATETIME'], df.loc[idx_before, 'DATETIME'], peak_datetime]
        all_high = all(value >= threshold for value in values)

        if all_high:
            return {'indices': [idx_before-1, idx_before, peak_idx],
                   'values': values,
                   'stds': stds,
                   'datetimes': datetimes}

    if valid_after and idx_after < len(df) - 1:
        values = [peak_value, df.loc[idx_after, 'TEC'], df.loc[idx_after+1, 'TEC']]
        stds = [df.loc[peak_idx, 'TEC_STD'], df.loc[idx_after, 'TEC_STD'], df.loc[idx_after+1, 'TEC_STD']]
        datetimes = [peak_datetime, df.loc[idx_after, 'DATETIME'], df.loc[idx_after+1, 'DATETIME']]
        all_high = all(value >= threshold for value in values)

        if all_high:
            return {'indices': [peak_idx, idx_after, idx_after+1],
                   'values': values,
                   'stds': stds,
                   'datetimes': datetimes}

    return None

def find_closest_value_to_datetime(df, target_datetime, max_minutes_diff=2):

    if isinstance(target_datetime, str):
        target_datetime = pd.to_datetime(target_datetime)
    elif isinstance(target_datetime, datetime):
        target_datetime = pd.Timestamp(target_datetime)

    time_diff = abs((df['DATETIME'] - target_datetime).dt.total_seconds() / 60)

    within_range = time_diff <= max_minutes_diff

    if not within_range.any():
        return None, None

    closest_idx = time_diff[within_range].idxmin()
    closest_diff = time_diff[closest_idx]

    return df.loc[closest_idx], closest_diff

def get_available_location_info(row):

    location_info = {}

    location_columns = ['LATITUDE', 'LONGITUDE', 'LAT', 'LON', 'STATION', 'SITE']

    for col in location_columns:
        if col in row.index:
            location_info[col] = row[col]

    return location_info

def analyze_specific_datetimes(target_datetimes, max_minutes_diff=2):

    print(f"\n{'='*100}")
    print(f"ANALYSIS OF TEC VALUES CLOSE TO SPECIFIC TIMES")
    print(f"(Maximum allowed difference: {max_minutes_diff} minutes)")
    print(f"{'='*100}")

    results = []

    for i, target_dt in enumerate(target_datetimes):
        print(f"\n{'-'*60}")
        print(f"LOOKING FOR VALUES NEAR: {target_dt}")
        print(f"{'-'*60}")

        closest_row, time_diff = find_closest_value_to_datetime(df_clean, target_dt, max_minutes_diff)

        if closest_row is not None:
            print(f" VALUE FOUND:")
            print(f"  Actual Date/Time: {closest_row['DATETIME']}")
            print(f"  Actual Date/Time: {target_dt}")
            print(f"  Difference: {time_diff:.2f} minutos")
            print(f"  TEC: {closest_row['TEC']:.2f} ± {closest_row['TEC_STD']:.2f} TECU")

            location_info = get_available_location_info(closest_row)
            for key, value in location_info.items():
                print(f"  {key}: {value}")

            sequence = check_consecutive_highs(df_clean, closest_row['DATETIME'], threshold_percent=90)

            if sequence:
                print(f"  HAS a sequence of 3 high values ​​(≥90% of the peak):")
                for j, (dt, val, std) in enumerate(zip(sequence['datetimes'], sequence['values'], sequence['stds'])):
                    print(f"    {j+1}. {dt}: {val:.2f} ± {std:.2f} TECU ({val/closest_row['TEC']*100:.1f}% of the value)")
            else:
                print(f"  Does NOT have a sequence of 3 consecutive high values")

            result = {
                'target_datetime': target_dt,
                'found_datetime': closest_row['DATETIME'],
                'time_diff_minutes': time_diff,
                'TEC': closest_row['TEC'],
                'TEC_STD': closest_row['TEC_STD'],
                'has_sequence': sequence is not None,
                'sequence': sequence,
                'location_info': location_info
            }

            results.append(result)

        else:
            print(f"NO VALUE FOUND within {max_minutes_diff} minutes of target time")
            results.append({
                'target_datetime': target_dt,
                'found_datetime': None,
                'time_diff_minutes': None,
                'TEC': None,
                'TEC_STD': None,
                'has_sequence': False,
                'sequence': None,
                'location_info': {}
            })

    print(f"\n{'='*120}")
    print(f"SUMMARY TABLE OF RESULTS")
    print(f"{'='*120}")

    header = f"{'#':<3}{'Target Time':<20}{'Found Time':<20}{'Diff(min)':<10}{'TEC':<10}{'TEC_STD':<10}{'Sequence':<12}"

    location_cols = set()
    for result in results:
        if result['location_info']:
            location_cols.update(result['location_info'].keys())

    for col in sorted(location_cols):
        header += f"{col:<12}"

    print(header)
    print(f"{'-'*len(header)}")

    for i, result in enumerate(results):
        if result['found_datetime'] is not None:
            seq_info = "Sim" if result['has_sequence'] else "Não"
            row = f"{i+1:<3}{str(result['target_datetime']):<20}{str(result['found_datetime']):<20}"
            row += f"{result['time_diff_minutes']:.2f}    {result['TEC']:.2f}    "
            row += f"{result['TEC_STD']:.2f}    {seq_info:<12}"

            for col in sorted(location_cols):
                value = result['location_info'].get(col, 'N/A')
                if isinstance(value, float):
                    row += f"{value:.2f}      "
                else:
                    row += f"{str(value):<12}"

            print(row)
        else:
            row = f"{i+1:<3}{str(result['target_datetime']):<20}{'NÃO ENCONTRADO':<20}"
            row += f"{'N/A':<10}{'N/A':<10}{'N/A':<10}{'N/A':<12}"

            for col in sorted(location_cols):
                row += f"{'N/A':<12}"

            print(row)

    print(f"{'-'*len(header)}")

    return results

target_datetimes = [
    "2024-12-18 18:00:00"
]

print("\n\n" + "*"*50 + " ANALYSIS OF SPECIFIC TIMES " + "*"*50)
results = analyze_specific_datetimes(target_datetimes, max_minutes_diff=2)

print("\nAnalysis complete!")

found_results = [r for r in results if r['found_datetime'] is not None]
if found_results:
    print(f"\n{'='*80}")
    print(f"STATISTICS OF THE RESULTS FOUND")
    print(f"{'='*80}")

    tec_values = [r['TEC'] for r in found_results]
    print(f"TEC values ​​found:")
    print(f"  Minimum: {min(tec_values):.2f} TECU")
    print(f"  Maximum: {max(tec_values):.2f} TECU")
    print(f"  Mean: {np.mean(tec_values):.2f} TECU")
    print(f"  Standard deviation: {np.std(tec_values):.2f} TECU")

    sequences_found = sum(1 for r in found_results if r['has_sequence'])
    print(f"\nHigh value sequences found: {sequences_found} de {len(found_results)} ({sequences_found/len(found_results)*100:.1f}%)")
# Out:
# Data loaded: 42320 records of 2024-12-01 until 2024-12-31
# Available columns in the DataFrame: ['DATETIME', 'TEC', 'TEC_STD', 'LATITUDE']
# Analysing 41633 points after removing missing values
#
#
# ************************************************** ANALYSIS OF SPECIFIC TIMES **************************************************
#
# ====================================================================================================
# ANALYSIS OF TEC VALUES CLOSE TO SPECIFIC TIMES
# (Maximum allowed difference: 2 minutes)
# ====================================================================================================
#
# ------------------------------------------------------------
# LOOKING FOR VALUES NEAR: 2024-12-18 18:00:00
# ------------------------------------------------------------
#  VALUE FOUND:
#   Actual Date/Time: 2024-12-18 18:00:00
#   Actual Date/Time: 2024-12-18 18:00:00
#   Difference: 0.00 minutos
#   TEC: 79.74 ± 5.18 TECU
#   LATITUDE: -15.95
#   HAS a sequence of 3 high values ​​(≥90% of the peak):
#     1. 2024-12-18 17:58:58: 79.59 ± 4.62 TECU (99.8% of the value)
#     2. 2024-12-18 18:00:00: 79.74 ± 5.18 TECU (100.0% of the value)
#     3. 2024-12-18 18:01:01: 79.87 ± 5.20 TECU (100.2% of the value)
#
# ========================================================================================================================
# SUMMARY TABLE OF RESULTS
# ========================================================================================================================
# #  Target Time         Found Time          Diff(min) TEC       TEC_STD   Sequence    LATITUDE
# -------------------------------------------------------------------------------------------------
# 1  2024-12-18 18:00:00 2024-12-18 18:00:00 0.00    79.74    5.18    Sim         -15.95
# -------------------------------------------------------------------------------------------------
#
# Analysis complete!
#
# ================================================================================
# STATISTICS OF THE RESULTS FOUND
# ================================================================================
# TEC values ​​found:
#   Minimum: 79.74 TECU
#   Maximum: 79.74 TECU
#   Mean: 79.74 TECU
#   Standard deviation: 0.00 TECU
#
# High value sequences found: 1 de 1 (100.0%)

# %% [markdown]
# ## 12/19 - 18:00

# %%
import pandas as pd
import numpy as np
from datetime import timedelta, time, datetime

df = pd.read_pickle('braz_dec_2024_complete.pkl')
print(f"Data loaded: {len(df)} records of {df['DATETIME'].min().date()} until {df['DATETIME'].max().date()}")

print(f"Columns available in the DataFrame: {list(df.columns)}")

df = df.sort_values('DATETIME').reset_index(drop=True)

df_clean = df.dropna(subset=['TEC', 'TEC_STD']).copy()
print(f"Analysing {len(df_clean)} points after removing missing values")

def check_consecutive_highs(df, peak_datetime, threshold_percent=90):
    peak_idx = df[df['DATETIME'] == peak_datetime].index[0]
    peak_value = df.loc[peak_idx, 'TEC']
    threshold = peak_value * (threshold_percent / 100)

    idx_before = peak_idx - 1
    idx_after = peak_idx + 1

    valid_before = idx_before >= 0
    valid_after = idx_after < len(df)

    if valid_before and valid_after:
        values = [df.loc[idx_before, 'TEC'], peak_value, df.loc[idx_after, 'TEC']]
        stds = [df.loc[idx_before, 'TEC_STD'], df.loc[peak_idx, 'TEC_STD'], df.loc[idx_after, 'TEC_STD']]
        datetimes = [df.loc[idx_before, 'DATETIME'], peak_datetime, df.loc[idx_after, 'DATETIME']]
        all_high = all(value >= threshold for value in values)

        if all_high:
            return {'indices': [idx_before, peak_idx, idx_after],
                   'values': values,
                   'stds': stds,
                   'datetimes': datetimes}

    if valid_before and idx_before > 0:
        values = [df.loc[idx_before-1, 'TEC'], df.loc[idx_before, 'TEC'], peak_value]
        stds = [df.loc[idx_before-1, 'TEC_STD'], df.loc[idx_before, 'TEC_STD'], df.loc[peak_idx, 'TEC_STD']]
        datetimes = [df.loc[idx_before-1, 'DATETIME'], df.loc[idx_before, 'DATETIME'], peak_datetime]
        all_high = all(value >= threshold for value in values)

        if all_high:
            return {'indices': [idx_before-1, idx_before, peak_idx],
                   'values': values,
                   'stds': stds,
                   'datetimes': datetimes}

    if valid_after and idx_after < len(df) - 1:
        values = [peak_value, df.loc[idx_after, 'TEC'], df.loc[idx_after+1, 'TEC']]
        stds = [df.loc[peak_idx, 'TEC_STD'], df.loc[idx_after, 'TEC_STD'], df.loc[idx_after+1, 'TEC_STD']]
        datetimes = [peak_datetime, df.loc[idx_after, 'DATETIME'], df.loc[idx_after+1, 'DATETIME']]
        all_high = all(value >= threshold for value in values)

        if all_high:
            return {'indices': [peak_idx, idx_after, idx_after+1],
                   'values': values,
                   'stds': stds,
                   'datetimes': datetimes}

    return None

def find_closest_value_to_datetime(df, target_datetime, max_minutes_diff=2):

    if isinstance(target_datetime, str):
        target_datetime = pd.to_datetime(target_datetime)
    elif isinstance(target_datetime, datetime):
        target_datetime = pd.Timestamp(target_datetime)

    time_diff = abs((df['DATETIME'] - target_datetime).dt.total_seconds() / 60)

    within_range = time_diff <= max_minutes_diff

    if not within_range.any():
        return None, None

    closest_idx = time_diff[within_range].idxmin()
    closest_diff = time_diff[closest_idx]

    return df.loc[closest_idx], closest_diff

def get_available_location_info(row):

    location_info = {}

    location_columns = ['LATITUDE', 'LONGITUDE', 'LAT', 'LON', 'STATION', 'SITE']

    for col in location_columns:
        if col in row.index:
            location_info[col] = row[col]

    return location_info

def analyze_specific_datetimes(target_datetimes, max_minutes_diff=2):

    print(f"\n{'='*100}")
    print(f"ANALYSIS OF TEC VALUES CLOSE TO SPECIFIC TIMES")
    print(f"(Maximum allowed difference: {max_minutes_diff} minutes)")
    print(f"{'='*100}")

    results = []

    for i, target_dt in enumerate(target_datetimes):
        print(f"\n{'-'*60}")
        print(f"LOOKING FOR VALUES CLOSE TO: {target_dt}")
        print(f"{'-'*60}")

        closest_row, time_diff = find_closest_value_to_datetime(df_clean, target_dt, max_minutes_diff)

        if closest_row is not None:
            print(f"  VALUE FOUND:")
            print(f"  Actual Date/Time: {closest_row['DATETIME']}")
            print(f"  Actual Date/Time: {target_dt}")
            print(f"  Difference: {time_diff:.2f} minutos")
            print(f"  TEC: {closest_row['TEC']:.2f} ± {closest_row['TEC_STD']:.2f} TECU")

            location_info = get_available_location_info(closest_row)
            for key, value in location_info.items():
                print(f"  {key}: {value}")

            sequence = check_consecutive_highs(df_clean, closest_row['DATETIME'], threshold_percent=90)

            if sequence:
                print(f"  HAS a sequence of 3 high values ​​(≥90% of the peak):")
                for j, (dt, val, std) in enumerate(zip(sequence['datetimes'], sequence['values'], sequence['stds'])):
                    print(f"    {j+1}. {dt}: {val:.2f} ± {std:.2f} TECU ({val/closest_row['TEC']*100:.1f}% of the value)")
            else:
                print(f"  Does NOT have a sequence of 3 consecutive high values")

            result = {
                'target_datetime': target_dt,
                'found_datetime': closest_row['DATETIME'],
                'time_diff_minutes': time_diff,
                'TEC': closest_row['TEC'],
                'TEC_STD': closest_row['TEC_STD'],
                'has_sequence': sequence is not None,
                'sequence': sequence,
                'location_info': location_info
            }

            results.append(result)

        else:
            print(f"NO VALUE FOUND within {max_minutes_diff} minutes of target time")
            results.append({
                'target_datetime': target_dt,
                'found_datetime': None,
                'time_diff_minutes': None,
                'TEC': None,
                'TEC_STD': None,
                'has_sequence': False,
                'sequence': None,
                'location_info': {}
            })

    print(f"\n{'='*120}")
    print(f"SUMMARY TABLE OF RESULTS")
    print(f"{'='*120}")

    header = f"{'#':<3}{'Target Time':<20}{'Found Time':<20}{'Diff(min)':<10}{'TEC':<10}{'TEC_STD':<10}{'Sequence':<12}"

    location_cols = set()
    for result in results:
        if result['location_info']:
            location_cols.update(result['location_info'].keys())

    for col in sorted(location_cols):
        header += f"{col:<12}"

    print(header)
    print(f"{'-'*len(header)}")

    for i, result in enumerate(results):
        if result['found_datetime'] is not None:
            seq_info = "Sim" if result['has_sequence'] else "Não"
            row = f"{i+1:<3}{str(result['target_datetime']):<20}{str(result['found_datetime']):<20}"
            row += f"{result['time_diff_minutes']:.2f}    {result['TEC']:.2f}    "
            row += f"{result['TEC_STD']:.2f}    {seq_info:<12}"

            for col in sorted(location_cols):
                value = result['location_info'].get(col, 'N/A')
                if isinstance(value, float):
                    row += f"{value:.2f}      "
                else:
                    row += f"{str(value):<12}"

            print(row)
        else:
            row = f"{i+1:<3}{str(result['target_datetime']):<20}{'NÃO ENCONTRADO':<20}"
            row += f"{'N/A':<10}{'N/A':<10}{'N/A':<10}{'N/A':<12}"

            for col in sorted(location_cols):
                row += f"{'N/A':<12}"

            print(row)

    print(f"{'-'*len(header)}")

    return results

target_datetimes = [
    "2024-12-19 18:00:00"
]

print("\n\n" + "*"*50 + " ANALYSIS OF SPECIFIC TIMES " + "*"*50)
results = analyze_specific_datetimes(target_datetimes, max_minutes_diff=2)

print("\nAnalysis complete!")

found_results = [r for r in results if r['found_datetime'] is not None]
if found_results:
    print(f"\n{'='*80}")
    print(f"STATISTICS OF THE RESULTS FOUND")
    print(f"{'='*80}")

    tec_values = [r['TEC'] for r in found_results]
    print(f"TEC values ​​found:")
    print(f"  Minimum: {min(tec_values):.2f} TECU")
    print(f"  Maximum: {max(tec_values):.2f} TECU")
    print(f"  Mean: {np.mean(tec_values):.2f} TECU")
    print(f"  Standard deviation: {np.std(tec_values):.2f} TECU")

    sequences_found = sum(1 for r in found_results if r['has_sequence'])
    print(f"\nHigh value sequences found: {sequences_found} de {len(found_results)} ({sequences_found/len(found_results)*100:.1f}%)")
# Out:
# Data loaded: 42320 records of 2024-12-01 until 2024-12-31
# Columns available in the DataFrame: ['DATETIME', 'TEC', 'TEC_STD', 'LATITUDE']
# Analysing 41633 points after removing missing values
#
#
# ************************************************** ANALYSIS OF SPECIFIC TIMES **************************************************
#
# ====================================================================================================
# ANALYSIS OF TEC VALUES CLOSE TO SPECIFIC TIMES
# (Maximum allowed difference: 2 minutes)
# ====================================================================================================
#
# ------------------------------------------------------------
# LOOKING FOR VALUES CLOSE TO: 2024-12-19 18:00:00
# ------------------------------------------------------------
#   VALUE FOUND:
#   Actual Date/Time: 2024-12-19 18:00:00
#   Actual Date/Time: 2024-12-19 18:00:00
#   Difference: 0.00 minutos
#   TEC: 72.14 ± 2.23 TECU
#   LATITUDE: -15.95
#   HAS a sequence of 3 high values ​​(≥90% of the peak):
#     1. 2024-12-19 17:58:58: 72.10 ± 2.20 TECU (99.9% of the value)
#     2. 2024-12-19 18:00:00: 72.14 ± 2.23 TECU (100.0% of the value)
#     3. 2024-12-19 18:01:01: 72.18 ± 2.27 TECU (100.1% of the value)
#
# ========================================================================================================================
# SUMMARY TABLE OF RESULTS
# ========================================================================================================================
# #  Target Time         Found Time          Diff(min) TEC       TEC_STD   Sequence    LATITUDE
# -------------------------------------------------------------------------------------------------
# 1  2024-12-19 18:00:00 2024-12-19 18:00:00 0.00    72.14    2.23    Sim         -15.95
# -------------------------------------------------------------------------------------------------
#
# Analysis complete!
#
# ================================================================================
# STATISTICS OF THE RESULTS FOUND
# ================================================================================
# TEC values ​​found:
#   Minimum: 72.14 TECU
#   Maximum: 72.14 TECU
#   Mean: 72.14 TECU
#   Standard deviation: 0.00 TECU
#
# High value sequences found: 1 de 1 (100.0%)

# %% [markdown]
# ## 12/22 - 18:00

# %%
import pandas as pd
import numpy as np
from datetime import timedelta, time, datetime

df = pd.read_pickle('braz_dec_2024_complete.pkl')
print(f"Data loaded: {len(df)} records of {df['DATETIME'].min().date()} until {df['DATETIME'].max().date()}")

print(f"Columns available in the DataFrame: {list(df.columns)}")

df = df.sort_values('DATETIME').reset_index(drop=True)

df_clean = df.dropna(subset=['TEC', 'TEC_STD']).copy()
print(f"Analysing {len(df_clean)} points after removing missing values")

def check_consecutive_highs(df, peak_datetime, threshold_percent=90):
    peak_idx = df[df['DATETIME'] == peak_datetime].index[0]
    peak_value = df.loc[peak_idx, 'TEC']
    threshold = peak_value * (threshold_percent / 100)

    idx_before = peak_idx - 1
    idx_after = peak_idx + 1

    valid_before = idx_before >= 0
    valid_after = idx_after < len(df)

    if valid_before and valid_after:
        values = [df.loc[idx_before, 'TEC'], peak_value, df.loc[idx_after, 'TEC']]
        stds = [df.loc[idx_before, 'TEC_STD'], df.loc[peak_idx, 'TEC_STD'], df.loc[idx_after, 'TEC_STD']]
        datetimes = [df.loc[idx_before, 'DATETIME'], peak_datetime, df.loc[idx_after, 'DATETIME']]
        all_high = all(value >= threshold for value in values)

        if all_high:
            return {'indices': [idx_before, peak_idx, idx_after],
                   'values': values,
                   'stds': stds,
                   'datetimes': datetimes}

    if valid_before and idx_before > 0:
        values = [df.loc[idx_before-1, 'TEC'], df.loc[idx_before, 'TEC'], peak_value]
        stds = [df.loc[idx_before-1, 'TEC_STD'], df.loc[idx_before, 'TEC_STD'], df.loc[peak_idx, 'TEC_STD']]
        datetimes = [df.loc[idx_before-1, 'DATETIME'], df.loc[idx_before, 'DATETIME'], peak_datetime]
        all_high = all(value >= threshold for value in values)

        if all_high:
            return {'indices': [idx_before-1, idx_before, peak_idx],
                   'values': values,
                   'stds': stds,
                   'datetimes': datetimes}

    if valid_after and idx_after < len(df) - 1:
        values = [peak_value, df.loc[idx_after, 'TEC'], df.loc[idx_after+1, 'TEC']]
        stds = [df.loc[peak_idx, 'TEC_STD'], df.loc[idx_after, 'TEC_STD'], df.loc[idx_after+1, 'TEC_STD']]
        datetimes = [peak_datetime, df.loc[idx_after, 'DATETIME'], df.loc[idx_after+1, 'DATETIME']]
        all_high = all(value >= threshold for value in values)

        if all_high:
            return {'indices': [peak_idx, idx_after, idx_after+1],
                   'values': values,
                   'stds': stds,
                   'datetimes': datetimes}

    return None

def find_closest_value_to_datetime(df, target_datetime, max_minutes_diff=2):

    if isinstance(target_datetime, str):
        target_datetime = pd.to_datetime(target_datetime)
    elif isinstance(target_datetime, datetime):
        target_datetime = pd.Timestamp(target_datetime)

    time_diff = abs((df['DATETIME'] - target_datetime).dt.total_seconds() / 60)

    within_range = time_diff <= max_minutes_diff

    if not within_range.any():
        return None, None

    closest_idx = time_diff[within_range].idxmin()
    closest_diff = time_diff[closest_idx]

    return df.loc[closest_idx], closest_diff

def get_available_location_info(row):

    location_info = {}

    location_columns = ['LATITUDE', 'LONGITUDE', 'LAT', 'LON', 'STATION', 'SITE']

    for col in location_columns:
        if col in row.index:
            location_info[col] = row[col]

    return location_info

def analyze_specific_datetimes(target_datetimes, max_minutes_diff=2):

    print(f"\n{'='*100}")
    print(f"ANALYSIS OF TEC VALUES CLOSE TO SPECIFIC TIMES")
    print(f"(Maximum allowed difference: {max_minutes_diff} minutes)")
    print(f"{'='*100}")

    results = []

    for i, target_dt in enumerate(target_datetimes):
        print(f"\n{'-'*60}")
        print(f"LOOKING FOR VALUES CLOSE TO: {target_dt}")
        print(f"{'-'*60}")

        closest_row, time_diff = find_closest_value_to_datetime(df_clean, target_dt, max_minutes_diff)

        if closest_row is not None:
            print(f"  VALUE FOUND:")
            print(f"  Actual Date/Time: {closest_row['DATETIME']}")
            print(f"  Actual Date/Time: {target_dt}")
            print(f"  Difference: {time_diff:.2f} minutos")
            print(f"  TEC: {closest_row['TEC']:.2f} ± {closest_row['TEC_STD']:.2f} TECU")

            location_info = get_available_location_info(closest_row)
            for key, value in location_info.items():
                print(f"  {key}: {value}")

            sequence = check_consecutive_highs(df_clean, closest_row['DATETIME'], threshold_percent=90)

            if sequence:
                print(f"  HAS a sequence of 3 high values ​​(≥90% of the peak):")
                for j, (dt, val, std) in enumerate(zip(sequence['datetimes'], sequence['values'], sequence['stds'])):
                    print(f"    {j+1}. {dt}: {val:.2f} ± {std:.2f} TECU ({val/closest_row['TEC']*100:.1f}% of the value)")
            else:
                print(f"  Does NOT have a sequence of 3 consecutive high values")

            result = {
                'target_datetime': target_dt,
                'found_datetime': closest_row['DATETIME'],
                'time_diff_minutes': time_diff,
                'TEC': closest_row['TEC'],
                'TEC_STD': closest_row['TEC_STD'],
                'has_sequence': sequence is not None,
                'sequence': sequence,
                'location_info': location_info
            }

            results.append(result)

        else:
            print(f"NO VALUE FOUND within {max_minutes_diff} minutes of target time")
            results.append({
                'target_datetime': target_dt,
                'found_datetime': None,
                'time_diff_minutes': None,
                'TEC': None,
                'TEC_STD': None,
                'has_sequence': False,
                'sequence': None,
                'location_info': {}
            })

    print(f"\n{'='*120}")
    print(f"SUMMARY TABLE OF RESULTS")
    print(f"{'='*120}")

    header = f"{'#':<3}{'Target Time':<20}{'Found Time':<20}{'Diff(min)':<10}{'TEC':<10}{'TEC_STD':<10}{'Sequence':<12}"

    location_cols = set()
    for result in results:
        if result['location_info']:
            location_cols.update(result['location_info'].keys())

    for col in sorted(location_cols):
        header += f"{col:<12}"

    print(header)
    print(f"{'-'*len(header)}")

    for i, result in enumerate(results):
        if result['found_datetime'] is not None:
            seq_info = "Sim" if result['has_sequence'] else "Não"
            row = f"{i+1:<3}{str(result['target_datetime']):<20}{str(result['found_datetime']):<20}"
            row += f"{result['time_diff_minutes']:.2f}    {result['TEC']:.2f}    "
            row += f"{result['TEC_STD']:.2f}    {seq_info:<12}"

            for col in sorted(location_cols):
                value = result['location_info'].get(col, 'N/A')
                if isinstance(value, float):
                    row += f"{value:.2f}      "
                else:
                    row += f"{str(value):<12}"

            print(row)
        else:
            row = f"{i+1:<3}{str(result['target_datetime']):<20}{'NÃO ENCONTRADO':<20}"
            row += f"{'N/A':<10}{'N/A':<10}{'N/A':<10}{'N/A':<12}"

            for col in sorted(location_cols):
                row += f"{'N/A':<12}"

            print(row)

    print(f"{'-'*len(header)}")

    return results

target_datetimes = [
    "2024-12-22 18:00:00"
]

print("\n\n" + "*"*50 + " ANALYSIS OF SPECIFIC TIMES " + "*"*50)
results = analyze_specific_datetimes(target_datetimes, max_minutes_diff=2)

print("\nAnalysis complete!")

found_results = [r for r in results if r['found_datetime'] is not None]
if found_results:
    print(f"\n{'='*80}")
    print(f"STATISTICS OF THE RESULTS FOUND")
    print(f"{'='*80}")

    tec_values = [r['TEC'] for r in found_results]
    print(f"TEC values ​​found:")
    print(f"  Minimum: {min(tec_values):.2f} TECU")
    print(f"  Maximum: {max(tec_values):.2f} TECU")
    print(f"  Mean: {np.mean(tec_values):.2f} TECU")
    print(f"  Standard deviation: {np.std(tec_values):.2f} TECU")

    sequences_found = sum(1 for r in found_results if r['has_sequence'])
    print(f"\nHigh value sequences found: {sequences_found} de {len(found_results)} ({sequences_found/len(found_results)*100:.1f}%)")
# Out:
# Data loaded: 42320 records of 2024-12-01 until 2024-12-31
# Columns available in the DataFrame: ['DATETIME', 'TEC', 'TEC_STD', 'LATITUDE']
# Analysing 41633 points after removing missing values
#
#
# ************************************************** ANALYSIS OF SPECIFIC TIMES **************************************************
#
# ====================================================================================================
# ANALYSIS OF TEC VALUES CLOSE TO SPECIFIC TIMES
# (Maximum allowed difference: 2 minutes)
# ====================================================================================================
#
# ------------------------------------------------------------
# LOOKING FOR VALUES CLOSE TO: 2024-12-22 18:00:00
# ------------------------------------------------------------
#   VALUE FOUND:
#   Actual Date/Time: 2024-12-22 18:00:00
#   Actual Date/Time: 2024-12-22 18:00:00
#   Difference: 0.00 minutos
#   TEC: 78.26 ± 5.59 TECU
#   LATITUDE: -15.95
#   HAS a sequence of 3 high values ​​(≥90% of the peak):
#     1. 2024-12-22 17:58:58: 78.28 ± 5.54 TECU (100.0% of the value)
#     2. 2024-12-22 18:00:00: 78.26 ± 5.59 TECU (100.0% of the value)
#     3. 2024-12-22 18:01:01: 78.24 ± 5.64 TECU (100.0% of the value)
#
# ========================================================================================================================
# SUMMARY TABLE OF RESULTS
# ========================================================================================================================
# #  Target Time         Found Time          Diff(min) TEC       TEC_STD   Sequence    LATITUDE
# -------------------------------------------------------------------------------------------------
# 1  2024-12-22 18:00:00 2024-12-22 18:00:00 0.00    78.26    5.59    Sim         -15.95
# -------------------------------------------------------------------------------------------------
#
# Analysis complete!
#
# ================================================================================
# STATISTICS OF THE RESULTS FOUND
# ================================================================================
# TEC values ​​found:
#   Minimum: 78.26 TECU
#   Maximum: 78.26 TECU
#   Mean: 78.26 TECU
#   Standard deviation: 0.00 TECU
#
# High value sequences found: 1 de 1 (100.0%)

# %% [markdown]
# # TEC maps analysis

# %%
from typing import Iterable

class TecMap:
    def __init__(self,
                 extent: Iterable[float] = (-90, -30, -60, 20),
                 lat_step: float = 2,
                 lon_step: float = 2.5):
        self.extent = extent
        self.lat_step = lat_step
        self.lon_step = lon_step

        lon_min, lon_max, lat_min, lat_max = extent
        n_lat = int((lat_max - lat_min) / lat_step) + 1
        n_lon = int((lon_max - lon_min) / lon_step) + 1

        self.grid_shape = (n_lat, n_lon)
        self.tec_map = None

    def find_nearest_points(self, lat: float, lon: float):

        lon_min, lon_max, lat_min, lat_max = self.extent
        lat_step, lon_step = self.lat_step, self.lon_step

        lat_idx_lower = int((lat - lat_min) / lat_step)
        lat_idx_upper = lat_idx_lower + 1

        lat_idx_lower = max(0, min(lat_idx_lower, self.grid_shape[0] - 1))
        lat_idx_upper = max(0, min(lat_idx_upper, self.grid_shape[0] - 1))

        lon_idx_lower = int((lon - lon_min) / lon_step)
        lon_idx_upper = lon_idx_lower + 1

        lon_idx_lower = max(0, min(lon_idx_lower, self.grid_shape[1] - 1))
        lon_idx_upper = max(0, min(lon_idx_upper, self.grid_shape[1] - 1))

        lat_lower = lat_min + lat_idx_lower * lat_step
        lat_upper = lat_min + lat_idx_upper * lat_step
        lon_lower = lon_min + lon_idx_lower * lon_step
        lon_upper = lon_min + lon_idx_upper * lon_step

        points = []

        if lat_idx_lower != lat_idx_upper and lon_idx_lower != lon_idx_upper:
            points = [
                (lat_lower, lon_lower, lat_idx_lower, lon_idx_lower),
                (lat_lower, lon_upper, lat_idx_lower, lon_idx_upper),
                (lat_upper, lon_lower, lat_idx_upper, lon_idx_lower),
                (lat_upper, lon_upper, lat_idx_upper, lon_idx_upper)
            ]
        elif lat_idx_lower != lat_idx_upper:
            points = [
                (lat_lower, lon_lower, lat_idx_lower, lon_idx_lower),
                (lat_upper, lon_lower, lat_idx_upper, lon_idx_lower)
            ]
        elif lon_idx_lower != lon_idx_upper:
            points = [
                (lat_lower, lon_lower, lat_idx_lower, lon_idx_lower),
                (lat_lower, lon_upper, lat_idx_lower, lon_idx_upper)
            ]
        else:
            points = [(lat_lower, lon_lower, lat_idx_lower, lon_idx_lower)]

        return points

# %% [markdown]
# ## EMBRACE

# %%
import pandas as pd
import numpy as np

# %%
#Download TF_EMBRACE_TEC_maps_intersection_case_study_from_Sept_05_2024_to_Dec_2024.pkl from https://doi.org/10.5281/zenodo.15453941

# %%
# !gdown '1LkY0IeFfdnahoH81OKYW-2xmXHgjFPhH'
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1LkY0IeFfdnahoH81OKYW-2xmXHgjFPhH
# From (redirected): https://drive.google.com/uc?id=1LkY0IeFfdnahoH81OKYW-2xmXHgjFPhH&confirm=t&uuid=a42ea82b-d644-4ff3-b4a3-2ad82f72dc88
# To: /content/TF_EMBRACE_TEC_maps_intersection_case_study_from_Sept_05_2024_to_Dec_2024.pkl
# 100% 157M/157M [00:01<00:00, 95.6MB/s]

# %%
df_embrace_maps_2024 = pd.read_pickle('/content/TF_EMBRACE_TEC_maps_intersection_case_study_from_Sept_05_2024_to_Dec_2024.pkl')

# %%
df_embrace_maps_2024
# Out:
#                                                                 TECMAP
# DATETIME
# 2024-09-05 00:00:00  [[nan, nan, nan, nan, nan, nan, nan, nan, nan,...
# 2024-09-05 00:10:00  [[nan, nan, nan, nan, nan, nan, nan, nan, nan,...
# 2024-09-05 00:20:00  [[nan, nan, nan, nan, nan, nan, nan, nan, nan,...
# 2024-09-05 00:30:00  [[nan, nan, nan, nan, nan, nan, nan, nan, nan,...
# 2024-09-05 00:40:00  [[nan, nan, nan, nan, nan, nan, nan, nan, nan,...
# ...                                                                ...
# 2024-12-30 23:10:00  [[nan, nan, nan, nan, nan, nan, nan, nan, nan,...
# 2024-12-30 23:20:00  [[nan, nan, nan, nan, nan, nan, nan, nan, nan,...
# 2024-12-30 23:30:00  [[nan, nan, nan, nan, nan, nan, nan, nan, nan,...
# 2024-12-30 23:40:00  [[nan, nan, nan, nan, nan, nan, nan, nan, nan,...
# 2024-12-30 23:50:00  [[nan, nan, nan, nan, nan, nan, nan, nan, nan,...
#
# [16704 rows x 1 columns]

# %%
class Embrace(TecMap):
    def __init__(self,
                 extent: Iterable[float] = (-90, -30, -60, 20),
                 lat_step: float = 2,
                 lon_step: float = 2.5):
        super().__init__(extent, lat_step, lon_step)

# %%
embrace_tec = Embrace()
embrace_points = embrace_tec.find_nearest_points(lat=-15.94748, lon=-47.87787)

# %%
embrace_points
# Out:
# [(-16, -50.0, 22, 16),
#  (-16, -47.5, 22, 17),
#  (-14, -50.0, 23, 16),
#  (-14, -47.5, 23, 17)]

# %% [markdown]
# ### 12/01 - 18:00

# %%
import pandas as pd

date = '2024-12-01'
time = '18:00:00'
timestamp_wanted = f'{date} {time}'

if df_embrace_maps_2024.index.name == 'DATETIME':
    result = df_embrace_maps_2024.loc[timestamp_wanted:timestamp_wanted]
else:
    if 'DATETIME' in df_embrace_maps_2024.columns:
        df_embrace_maps_2024 = df_embrace_maps_2024.set_index('DATETIME')
        result = df_embrace_maps_2024.loc[timestamp_wanted:timestamp_wanted]
    else:
        print("DATETIME column not found!")
        print("Available columns:", df_embrace_maps_2024.columns.tolist())

if result.empty:
    if not isinstance(df_embrace_maps_2024.index, pd.DatetimeIndex):
        df_embrace_maps_2024.index = pd.to_datetime(df_embrace_maps_2024.index)

    timestamp_dt = pd.to_datetime(timestamp_wanted)

    diference = abs((df_embrace_maps_2024.index - timestamp_dt).total_seconds())
    idx_nearest = diference.argmin()

    result = df_embrace_maps_2024.iloc[[idx_nearest]]
    print(f"Exact date not found. Using closest record: {df_embrace_maps_2024.index[idx_nearest]}")

# %%
result
# Out:
#                                                                 TECMAP
# DATETIME
# 2024-12-01 18:00:00  [[nan, nan, nan, nan, nan, nan, nan, nan, nan,...

# %%
embrace_maps = np.array(result.iloc[:]['TECMAP'])

# %%
np_embrace_maps = []
for i in range(len(embrace_maps)):
    np_embrace_maps.append(embrace_maps[i])
np_embrace_maps = np.array(np_embrace_maps)

# %%
np_embrace_maps
# Out:
# array([[[nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         ...,
#         [nan, 46., nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan]]])

# %%
np_embrace_maps.shape
# Out:
# (1, 41, 25)

# %%
embrace_tec.tec_map = np_embrace_maps[0]

print("=" * 60)
print("DETAILED BILINEAR INTERPOLATION ANALYSIS")
print("=" * 60)

print("\n1. THE 4 CLOSEST POINTS:")
for i, point in enumerate(embrace_points):
    lat, lon, lat_idx, lon_idx = point
    tec_value = embrace_tec.tec_map[lat_idx, lon_idx]
    print(f"   P{i+1}: ({lat:+6.1f}°, {lon:+6.1f}°) - Indexes: [{lat_idx:2d}, {lon_idx:2d}] - TEC: {tec_value:5.1f}")

target_lat = -15.94748
target_lon = -47.87787

print(f"\n2. TARGET POINT: ({target_lat:+6.5f}°, {target_lon:+6.5f}°)")

values = []
for point in embrace_points:
    lat, lon, lat_idx, lon_idx = point
    values.append(embrace_tec.tec_map[lat_idx, lon_idx])

lats = [p[0] for p in embrace_points]
lons = [p[1] for p in embrace_points]

lat_min, lat_max = min(lats), max(lats)
lon_min, lon_max = min(lons), max(lons)

print(f"\n3. INTERPOLATION RECTANGLE BOUNDS:")
print(f"   Latitude:  {lat_min:+6.1f}° to {lat_max:+6.1f}° (range: {lat_max - lat_min:4.1f}°)")
print(f"   Longitude: {lon_min:+6.1f}° to {lon_max:+6.1f}° (range: {lon_max - lon_min:4.1f}°)")

point_values = {}
for i, point in enumerate(embrace_points):
    point_values[(point[0], point[1])] = values[i]

f_00 = point_values[(lat_min, lon_min)]
f_01 = point_values[(lat_min, lon_max)]
f_10 = point_values[(lat_max, lon_min)]
f_11 = point_values[(lat_max, lon_max)]

print(f"\n4. TEC VALUES MAPPING:")
print(f"   f_00 (lat_min, lon_min) = ({lat_min:+6.1f}°, {lon_min:+6.1f}°) = {f_00:5.1f}")
print(f"   f_01 (lat_min, lon_max) = ({lat_min:+6.1f}°, {lon_max:+6.1f}°) = {f_01:5.1f}")
print(f"   f_10 (lat_max, lon_min) = ({lat_max:+6.1f}°, {lon_min:+6.1f}°) = {f_10:5.1f}")
print(f"   f_11 (lat_max, lon_max) = ({lat_max:+6.1f}°, {lon_max:+6.1f}°) = {f_11:5.1f}")

t_x = (target_lon - lon_min) / (lon_max - lon_min) if lon_max != lon_min else 0
t_y = (target_lat - lat_min) / (lat_max - lat_min) if lat_max != lat_min else 0

print(f"\n5. INTERPOLATION PARAMETERS:")
print(f"   t_x = (target_lon - lon_min) / (lon_max - lon_min)")
print(f"   t_x = ({target_lon:+6.5f} - ({lon_min:+6.1f})) / ({lon_max:+6.1f} - ({lon_min:+6.1f}))")
print(f"   t_x = {target_lon - lon_min:6.5f} / {lon_max - lon_min:4.1f} = {t_x:.6f}")
print(f"   ")
print(f"   t_y = (target_lat - lat_min) / (lat_max - lat_min)")
print(f"   t_y = ({target_lat:+6.5f} - ({lat_min:+6.1f})) / ({lat_max:+6.1f} - ({lat_min:+6.1f}))")
print(f"   t_y = {target_lat - lat_min:6.5f} / {lat_max - lat_min:4.1f} = {t_y:.6f}")

w_00 = (1 - t_x) * (1 - t_y)
w_01 = t_x * (1 - t_y)
w_10 = (1 - t_x) * t_y
w_11 = t_x * t_y

print(f"\n6. INTERPOLATION WEIGHTS:")
print(f"   w_00 = (1 - t_x) * (1 - t_y) = (1 - {t_x:.6f}) * (1 - {t_y:.6f}) = {w_00:.6f}")
print(f"   w_01 = t_x * (1 - t_y)       = {t_x:.6f} * (1 - {t_y:.6f})       = {w_01:.6f}")
print(f"   w_10 = (1 - t_x) * t_y       = (1 - {t_x:.6f}) * {t_y:.6f}       = {w_10:.6f}")
print(f"   w_11 = t_x * t_y             = {t_x:.6f} * {t_y:.6f}             = {w_11:.6f}")
print(f"   Sum of weights = {w_00 + w_01 + w_10 + w_11:.6f} (should be 1.0)")

interpolated_value = w_00 * f_00 + w_01 * f_01 + w_10 * f_10 + w_11 * f_11

print(f"\n7. FINAL CALCULATION:")
print(f"   Value = w_00*f_00 + w_01*f_01 + w_10*f_10 + w_11*f_11")
print(f"   Value = {w_00:.6f}*{f_00:5.1f} + {w_01:.6f}*{f_01:5.1f} + {w_10:.6f}*{f_10:5.1f} + {w_11:.6f}*{f_11:5.1f}")
print(f"   Value = {w_00*f_00:8.4f} + {w_01*f_01:8.4f} + {w_10*f_10:8.4f} + {w_11*f_11:8.4f}")
print(f"   Value = {interpolated_value:.6f}")

print(f"\n8. TARGET POINT RELATIVE POSITION:")
print(f"   In X direction (longitude): {t_x*100:.2f}% of the way from {lon_min}° to {lon_max}°")
print(f"   In Y direction (latitude):  {t_y*100:.2f}% of the way from {lat_min}° to {lat_max}°")

print(f"\n{'='*60}")
print(f"FINAL RESULT: TEC = {interpolated_value:.4f}")
print(f"{'='*60}")
# Out:
# ============================================================
# DETAILED BILINEAR INTERPOLATION ANALYSIS
# ============================================================
#
# 1. THE 4 CLOSEST POINTS:
#    P1: ( -16.0°,  -50.0°) - Indexes: [22, 16] - TEC:  61.0
#    P2: ( -16.0°,  -47.5°) - Indexes: [22, 17] - TEC:  74.0
#    P3: ( -14.0°,  -50.0°) - Indexes: [23, 16] - TEC:  58.0
#    P4: ( -14.0°,  -47.5°) - Indexes: [23, 17] - TEC:  62.0
#
# 2. TARGET POINT: (-15.94748°, -47.87787°)
#
# 3. INTERPOLATION RECTANGLE BOUNDS:
#    Latitude:   -16.0° to  -14.0° (range:  2.0°)
#    Longitude:  -50.0° to  -47.5° (range:  2.5°)
#
# 4. TEC VALUES MAPPING:
#    f_00 (lat_min, lon_min) = ( -16.0°,  -50.0°) =  61.0
#    f_01 (lat_min, lon_max) = ( -16.0°,  -47.5°) =  74.0
#    f_10 (lat_max, lon_min) = ( -14.0°,  -50.0°) =  58.0
#    f_11 (lat_max, lon_max) = ( -14.0°,  -47.5°) =  62.0
#
# 5. INTERPOLATION PARAMETERS:
#    t_x = (target_lon - lon_min) / (lon_max - lon_min)
#    t_x = (-47.87787 - ( -50.0)) / ( -47.5 - ( -50.0))
#    t_x = 2.12213 /  2.5 = 0.848852
#
#    t_y = (target_lat - lat_min) / (lat_max - lat_min)
#    t_y = (-15.94748 - ( -16.0)) / ( -14.0 - ( -16.0))
#    t_y = 0.05252 /  2.0 = 0.026260
#
# 6. INTERPOLATION WEIGHTS:
#    w_00 = (1 - t_x) * (1 - t_y) = (1 - 0.848852) * (1 - 0.026260) = 0.147179
#    w_01 = t_x * (1 - t_y)       = 0.848852 * (1 - 0.026260)       = 0.826561
#    w_10 = (1 - t_x) * t_y       = (1 - 0.848852) * 0.026260       = 0.003969
#    w_11 = t_x * t_y             = 0.848852 * 0.026260             = 0.022291
#    Sum of weights = 1.000000 (should be 1.0)
#
# 7. FINAL CALCULATION:
#    Value = w_00*f_00 + w_01*f_01 + w_10*f_10 + w_11*f_11
#    Value = 0.147179* 61.0 + 0.826561* 74.0 + 0.003969* 58.0 + 0.022291* 62.0
#    Value =   8.9779 +  61.1655 +   0.2302 +   1.3820
#    Value = 71.755678
#
# 8. TARGET POINT RELATIVE POSITION:
#    In X direction (longitude): 84.89% of the way from -50.0° to -47.5°
#    In Y direction (latitude):  2.63% of the way from -16° to -14°
#
# ============================================================
# FINAL RESULT: TEC = 71.7557
# ============================================================

# %% [markdown]
# ### 12/18 - 18:00

# %%
import pandas as pd

date = '2024-12-18'
time = '18:00:00'
timestamp_wanted = f'{date} {time}'

if df_embrace_maps_2024.index.name == 'DATETIME':
    result = df_embrace_maps_2024.loc[timestamp_wanted:timestamp_wanted]
else:
    if 'DATETIME' in df_embrace_maps_2024.columns:
        df_embrace_maps_2024 = df_embrace_maps_2024.set_index('DATETIME')
        result = df_embrace_maps_2024.loc[timestamp_wanted:timestamp_wanted]
    else:
        print("DATETIME column not found!")
        print("Available columns:", df_embrace_maps_2024.columns.tolist())

if result.empty:
    if not isinstance(df_embrace_maps_2024.index, pd.DatetimeIndex):
        df_embrace_maps_2024.index = pd.to_datetime(df_embrace_maps_2024.index)

    timestamp_dt = pd.to_datetime(timestamp_wanted)

    diference = abs((df_embrace_maps_2024.index - timestamp_dt).total_seconds())
    idx_nearest = diference.argmin()

    result = df_embrace_maps_2024.iloc[[idx_nearest]]
    print(f"Exact date not found. Using closest record: {df_embrace_maps_2024.index[idx_nearest]}")

# %%
result
# Out:
#                                                                 TECMAP
# DATETIME
# 2024-12-18 18:00:00  [[nan, nan, nan, nan, nan, nan, nan, nan, nan,...

# %%
embrace_maps = np.array(result.iloc[:]['TECMAP'])

# %%
np_embrace_maps = []
for i in range(len(embrace_maps)):
    np_embrace_maps.append(embrace_maps[i])
np_embrace_maps = np.array(np_embrace_maps)

# %%
np_embrace_maps
# Out:
# array([[[nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         ...,
#         [nan, 36., nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan]]])

# %%
np_embrace_maps.shape
# Out:
# (1, 41, 25)

# %%
embrace_tec.tec_map = np_embrace_maps[0]

print("=" * 60)
print("DETAILED BILINEAR INTERPOLATION ANALYSIS")
print("=" * 60)

print("\n1. THE 4 CLOSEST POINTS:")
for i, point in enumerate(embrace_points):
    lat, lon, lat_idx, lon_idx = point
    tec_value = embrace_tec.tec_map[lat_idx, lon_idx]
    print(f"   P{i+1}: ({lat:+6.1f}°, {lon:+6.1f}°) - Indexes: [{lat_idx:2d}, {lon_idx:2d}] - TEC: {tec_value:5.1f}")

target_lat = -15.94748
target_lon = -47.87787

print(f"\n2. TARGET POINT: ({target_lat:+6.5f}°, {target_lon:+6.5f}°)")

values = []
for point in embrace_points:
    lat, lon, lat_idx, lon_idx = point
    values.append(embrace_tec.tec_map[lat_idx, lon_idx])

lats = [p[0] for p in embrace_points]
lons = [p[1] for p in embrace_points]

lat_min, lat_max = min(lats), max(lats)
lon_min, lon_max = min(lons), max(lons)

print(f"\n3. INTERPOLATION RECTANGLE BOUNDS:")
print(f"   Latitude:  {lat_min:+6.1f}° to {lat_max:+6.1f}° (range: {lat_max - lat_min:4.1f}°)")
print(f"   Longitude: {lon_min:+6.1f}° to {lon_max:+6.1f}° (range: {lon_max - lon_min:4.1f}°)")

point_values = {}
for i, point in enumerate(embrace_points):
    point_values[(point[0], point[1])] = values[i]

f_00 = point_values[(lat_min, lon_min)]
f_01 = point_values[(lat_min, lon_max)]
f_10 = point_values[(lat_max, lon_min)]
f_11 = point_values[(lat_max, lon_max)]

print(f"\n4. TEC VALUES MAPPING:")
print(f"   f_00 (lat_min, lon_min) = ({lat_min:+6.1f}°, {lon_min:+6.1f}°) = {f_00:5.1f}")
print(f"   f_01 (lat_min, lon_max) = ({lat_min:+6.1f}°, {lon_max:+6.1f}°) = {f_01:5.1f}")
print(f"   f_10 (lat_max, lon_min) = ({lat_max:+6.1f}°, {lon_min:+6.1f}°) = {f_10:5.1f}")
print(f"   f_11 (lat_max, lon_max) = ({lat_max:+6.1f}°, {lon_max:+6.1f}°) = {f_11:5.1f}")

t_x = (target_lon - lon_min) / (lon_max - lon_min) if lon_max != lon_min else 0
t_y = (target_lat - lat_min) / (lat_max - lat_min) if lat_max != lat_min else 0

print(f"\n5. INTERPOLATION PARAMETERS:")
print(f"   t_x = (target_lon - lon_min) / (lon_max - lon_min)")
print(f"   t_x = ({target_lon:+6.5f} - ({lon_min:+6.1f})) / ({lon_max:+6.1f} - ({lon_min:+6.1f}))")
print(f"   t_x = {target_lon - lon_min:6.5f} / {lon_max - lon_min:4.1f} = {t_x:.6f}")
print(f"   ")
print(f"   t_y = (target_lat - lat_min) / (lat_max - lat_min)")
print(f"   t_y = ({target_lat:+6.5f} - ({lat_min:+6.1f})) / ({lat_max:+6.1f} - ({lat_min:+6.1f}))")
print(f"   t_y = {target_lat - lat_min:6.5f} / {lat_max - lat_min:4.1f} = {t_y:.6f}")

w_00 = (1 - t_x) * (1 - t_y)
w_01 = t_x * (1 - t_y)
w_10 = (1 - t_x) * t_y
w_11 = t_x * t_y

print(f"\n6. INTERPOLATION WEIGHTS:")
print(f"   w_00 = (1 - t_x) * (1 - t_y) = (1 - {t_x:.6f}) * (1 - {t_y:.6f}) = {w_00:.6f}")
print(f"   w_01 = t_x * (1 - t_y)       = {t_x:.6f} * (1 - {t_y:.6f})       = {w_01:.6f}")
print(f"   w_10 = (1 - t_x) * t_y       = (1 - {t_x:.6f}) * {t_y:.6f}       = {w_10:.6f}")
print(f"   w_11 = t_x * t_y             = {t_x:.6f} * {t_y:.6f}             = {w_11:.6f}")
print(f"   Sum of weights = {w_00 + w_01 + w_10 + w_11:.6f} (should be 1.0)")

interpolated_value = w_00 * f_00 + w_01 * f_01 + w_10 * f_10 + w_11 * f_11

print(f"\n7. FINAL CALCULATION:")
print(f"   Value = w_00*f_00 + w_01*f_01 + w_10*f_10 + w_11*f_11")
print(f"   Value = {w_00:.6f}*{f_00:5.1f} + {w_01:.6f}*{f_01:5.1f} + {w_10:.6f}*{f_10:5.1f} + {w_11:.6f}*{f_11:5.1f}")
print(f"   Value = {w_00*f_00:8.4f} + {w_01*f_01:8.4f} + {w_10*f_10:8.4f} + {w_11*f_11:8.4f}")
print(f"   Value = {interpolated_value:.6f}")

print(f"\n8. TARGET POINT RELATIVE POSITION:")
print(f"   In X direction (longitude): {t_x*100:.2f}% of the way from {lon_min}° to {lon_max}°")
print(f"   In Y direction (latitude):  {t_y*100:.2f}% of the way from {lat_min}° to {lat_max}°")

print(f"\n{'='*60}")
print(f"FINAL RESULT: TEC = {interpolated_value:.4f}")
print(f"{'='*60}")
# Out:
# ============================================================
# DETAILED BILINEAR INTERPOLATION ANALYSIS
# ============================================================
#
# 1. THE 4 CLOSEST POINTS:
#    P1: ( -16.0°,  -50.0°) - Indexes: [22, 16] - TEC:  79.0
#    P2: ( -16.0°,  -47.5°) - Indexes: [22, 17] - TEC:  82.0
#    P3: ( -14.0°,  -50.0°) - Indexes: [23, 16] - TEC:  71.0
#    P4: ( -14.0°,  -47.5°) - Indexes: [23, 17] - TEC:  75.0
#
# 2. TARGET POINT: (-15.94748°, -47.87787°)
#
# 3. INTERPOLATION RECTANGLE BOUNDS:
#    Latitude:   -16.0° to  -14.0° (range:  2.0°)
#    Longitude:  -50.0° to  -47.5° (range:  2.5°)
#
# 4. TEC VALUES MAPPING:
#    f_00 (lat_min, lon_min) = ( -16.0°,  -50.0°) =  79.0
#    f_01 (lat_min, lon_max) = ( -16.0°,  -47.5°) =  82.0
#    f_10 (lat_max, lon_min) = ( -14.0°,  -50.0°) =  71.0
#    f_11 (lat_max, lon_max) = ( -14.0°,  -47.5°) =  75.0
#
# 5. INTERPOLATION PARAMETERS:
#    t_x = (target_lon - lon_min) / (lon_max - lon_min)
#    t_x = (-47.87787 - ( -50.0)) / ( -47.5 - ( -50.0))
#    t_x = 2.12213 /  2.5 = 0.848852
#
#    t_y = (target_lat - lat_min) / (lat_max - lat_min)
#    t_y = (-15.94748 - ( -16.0)) / ( -14.0 - ( -16.0))
#    t_y = 0.05252 /  2.0 = 0.026260
#
# 6. INTERPOLATION WEIGHTS:
#    w_00 = (1 - t_x) * (1 - t_y) = (1 - 0.848852) * (1 - 0.026260) = 0.147179
#    w_01 = t_x * (1 - t_y)       = 0.848852 * (1 - 0.026260)       = 0.826561
#    w_10 = (1 - t_x) * t_y       = (1 - 0.848852) * 0.026260       = 0.003969
#    w_11 = t_x * t_y             = 0.848852 * 0.026260             = 0.022291
#    Sum of weights = 1.000000 (should be 1.0)
#
# 7. FINAL CALCULATION:
#    Value = w_00*f_00 + w_01*f_01 + w_10*f_10 + w_11*f_11
#    Value = 0.147179* 79.0 + 0.826561* 82.0 + 0.003969* 71.0 + 0.022291* 75.0
#    Value =  11.6271 +  67.7780 +   0.2818 +   1.6718
#    Value = 81.358767
#
# 8. TARGET POINT RELATIVE POSITION:
#    In X direction (longitude): 84.89% of the way from -50.0° to -47.5°
#    In Y direction (latitude):  2.63% of the way from -16° to -14°
#
# ============================================================
# FINAL RESULT: TEC = 81.3588
# ============================================================

# %% [markdown]
# ### 12/18 - 18:10

# %%
import pandas as pd

date = '2024-12-18'
time = '18:10:00'
timestamp_wanted = f'{date} {time}'

if df_embrace_maps_2024.index.name == 'DATETIME':
    result = df_embrace_maps_2024.loc[timestamp_wanted:timestamp_wanted]
else:
    if 'DATETIME' in df_embrace_maps_2024.columns:
        df_embrace_maps_2024 = df_embrace_maps_2024.set_index('DATETIME')
        result = df_embrace_maps_2024.loc[timestamp_wanted:timestamp_wanted]
    else:
        print("DATETIME column not found!")
        print("Available columns:", df_embrace_maps_2024.columns.tolist())

if result.empty:
    if not isinstance(df_embrace_maps_2024.index, pd.DatetimeIndex):
        df_embrace_maps_2024.index = pd.to_datetime(df_embrace_maps_2024.index)

    timestamp_dt = pd.to_datetime(timestamp_wanted)

    diference = abs((df_embrace_maps_2024.index - timestamp_dt).total_seconds())
    idx_nearest = diference.argmin()

    result = df_embrace_maps_2024.iloc[[idx_nearest]]
    print(f"Exact date not found. Using closest record: {df_embrace_maps_2024.index[idx_nearest]}")

# %%
result
# Out:
#                                                                 TECMAP
# DATETIME
# 2024-12-18 18:10:00  [[nan, nan, nan, nan, nan, nan, nan, nan, nan,...

# %%
embrace_maps = np.array(result.iloc[:]['TECMAP'])

# %%
np_embrace_maps = []
for i in range(len(embrace_maps)):
    np_embrace_maps.append(embrace_maps[i])
np_embrace_maps = np.array(np_embrace_maps)

# %%
np_embrace_maps
# Out:
# array([[[nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         ...,
#         [nan, 37., nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan]]])

# %%
np_embrace_maps.shape
# Out:
# (1, 41, 25)

# %%
embrace_tec.tec_map = np_embrace_maps[0]

print("=" * 60)
print("DETAILED BILINEAR INTERPOLATION ANALYSIS")
print("=" * 60)

print("\n1. THE 4 CLOSEST POINTS:")
for i, point in enumerate(embrace_points):
    lat, lon, lat_idx, lon_idx = point
    tec_value = embrace_tec.tec_map[lat_idx, lon_idx]
    print(f"   P{i+1}: ({lat:+6.1f}°, {lon:+6.1f}°) - Indexes: [{lat_idx:2d}, {lon_idx:2d}] - TEC: {tec_value:5.1f}")

target_lat = -15.94748
target_lon = -47.87787

print(f"\n2. TARGET POINT: ({target_lat:+6.5f}°, {target_lon:+6.5f}°)")

values = []
for point in embrace_points:
    lat, lon, lat_idx, lon_idx = point
    values.append(embrace_tec.tec_map[lat_idx, lon_idx])

lats = [p[0] for p in embrace_points]
lons = [p[1] for p in embrace_points]

lat_min, lat_max = min(lats), max(lats)
lon_min, lon_max = min(lons), max(lons)

print(f"\n3. INTERPOLATION RECTANGLE BOUNDS:")
print(f"   Latitude:  {lat_min:+6.1f}° to {lat_max:+6.1f}° (range: {lat_max - lat_min:4.1f}°)")
print(f"   Longitude: {lon_min:+6.1f}° to {lon_max:+6.1f}° (range: {lon_max - lon_min:4.1f}°)")

point_values = {}
for i, point in enumerate(embrace_points):
    point_values[(point[0], point[1])] = values[i]

f_00 = point_values[(lat_min, lon_min)]
f_01 = point_values[(lat_min, lon_max)]
f_10 = point_values[(lat_max, lon_min)]
f_11 = point_values[(lat_max, lon_max)]

print(f"\n4. TEC VALUES MAPPING:")
print(f"   f_00 (lat_min, lon_min) = ({lat_min:+6.1f}°, {lon_min:+6.1f}°) = {f_00:5.1f}")
print(f"   f_01 (lat_min, lon_max) = ({lat_min:+6.1f}°, {lon_max:+6.1f}°) = {f_01:5.1f}")
print(f"   f_10 (lat_max, lon_min) = ({lat_max:+6.1f}°, {lon_min:+6.1f}°) = {f_10:5.1f}")
print(f"   f_11 (lat_max, lon_max) = ({lat_max:+6.1f}°, {lon_max:+6.1f}°) = {f_11:5.1f}")

t_x = (target_lon - lon_min) / (lon_max - lon_min) if lon_max != lon_min else 0
t_y = (target_lat - lat_min) / (lat_max - lat_min) if lat_max != lat_min else 0

print(f"\n5. INTERPOLATION PARAMETERS:")
print(f"   t_x = (target_lon - lon_min) / (lon_max - lon_min)")
print(f"   t_x = ({target_lon:+6.5f} - ({lon_min:+6.1f})) / ({lon_max:+6.1f} - ({lon_min:+6.1f}))")
print(f"   t_x = {target_lon - lon_min:6.5f} / {lon_max - lon_min:4.1f} = {t_x:.6f}")
print(f"   ")
print(f"   t_y = (target_lat - lat_min) / (lat_max - lat_min)")
print(f"   t_y = ({target_lat:+6.5f} - ({lat_min:+6.1f})) / ({lat_max:+6.1f} - ({lat_min:+6.1f}))")
print(f"   t_y = {target_lat - lat_min:6.5f} / {lat_max - lat_min:4.1f} = {t_y:.6f}")

w_00 = (1 - t_x) * (1 - t_y)
w_01 = t_x * (1 - t_y)
w_10 = (1 - t_x) * t_y
w_11 = t_x * t_y

print(f"\n6. INTERPOLATION WEIGHTS:")
print(f"   w_00 = (1 - t_x) * (1 - t_y) = (1 - {t_x:.6f}) * (1 - {t_y:.6f}) = {w_00:.6f}")
print(f"   w_01 = t_x * (1 - t_y)       = {t_x:.6f} * (1 - {t_y:.6f})       = {w_01:.6f}")
print(f"   w_10 = (1 - t_x) * t_y       = (1 - {t_x:.6f}) * {t_y:.6f}       = {w_10:.6f}")
print(f"   w_11 = t_x * t_y             = {t_x:.6f} * {t_y:.6f}             = {w_11:.6f}")
print(f"   Sum of weights = {w_00 + w_01 + w_10 + w_11:.6f} (should be 1.0)")

interpolated_value = w_00 * f_00 + w_01 * f_01 + w_10 * f_10 + w_11 * f_11

print(f"\n7. FINAL CALCULATION:")
print(f"   Value = w_00*f_00 + w_01*f_01 + w_10*f_10 + w_11*f_11")
print(f"   Value = {w_00:.6f}*{f_00:5.1f} + {w_01:.6f}*{f_01:5.1f} + {w_10:.6f}*{f_10:5.1f} + {w_11:.6f}*{f_11:5.1f}")
print(f"   Value = {w_00*f_00:8.4f} + {w_01*f_01:8.4f} + {w_10*f_10:8.4f} + {w_11*f_11:8.4f}")
print(f"   Value = {interpolated_value:.6f}")

print(f"\n8. TARGET POINT RELATIVE POSITION:")
print(f"   In X direction (longitude): {t_x*100:.2f}% of the way from {lon_min}° to {lon_max}°")
print(f"   In Y direction (latitude):  {t_y*100:.2f}% of the way from {lat_min}° to {lat_max}°")

print(f"\n{'='*60}")
print(f"FINAL RESULT: TEC = {interpolated_value:.4f}")
print(f"{'='*60}")
# Out:
# ============================================================
# DETAILED BILINEAR INTERPOLATION ANALYSIS
# ============================================================
#
# 1. THE 4 CLOSEST POINTS:
#    P1: ( -16.0°,  -50.0°) - Indexes: [22, 16] - TEC:  81.0
#    P2: ( -16.0°,  -47.5°) - Indexes: [22, 17] - TEC:  83.0
#    P3: ( -14.0°,  -50.0°) - Indexes: [23, 16] - TEC:  87.0
#    P4: ( -14.0°,  -47.5°) - Indexes: [23, 17] - TEC:  79.0
#
# 2. TARGET POINT: (-15.94748°, -47.87787°)
#
# 3. INTERPOLATION RECTANGLE BOUNDS:
#    Latitude:   -16.0° to  -14.0° (range:  2.0°)
#    Longitude:  -50.0° to  -47.5° (range:  2.5°)
#
# 4. TEC VALUES MAPPING:
#    f_00 (lat_min, lon_min) = ( -16.0°,  -50.0°) =  81.0
#    f_01 (lat_min, lon_max) = ( -16.0°,  -47.5°) =  83.0
#    f_10 (lat_max, lon_min) = ( -14.0°,  -50.0°) =  87.0
#    f_11 (lat_max, lon_max) = ( -14.0°,  -47.5°) =  79.0
#
# 5. INTERPOLATION PARAMETERS:
#    t_x = (target_lon - lon_min) / (lon_max - lon_min)
#    t_x = (-47.87787 - ( -50.0)) / ( -47.5 - ( -50.0))
#    t_x = 2.12213 /  2.5 = 0.848852
#
#    t_y = (target_lat - lat_min) / (lat_max - lat_min)
#    t_y = (-15.94748 - ( -16.0)) / ( -14.0 - ( -16.0))
#    t_y = 0.05252 /  2.0 = 0.026260
#
# 6. INTERPOLATION WEIGHTS:
#    w_00 = (1 - t_x) * (1 - t_y) = (1 - 0.848852) * (1 - 0.026260) = 0.147179
#    w_01 = t_x * (1 - t_y)       = 0.848852 * (1 - 0.026260)       = 0.826561
#    w_10 = (1 - t_x) * t_y       = (1 - 0.848852) * 0.026260       = 0.003969
#    w_11 = t_x * t_y             = 0.848852 * 0.026260             = 0.022291
#    Sum of weights = 1.000000 (should be 1.0)
#
# 7. FINAL CALCULATION:
#    Value = w_00*f_00 + w_01*f_01 + w_10*f_10 + w_11*f_11
#    Value = 0.147179* 81.0 + 0.826561* 83.0 + 0.003969* 87.0 + 0.022291* 79.0
#    Value =  11.9215 +  68.6046 +   0.3453 +   1.7610
#    Value = 82.632355
#
# 8. TARGET POINT RELATIVE POSITION:
#    In X direction (longitude): 84.89% of the way from -50.0° to -47.5°
#    In Y direction (latitude):  2.63% of the way from -16° to -14°
#
# ============================================================
# FINAL RESULT: TEC = 82.6324
# ============================================================

# %% [markdown]
# ### 12/18 - 18:20

# %%
import pandas as pd

date = '2024-12-18'
time = '18:20:00'
timestamp_wanted = f'{date} {time}'

if df_embrace_maps_2024.index.name == 'DATETIME':
    result = df_embrace_maps_2024.loc[timestamp_wanted:timestamp_wanted]
else:
    if 'DATETIME' in df_embrace_maps_2024.columns:
        df_embrace_maps_2024 = df_embrace_maps_2024.set_index('DATETIME')
        result = df_embrace_maps_2024.loc[timestamp_wanted:timestamp_wanted]
    else:
        print("DATETIME column not found!")
        print("Available columns:", df_embrace_maps_2024.columns.tolist())

if result.empty:
    if not isinstance(df_embrace_maps_2024.index, pd.DatetimeIndex):
        df_embrace_maps_2024.index = pd.to_datetime(df_embrace_maps_2024.index)

    timestamp_dt = pd.to_datetime(timestamp_wanted)

    diference = abs((df_embrace_maps_2024.index - timestamp_dt).total_seconds())
    idx_nearest = diference.argmin()

    result = df_embrace_maps_2024.iloc[[idx_nearest]]
    print(f"Exact date not found. Using closest record: {df_embrace_maps_2024.index[idx_nearest]}")

# %%
result
# Out:
#                                                                 TECMAP
# DATETIME
# 2024-12-18 18:20:00  [[nan, nan, nan, nan, nan, nan, nan, nan, nan,...

# %%
embrace_maps = np.array(result.iloc[:]['TECMAP'])

# %%
np_embrace_maps = []
for i in range(len(embrace_maps)):
    np_embrace_maps.append(embrace_maps[i])
np_embrace_maps = np.array(np_embrace_maps)

# %%
np_embrace_maps
# Out:
# array([[[nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         ...,
#         [nan, 39., nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan]]])

# %%
np_embrace_maps.shape
# Out:
# (1, 41, 25)

# %%
embrace_tec.tec_map = np_embrace_maps[0]

print("=" * 60)
print("DETAILED BILINEAR INTERPOLATION ANALYSIS")
print("=" * 60)

print("\n1. THE 4 CLOSEST POINTS:")
for i, point in enumerate(embrace_points):
    lat, lon, lat_idx, lon_idx = point
    tec_value = embrace_tec.tec_map[lat_idx, lon_idx]
    print(f"   P{i+1}: ({lat:+6.1f}°, {lon:+6.1f}°) - Indexes: [{lat_idx:2d}, {lon_idx:2d}] - TEC: {tec_value:5.1f}")

target_lat = -15.94748
target_lon = -47.87787

print(f"\n2. TARGET POINT: ({target_lat:+6.5f}°, {target_lon:+6.5f}°)")

values = []
for point in embrace_points:
    lat, lon, lat_idx, lon_idx = point
    values.append(embrace_tec.tec_map[lat_idx, lon_idx])

lats = [p[0] for p in embrace_points]
lons = [p[1] for p in embrace_points]

lat_min, lat_max = min(lats), max(lats)
lon_min, lon_max = min(lons), max(lons)

print(f"\n3. INTERPOLATION RECTANGLE BOUNDS:")
print(f"   Latitude:  {lat_min:+6.1f}° to {lat_max:+6.1f}° (range: {lat_max - lat_min:4.1f}°)")
print(f"   Longitude: {lon_min:+6.1f}° to {lon_max:+6.1f}° (range: {lon_max - lon_min:4.1f}°)")

point_values = {}
for i, point in enumerate(embrace_points):
    point_values[(point[0], point[1])] = values[i]

f_00 = point_values[(lat_min, lon_min)]
f_01 = point_values[(lat_min, lon_max)]
f_10 = point_values[(lat_max, lon_min)]
f_11 = point_values[(lat_max, lon_max)]

print(f"\n4. TEC VALUES MAPPING:")
print(f"   f_00 (lat_min, lon_min) = ({lat_min:+6.1f}°, {lon_min:+6.1f}°) = {f_00:5.1f}")
print(f"   f_01 (lat_min, lon_max) = ({lat_min:+6.1f}°, {lon_max:+6.1f}°) = {f_01:5.1f}")
print(f"   f_10 (lat_max, lon_min) = ({lat_max:+6.1f}°, {lon_min:+6.1f}°) = {f_10:5.1f}")
print(f"   f_11 (lat_max, lon_max) = ({lat_max:+6.1f}°, {lon_max:+6.1f}°) = {f_11:5.1f}")

t_x = (target_lon - lon_min) / (lon_max - lon_min) if lon_max != lon_min else 0
t_y = (target_lat - lat_min) / (lat_max - lat_min) if lat_max != lat_min else 0

print(f"\n5. INTERPOLATION PARAMETERS:")
print(f"   t_x = (target_lon - lon_min) / (lon_max - lon_min)")
print(f"   t_x = ({target_lon:+6.5f} - ({lon_min:+6.1f})) / ({lon_max:+6.1f} - ({lon_min:+6.1f}))")
print(f"   t_x = {target_lon - lon_min:6.5f} / {lon_max - lon_min:4.1f} = {t_x:.6f}")
print(f"   ")
print(f"   t_y = (target_lat - lat_min) / (lat_max - lat_min)")
print(f"   t_y = ({target_lat:+6.5f} - ({lat_min:+6.1f})) / ({lat_max:+6.1f} - ({lat_min:+6.1f}))")
print(f"   t_y = {target_lat - lat_min:6.5f} / {lat_max - lat_min:4.1f} = {t_y:.6f}")

w_00 = (1 - t_x) * (1 - t_y)
w_01 = t_x * (1 - t_y)
w_10 = (1 - t_x) * t_y
w_11 = t_x * t_y

print(f"\n6. INTERPOLATION WEIGHTS:")
print(f"   w_00 = (1 - t_x) * (1 - t_y) = (1 - {t_x:.6f}) * (1 - {t_y:.6f}) = {w_00:.6f}")
print(f"   w_01 = t_x * (1 - t_y)       = {t_x:.6f} * (1 - {t_y:.6f})       = {w_01:.6f}")
print(f"   w_10 = (1 - t_x) * t_y       = (1 - {t_x:.6f}) * {t_y:.6f}       = {w_10:.6f}")
print(f"   w_11 = t_x * t_y             = {t_x:.6f} * {t_y:.6f}             = {w_11:.6f}")
print(f"   Sum of weights = {w_00 + w_01 + w_10 + w_11:.6f} (should be 1.0)")

interpolated_value = w_00 * f_00 + w_01 * f_01 + w_10 * f_10 + w_11 * f_11

print(f"\n7. FINAL CALCULATION:")
print(f"   Value = w_00*f_00 + w_01*f_01 + w_10*f_10 + w_11*f_11")
print(f"   Value = {w_00:.6f}*{f_00:5.1f} + {w_01:.6f}*{f_01:5.1f} + {w_10:.6f}*{f_10:5.1f} + {w_11:.6f}*{f_11:5.1f}")
print(f"   Value = {w_00*f_00:8.4f} + {w_01*f_01:8.4f} + {w_10*f_10:8.4f} + {w_11*f_11:8.4f}")
print(f"   Value = {interpolated_value:.6f}")

print(f"\n8. TARGET POINT RELATIVE POSITION:")
print(f"   In X direction (longitude): {t_x*100:.2f}% of the way from {lon_min}° to {lon_max}°")
print(f"   In Y direction (latitude):  {t_y*100:.2f}% of the way from {lat_min}° to {lat_max}°")

print(f"\n{'='*60}")
print(f"FINAL RESULT: TEC = {interpolated_value:.4f}")
print(f"{'='*60}")
# Out:
# ============================================================
# DETAILED BILINEAR INTERPOLATION ANALYSIS
# ============================================================
#
# 1. THE 4 CLOSEST POINTS:
#    P1: ( -16.0°,  -50.0°) - Indexes: [22, 16] - TEC:  82.0
#    P2: ( -16.0°,  -47.5°) - Indexes: [22, 17] - TEC:  87.0
#    P3: ( -14.0°,  -50.0°) - Indexes: [23, 16] - TEC:  79.0
#    P4: ( -14.0°,  -47.5°) - Indexes: [23, 17] - TEC:  82.0
#
# 2. TARGET POINT: (-15.94748°, -47.87787°)
#
# 3. INTERPOLATION RECTANGLE BOUNDS:
#    Latitude:   -16.0° to  -14.0° (range:  2.0°)
#    Longitude:  -50.0° to  -47.5° (range:  2.5°)
#
# 4. TEC VALUES MAPPING:
#    f_00 (lat_min, lon_min) = ( -16.0°,  -50.0°) =  82.0
#    f_01 (lat_min, lon_max) = ( -16.0°,  -47.5°) =  87.0
#    f_10 (lat_max, lon_min) = ( -14.0°,  -50.0°) =  79.0
#    f_11 (lat_max, lon_max) = ( -14.0°,  -47.5°) =  82.0
#
# 5. INTERPOLATION PARAMETERS:
#    t_x = (target_lon - lon_min) / (lon_max - lon_min)
#    t_x = (-47.87787 - ( -50.0)) / ( -47.5 - ( -50.0))
#    t_x = 2.12213 /  2.5 = 0.848852
#
#    t_y = (target_lat - lat_min) / (lat_max - lat_min)
#    t_y = (-15.94748 - ( -16.0)) / ( -14.0 - ( -16.0))
#    t_y = 0.05252 /  2.0 = 0.026260
#
# 6. INTERPOLATION WEIGHTS:
#    w_00 = (1 - t_x) * (1 - t_y) = (1 - 0.848852) * (1 - 0.026260) = 0.147179
#    w_01 = t_x * (1 - t_y)       = 0.848852 * (1 - 0.026260)       = 0.826561
#    w_10 = (1 - t_x) * t_y       = (1 - 0.848852) * 0.026260       = 0.003969
#    w_11 = t_x * t_y             = 0.848852 * 0.026260             = 0.022291
#    Sum of weights = 1.000000 (should be 1.0)
#
# 7. FINAL CALCULATION:
#    Value = w_00*f_00 + w_01*f_01 + w_10*f_10 + w_11*f_11
#    Value = 0.147179* 82.0 + 0.826561* 87.0 + 0.003969* 79.0 + 0.022291* 82.0
#    Value =  12.0687 +  71.9108 +   0.3136 +   1.8278
#    Value = 86.120898
#
# 8. TARGET POINT RELATIVE POSITION:
#    In X direction (longitude): 84.89% of the way from -50.0° to -47.5°
#    In Y direction (latitude):  2.63% of the way from -16° to -14°
#
# ============================================================
# FINAL RESULT: TEC = 86.1209
# ============================================================

# %% [markdown]
# ### 12/18 - 18:30

# %%
import pandas as pd

date = '2024-12-18'
time = '18:30:00'
timestamp_wanted = f'{date} {time}'

if df_embrace_maps_2024.index.name == 'DATETIME':
    result = df_embrace_maps_2024.loc[timestamp_wanted:timestamp_wanted]
else:
    if 'DATETIME' in df_embrace_maps_2024.columns:
        df_embrace_maps_2024 = df_embrace_maps_2024.set_index('DATETIME')
        result = df_embrace_maps_2024.loc[timestamp_wanted:timestamp_wanted]
    else:
        print("DATETIME column not found!")
        print("Available columns:", df_embrace_maps_2024.columns.tolist())

if result.empty:
    if not isinstance(df_embrace_maps_2024.index, pd.DatetimeIndex):
        df_embrace_maps_2024.index = pd.to_datetime(df_embrace_maps_2024.index)

    timestamp_dt = pd.to_datetime(timestamp_wanted)

    diference = abs((df_embrace_maps_2024.index - timestamp_dt).total_seconds())
    idx_nearest = diference.argmin()

    result = df_embrace_maps_2024.iloc[[idx_nearest]]
    print(f"Exact date not found. Using closest record: {df_embrace_maps_2024.index[idx_nearest]}")

# %%
result
# Out:
#                                                                 TECMAP
# DATETIME
# 2024-12-18 18:30:00  [[nan, nan, nan, nan, nan, nan, nan, nan, nan,...

# %%
embrace_maps = np.array(result.iloc[:]['TECMAP'])

# %%
np_embrace_maps = []
for i in range(len(embrace_maps)):
    np_embrace_maps.append(embrace_maps[i])
np_embrace_maps = np.array(np_embrace_maps)

# %%
np_embrace_maps
# Out:
# array([[[nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         ...,
#         [nan, 39., nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan]]])

# %%
np_embrace_maps.shape
# Out:
# (1, 41, 25)

# %%
embrace_tec.tec_map = np_embrace_maps[0]

print("=" * 60)
print("DETAILED BILINEAR INTERPOLATION ANALYSIS")
print("=" * 60)

print("\n1. THE 4 CLOSEST POINTS:")
for i, point in enumerate(embrace_points):
    lat, lon, lat_idx, lon_idx = point
    tec_value = embrace_tec.tec_map[lat_idx, lon_idx]
    print(f"   P{i+1}: ({lat:+6.1f}°, {lon:+6.1f}°) - Indexes: [{lat_idx:2d}, {lon_idx:2d}] - TEC: {tec_value:5.1f}")

target_lat = -15.94748
target_lon = -47.87787

print(f"\n2. TARGET POINT: ({target_lat:+6.5f}°, {target_lon:+6.5f}°)")

values = []
for point in embrace_points:
    lat, lon, lat_idx, lon_idx = point
    values.append(embrace_tec.tec_map[lat_idx, lon_idx])

lats = [p[0] for p in embrace_points]
lons = [p[1] for p in embrace_points]

lat_min, lat_max = min(lats), max(lats)
lon_min, lon_max = min(lons), max(lons)

print(f"\n3. INTERPOLATION RECTANGLE BOUNDS:")
print(f"   Latitude:  {lat_min:+6.1f}° to {lat_max:+6.1f}° (range: {lat_max - lat_min:4.1f}°)")
print(f"   Longitude: {lon_min:+6.1f}° to {lon_max:+6.1f}° (range: {lon_max - lon_min:4.1f}°)")

point_values = {}
for i, point in enumerate(embrace_points):
    point_values[(point[0], point[1])] = values[i]

f_00 = point_values[(lat_min, lon_min)]
f_01 = point_values[(lat_min, lon_max)]
f_10 = point_values[(lat_max, lon_min)]
f_11 = point_values[(lat_max, lon_max)]

print(f"\n4. TEC VALUES MAPPING:")
print(f"   f_00 (lat_min, lon_min) = ({lat_min:+6.1f}°, {lon_min:+6.1f}°) = {f_00:5.1f}")
print(f"   f_01 (lat_min, lon_max) = ({lat_min:+6.1f}°, {lon_max:+6.1f}°) = {f_01:5.1f}")
print(f"   f_10 (lat_max, lon_min) = ({lat_max:+6.1f}°, {lon_min:+6.1f}°) = {f_10:5.1f}")
print(f"   f_11 (lat_max, lon_max) = ({lat_max:+6.1f}°, {lon_max:+6.1f}°) = {f_11:5.1f}")

t_x = (target_lon - lon_min) / (lon_max - lon_min) if lon_max != lon_min else 0
t_y = (target_lat - lat_min) / (lat_max - lat_min) if lat_max != lat_min else 0

print(f"\n5. INTERPOLATION PARAMETERS:")
print(f"   t_x = (target_lon - lon_min) / (lon_max - lon_min)")
print(f"   t_x = ({target_lon:+6.5f} - ({lon_min:+6.1f})) / ({lon_max:+6.1f} - ({lon_min:+6.1f}))")
print(f"   t_x = {target_lon - lon_min:6.5f} / {lon_max - lon_min:4.1f} = {t_x:.6f}")
print(f"   ")
print(f"   t_y = (target_lat - lat_min) / (lat_max - lat_min)")
print(f"   t_y = ({target_lat:+6.5f} - ({lat_min:+6.1f})) / ({lat_max:+6.1f} - ({lat_min:+6.1f}))")
print(f"   t_y = {target_lat - lat_min:6.5f} / {lat_max - lat_min:4.1f} = {t_y:.6f}")

w_00 = (1 - t_x) * (1 - t_y)
w_01 = t_x * (1 - t_y)
w_10 = (1 - t_x) * t_y
w_11 = t_x * t_y

print(f"\n6. INTERPOLATION WEIGHTS:")
print(f"   w_00 = (1 - t_x) * (1 - t_y) = (1 - {t_x:.6f}) * (1 - {t_y:.6f}) = {w_00:.6f}")
print(f"   w_01 = t_x * (1 - t_y)       = {t_x:.6f} * (1 - {t_y:.6f})       = {w_01:.6f}")
print(f"   w_10 = (1 - t_x) * t_y       = (1 - {t_x:.6f}) * {t_y:.6f}       = {w_10:.6f}")
print(f"   w_11 = t_x * t_y             = {t_x:.6f} * {t_y:.6f}             = {w_11:.6f}")
print(f"   Sum of weights = {w_00 + w_01 + w_10 + w_11:.6f} (should be 1.0)")

interpolated_value = w_00 * f_00 + w_01 * f_01 + w_10 * f_10 + w_11 * f_11

print(f"\n7. FINAL CALCULATION:")
print(f"   Value = w_00*f_00 + w_01*f_01 + w_10*f_10 + w_11*f_11")
print(f"   Value = {w_00:.6f}*{f_00:5.1f} + {w_01:.6f}*{f_01:5.1f} + {w_10:.6f}*{f_10:5.1f} + {w_11:.6f}*{f_11:5.1f}")
print(f"   Value = {w_00*f_00:8.4f} + {w_01*f_01:8.4f} + {w_10*f_10:8.4f} + {w_11*f_11:8.4f}")
print(f"   Value = {interpolated_value:.6f}")

print(f"\n8. TARGET POINT RELATIVE POSITION:")
print(f"   In X direction (longitude): {t_x*100:.2f}% of the way from {lon_min}° to {lon_max}°")
print(f"   In Y direction (latitude):  {t_y*100:.2f}% of the way from {lat_min}° to {lat_max}°")

print(f"\n{'='*60}")
print(f"FINAL RESULT: TEC = {interpolated_value:.4f}")
print(f"{'='*60}")
# Out:
# ============================================================
# DETAILED BILINEAR INTERPOLATION ANALYSIS
# ============================================================
#
# 1. THE 4 CLOSEST POINTS:
#    P1: ( -16.0°,  -50.0°) - Indexes: [22, 16] - TEC:  81.0
#    P2: ( -16.0°,  -47.5°) - Indexes: [22, 17] - TEC:  91.0
#    P3: ( -14.0°,  -50.0°) - Indexes: [23, 16] - TEC:  79.0
#    P4: ( -14.0°,  -47.5°) - Indexes: [23, 17] - TEC:  81.0
#
# 2. TARGET POINT: (-15.94748°, -47.87787°)
#
# 3. INTERPOLATION RECTANGLE BOUNDS:
#    Latitude:   -16.0° to  -14.0° (range:  2.0°)
#    Longitude:  -50.0° to  -47.5° (range:  2.5°)
#
# 4. TEC VALUES MAPPING:
#    f_00 (lat_min, lon_min) = ( -16.0°,  -50.0°) =  81.0
#    f_01 (lat_min, lon_max) = ( -16.0°,  -47.5°) =  91.0
#    f_10 (lat_max, lon_min) = ( -14.0°,  -50.0°) =  79.0
#    f_11 (lat_max, lon_max) = ( -14.0°,  -47.5°) =  81.0
#
# 5. INTERPOLATION PARAMETERS:
#    t_x = (target_lon - lon_min) / (lon_max - lon_min)
#    t_x = (-47.87787 - ( -50.0)) / ( -47.5 - ( -50.0))
#    t_x = 2.12213 /  2.5 = 0.848852
#
#    t_y = (target_lat - lat_min) / (lat_max - lat_min)
#    t_y = (-15.94748 - ( -16.0)) / ( -14.0 - ( -16.0))
#    t_y = 0.05252 /  2.0 = 0.026260
#
# 6. INTERPOLATION WEIGHTS:
#    w_00 = (1 - t_x) * (1 - t_y) = (1 - 0.848852) * (1 - 0.026260) = 0.147179
#    w_01 = t_x * (1 - t_y)       = 0.848852 * (1 - 0.026260)       = 0.826561
#    w_10 = (1 - t_x) * t_y       = (1 - 0.848852) * 0.026260       = 0.003969
#    w_11 = t_x * t_y             = 0.848852 * 0.026260             = 0.022291
#    Sum of weights = 1.000000 (should be 1.0)
#
# 7. FINAL CALCULATION:
#    Value = w_00*f_00 + w_01*f_01 + w_10*f_10 + w_11*f_11
#    Value = 0.147179* 81.0 + 0.826561* 91.0 + 0.003969* 79.0 + 0.022291* 81.0
#    Value =  11.9215 +  75.2171 +   0.3136 +   1.8056
#    Value = 89.257673
#
# 8. TARGET POINT RELATIVE POSITION:
#    In X direction (longitude): 84.89% of the way from -50.0° to -47.5°
#    In Y direction (latitude):  2.63% of the way from -16° to -14°
#
# ============================================================
# FINAL RESULT: TEC = 89.2577
# ============================================================

# %% [markdown]
# ### 12/19 - 18:00

# %%
import pandas as pd

date = '2024-12-19'
time = '18:00:00'
timestamp_wanted = f'{date} {time}'

if df_embrace_maps_2024.index.name == 'DATETIME':
    result = df_embrace_maps_2024.loc[timestamp_wanted:timestamp_wanted]
else:
    if 'DATETIME' in df_embrace_maps_2024.columns:
        df_embrace_maps_2024 = df_embrace_maps_2024.set_index('DATETIME')
        result = df_embrace_maps_2024.loc[timestamp_wanted:timestamp_wanted]
    else:
        print("DATETIME column not found!")
        print("Available columns:", df_embrace_maps_2024.columns.tolist())

if result.empty:
    if not isinstance(df_embrace_maps_2024.index, pd.DatetimeIndex):
        df_embrace_maps_2024.index = pd.to_datetime(df_embrace_maps_2024.index)

    timestamp_dt = pd.to_datetime(timestamp_wanted)

    diference = abs((df_embrace_maps_2024.index - timestamp_dt).total_seconds())
    idx_nearest = diference.argmin()

    result = df_embrace_maps_2024.iloc[[idx_nearest]]
    print(f"Exact date not found. Using closest record: {df_embrace_maps_2024.index[idx_nearest]}")

# %%
result
# Out:
#                                                                 TECMAP
# DATETIME
# 2024-12-19 18:00:00  [[nan, nan, nan, nan, nan, nan, nan, nan, nan,...

# %%
embrace_maps = np.array(result.iloc[:]['TECMAP'])

# %%
np_embrace_maps = []
for i in range(len(embrace_maps)):
    np_embrace_maps.append(embrace_maps[i])
np_embrace_maps = np.array(np_embrace_maps)

# %%
np_embrace_maps
# Out:
# array([[[nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         ...,
#         [nan, 41., nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan]]])

# %%
np_embrace_maps.shape
# Out:
# (1, 41, 25)

# %%
embrace_tec.tec_map = np_embrace_maps[0]

print("=" * 60)
print("DETAILED BILINEAR INTERPOLATION ANALYSIS")
print("=" * 60)

print("\n1. THE 4 CLOSEST POINTS:")
for i, point in enumerate(embrace_points):
    lat, lon, lat_idx, lon_idx = point
    tec_value = embrace_tec.tec_map[lat_idx, lon_idx]
    print(f"   P{i+1}: ({lat:+6.1f}°, {lon:+6.1f}°) - Indexes: [{lat_idx:2d}, {lon_idx:2d}] - TEC: {tec_value:5.1f}")

target_lat = -15.94748
target_lon = -47.87787

print(f"\n2. TARGET POINT: ({target_lat:+6.5f}°, {target_lon:+6.5f}°)")

values = []
for point in embrace_points:
    lat, lon, lat_idx, lon_idx = point
    values.append(embrace_tec.tec_map[lat_idx, lon_idx])

lats = [p[0] for p in embrace_points]
lons = [p[1] for p in embrace_points]

lat_min, lat_max = min(lats), max(lats)
lon_min, lon_max = min(lons), max(lons)

print(f"\n3. INTERPOLATION RECTANGLE BOUNDS:")
print(f"   Latitude:  {lat_min:+6.1f}° to {lat_max:+6.1f}° (range: {lat_max - lat_min:4.1f}°)")
print(f"   Longitude: {lon_min:+6.1f}° to {lon_max:+6.1f}° (range: {lon_max - lon_min:4.1f}°)")

point_values = {}
for i, point in enumerate(embrace_points):
    point_values[(point[0], point[1])] = values[i]

f_00 = point_values[(lat_min, lon_min)]
f_01 = point_values[(lat_min, lon_max)]
f_10 = point_values[(lat_max, lon_min)]
f_11 = point_values[(lat_max, lon_max)]

print(f"\n4. TEC VALUES MAPPING:")
print(f"   f_00 (lat_min, lon_min) = ({lat_min:+6.1f}°, {lon_min:+6.1f}°) = {f_00:5.1f}")
print(f"   f_01 (lat_min, lon_max) = ({lat_min:+6.1f}°, {lon_max:+6.1f}°) = {f_01:5.1f}")
print(f"   f_10 (lat_max, lon_min) = ({lat_max:+6.1f}°, {lon_min:+6.1f}°) = {f_10:5.1f}")
print(f"   f_11 (lat_max, lon_max) = ({lat_max:+6.1f}°, {lon_max:+6.1f}°) = {f_11:5.1f}")

t_x = (target_lon - lon_min) / (lon_max - lon_min) if lon_max != lon_min else 0
t_y = (target_lat - lat_min) / (lat_max - lat_min) if lat_max != lat_min else 0

print(f"\n5. INTERPOLATION PARAMETERS:")
print(f"   t_x = (target_lon - lon_min) / (lon_max - lon_min)")
print(f"   t_x = ({target_lon:+6.5f} - ({lon_min:+6.1f})) / ({lon_max:+6.1f} - ({lon_min:+6.1f}))")
print(f"   t_x = {target_lon - lon_min:6.5f} / {lon_max - lon_min:4.1f} = {t_x:.6f}")
print(f"   ")
print(f"   t_y = (target_lat - lat_min) / (lat_max - lat_min)")
print(f"   t_y = ({target_lat:+6.5f} - ({lat_min:+6.1f})) / ({lat_max:+6.1f} - ({lat_min:+6.1f}))")
print(f"   t_y = {target_lat - lat_min:6.5f} / {lat_max - lat_min:4.1f} = {t_y:.6f}")

w_00 = (1 - t_x) * (1 - t_y)
w_01 = t_x * (1 - t_y)
w_10 = (1 - t_x) * t_y
w_11 = t_x * t_y

print(f"\n6. INTERPOLATION WEIGHTS:")
print(f"   w_00 = (1 - t_x) * (1 - t_y) = (1 - {t_x:.6f}) * (1 - {t_y:.6f}) = {w_00:.6f}")
print(f"   w_01 = t_x * (1 - t_y)       = {t_x:.6f} * (1 - {t_y:.6f})       = {w_01:.6f}")
print(f"   w_10 = (1 - t_x) * t_y       = (1 - {t_x:.6f}) * {t_y:.6f}       = {w_10:.6f}")
print(f"   w_11 = t_x * t_y             = {t_x:.6f} * {t_y:.6f}             = {w_11:.6f}")
print(f"   Sum of weights = {w_00 + w_01 + w_10 + w_11:.6f} (should be 1.0)")

interpolated_value = w_00 * f_00 + w_01 * f_01 + w_10 * f_10 + w_11 * f_11

print(f"\n7. FINAL CALCULATION:")
print(f"   Value = w_00*f_00 + w_01*f_01 + w_10*f_10 + w_11*f_11")
print(f"   Value = {w_00:.6f}*{f_00:5.1f} + {w_01:.6f}*{f_01:5.1f} + {w_10:.6f}*{f_10:5.1f} + {w_11:.6f}*{f_11:5.1f}")
print(f"   Value = {w_00*f_00:8.4f} + {w_01*f_01:8.4f} + {w_10*f_10:8.4f} + {w_11*f_11:8.4f}")
print(f"   Value = {interpolated_value:.6f}")

print(f"\n8. TARGET POINT RELATIVE POSITION:")
print(f"   In X direction (longitude): {t_x*100:.2f}% of the way from {lon_min}° to {lon_max}°")
print(f"   In Y direction (latitude):  {t_y*100:.2f}% of the way from {lat_min}° to {lat_max}°")

print(f"\n{'='*60}")
print(f"FINAL RESULT: TEC = {interpolated_value:.4f}")
print(f"{'='*60}")
# Out:
# ============================================================
# DETAILED BILINEAR INTERPOLATION ANALYSIS
# ============================================================
#
# 1. THE 4 CLOSEST POINTS:
#    P1: ( -16.0°,  -50.0°) - Indexes: [22, 16] - TEC:  55.0
#    P2: ( -16.0°,  -47.5°) - Indexes: [22, 17] - TEC:  62.0
#    P3: ( -14.0°,  -50.0°) - Indexes: [23, 16] - TEC:  62.0
#    P4: ( -14.0°,  -47.5°) - Indexes: [23, 17] - TEC:  64.0
#
# 2. TARGET POINT: (-15.94748°, -47.87787°)
#
# 3. INTERPOLATION RECTANGLE BOUNDS:
#    Latitude:   -16.0° to  -14.0° (range:  2.0°)
#    Longitude:  -50.0° to  -47.5° (range:  2.5°)
#
# 4. TEC VALUES MAPPING:
#    f_00 (lat_min, lon_min) = ( -16.0°,  -50.0°) =  55.0
#    f_01 (lat_min, lon_max) = ( -16.0°,  -47.5°) =  62.0
#    f_10 (lat_max, lon_min) = ( -14.0°,  -50.0°) =  62.0
#    f_11 (lat_max, lon_max) = ( -14.0°,  -47.5°) =  64.0
#
# 5. INTERPOLATION PARAMETERS:
#    t_x = (target_lon - lon_min) / (lon_max - lon_min)
#    t_x = (-47.87787 - ( -50.0)) / ( -47.5 - ( -50.0))
#    t_x = 2.12213 /  2.5 = 0.848852
#
#    t_y = (target_lat - lat_min) / (lat_max - lat_min)
#    t_y = (-15.94748 - ( -16.0)) / ( -14.0 - ( -16.0))
#    t_y = 0.05252 /  2.0 = 0.026260
#
# 6. INTERPOLATION WEIGHTS:
#    w_00 = (1 - t_x) * (1 - t_y) = (1 - 0.848852) * (1 - 0.026260) = 0.147179
#    w_01 = t_x * (1 - t_y)       = 0.848852 * (1 - 0.026260)       = 0.826561
#    w_10 = (1 - t_x) * t_y       = (1 - 0.848852) * 0.026260       = 0.003969
#    w_11 = t_x * t_y             = 0.848852 * 0.026260             = 0.022291
#    Sum of weights = 1.000000 (should be 1.0)
#
# 7. FINAL CALCULATION:
#    Value = w_00*f_00 + w_01*f_01 + w_10*f_10 + w_11*f_11
#    Value = 0.147179* 55.0 + 0.826561* 62.0 + 0.003969* 62.0 + 0.022291* 64.0
#    Value =   8.0948 +  51.2468 +   0.2461 +   1.4266
#    Value = 61.014330
#
# 8. TARGET POINT RELATIVE POSITION:
#    In X direction (longitude): 84.89% of the way from -50.0° to -47.5°
#    In Y direction (latitude):  2.63% of the way from -16° to -14°
#
# ============================================================
# FINAL RESULT: TEC = 61.0143
# ============================================================

# %% [markdown]
# ### 12/22 - 18:00

# %%
import pandas as pd

date = '2024-12-22'
time = '18:00:00'
timestamp_wanted = f'{date} {time}'

if df_embrace_maps_2024.index.name == 'DATETIME':
    result = df_embrace_maps_2024.loc[timestamp_wanted:timestamp_wanted]
else:
    if 'DATETIME' in df_embrace_maps_2024.columns:
        df_embrace_maps_2024 = df_embrace_maps_2024.set_index('DATETIME')
        result = df_embrace_maps_2024.loc[timestamp_wanted:timestamp_wanted]
    else:
        print("DATETIME column not found!")
        print("Available columns:", df_embrace_maps_2024.columns.tolist())

if result.empty:
    if not isinstance(df_embrace_maps_2024.index, pd.DatetimeIndex):
        df_embrace_maps_2024.index = pd.to_datetime(df_embrace_maps_2024.index)

    timestamp_dt = pd.to_datetime(timestamp_wanted)

    diference = abs((df_embrace_maps_2024.index - timestamp_dt).total_seconds())
    idx_nearest = diference.argmin()

    result = df_embrace_maps_2024.iloc[[idx_nearest]]
    print(f"Exact date not found. Using closest record: {df_embrace_maps_2024.index[idx_nearest]}")

# %%
result
# Out:
#                                                                 TECMAP
# DATETIME
# 2024-12-22 18:00:00  [[nan, nan, nan, nan, nan, nan, nan, nan, nan,...

# %%
embrace_maps = np.array(result.iloc[:]['TECMAP'])

# %%
np_embrace_maps = []
for i in range(len(embrace_maps)):
    np_embrace_maps.append(embrace_maps[i])
np_embrace_maps = np.array(np_embrace_maps)

# %%
np_embrace_maps
# Out:
# array([[[nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         ...,
#         [nan, 52., nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan]]])

# %%
np_embrace_maps.shape
# Out:
# (1, 41, 25)

# %%
embrace_tec.tec_map = np_embrace_maps[0]

print("=" * 60)
print("DETAILED BILINEAR INTERPOLATION ANALYSIS")
print("=" * 60)

print("\n1. THE 4 CLOSEST POINTS:")
for i, point in enumerate(embrace_points):
    lat, lon, lat_idx, lon_idx = point
    tec_value = embrace_tec.tec_map[lat_idx, lon_idx]
    print(f"   P{i+1}: ({lat:+6.1f}°, {lon:+6.1f}°) - Indexes: [{lat_idx:2d}, {lon_idx:2d}] - TEC: {tec_value:5.1f}")

target_lat = -15.94748
target_lon = -47.87787

print(f"\n2. TARGET POINT: ({target_lat:+6.5f}°, {target_lon:+6.5f}°)")

values = []
for point in embrace_points:
    lat, lon, lat_idx, lon_idx = point
    values.append(embrace_tec.tec_map[lat_idx, lon_idx])

lats = [p[0] for p in embrace_points]
lons = [p[1] for p in embrace_points]

lat_min, lat_max = min(lats), max(lats)
lon_min, lon_max = min(lons), max(lons)

print(f"\n3. INTERPOLATION RECTANGLE BOUNDS:")
print(f"   Latitude:  {lat_min:+6.1f}° to {lat_max:+6.1f}° (range: {lat_max - lat_min:4.1f}°)")
print(f"   Longitude: {lon_min:+6.1f}° to {lon_max:+6.1f}° (range: {lon_max - lon_min:4.1f}°)")

point_values = {}
for i, point in enumerate(embrace_points):
    point_values[(point[0], point[1])] = values[i]

f_00 = point_values[(lat_min, lon_min)]
f_01 = point_values[(lat_min, lon_max)]
f_10 = point_values[(lat_max, lon_min)]
f_11 = point_values[(lat_max, lon_max)]

print(f"\n4. TEC VALUES MAPPING:")
print(f"   f_00 (lat_min, lon_min) = ({lat_min:+6.1f}°, {lon_min:+6.1f}°) = {f_00:5.1f}")
print(f"   f_01 (lat_min, lon_max) = ({lat_min:+6.1f}°, {lon_max:+6.1f}°) = {f_01:5.1f}")
print(f"   f_10 (lat_max, lon_min) = ({lat_max:+6.1f}°, {lon_min:+6.1f}°) = {f_10:5.1f}")
print(f"   f_11 (lat_max, lon_max) = ({lat_max:+6.1f}°, {lon_max:+6.1f}°) = {f_11:5.1f}")

t_x = (target_lon - lon_min) / (lon_max - lon_min) if lon_max != lon_min else 0
t_y = (target_lat - lat_min) / (lat_max - lat_min) if lat_max != lat_min else 0

print(f"\n5. INTERPOLATION PARAMETERS:")
print(f"   t_x = (target_lon - lon_min) / (lon_max - lon_min)")
print(f"   t_x = ({target_lon:+6.5f} - ({lon_min:+6.1f})) / ({lon_max:+6.1f} - ({lon_min:+6.1f}))")
print(f"   t_x = {target_lon - lon_min:6.5f} / {lon_max - lon_min:4.1f} = {t_x:.6f}")
print(f"   ")
print(f"   t_y = (target_lat - lat_min) / (lat_max - lat_min)")
print(f"   t_y = ({target_lat:+6.5f} - ({lat_min:+6.1f})) / ({lat_max:+6.1f} - ({lat_min:+6.1f}))")
print(f"   t_y = {target_lat - lat_min:6.5f} / {lat_max - lat_min:4.1f} = {t_y:.6f}")

w_00 = (1 - t_x) * (1 - t_y)
w_01 = t_x * (1 - t_y)
w_10 = (1 - t_x) * t_y
w_11 = t_x * t_y

print(f"\n6. INTERPOLATION WEIGHTS:")
print(f"   w_00 = (1 - t_x) * (1 - t_y) = (1 - {t_x:.6f}) * (1 - {t_y:.6f}) = {w_00:.6f}")
print(f"   w_01 = t_x * (1 - t_y)       = {t_x:.6f} * (1 - {t_y:.6f})       = {w_01:.6f}")
print(f"   w_10 = (1 - t_x) * t_y       = (1 - {t_x:.6f}) * {t_y:.6f}       = {w_10:.6f}")
print(f"   w_11 = t_x * t_y             = {t_x:.6f} * {t_y:.6f}             = {w_11:.6f}")
print(f"   Sum of weights = {w_00 + w_01 + w_10 + w_11:.6f} (should be 1.0)")

interpolated_value = w_00 * f_00 + w_01 * f_01 + w_10 * f_10 + w_11 * f_11

print(f"\n7. FINAL CALCULATION:")
print(f"   Value = w_00*f_00 + w_01*f_01 + w_10*f_10 + w_11*f_11")
print(f"   Value = {w_00:.6f}*{f_00:5.1f} + {w_01:.6f}*{f_01:5.1f} + {w_10:.6f}*{f_10:5.1f} + {w_11:.6f}*{f_11:5.1f}")
print(f"   Value = {w_00*f_00:8.4f} + {w_01*f_01:8.4f} + {w_10*f_10:8.4f} + {w_11*f_11:8.4f}")
print(f"   Value = {interpolated_value:.6f}")

print(f"\n8. TARGET POINT RELATIVE POSITION:")
print(f"   In X direction (longitude): {t_x*100:.2f}% of the way from {lon_min}° to {lon_max}°")
print(f"   In Y direction (latitude):  {t_y*100:.2f}% of the way from {lat_min}° to {lat_max}°")

print(f"\n{'='*60}")
print(f"FINAL RESULT: TEC = {interpolated_value:.4f}")
print(f"{'='*60}")
# Out:
# ============================================================
# DETAILED BILINEAR INTERPOLATION ANALYSIS
# ============================================================
#
# 1. THE 4 CLOSEST POINTS:
#    P1: ( -16.0°,  -50.0°) - Indexes: [22, 16] - TEC:  76.0
#    P2: ( -16.0°,  -47.5°) - Indexes: [22, 17] - TEC:  77.0
#    P3: ( -14.0°,  -50.0°) - Indexes: [23, 16] - TEC:  74.0
#    P4: ( -14.0°,  -47.5°) - Indexes: [23, 17] - TEC:  80.0
#
# 2. TARGET POINT: (-15.94748°, -47.87787°)
#
# 3. INTERPOLATION RECTANGLE BOUNDS:
#    Latitude:   -16.0° to  -14.0° (range:  2.0°)
#    Longitude:  -50.0° to  -47.5° (range:  2.5°)
#
# 4. TEC VALUES MAPPING:
#    f_00 (lat_min, lon_min) = ( -16.0°,  -50.0°) =  76.0
#    f_01 (lat_min, lon_max) = ( -16.0°,  -47.5°) =  77.0
#    f_10 (lat_max, lon_min) = ( -14.0°,  -50.0°) =  74.0
#    f_11 (lat_max, lon_max) = ( -14.0°,  -47.5°) =  80.0
#
# 5. INTERPOLATION PARAMETERS:
#    t_x = (target_lon - lon_min) / (lon_max - lon_min)
#    t_x = (-47.87787 - ( -50.0)) / ( -47.5 - ( -50.0))
#    t_x = 2.12213 /  2.5 = 0.848852
#
#    t_y = (target_lat - lat_min) / (lat_max - lat_min)
#    t_y = (-15.94748 - ( -16.0)) / ( -14.0 - ( -16.0))
#    t_y = 0.05252 /  2.0 = 0.026260
#
# 6. INTERPOLATION WEIGHTS:
#    w_00 = (1 - t_x) * (1 - t_y) = (1 - 0.848852) * (1 - 0.026260) = 0.147179
#    w_01 = t_x * (1 - t_y)       = 0.848852 * (1 - 0.026260)       = 0.826561
#    w_10 = (1 - t_x) * t_y       = (1 - 0.848852) * 0.026260       = 0.003969
#    w_11 = t_x * t_y             = 0.848852 * 0.026260             = 0.022291
#    Sum of weights = 1.000000 (should be 1.0)
#
# 7. FINAL CALCULATION:
#    Value = w_00*f_00 + w_01*f_01 + w_10*f_10 + w_11*f_11
#    Value = 0.147179* 76.0 + 0.826561* 77.0 + 0.003969* 74.0 + 0.022291* 80.0
#    Value =  11.1856 +  63.6452 +   0.2937 +   1.7833
#    Value = 76.907786
#
# 8. TARGET POINT RELATIVE POSITION:
#    In X direction (longitude): 84.89% of the way from -50.0° to -47.5°
#    In Y direction (latitude):  2.63% of the way from -16° to -14°
#
# ============================================================
# FINAL RESULT: TEC = 76.9078
# ============================================================

# %% [markdown]
# ## IGS

# %%
import pandas as pd
import numpy as np

# %%
#Download TF_IGS_TEC_maps_intersection_case_study_Dec_2024.pkl from https://doi.org/10.5281/zenodo.15453941

# %%
# !gdown '1T0gBaH6IyIX72T1VPJuZa2D43HCrRFVp'
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1T0gBaH6IyIX72T1VPJuZa2D43HCrRFVp
# To: /content/TF_IGS_TEC_maps_intersection_case_study_Dec_2024.pkl
# 100% 3.60M/3.60M [00:00<00:00, 182MB/s]

# %%
df_igs_maps_2024 = pd.read_pickle('/content/TF_IGS_TEC_maps_intersection_case_study_Dec_2024.pkl')

# %%
df_igs_maps_2024
# Out:
#                DATETIME                                             TECMAP
# 0   2024-12-01 00:00:00  [[37.7, 34.6, 31.9, 30.0, 28.6, 27.2, 25.8, 24...
# 1   2024-12-01 02:00:00  [[20.3, 18.7, 18.1, 18.2, 18.2, 18.1, 17.7, 17...
# 2   2024-12-01 04:00:00  [[11.6, 11.8, 12.0, 12.4, 13.0, 13.5, 14.0, 14...
# 3   2024-12-01 06:00:00  [[10.4, 10.8, 11.1, 11.7, 12.1, 12.7, 13.3, 13...
# 4   2024-12-01 08:00:00  [[9.9, 10.1, 10.3, 10.6, 11.0, 11.6, 12.3, 13....
# ..                  ...                                                ...
# 343 2024-12-30 14:00:00  [[8.9, 11.1, 14.4, 18.8, 23.7, 28.3, 32.7, 36....
# 344 2024-12-30 16:00:00  [[26.3, 29.8, 33.4, 37.1, 40.5, 43.7, 47.0, 49...
# 345 2024-12-30 18:00:00  [[43.5, 44.5, 45.3, 46.2, 47.1, 48.6, 50.0, 51...
# 346 2024-12-30 20:00:00  [[48.8, 49.1, 49.0, 48.7, 48.5, 48.1, 48.0, 47...
# 347 2024-12-30 22:00:00  [[47.0, 46.6, 45.6, 44.4, 43.2, 42.0, 40.4, 38...
#
# [348 rows x 2 columns]

# %%
class Igs(TecMap):
    def __init__(self,
                 extent: Iterable[float] = (-110, 0, -80, 40),  # (lon_min, lon_max, lat_min_geo, lat_max_geo)
                 lat_step: float = 2.5,
                 lon_step: float = 5):
        """
        IGS TEC Map - Specific implementation for IGS data structure.

        IMPORTANT: IGS arrays are organized North to South:
        - Array[0, :] contains the NORTHERNMOST latitudes (+40°)
        - Array[-1, :] contains the SOUTHERNMOST latitudes (-80°)

        The extent parameter follows GEOGRAPHIC convention:
        - extent = (lon_min, lon_max, lat_min_geographic, lat_max_geographic)
        - lat_min_geographic = -80° (southernmost point)
        - lat_max_geographic = +40° (northernmost point)

        This differs from array indexing where Array[0] = +40° (North).
        The find_nearest_points method handles this coordinate conversion.
        """
        super().__init__(extent, lat_step, lon_step)

    def find_nearest_points(self, lat: float, lon: float):

        lon_min, lon_max, lat_min, lat_max = self.extent
        lat_step, lon_step = self.lat_step, self.lon_step

        lat_idx_lower = int((lat_max - lat) / lat_step)
        lat_idx_upper = lat_idx_lower + 1

        lat_idx_lower = max(0, min(lat_idx_lower, self.grid_shape[0] - 1))
        lat_idx_upper = max(0, min(lat_idx_upper, self.grid_shape[0] - 1))

        lon_idx_lower = int((lon - lon_min) / lon_step)
        lon_idx_upper = lon_idx_lower + 1

        lon_idx_lower = max(0, min(lon_idx_lower, self.grid_shape[1] - 1))
        lon_idx_upper = max(0, min(lon_idx_upper, self.grid_shape[1] - 1))

        lat_lower = lat_max - lat_idx_lower * lat_step
        lat_upper = lat_max - lat_idx_upper * lat_step
        lon_lower = lon_min + lon_idx_lower * lon_step
        lon_upper = lon_min + lon_idx_upper * lon_step

        points = []

        if lat_idx_lower != lat_idx_upper and lon_idx_lower != lon_idx_upper:
            points = [
                (lat_lower, lon_lower, lat_idx_lower, lon_idx_lower),
                (lat_lower, lon_upper, lat_idx_lower, lon_idx_upper),
                (lat_upper, lon_lower, lat_idx_upper, lon_idx_lower),
                (lat_upper, lon_upper, lat_idx_upper, lon_idx_upper)
            ]
        elif lat_idx_lower != lat_idx_upper:
            points = [
                (lat_lower, lon_lower, lat_idx_lower, lon_idx_lower),
                (lat_upper, lon_lower, lat_idx_upper, lon_idx_lower)
            ]
        elif lon_idx_lower != lon_idx_upper:
            points = [
                (lat_lower, lon_lower, lat_idx_lower, lon_idx_lower),
                (lat_lower, lon_upper, lat_idx_lower, lon_idx_upper)
            ]
        else:
            points = [(lat_lower, lon_lower, lat_idx_lower, lon_idx_lower)]

        return points

# %%
igs_tec = Igs()
igs_points = igs_tec.find_nearest_points(lat=-15.94748, lon=-47.87787)

# %%
igs_points
# Out:
# [(-15.0, -50, 22, 12),
#  (-15.0, -45, 22, 13),
#  (-17.5, -50, 23, 12),
#  (-17.5, -45, 23, 13)]

# %% [markdown]
# ### 12/01 - 18:00

# %%
import pandas as pd

date = '2024-12-01'
time = '18:00:00'
timestamp_wanted = f'{date} {time}'

result = df_igs_maps_2024[df_igs_maps_2024['DATETIME'] == timestamp_wanted]

if result.empty:
    df_temp = df_igs_maps_2024.copy()
    df_temp['DATETIME'] = pd.to_datetime(df_temp['DATETIME'])
    timestamp_dt = pd.to_datetime(timestamp_wanted)

    df_temp['diff'] = abs((df_temp['DATETIME'] - timestamp_dt).dt.total_seconds())
    idx_nearest = df_temp['diff'].idxmin()

    result = df_igs_maps_2024.iloc[[idx_nearest]]
    print(f"Exact date not found. Using closest record: {df_igs_maps_2024.iloc[idx_nearest]['DATETIME']}")

# %%
result
# Out:
#              DATETIME                                             TECMAP
# 9 2024-12-01 18:00:00  [[50.5, 53.3, 54.8, 55.0, 54.6, 54.1, 54.0, 54...

# %%
igs_maps = np.array(result.iloc[:]['TECMAP'])

# %%
np_igs_maps = []
for i in range(len(igs_maps)):
    np_igs_maps.append(igs_maps[i])
np_igs_maps = np.array(np_igs_maps)

# %%
np_igs_maps
# Out:
# array([[[50.5, 53.3, 54.8, ..., 26.7, 24.5, 22.9],
#         [50.2, 52.6, 54.1, ..., 30.3, 28.1, 26.2],
#         [50.4, 52.2, 53.4, ..., 36.6, 34. , 31.8],
#         ...,
#         [30.4, 30.4, 30.2, ..., 23.1, 22.6, 22. ],
#         [30.3, 30.3, 30.1, ..., 23.2, 22.9, 22.5],
#         [29.4, 29.3, 29.2, ..., 23.3, 23.1, 22.8]]])

# %%
np_igs_maps.shape
# Out:
# (1, 49, 23)

# %%
igs_tec.tec_map = np_igs_maps[0]

print("=" * 60)
print("DETAILED BILINEAR INTERPOLATION ANALYSIS")
print("=" * 60)

print("\n1. THE 4 CLOSEST POINTS:")
for i, point in enumerate(igs_points):
    lat, lon, lat_idx, lon_idx = point
    tec_value = igs_tec.tec_map[lat_idx, lon_idx]
    print(f"   P{i+1}: ({lat:+6.1f}°, {lon:+6.1f}°) - Indexes: [{lat_idx:2d}, {lon_idx:2d}] - TEC: {tec_value:5.1f}")

target_lat = -15.94748
target_lon = -47.87787

print(f"\n2. TARGET POINT: ({target_lat:+6.5f}°, {target_lon:+6.5f}°)")

values = []
for point in igs_points:
    lat, lon, lat_idx, lon_idx = point
    values.append(igs_tec.tec_map[lat_idx, lon_idx])

lats = [p[0] for p in igs_points]
lons = [p[1] for p in igs_points]

lat_min, lat_max = min(lats), max(lats)
lon_min, lon_max = min(lons), max(lons)

print(f"\n3. INTERPOLATION RECTANGLE BOUNDS:")
print(f"   Latitude:  {lat_min:+6.1f}° to {lat_max:+6.1f}° (range: {lat_max - lat_min:4.1f}°)")
print(f"   Longitude: {lon_min:+6.1f}° to {lon_max:+6.1f}° (range: {lon_max - lon_min:4.1f}°)")

point_values = {}
for i, point in enumerate(igs_points):
    point_values[(point[0], point[1])] = values[i]

f_00 = point_values[(lat_min, lon_min)]
f_01 = point_values[(lat_min, lon_max)]
f_10 = point_values[(lat_max, lon_min)]
f_11 = point_values[(lat_max, lon_max)]

print(f"\n4. TEC VALUES MAPPING:")
print(f"   f_00 (lat_min, lon_min) = ({lat_min:+6.1f}°, {lon_min:+6.1f}°) = {f_00:5.1f}")
print(f"   f_01 (lat_min, lon_max) = ({lat_min:+6.1f}°, {lon_max:+6.1f}°) = {f_01:5.1f}")
print(f"   f_10 (lat_max, lon_min) = ({lat_max:+6.1f}°, {lon_min:+6.1f}°) = {f_10:5.1f}")
print(f"   f_11 (lat_max, lon_max) = ({lat_max:+6.1f}°, {lon_max:+6.1f}°) = {f_11:5.1f}")

t_x = (target_lon - lon_min) / (lon_max - lon_min) if lon_max != lon_min else 0
t_y = (target_lat - lat_min) / (lat_max - lat_min) if lat_max != lat_min else 0

print(f"\n5. INTERPOLATION PARAMETERS:")
print(f"   t_x = (target_lon - lon_min) / (lon_max - lon_min)")
print(f"   t_x = ({target_lon:+6.5f} - ({lon_min:+6.1f})) / ({lon_max:+6.1f} - ({lon_min:+6.1f}))")
print(f"   t_x = {target_lon - lon_min:6.5f} / {lon_max - lon_min:4.1f} = {t_x:.6f}")
print(f"   ")
print(f"   t_y = (target_lat - lat_min) / (lat_max - lat_min)")
print(f"   t_y = ({target_lat:+6.5f} - ({lat_min:+6.1f})) / ({lat_max:+6.1f} - ({lat_min:+6.1f}))")
print(f"   t_y = {target_lat - lat_min:6.5f} / {lat_max - lat_min:4.1f} = {t_y:.6f}")

w_00 = (1 - t_x) * (1 - t_y)
w_01 = t_x * (1 - t_y)
w_10 = (1 - t_x) * t_y
w_11 = t_x * t_y

print(f"\n6. INTERPOLATION WEIGHTS:")
print(f"   w_00 = (1 - t_x) * (1 - t_y) = (1 - {t_x:.6f}) * (1 - {t_y:.6f}) = {w_00:.6f}")
print(f"   w_01 = t_x * (1 - t_y)       = {t_x:.6f} * (1 - {t_y:.6f})       = {w_01:.6f}")
print(f"   w_10 = (1 - t_x) * t_y       = (1 - {t_x:.6f}) * {t_y:.6f}       = {w_10:.6f}")
print(f"   w_11 = t_x * t_y             = {t_x:.6f} * {t_y:.6f}             = {w_11:.6f}")
print(f"   Sum of weights = {w_00 + w_01 + w_10 + w_11:.6f} (should be 1.0)")

interpolated_value = w_00 * f_00 + w_01 * f_01 + w_10 * f_10 + w_11 * f_11

print(f"\n7. FINAL CALCULATION:")
print(f"   Value = w_00*f_00 + w_01*f_01 + w_10*f_10 + w_11*f_11")
print(f"   Value = {w_00:.6f}*{f_00:5.1f} + {w_01:.6f}*{f_01:5.1f} + {w_10:.6f}*{f_10:5.1f} + {w_11:.6f}*{f_11:5.1f}")
print(f"   Value = {w_00*f_00:8.4f} + {w_01*f_01:8.4f} + {w_10*f_10:8.4f} + {w_11*f_11:8.4f}")
print(f"   Value = {interpolated_value:.6f}")

print(f"\n8. TARGET POINT RELATIVE POSITION:")
print(f"   In X direction (longitude): {t_x*100:.2f}% of the way from {lon_min}° to {lon_max}°")
print(f"   In Y direction (latitude):  {t_y*100:.2f}% of the way from {lat_min}° to {lat_max}°")

print(f"\n{'='*60}")
print(f"FINAL RESULT: TEC = {interpolated_value:.4f}")
print(f"{'='*60}")
# Out:
# ============================================================
# DETAILED BILINEAR INTERPOLATION ANALYSIS
# ============================================================
#
# 1. THE 4 CLOSEST POINTS:
#    P1: ( -15.0°,  -50.0°) - Indexes: [22, 12] - TEC:  95.6
#    P2: ( -15.0°,  -45.0°) - Indexes: [22, 13] - TEC:  94.9
#    P3: ( -17.5°,  -50.0°) - Indexes: [23, 12] - TEC:  93.9
#    P4: ( -17.5°,  -45.0°) - Indexes: [23, 13] - TEC:  92.7
#
# 2. TARGET POINT: (-15.94748°, -47.87787°)
#
# 3. INTERPOLATION RECTANGLE BOUNDS:
#    Latitude:   -17.5° to  -15.0° (range:  2.5°)
#    Longitude:  -50.0° to  -45.0° (range:  5.0°)
#
# 4. TEC VALUES MAPPING:
#    f_00 (lat_min, lon_min) = ( -17.5°,  -50.0°) =  93.9
#    f_01 (lat_min, lon_max) = ( -17.5°,  -45.0°) =  92.7
#    f_10 (lat_max, lon_min) = ( -15.0°,  -50.0°) =  95.6
#    f_11 (lat_max, lon_max) = ( -15.0°,  -45.0°) =  94.9
#
# 5. INTERPOLATION PARAMETERS:
#    t_x = (target_lon - lon_min) / (lon_max - lon_min)
#    t_x = (-47.87787 - ( -50.0)) / ( -45.0 - ( -50.0))
#    t_x = 2.12213 /  5.0 = 0.424426
#
#    t_y = (target_lat - lat_min) / (lat_max - lat_min)
#    t_y = (-15.94748 - ( -17.5)) / ( -15.0 - ( -17.5))
#    t_y = 1.55252 /  2.5 = 0.621008
#
# 6. INTERPOLATION WEIGHTS:
#    w_00 = (1 - t_x) * (1 - t_y) = (1 - 0.424426) * (1 - 0.621008) = 0.218138
#    w_01 = t_x * (1 - t_y)       = 0.424426 * (1 - 0.621008)       = 0.160854
#    w_10 = (1 - t_x) * t_y       = (1 - 0.424426) * 0.621008       = 0.357436
#    w_11 = t_x * t_y             = 0.424426 * 0.621008             = 0.263572
#    Sum of weights = 1.000000 (should be 1.0)
#
# 7. FINAL CALCULATION:
#    Value = w_00*f_00 + w_01*f_01 + w_10*f_10 + w_11*f_11
#    Value = 0.218138* 93.9 + 0.160854* 92.7 + 0.357436* 95.6 + 0.263572* 94.9
#    Value =  20.4832 +  14.9112 +  34.1709 +  25.0130
#    Value = 94.578188
#
# 8. TARGET POINT RELATIVE POSITION:
#    In X direction (longitude): 42.44% of the way from -50° to -45°
#    In Y direction (latitude):  62.10% of the way from -17.5° to -15.0°
#
# ============================================================
# FINAL RESULT: TEC = 94.5782
# ============================================================

# %% [markdown]
# ### 12/18 - 18:00

# %%
import pandas as pd

date = '2024-12-18'
time = '18:00:00'
timestamp_wanted = f'{date} {time}'

result = df_igs_maps_2024[df_igs_maps_2024['DATETIME'] == timestamp_wanted]

if result.empty:

    df_temp = df_igs_maps_2024.copy()
    df_temp['DATETIME'] = pd.to_datetime(df_temp['DATETIME'])
    timestamp_dt = pd.to_datetime(timestamp_wanted)

    df_temp['diff'] = abs((df_temp['DATETIME'] - timestamp_dt).dt.total_seconds())
    idx_nearest = df_temp['diff'].idxmin()

    result = df_igs_maps_2024.iloc[[idx_nearest]]
    print(f"Exact date not found. Using closest record: {df_igs_maps_2024.iloc[idx_nearest]['DATETIME']}")

# %%
result
# Out:
#                DATETIME                                             TECMAP
# 201 2024-12-18 18:00:00  [[38.6, 42.2, 45.2, 47.7, 49.5, 50.3, 49.9, 49...

# %%
igs_maps = np.array(result.iloc[:]['TECMAP'])

# %%
np_igs_maps = []
for i in range(len(igs_maps)):
    np_igs_maps.append(igs_maps[i])
np_igs_maps = np.array(np_igs_maps)

# %%
np_igs_maps
# Out:
# array([[[38.6, 42.2, 45.2, ..., 15.9, 15.3, 15.4],
#         [38.9, 42.4, 45.9, ..., 18.4, 17.5, 17.4],
#         [39.1, 42.5, 46.1, ..., 23.7, 22. , 21. ],
#         ...,
#         [24.3, 24. , 23.8, ..., 19.1, 18.4, 17.9],
#         [24.1, 23.9, 23.6, ..., 18.6, 18.1, 17.7],
#         [23.5, 23.3, 23.1, ..., 18.1, 17.6, 17.3]]])

# %%
np_igs_maps.shape
# Out:
# (1, 49, 23)

# %%
igs_tec.tec_map = np_igs_maps[0]

print("=" * 60)
print("DETAILED BILINEAR INTERPOLATION ANALYSIS")
print("=" * 60)

print("\n1. THE 4 CLOSEST POINTS:")
for i, point in enumerate(igs_points):
    lat, lon, lat_idx, lon_idx = point
    tec_value = igs_tec.tec_map[lat_idx, lon_idx]
    print(f"   P{i+1}: ({lat:+6.1f}°, {lon:+6.1f}°) - Indexes: [{lat_idx:2d}, {lon_idx:2d}] - TEC: {tec_value:5.1f}")

target_lat = -15.94748
target_lon = -47.87787

print(f"\n2. TARGET POINT: ({target_lat:+6.5f}°, {target_lon:+6.5f}°)")

values = []
for point in igs_points:
    lat, lon, lat_idx, lon_idx = point
    values.append(igs_tec.tec_map[lat_idx, lon_idx])

lats = [p[0] for p in igs_points]
lons = [p[1] for p in igs_points]

lat_min, lat_max = min(lats), max(lats)
lon_min, lon_max = min(lons), max(lons)

print(f"\n3. INTERPOLATION RECTANGLE BOUNDS:")
print(f"   Latitude:  {lat_min:+6.1f}° to {lat_max:+6.1f}° (range: {lat_max - lat_min:4.1f}°)")
print(f"   Longitude: {lon_min:+6.1f}° to {lon_max:+6.1f}° (range: {lon_max - lon_min:4.1f}°)")

point_values = {}
for i, point in enumerate(igs_points):
    point_values[(point[0], point[1])] = values[i]

f_00 = point_values[(lat_min, lon_min)]
f_01 = point_values[(lat_min, lon_max)]
f_10 = point_values[(lat_max, lon_min)]
f_11 = point_values[(lat_max, lon_max)]

print(f"\n4. TEC VALUES MAPPING:")
print(f"   f_00 (lat_min, lon_min) = ({lat_min:+6.1f}°, {lon_min:+6.1f}°) = {f_00:5.1f}")
print(f"   f_01 (lat_min, lon_max) = ({lat_min:+6.1f}°, {lon_max:+6.1f}°) = {f_01:5.1f}")
print(f"   f_10 (lat_max, lon_min) = ({lat_max:+6.1f}°, {lon_min:+6.1f}°) = {f_10:5.1f}")
print(f"   f_11 (lat_max, lon_max) = ({lat_max:+6.1f}°, {lon_max:+6.1f}°) = {f_11:5.1f}")

t_x = (target_lon - lon_min) / (lon_max - lon_min) if lon_max != lon_min else 0
t_y = (target_lat - lat_min) / (lat_max - lat_min) if lat_max != lat_min else 0

print(f"\n5. INTERPOLATION PARAMETERS:")
print(f"   t_x = (target_lon - lon_min) / (lon_max - lon_min)")
print(f"   t_x = ({target_lon:+6.5f} - ({lon_min:+6.1f})) / ({lon_max:+6.1f} - ({lon_min:+6.1f}))")
print(f"   t_x = {target_lon - lon_min:6.5f} / {lon_max - lon_min:4.1f} = {t_x:.6f}")
print(f"   ")
print(f"   t_y = (target_lat - lat_min) / (lat_max - lat_min)")
print(f"   t_y = ({target_lat:+6.5f} - ({lat_min:+6.1f})) / ({lat_max:+6.1f} - ({lat_min:+6.1f}))")
print(f"   t_y = {target_lat - lat_min:6.5f} / {lat_max - lat_min:4.1f} = {t_y:.6f}")

w_00 = (1 - t_x) * (1 - t_y)
w_01 = t_x * (1 - t_y)
w_10 = (1 - t_x) * t_y
w_11 = t_x * t_y

print(f"\n6. INTERPOLATION WEIGHTS:")
print(f"   w_00 = (1 - t_x) * (1 - t_y) = (1 - {t_x:.6f}) * (1 - {t_y:.6f}) = {w_00:.6f}")
print(f"   w_01 = t_x * (1 - t_y)       = {t_x:.6f} * (1 - {t_y:.6f})       = {w_01:.6f}")
print(f"   w_10 = (1 - t_x) * t_y       = (1 - {t_x:.6f}) * {t_y:.6f}       = {w_10:.6f}")
print(f"   w_11 = t_x * t_y             = {t_x:.6f} * {t_y:.6f}             = {w_11:.6f}")
print(f"   Sum of weights = {w_00 + w_01 + w_10 + w_11:.6f} (should be 1.0)")

interpolated_value = w_00 * f_00 + w_01 * f_01 + w_10 * f_10 + w_11 * f_11

print(f"\n7. FINAL CALCULATION:")
print(f"   Value = w_00*f_00 + w_01*f_01 + w_10*f_10 + w_11*f_11")
print(f"   Value = {w_00:.6f}*{f_00:5.1f} + {w_01:.6f}*{f_01:5.1f} + {w_10:.6f}*{f_10:5.1f} + {w_11:.6f}*{f_11:5.1f}")
print(f"   Value = {w_00*f_00:8.4f} + {w_01*f_01:8.4f} + {w_10*f_10:8.4f} + {w_11*f_11:8.4f}")
print(f"   Value = {interpolated_value:.6f}")

print(f"\n8. TARGET POINT RELATIVE POSITION:")
print(f"   In X direction (longitude): {t_x*100:.2f}% of the way from {lon_min}° to {lon_max}°")
print(f"   In Y direction (latitude):  {t_y*100:.2f}% of the way from {lat_min}° to {lat_max}°")

print(f"\n{'='*60}")
print(f"FINAL RESULT: TEC = {interpolated_value:.4f}")
print(f"{'='*60}")
# Out:
# ============================================================
# DETAILED BILINEAR INTERPOLATION ANALYSIS
# ============================================================
#
# 1. THE 4 CLOSEST POINTS:
#    P1: ( -15.0°,  -50.0°) - Indexes: [22, 12] - TEC:  93.5
#    P2: ( -15.0°,  -45.0°) - Indexes: [22, 13] - TEC:  94.5
#    P3: ( -17.5°,  -50.0°) - Indexes: [23, 12] - TEC:  93.4
#    P4: ( -17.5°,  -45.0°) - Indexes: [23, 13] - TEC:  93.6
#
# 2. TARGET POINT: (-15.94748°, -47.87787°)
#
# 3. INTERPOLATION RECTANGLE BOUNDS:
#    Latitude:   -17.5° to  -15.0° (range:  2.5°)
#    Longitude:  -50.0° to  -45.0° (range:  5.0°)
#
# 4. TEC VALUES MAPPING:
#    f_00 (lat_min, lon_min) = ( -17.5°,  -50.0°) =  93.4
#    f_01 (lat_min, lon_max) = ( -17.5°,  -45.0°) =  93.6
#    f_10 (lat_max, lon_min) = ( -15.0°,  -50.0°) =  93.5
#    f_11 (lat_max, lon_max) = ( -15.0°,  -45.0°) =  94.5
#
# 5. INTERPOLATION PARAMETERS:
#    t_x = (target_lon - lon_min) / (lon_max - lon_min)
#    t_x = (-47.87787 - ( -50.0)) / ( -45.0 - ( -50.0))
#    t_x = 2.12213 /  5.0 = 0.424426
#
#    t_y = (target_lat - lat_min) / (lat_max - lat_min)
#    t_y = (-15.94748 - ( -17.5)) / ( -15.0 - ( -17.5))
#    t_y = 1.55252 /  2.5 = 0.621008
#
# 6. INTERPOLATION WEIGHTS:
#    w_00 = (1 - t_x) * (1 - t_y) = (1 - 0.424426) * (1 - 0.621008) = 0.218138
#    w_01 = t_x * (1 - t_y)       = 0.424426 * (1 - 0.621008)       = 0.160854
#    w_10 = (1 - t_x) * t_y       = (1 - 0.424426) * 0.621008       = 0.357436
#    w_11 = t_x * t_y             = 0.424426 * 0.621008             = 0.263572
#    Sum of weights = 1.000000 (should be 1.0)
#
# 7. FINAL CALCULATION:
#    Value = w_00*f_00 + w_01*f_01 + w_10*f_10 + w_11*f_11
#    Value = 0.218138* 93.4 + 0.160854* 93.6 + 0.357436* 93.5 + 0.263572* 94.5
#    Value =  20.3741 +  15.0559 +  33.4203 +  24.9075
#    Value = 93.757844
#
# 8. TARGET POINT RELATIVE POSITION:
#    In X direction (longitude): 42.44% of the way from -50° to -45°
#    In Y direction (latitude):  62.10% of the way from -17.5° to -15.0°
#
# ============================================================
# FINAL RESULT: TEC = 93.7578
# ============================================================

# %% [markdown]
# ### 12/19 - 18:00

# %%
import pandas as pd

date = '2024-12-19'
time = '18:00:00'
timestamp_wanted = f'{date} {time}'

result = df_igs_maps_2024[df_igs_maps_2024['DATETIME'] == timestamp_wanted]

if result.empty:
    df_temp = df_igs_maps_2024.copy()
    df_temp['DATETIME'] = pd.to_datetime(df_temp['DATETIME'])
    timestamp_dt = pd.to_datetime(timestamp_wanted)

    df_temp['diff'] = abs((df_temp['DATETIME'] - timestamp_dt).dt.total_seconds())
    idx_nearest = df_temp['diff'].idxmin()

    result = df_igs_maps_2024.iloc[[idx_nearest]]
    print(f"Exact date not found. Using closest record: {df_igs_maps_2024.iloc[idx_nearest]['DATETIME']}")

# %%
result
# Out:
#                DATETIME                                             TECMAP
# 213 2024-12-19 18:00:00  [[36.1, 39.3, 41.5, 42.6, 42.4, 41.2, 39.2, 37...

# %%
igs_maps = np.array(result.iloc[:]['TECMAP'])

# %%
np_igs_maps = []
for i in range(len(igs_maps)):
    np_igs_maps.append(igs_maps[i])
np_igs_maps = np.array(np_igs_maps)

# %%
np_igs_maps
# Out:
# array([[[36.1, 39.3, 41.5, ..., 15. , 14.4, 14.1],
#         [37.3, 40. , 42.4, ..., 17. , 16.5, 16.2],
#         [38.2, 40.5, 42.6, ..., 20.6, 20.1, 19.7],
#         ...,
#         [23.4, 23.3, 23.2, ..., 23.6, 23.2, 22.9],
#         [23.3, 23.2, 23.1, ..., 23.7, 23.5, 23.2],
#         [23. , 23.1, 22.9, ..., 23.5, 23.6, 23.5]]])

# %%
np_igs_maps.shape
# Out:
# (1, 49, 23)

# %%
igs_tec.tec_map = np_igs_maps[0]

print("=" * 60)
print("DETAILED BILINEAR INTERPOLATION ANALYSIS")
print("=" * 60)

print("\n1. THE 4 CLOSEST POINTS:")
for i, point in enumerate(igs_points):
    lat, lon, lat_idx, lon_idx = point
    tec_value = igs_tec.tec_map[lat_idx, lon_idx]
    print(f"   P{i+1}: ({lat:+6.1f}°, {lon:+6.1f}°) - Indexes: [{lat_idx:2d}, {lon_idx:2d}] - TEC: {tec_value:5.1f}")

target_lat = -15.94748
target_lon = -47.87787

print(f"\n2. TARGET POINT: ({target_lat:+6.5f}°, {target_lon:+6.5f}°)")

values = []
for point in igs_points:
    lat, lon, lat_idx, lon_idx = point
    values.append(igs_tec.tec_map[lat_idx, lon_idx])

lats = [p[0] for p in igs_points]
lons = [p[1] for p in igs_points]

lat_min, lat_max = min(lats), max(lats)
lon_min, lon_max = min(lons), max(lons)

print(f"\n3. INTERPOLATION RECTANGLE BOUNDS:")
print(f"   Latitude:  {lat_min:+6.1f}° to {lat_max:+6.1f}° (range: {lat_max - lat_min:4.1f}°)")
print(f"   Longitude: {lon_min:+6.1f}° to {lon_max:+6.1f}° (range: {lon_max - lon_min:4.1f}°)")

point_values = {}
for i, point in enumerate(igs_points):
    point_values[(point[0], point[1])] = values[i]

f_00 = point_values[(lat_min, lon_min)]
f_01 = point_values[(lat_min, lon_max)]
f_10 = point_values[(lat_max, lon_min)]
f_11 = point_values[(lat_max, lon_max)]

print(f"\n4. TEC VALUES MAPPING:")
print(f"   f_00 (lat_min, lon_min) = ({lat_min:+6.1f}°, {lon_min:+6.1f}°) = {f_00:5.1f}")
print(f"   f_01 (lat_min, lon_max) = ({lat_min:+6.1f}°, {lon_max:+6.1f}°) = {f_01:5.1f}")
print(f"   f_10 (lat_max, lon_min) = ({lat_max:+6.1f}°, {lon_min:+6.1f}°) = {f_10:5.1f}")
print(f"   f_11 (lat_max, lon_max) = ({lat_max:+6.1f}°, {lon_max:+6.1f}°) = {f_11:5.1f}")

t_x = (target_lon - lon_min) / (lon_max - lon_min) if lon_max != lon_min else 0
t_y = (target_lat - lat_min) / (lat_max - lat_min) if lat_max != lat_min else 0

print(f"\n5. INTERPOLATION PARAMETERS:")
print(f"   t_x = (target_lon - lon_min) / (lon_max - lon_min)")
print(f"   t_x = ({target_lon:+6.5f} - ({lon_min:+6.1f})) / ({lon_max:+6.1f} - ({lon_min:+6.1f}))")
print(f"   t_x = {target_lon - lon_min:6.5f} / {lon_max - lon_min:4.1f} = {t_x:.6f}")
print(f"   ")
print(f"   t_y = (target_lat - lat_min) / (lat_max - lat_min)")
print(f"   t_y = ({target_lat:+6.5f} - ({lat_min:+6.1f})) / ({lat_max:+6.1f} - ({lat_min:+6.1f}))")
print(f"   t_y = {target_lat - lat_min:6.5f} / {lat_max - lat_min:4.1f} = {t_y:.6f}")

w_00 = (1 - t_x) * (1 - t_y)
w_01 = t_x * (1 - t_y)
w_10 = (1 - t_x) * t_y
w_11 = t_x * t_y

print(f"\n6. INTERPOLATION WEIGHTS:")
print(f"   w_00 = (1 - t_x) * (1 - t_y) = (1 - {t_x:.6f}) * (1 - {t_y:.6f}) = {w_00:.6f}")
print(f"   w_01 = t_x * (1 - t_y)       = {t_x:.6f} * (1 - {t_y:.6f})       = {w_01:.6f}")
print(f"   w_10 = (1 - t_x) * t_y       = (1 - {t_x:.6f}) * {t_y:.6f}       = {w_10:.6f}")
print(f"   w_11 = t_x * t_y             = {t_x:.6f} * {t_y:.6f}             = {w_11:.6f}")
print(f"   Sum of weights = {w_00 + w_01 + w_10 + w_11:.6f} (should be 1.0)")

interpolated_value = w_00 * f_00 + w_01 * f_01 + w_10 * f_10 + w_11 * f_11

print(f"\n7. FINAL CALCULATION:")
print(f"   Value = w_00*f_00 + w_01*f_01 + w_10*f_10 + w_11*f_11")
print(f"   Value = {w_00:.6f}*{f_00:5.1f} + {w_01:.6f}*{f_01:5.1f} + {w_10:.6f}*{f_10:5.1f} + {w_11:.6f}*{f_11:5.1f}")
print(f"   Value = {w_00*f_00:8.4f} + {w_01*f_01:8.4f} + {w_10*f_10:8.4f} + {w_11*f_11:8.4f}")
print(f"   Value = {interpolated_value:.6f}")

print(f"\n8. TARGET POINT RELATIVE POSITION:")
print(f"   In X direction (longitude): {t_x*100:.2f}% of the way from {lon_min}° to {lon_max}°")
print(f"   In Y direction (latitude):  {t_y*100:.2f}% of the way from {lat_min}° to {lat_max}°")

print(f"\n{'='*60}")
print(f"FINAL RESULT: TEC = {interpolated_value:.4f}")
print(f"{'='*60}")
# Out:
# ============================================================
# DETAILED BILINEAR INTERPOLATION ANALYSIS
# ============================================================
#
# 1. THE 4 CLOSEST POINTS:
#    P1: ( -15.0°,  -50.0°) - Indexes: [22, 12] - TEC:  83.2
#    P2: ( -15.0°,  -45.0°) - Indexes: [22, 13] - TEC:  83.7
#    P3: ( -17.5°,  -50.0°) - Indexes: [23, 12] - TEC:  83.8
#    P4: ( -17.5°,  -45.0°) - Indexes: [23, 13] - TEC:  83.6
#
# 2. TARGET POINT: (-15.94748°, -47.87787°)
#
# 3. INTERPOLATION RECTANGLE BOUNDS:
#    Latitude:   -17.5° to  -15.0° (range:  2.5°)
#    Longitude:  -50.0° to  -45.0° (range:  5.0°)
#
# 4. TEC VALUES MAPPING:
#    f_00 (lat_min, lon_min) = ( -17.5°,  -50.0°) =  83.8
#    f_01 (lat_min, lon_max) = ( -17.5°,  -45.0°) =  83.6
#    f_10 (lat_max, lon_min) = ( -15.0°,  -50.0°) =  83.2
#    f_11 (lat_max, lon_max) = ( -15.0°,  -45.0°) =  83.7
#
# 5. INTERPOLATION PARAMETERS:
#    t_x = (target_lon - lon_min) / (lon_max - lon_min)
#    t_x = (-47.87787 - ( -50.0)) / ( -45.0 - ( -50.0))
#    t_x = 2.12213 /  5.0 = 0.424426
#
#    t_y = (target_lat - lat_min) / (lat_max - lat_min)
#    t_y = (-15.94748 - ( -17.5)) / ( -15.0 - ( -17.5))
#    t_y = 1.55252 /  2.5 = 0.621008
#
# 6. INTERPOLATION WEIGHTS:
#    w_00 = (1 - t_x) * (1 - t_y) = (1 - 0.424426) * (1 - 0.621008) = 0.218138
#    w_01 = t_x * (1 - t_y)       = 0.424426 * (1 - 0.621008)       = 0.160854
#    w_10 = (1 - t_x) * t_y       = (1 - 0.424426) * 0.621008       = 0.357436
#    w_11 = t_x * t_y             = 0.424426 * 0.621008             = 0.263572
#    Sum of weights = 1.000000 (should be 1.0)
#
# 7. FINAL CALCULATION:
#    Value = w_00*f_00 + w_01*f_01 + w_10*f_10 + w_11*f_11
#    Value = 0.218138* 83.8 + 0.160854* 83.6 + 0.357436* 83.2 + 0.263572* 83.7
#    Value =  18.2800 +  13.4474 +  29.7387 +  22.0610
#    Value = 83.527010
#
# 8. TARGET POINT RELATIVE POSITION:
#    In X direction (longitude): 42.44% of the way from -50° to -45°
#    In Y direction (latitude):  62.10% of the way from -17.5° to -15.0°
#
# ============================================================
# FINAL RESULT: TEC = 83.5270
# ============================================================

# %% [markdown]
# ### 12/22 - 18:00

# %%
import pandas as pd

date = '2024-12-22'
time = '18:00:00'
timestamp_wanted = f'{date} {time}'

result = df_igs_maps_2024[df_igs_maps_2024['DATETIME'] == timestamp_wanted]

if result.empty:
    df_temp = df_igs_maps_2024.copy()
    df_temp['DATETIME'] = pd.to_datetime(df_temp['DATETIME'])
    timestamp_dt = pd.to_datetime(timestamp_wanted)

    df_temp['diff'] = abs((df_temp['DATETIME'] - timestamp_dt).dt.total_seconds())
    idx_nearest = df_temp['diff'].idxmin()

    result = df_igs_maps_2024.iloc[[idx_nearest]]
    print(f"Exact date not found. Using closest record: {df_igs_maps_2024.iloc[idx_nearest]['DATETIME']}")

# %%
result
# Out:
#                DATETIME                                             TECMAP
# 249 2024-12-22 18:00:00  [[48.9, 51.6, 53.7, 54.6, 54.9, 54.7, 54.6, 54...

# %%
igs_maps = np.array(result.iloc[:]['TECMAP'])

# %%
np_igs_maps = []
for i in range(len(igs_maps)):
    np_igs_maps.append(igs_maps[i])
np_igs_maps = np.array(np_igs_maps)

# %%
np_igs_maps
# Out:
# array([[[48.9, 51.6, 53.7, ..., 23. , 21.7, 20.7],
#         [49.6, 52. , 53.9, ..., 25.5, 24.4, 23. ],
#         [50.2, 52.1, 53.8, ..., 30.7, 29.2, 27.9],
#         ...,
#         [24.7, 24.7, 24.4, ..., 20.9, 20.5, 20.2],
#         [25. , 24.9, 24.8, ..., 21.5, 21. , 20.8],
#         [24.7, 24.8, 24.5, ..., 21.6, 21.2, 20.9]]])

# %%
np_igs_maps.shape
# Out:
# (1, 49, 23)

# %%
igs_tec.tec_map = np_igs_maps[0]

print("=" * 60)
print("DETAILED BILINEAR INTERPOLATION ANALYSIS")
print("=" * 60)

print("\n1. THE 4 CLOSEST POINTS:")
for i, point in enumerate(igs_points):
    lat, lon, lat_idx, lon_idx = point
    tec_value = igs_tec.tec_map[lat_idx, lon_idx]
    print(f"   P{i+1}: ({lat:+6.1f}°, {lon:+6.1f}°) - Indexes: [{lat_idx:2d}, {lon_idx:2d}] - TEC: {tec_value:5.1f}")

target_lat = -15.94748
target_lon = -47.87787

print(f"\n2. TARGET POINT: ({target_lat:+6.5f}°, {target_lon:+6.5f}°)")

values = []
for point in igs_points:
    lat, lon, lat_idx, lon_idx = point
    values.append(igs_tec.tec_map[lat_idx, lon_idx])

lats = [p[0] for p in igs_points]
lons = [p[1] for p in igs_points]

lat_min, lat_max = min(lats), max(lats)
lon_min, lon_max = min(lons), max(lons)

print(f"\n3. INTERPOLATION RECTANGLE BOUNDS:")
print(f"   Latitude:  {lat_min:+6.1f}° to {lat_max:+6.1f}° (range: {lat_max - lat_min:4.1f}°)")
print(f"   Longitude: {lon_min:+6.1f}° to {lon_max:+6.1f}° (range: {lon_max - lon_min:4.1f}°)")

point_values = {}
for i, point in enumerate(igs_points):
    point_values[(point[0], point[1])] = values[i]

f_00 = point_values[(lat_min, lon_min)]
f_01 = point_values[(lat_min, lon_max)]
f_10 = point_values[(lat_max, lon_min)]
f_11 = point_values[(lat_max, lon_max)]

print(f"\n4. TEC VALUES MAPPING:")
print(f"   f_00 (lat_min, lon_min) = ({lat_min:+6.1f}°, {lon_min:+6.1f}°) = {f_00:5.1f}")
print(f"   f_01 (lat_min, lon_max) = ({lat_min:+6.1f}°, {lon_max:+6.1f}°) = {f_01:5.1f}")
print(f"   f_10 (lat_max, lon_min) = ({lat_max:+6.1f}°, {lon_min:+6.1f}°) = {f_10:5.1f}")
print(f"   f_11 (lat_max, lon_max) = ({lat_max:+6.1f}°, {lon_max:+6.1f}°) = {f_11:5.1f}")

t_x = (target_lon - lon_min) / (lon_max - lon_min) if lon_max != lon_min else 0
t_y = (target_lat - lat_min) / (lat_max - lat_min) if lat_max != lat_min else 0

print(f"\n5. INTERPOLATION PARAMETERS:")
print(f"   t_x = (target_lon - lon_min) / (lon_max - lon_min)")
print(f"   t_x = ({target_lon:+6.5f} - ({lon_min:+6.1f})) / ({lon_max:+6.1f} - ({lon_min:+6.1f}))")
print(f"   t_x = {target_lon - lon_min:6.5f} / {lon_max - lon_min:4.1f} = {t_x:.6f}")
print(f"   ")
print(f"   t_y = (target_lat - lat_min) / (lat_max - lat_min)")
print(f"   t_y = ({target_lat:+6.5f} - ({lat_min:+6.1f})) / ({lat_max:+6.1f} - ({lat_min:+6.1f}))")
print(f"   t_y = {target_lat - lat_min:6.5f} / {lat_max - lat_min:4.1f} = {t_y:.6f}")

w_00 = (1 - t_x) * (1 - t_y)
w_01 = t_x * (1 - t_y)
w_10 = (1 - t_x) * t_y
w_11 = t_x * t_y

print(f"\n6. INTERPOLATION WEIGHTS:")
print(f"   w_00 = (1 - t_x) * (1 - t_y) = (1 - {t_x:.6f}) * (1 - {t_y:.6f}) = {w_00:.6f}")
print(f"   w_01 = t_x * (1 - t_y)       = {t_x:.6f} * (1 - {t_y:.6f})       = {w_01:.6f}")
print(f"   w_10 = (1 - t_x) * t_y       = (1 - {t_x:.6f}) * {t_y:.6f}       = {w_10:.6f}")
print(f"   w_11 = t_x * t_y             = {t_x:.6f} * {t_y:.6f}             = {w_11:.6f}")
print(f"   Sum of weights = {w_00 + w_01 + w_10 + w_11:.6f} (should be 1.0)")

interpolated_value = w_00 * f_00 + w_01 * f_01 + w_10 * f_10 + w_11 * f_11

print(f"\n7. FINAL CALCULATION:")
print(f"   Value = w_00*f_00 + w_01*f_01 + w_10*f_10 + w_11*f_11")
print(f"   Value = {w_00:.6f}*{f_00:5.1f} + {w_01:.6f}*{f_01:5.1f} + {w_10:.6f}*{f_10:5.1f} + {w_11:.6f}*{f_11:5.1f}")
print(f"   Value = {w_00*f_00:8.4f} + {w_01*f_01:8.4f} + {w_10*f_10:8.4f} + {w_11*f_11:8.4f}")
print(f"   Value = {interpolated_value:.6f}")

print(f"\n8. TARGET POINT RELATIVE POSITION:")
print(f"   In X direction (longitude): {t_x*100:.2f}% of the way from {lon_min}° to {lon_max}°")
print(f"   In Y direction (latitude):  {t_y*100:.2f}% of the way from {lat_min}° to {lat_max}°")

print(f"\n{'='*60}")
print(f"FINAL RESULT: TEC = {interpolated_value:.4f}")
print(f"{'='*60}")
# Out:
# ============================================================
# DETAILED BILINEAR INTERPOLATION ANALYSIS
# ============================================================
#
# 1. THE 4 CLOSEST POINTS:
#    P1: ( -15.0°,  -50.0°) - Indexes: [22, 12] - TEC:  92.5
#    P2: ( -15.0°,  -45.0°) - Indexes: [22, 13] - TEC:  92.7
#    P3: ( -17.5°,  -50.0°) - Indexes: [23, 12] - TEC:  91.9
#    P4: ( -17.5°,  -45.0°) - Indexes: [23, 13] - TEC:  91.5
#
# 2. TARGET POINT: (-15.94748°, -47.87787°)
#
# 3. INTERPOLATION RECTANGLE BOUNDS:
#    Latitude:   -17.5° to  -15.0° (range:  2.5°)
#    Longitude:  -50.0° to  -45.0° (range:  5.0°)
#
# 4. TEC VALUES MAPPING:
#    f_00 (lat_min, lon_min) = ( -17.5°,  -50.0°) =  91.9
#    f_01 (lat_min, lon_max) = ( -17.5°,  -45.0°) =  91.5
#    f_10 (lat_max, lon_min) = ( -15.0°,  -50.0°) =  92.5
#    f_11 (lat_max, lon_max) = ( -15.0°,  -45.0°) =  92.7
#
# 5. INTERPOLATION PARAMETERS:
#    t_x = (target_lon - lon_min) / (lon_max - lon_min)
#    t_x = (-47.87787 - ( -50.0)) / ( -45.0 - ( -50.0))
#    t_x = 2.12213 /  5.0 = 0.424426
#
#    t_y = (target_lat - lat_min) / (lat_max - lat_min)
#    t_y = (-15.94748 - ( -17.5)) / ( -15.0 - ( -17.5))
#    t_y = 1.55252 /  2.5 = 0.621008
#
# 6. INTERPOLATION WEIGHTS:
#    w_00 = (1 - t_x) * (1 - t_y) = (1 - 0.424426) * (1 - 0.621008) = 0.218138
#    w_01 = t_x * (1 - t_y)       = 0.424426 * (1 - 0.621008)       = 0.160854
#    w_10 = (1 - t_x) * t_y       = (1 - 0.424426) * 0.621008       = 0.357436
#    w_11 = t_x * t_y             = 0.424426 * 0.621008             = 0.263572
#    Sum of weights = 1.000000 (should be 1.0)
#
# 7. FINAL CALCULATION:
#    Value = w_00*f_00 + w_01*f_01 + w_10*f_10 + w_11*f_11
#    Value = 0.218138* 91.9 + 0.160854* 91.5 + 0.357436* 92.5 + 0.263572* 92.7
#    Value =  20.0469 +  14.7181 +  33.0628 +  24.4331
#    Value = 92.260978
#
# 8. TARGET POINT RELATIVE POSITION:
#    In X direction (longitude): 42.44% of the way from -50° to -45°
#    In Y direction (latitude):  62.10% of the way from -17.5° to -15.0°
#
# ============================================================
# FINAL RESULT: TEC = 92.2610
# ============================================================

# %% [markdown]
# ## MAGGIA

# %%
import pandas as pd
import numpy as np

# %%
#Download TF_MAGGIA_TEC_maps_intersection_case_study_from_Sept_05_2024_to_Dec_2024.pkl from https://doi.org/10.5281/zenodo.15453941

# %%
# !gdown '1Qi7Xm93lhuwGWQnr3N-gquhzzUxegI33'
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1Qi7Xm93lhuwGWQnr3N-gquhzzUxegI33
# From (redirected): https://drive.google.com/uc?id=1Qi7Xm93lhuwGWQnr3N-gquhzzUxegI33&confirm=t&uuid=87df5ec7-0c8b-4439-a194-440d9563a1e1
# To: /content/TF_MAGGIA_TEC_maps_intersection_case_study_from_Sept_05_2024_to_Dec_2024.pkl
# 100% 7.51G/7.51G [01:10<00:00, 107MB/s]

# %%
df_maggia_maps_2024 = pd.read_pickle('/content/TF_MAGGIA_TEC_maps_intersection_case_study_from_Sept_05_2024_to_Dec_2024.pkl')

# %%
df_maggia_maps_2024
# Out:
#                  DATETIME                                             TECMAP
# 0     2024-09-05 00:00:00  [[nan, nan, nan, nan, nan, nan, nan, nan, nan,...
# 1     2024-09-05 00:10:00  [[nan, nan, nan, nan, nan, nan, nan, nan, nan,...
# 2     2024-09-05 00:15:00  [[nan, nan, nan, nan, nan, nan, nan, nan, nan,...
# 3     2024-09-05 00:20:00  [[nan, nan, nan, nan, nan, nan, nan, nan, nan,...
# 4     2024-09-05 00:30:00  [[nan, nan, nan, nan, nan, nan, nan, nan, nan,...
# ...                   ...                                                ...
# 15619 2024-12-31 23:10:00  [[nan, nan, nan, nan, nan, nan, nan, nan, nan,...
# 15620 2024-12-31 23:20:00  [[nan, nan, nan, nan, nan, nan, nan, nan, nan,...
# 15621 2024-12-31 23:30:00  [[nan, nan, nan, nan, nan, nan, nan, nan, nan,...
# 15622 2024-12-31 23:40:00  [[nan, nan, nan, nan, nan, nan, nan, nan, nan,...
# 15623 2024-12-31 23:50:00  [[nan, nan, nan, nan, nan, nan, nan, nan, nan,...
#
# [15624 rows x 2 columns]

# %%
class Maggia(TecMap):
    def __init__(self,
                 extent: Iterable[float] = (-110, 0, -80, 40),
                 lat_step: float = 0.5,
                 lon_step: float = 0.5):
        super().__init__(extent, lat_step, lon_step)

# %%
maggia_tec = Maggia()
maggia_points = maggia_tec.find_nearest_points(lat=-15.94748, lon=-47.87787)

# %%
maggia_points
# Out:
# [(-16.0, -48.0, 128, 124),
#  (-16.0, -47.5, 128, 125),
#  (-15.5, -48.0, 129, 124),
#  (-15.5, -47.5, 129, 125)]

# %% [markdown]
# ### 12/01 - 18:00

# %%
import pandas as pd

date = '2024-12-01'
time = '18:00:00'
timestamp_wanted = f'{date} {time}'

result = df_maggia_maps_2024[df_maggia_maps_2024['DATETIME'] == timestamp_wanted]

if result.empty:
    df_temp = df_maggia_maps_2024.copy()
    df_temp['DATETIME'] = pd.to_datetime(df_temp['DATETIME'])
    timestamp_dt = pd.to_datetime(timestamp_wanted)

    df_temp['diff'] = abs((df_temp['DATETIME'] - timestamp_dt).dt.total_seconds())
    idx_nearest = df_temp['diff'].idxmin()

    result = df_maggia_maps_2024.iloc[[idx_nearest]]
    print(f"Exact date not found. Using closest record: {df_maggia_maps_2024.iloc[idx_nearest]['DATETIME']}")

# %%
result
# Out:
#                  DATETIME                                             TECMAP
# 11268 2024-12-01 18:00:00  [[nan, nan, nan, nan, nan, nan, nan, nan, nan,...

# %%
maggia_maps = np.array(result.iloc[:]['TECMAP'])

# %%
np_maggia_maps = []
for i in range(len(maggia_maps)):
    np_maggia_maps.append(maggia_maps[i])
np_maggia_maps = np.array(np_maggia_maps)

# %%
np_maggia_maps
# Out:
# array([[[        nan,         nan,         nan, ...,         nan,
#                  nan,         nan],
#         [        nan,         nan,         nan, ...,         nan,
#                  nan,         nan],
#         [        nan,         nan,         nan, ...,         nan,
#                  nan,         nan],
#         ...,
#         [45.95299911, 45.88100052, 45.71300125, ..., 23.45899963,
#          23.20400047, 22.93400002],
#         [45.90299988, 45.8370018 , 45.67300034, ..., 23.38800049,
#          23.23900032, 23.04000092],
#         [45.86399841, 45.79700089, 45.63999939, ..., 23.29700089,
#          23.1590004 , 23.00300026]]])

# %%
np_maggia_maps.shape
# Out:
# (1, 241, 221)

# %%
maggia_tec.tec_map = np_maggia_maps[0]

print("=" * 60)
print("DETAILED BILINEAR INTERPOLATION ANALYSIS")
print("=" * 60)

print("\n1. THE 4 CLOSEST POINTS:")
for i, point in enumerate(maggia_points):
    lat, lon, lat_idx, lon_idx = point
    tec_value = maggia_tec.tec_map[lat_idx, lon_idx]
    print(f"   P{i+1}: ({lat:+6.1f}°, {lon:+6.1f}°) - Indexes: [{lat_idx:2d}, {lon_idx:2d}] - TEC: {tec_value:5.1f}")

target_lat = -15.94748
target_lon = -47.87787

print(f"\n2. TARGET POINT: ({target_lat:+6.5f}°, {target_lon:+6.5f}°)")

values = []
for point in maggia_points:
    lat, lon, lat_idx, lon_idx = point
    values.append(maggia_tec.tec_map[lat_idx, lon_idx])

lats = [p[0] for p in maggia_points]
lons = [p[1] for p in maggia_points]

lat_min, lat_max = min(lats), max(lats)
lon_min, lon_max = min(lons), max(lons)

print(f"\n3. INTERPOLATION RECTANGLE BOUNDS:")
print(f"   Latitude:  {lat_min:+6.1f}° to {lat_max:+6.1f}° (range: {lat_max - lat_min:4.1f}°)")
print(f"   Longitude: {lon_min:+6.1f}° to {lon_max:+6.1f}° (range: {lon_max - lon_min:4.1f}°)")

point_values = {}
for i, point in enumerate(maggia_points):
    point_values[(point[0], point[1])] = values[i]

f_00 = point_values[(lat_min, lon_min)]
f_01 = point_values[(lat_min, lon_max)]
f_10 = point_values[(lat_max, lon_min)]
f_11 = point_values[(lat_max, lon_max)]

print(f"\n4. TEC VALUES MAPPING:")
print(f"   f_00 (lat_min, lon_min) = ({lat_min:+6.1f}°, {lon_min:+6.1f}°) = {f_00:5.1f}")
print(f"   f_01 (lat_min, lon_max) = ({lat_min:+6.1f}°, {lon_max:+6.1f}°) = {f_01:5.1f}")
print(f"   f_10 (lat_max, lon_min) = ({lat_max:+6.1f}°, {lon_min:+6.1f}°) = {f_10:5.1f}")
print(f"   f_11 (lat_max, lon_max) = ({lat_max:+6.1f}°, {lon_max:+6.1f}°) = {f_11:5.1f}")

t_x = (target_lon - lon_min) / (lon_max - lon_min) if lon_max != lon_min else 0
t_y = (target_lat - lat_min) / (lat_max - lat_min) if lat_max != lat_min else 0

print(f"\n5. INTERPOLATION PARAMETERS:")
print(f"   t_x = (target_lon - lon_min) / (lon_max - lon_min)")
print(f"   t_x = ({target_lon:+6.5f} - ({lon_min:+6.1f})) / ({lon_max:+6.1f} - ({lon_min:+6.1f}))")
print(f"   t_x = {target_lon - lon_min:6.5f} / {lon_max - lon_min:4.1f} = {t_x:.6f}")
print(f"   ")
print(f"   t_y = (target_lat - lat_min) / (lat_max - lat_min)")
print(f"   t_y = ({target_lat:+6.5f} - ({lat_min:+6.1f})) / ({lat_max:+6.1f} - ({lat_min:+6.1f}))")
print(f"   t_y = {target_lat - lat_min:6.5f} / {lat_max - lat_min:4.1f} = {t_y:.6f}")

w_00 = (1 - t_x) * (1 - t_y)
w_01 = t_x * (1 - t_y)
w_10 = (1 - t_x) * t_y
w_11 = t_x * t_y

print(f"\n6. INTERPOLATION WEIGHTS:")
print(f"   w_00 = (1 - t_x) * (1 - t_y) = (1 - {t_x:.6f}) * (1 - {t_y:.6f}) = {w_00:.6f}")
print(f"   w_01 = t_x * (1 - t_y)       = {t_x:.6f} * (1 - {t_y:.6f})       = {w_01:.6f}")
print(f"   w_10 = (1 - t_x) * t_y       = (1 - {t_x:.6f}) * {t_y:.6f}       = {w_10:.6f}")
print(f"   w_11 = t_x * t_y             = {t_x:.6f} * {t_y:.6f}             = {w_11:.6f}")
print(f"   Sum of weights = {w_00 + w_01 + w_10 + w_11:.6f} (should be 1.0)")

interpolated_value = w_00 * f_00 + w_01 * f_01 + w_10 * f_10 + w_11 * f_11

print(f"\n7. FINAL CALCULATION:")
print(f"   Value = w_00*f_00 + w_01*f_01 + w_10*f_10 + w_11*f_11")
print(f"   Value = {w_00:.6f}*{f_00:5.1f} + {w_01:.6f}*{f_01:5.1f} + {w_10:.6f}*{f_10:5.1f} + {w_11:.6f}*{f_11:5.1f}")
print(f"   Value = {w_00*f_00:8.4f} + {w_01*f_01:8.4f} + {w_10*f_10:8.4f} + {w_11*f_11:8.4f}")
print(f"   Value = {interpolated_value:.6f}")

print(f"\n8. TARGET POINT RELATIVE POSITION:")
print(f"   In X direction (longitude): {t_x*100:.2f}% of the way from {lon_min}° to {lon_max}°")
print(f"   In Y direction (latitude):  {t_y*100:.2f}% of the way from {lat_min}° to {lat_max}°")

print(f"\n{'='*60}")
print(f"FINAL RESULT: TEC = {interpolated_value:.4f}")
print(f"{'='*60}")
# Out:
# ============================================================
# DETAILED BILINEAR INTERPOLATION ANALYSIS
# ============================================================
#
# 1. THE 4 CLOSEST POINTS:
#    P1: ( -16.0°,  -48.0°) - Indexes: [128, 124] - TEC:  92.5
#    P2: ( -16.0°,  -47.5°) - Indexes: [128, 125] - TEC:  94.9
#    P3: ( -15.5°,  -48.0°) - Indexes: [129, 124] - TEC:  93.6
#    P4: ( -15.5°,  -47.5°) - Indexes: [129, 125] - TEC:  93.8
#
# 2. TARGET POINT: (-15.94748°, -47.87787°)
#
# 3. INTERPOLATION RECTANGLE BOUNDS:
#    Latitude:   -16.0° to  -15.5° (range:  0.5°)
#    Longitude:  -48.0° to  -47.5° (range:  0.5°)
#
# 4. TEC VALUES MAPPING:
#    f_00 (lat_min, lon_min) = ( -16.0°,  -48.0°) =  92.5
#    f_01 (lat_min, lon_max) = ( -16.0°,  -47.5°) =  94.9
#    f_10 (lat_max, lon_min) = ( -15.5°,  -48.0°) =  93.6
#    f_11 (lat_max, lon_max) = ( -15.5°,  -47.5°) =  93.8
#
# 5. INTERPOLATION PARAMETERS:
#    t_x = (target_lon - lon_min) / (lon_max - lon_min)
#    t_x = (-47.87787 - ( -48.0)) / ( -47.5 - ( -48.0))
#    t_x = 0.12213 /  0.5 = 0.244260
#
#    t_y = (target_lat - lat_min) / (lat_max - lat_min)
#    t_y = (-15.94748 - ( -16.0)) / ( -15.5 - ( -16.0))
#    t_y = 0.05252 /  0.5 = 0.105040
#
# 6. INTERPOLATION WEIGHTS:
#    w_00 = (1 - t_x) * (1 - t_y) = (1 - 0.244260) * (1 - 0.105040) = 0.676357
#    w_01 = t_x * (1 - t_y)       = 0.244260 * (1 - 0.105040)       = 0.218603
#    w_10 = (1 - t_x) * t_y       = (1 - 0.244260) * 0.105040       = 0.079383
#    w_11 = t_x * t_y             = 0.244260 * 0.105040             = 0.025657
#    Sum of weights = 1.000000 (should be 1.0)
#
# 7. FINAL CALCULATION:
#    Value = w_00*f_00 + w_01*f_01 + w_10*f_10 + w_11*f_11
#    Value = 0.676357* 92.5 + 0.218603* 94.9 + 0.079383* 93.6 + 0.025657* 93.8
#    Value =  62.5806 +  20.7518 +   7.4321 +   2.4074
#    Value = 93.171949
#
# 8. TARGET POINT RELATIVE POSITION:
#    In X direction (longitude): 24.43% of the way from -48.0° to -47.5°
#    In Y direction (latitude):  10.50% of the way from -16.0° to -15.5°
#
# ============================================================
# FINAL RESULT: TEC = 93.1719
# ============================================================

# %% [markdown]
# ### 12/18 - 18:00

# %%
import pandas as pd

date = '2024-12-18'
time = '18:00:00'
timestamp_wanted = f'{date} {time}'

result = df_maggia_maps_2024[df_maggia_maps_2024['DATETIME'] == timestamp_wanted]

if result.empty:
    df_temp = df_maggia_maps_2024.copy()
    df_temp['DATETIME'] = pd.to_datetime(df_temp['DATETIME'])
    timestamp_dt = pd.to_datetime(timestamp_wanted)

    df_temp['diff'] = abs((df_temp['DATETIME'] - timestamp_dt).dt.total_seconds())
    idx_nearest = df_temp['diff'].idxmin()

    result = df_maggia_maps_2024.iloc[[idx_nearest]]
    print(f"Exact date not found. Using closest record: {df_maggia_maps_2024.iloc[idx_nearest]['DATETIME']}")

# %%
result
# Out:
#                  DATETIME                                             TECMAP
# 13716 2024-12-18 18:00:00  [[nan, nan, nan, nan, nan, nan, nan, nan, nan,...

# %%
maggia_maps = np.array(result.iloc[:]['TECMAP'])

# %%
np_maggia_maps = []
for i in range(len(maggia_maps)):
    np_maggia_maps.append(maggia_maps[i])
np_maggia_maps = np.array(np_maggia_maps)

# %%
np_maggia_maps
# Out:
# array([[[        nan,         nan,         nan, ...,         nan,
#                  nan,         nan],
#         [        nan,         nan,         nan, ...,         nan,
#                  nan,         nan],
#         [        nan,         nan,         nan, ...,         nan,
#                  nan,         nan],
#         ...,
#         [34.4980011 , 34.72600174, 34.9109993 , ..., 13.43500042,
#          13.27900028, 12.76099968],
#         [34.2859993 , 34.53300095, 34.74300003, ..., 13.2489996 ,
#          12.7510004 , 12.31400013],
#         [34.10699844, 34.35800171, 34.58399963, ..., 12.86299992,
#          12.45899963, 12.0880003 ]]])

# %%
np_maggia_maps.shape
# Out:
# (1, 241, 221)

# %%
maggia_tec.tec_map = np_maggia_maps[0]

print("=" * 60)
print("DETAILED BILINEAR INTERPOLATION ANALYSIS")
print("=" * 60)

print("\n1. THE 4 CLOSEST POINTS:")
for i, point in enumerate(maggia_points):
    lat, lon, lat_idx, lon_idx = point
    tec_value = maggia_tec.tec_map[lat_idx, lon_idx]
    print(f"   P{i+1}: ({lat:+6.1f}°, {lon:+6.1f}°) - Indexes: [{lat_idx:2d}, {lon_idx:2d}] - TEC: {tec_value:5.1f}")

target_lat = -15.94748
target_lon = -47.87787

print(f"\n2. TARGET POINT: ({target_lat:+6.5f}°, {target_lon:+6.5f}°)")

values = []
for point in maggia_points:
    lat, lon, lat_idx, lon_idx = point
    values.append(maggia_tec.tec_map[lat_idx, lon_idx])

lats = [p[0] for p in maggia_points]
lons = [p[1] for p in maggia_points]

lat_min, lat_max = min(lats), max(lats)
lon_min, lon_max = min(lons), max(lons)

print(f"\n3. INTERPOLATION RECTANGLE BOUNDS:")
print(f"   Latitude:  {lat_min:+6.1f}° to {lat_max:+6.1f}° (range: {lat_max - lat_min:4.1f}°)")
print(f"   Longitude: {lon_min:+6.1f}° to {lon_max:+6.1f}° (range: {lon_max - lon_min:4.1f}°)")

point_values = {}
for i, point in enumerate(maggia_points):
    point_values[(point[0], point[1])] = values[i]

f_00 = point_values[(lat_min, lon_min)]
f_01 = point_values[(lat_min, lon_max)]
f_10 = point_values[(lat_max, lon_min)]
f_11 = point_values[(lat_max, lon_max)]

print(f"\n4. TEC VALUES MAPPING:")
print(f"   f_00 (lat_min, lon_min) = ({lat_min:+6.1f}°, {lon_min:+6.1f}°) = {f_00:5.1f}")
print(f"   f_01 (lat_min, lon_max) = ({lat_min:+6.1f}°, {lon_max:+6.1f}°) = {f_01:5.1f}")
print(f"   f_10 (lat_max, lon_min) = ({lat_max:+6.1f}°, {lon_min:+6.1f}°) = {f_10:5.1f}")
print(f"   f_11 (lat_max, lon_max) = ({lat_max:+6.1f}°, {lon_max:+6.1f}°) = {f_11:5.1f}")

t_x = (target_lon - lon_min) / (lon_max - lon_min) if lon_max != lon_min else 0
t_y = (target_lat - lat_min) / (lat_max - lat_min) if lat_max != lat_min else 0

print(f"\n5. INTERPOLATION PARAMETERS:")
print(f"   t_x = (target_lon - lon_min) / (lon_max - lon_min)")
print(f"   t_x = ({target_lon:+6.5f} - ({lon_min:+6.1f})) / ({lon_max:+6.1f} - ({lon_min:+6.1f}))")
print(f"   t_x = {target_lon - lon_min:6.5f} / {lon_max - lon_min:4.1f} = {t_x:.6f}")
print(f"   ")
print(f"   t_y = (target_lat - lat_min) / (lat_max - lat_min)")
print(f"   t_y = ({target_lat:+6.5f} - ({lat_min:+6.1f})) / ({lat_max:+6.1f} - ({lat_min:+6.1f}))")
print(f"   t_y = {target_lat - lat_min:6.5f} / {lat_max - lat_min:4.1f} = {t_y:.6f}")

w_00 = (1 - t_x) * (1 - t_y)
w_01 = t_x * (1 - t_y)
w_10 = (1 - t_x) * t_y
w_11 = t_x * t_y

print(f"\n6. INTERPOLATION WEIGHTS:")
print(f"   w_00 = (1 - t_x) * (1 - t_y) = (1 - {t_x:.6f}) * (1 - {t_y:.6f}) = {w_00:.6f}")
print(f"   w_01 = t_x * (1 - t_y)       = {t_x:.6f} * (1 - {t_y:.6f})       = {w_01:.6f}")
print(f"   w_10 = (1 - t_x) * t_y       = (1 - {t_x:.6f}) * {t_y:.6f}       = {w_10:.6f}")
print(f"   w_11 = t_x * t_y             = {t_x:.6f} * {t_y:.6f}             = {w_11:.6f}")
print(f"   Sum of weights = {w_00 + w_01 + w_10 + w_11:.6f} (should be 1.0)")

interpolated_value = w_00 * f_00 + w_01 * f_01 + w_10 * f_10 + w_11 * f_11

print(f"\n7. FINAL CALCULATION:")
print(f"   Value = w_00*f_00 + w_01*f_01 + w_10*f_10 + w_11*f_11")
print(f"   Value = {w_00:.6f}*{f_00:5.1f} + {w_01:.6f}*{f_01:5.1f} + {w_10:.6f}*{f_10:5.1f} + {w_11:.6f}*{f_11:5.1f}")
print(f"   Value = {w_00*f_00:8.4f} + {w_01*f_01:8.4f} + {w_10*f_10:8.4f} + {w_11*f_11:8.4f}")
print(f"   Value = {interpolated_value:.6f}")

print(f"\n8. TARGET POINT RELATIVE POSITION:")
print(f"   In X direction (longitude): {t_x*100:.2f}% of the way from {lon_min}° to {lon_max}°")
print(f"   In Y direction (latitude):  {t_y*100:.2f}% of the way from {lat_min}° to {lat_max}°")

print(f"\n{'='*60}")
print(f"FINAL RESULT: TEC = {interpolated_value:.4f}")
print(f"{'='*60}")
# Out:
# ============================================================
# DETAILED BILINEAR INTERPOLATION ANALYSIS
# ============================================================
#
# 1. THE 4 CLOSEST POINTS:
#    P1: ( -16.0°,  -48.0°) - Indexes: [128, 124] - TEC: 100.4
#    P2: ( -16.0°,  -47.5°) - Indexes: [128, 125] - TEC:  97.8
#    P3: ( -15.5°,  -48.0°) - Indexes: [129, 124] - TEC: 100.9
#    P4: ( -15.5°,  -47.5°) - Indexes: [129, 125] - TEC:  97.8
#
# 2. TARGET POINT: (-15.94748°, -47.87787°)
#
# 3. INTERPOLATION RECTANGLE BOUNDS:
#    Latitude:   -16.0° to  -15.5° (range:  0.5°)
#    Longitude:  -48.0° to  -47.5° (range:  0.5°)
#
# 4. TEC VALUES MAPPING:
#    f_00 (lat_min, lon_min) = ( -16.0°,  -48.0°) = 100.4
#    f_01 (lat_min, lon_max) = ( -16.0°,  -47.5°) =  97.8
#    f_10 (lat_max, lon_min) = ( -15.5°,  -48.0°) = 100.9
#    f_11 (lat_max, lon_max) = ( -15.5°,  -47.5°) =  97.8
#
# 5. INTERPOLATION PARAMETERS:
#    t_x = (target_lon - lon_min) / (lon_max - lon_min)
#    t_x = (-47.87787 - ( -48.0)) / ( -47.5 - ( -48.0))
#    t_x = 0.12213 /  0.5 = 0.244260
#
#    t_y = (target_lat - lat_min) / (lat_max - lat_min)
#    t_y = (-15.94748 - ( -16.0)) / ( -15.5 - ( -16.0))
#    t_y = 0.05252 /  0.5 = 0.105040
#
# 6. INTERPOLATION WEIGHTS:
#    w_00 = (1 - t_x) * (1 - t_y) = (1 - 0.244260) * (1 - 0.105040) = 0.676357
#    w_01 = t_x * (1 - t_y)       = 0.244260 * (1 - 0.105040)       = 0.218603
#    w_10 = (1 - t_x) * t_y       = (1 - 0.244260) * 0.105040       = 0.079383
#    w_11 = t_x * t_y             = 0.244260 * 0.105040             = 0.025657
#    Sum of weights = 1.000000 (should be 1.0)
#
# 7. FINAL CALCULATION:
#    Value = w_00*f_00 + w_01*f_01 + w_10*f_10 + w_11*f_11
#    Value = 0.676357*100.4 + 0.218603* 97.8 + 0.079383*100.9 + 0.025657* 97.8
#    Value =  67.8860 +  21.3752 +   8.0106 +   2.5088
#    Value = 99.780559
#
# 8. TARGET POINT RELATIVE POSITION:
#    In X direction (longitude): 24.43% of the way from -48.0° to -47.5°
#    In Y direction (latitude):  10.50% of the way from -16.0° to -15.5°
#
# ============================================================
# FINAL RESULT: TEC = 99.7806
# ============================================================

# %% [markdown]
# ### 12/18 - 18:10

# %%
import pandas as pd

date = '2024-12-18'
time = '18:10:00'
timestamp_wanted = f'{date} {time}'

result = df_maggia_maps_2024[df_maggia_maps_2024['DATETIME'] == timestamp_wanted]

if result.empty:
    df_temp = df_maggia_maps_2024.copy()
    df_temp['DATETIME'] = pd.to_datetime(df_temp['DATETIME'])
    timestamp_dt = pd.to_datetime(timestamp_wanted)

    df_temp['diff'] = abs((df_temp['DATETIME'] - timestamp_dt).dt.total_seconds())
    idx_nearest = df_temp['diff'].idxmin()

    result = df_maggia_maps_2024.iloc[[idx_nearest]]
    print(f"Exact date not found. Using closest record: {df_maggia_maps_2024.iloc[idx_nearest]['DATETIME']}")

# %%
result
# Out:
#                  DATETIME                                             TECMAP
# 13717 2024-12-18 18:10:00  [[nan, nan, nan, nan, nan, nan, nan, nan, nan,...

# %%
maggia_maps = np.array(result.iloc[:]['TECMAP'])

# %%
np_maggia_maps = []
for i in range(len(maggia_maps)):
    np_maggia_maps.append(maggia_maps[i])
np_maggia_maps = np.array(np_maggia_maps)

# %%
np_maggia_maps
# Out:
# array([[[        nan,         nan,         nan, ...,         nan,
#                  nan,         nan],
#         [        nan,         nan,         nan, ...,         nan,
#                  nan,         nan],
#         [        nan,         nan,         nan, ...,         nan,
#                  nan,         nan],
#         ...,
#         [36.83499908, 37.06399918, 37.23899841, ..., 12.40799999,
#          12.40799999, 12.40799999],
#         [36.57699966, 36.82799911, 37.03300095, ..., 12.85900021,
#          12.6619997 , 12.54399967],
#         [36.34600067, 36.5909996 , 36.81399918, ..., 13.00500011,
#          12.82999992, 12.32600021]]])

# %%
np_maggia_maps.shape
# Out:
# (1, 241, 221)

# %%
maggia_tec.tec_map = np_maggia_maps[0]

print("=" * 60)
print("DETAILED BILINEAR INTERPOLATION ANALYSIS")
print("=" * 60)

print("\n1. THE 4 CLOSEST POINTS:")
for i, point in enumerate(maggia_points):
    lat, lon, lat_idx, lon_idx = point
    tec_value = maggia_tec.tec_map[lat_idx, lon_idx]
    print(f"   P{i+1}: ({lat:+6.1f}°, {lon:+6.1f}°) - Indexes: [{lat_idx:2d}, {lon_idx:2d}] - TEC: {tec_value:5.1f}")

target_lat = -15.94748
target_lon = -47.87787

print(f"\n2. TARGET POINT: ({target_lat:+6.5f}°, {target_lon:+6.5f}°)")

values = []
for point in maggia_points:
    lat, lon, lat_idx, lon_idx = point
    values.append(maggia_tec.tec_map[lat_idx, lon_idx])

lats = [p[0] for p in maggia_points]
lons = [p[1] for p in maggia_points]

lat_min, lat_max = min(lats), max(lats)
lon_min, lon_max = min(lons), max(lons)

print(f"\n3. INTERPOLATION RECTANGLE BOUNDS:")
print(f"   Latitude:  {lat_min:+6.1f}° to {lat_max:+6.1f}° (range: {lat_max - lat_min:4.1f}°)")
print(f"   Longitude: {lon_min:+6.1f}° to {lon_max:+6.1f}° (range: {lon_max - lon_min:4.1f}°)")

point_values = {}
for i, point in enumerate(maggia_points):
    point_values[(point[0], point[1])] = values[i]

f_00 = point_values[(lat_min, lon_min)]
f_01 = point_values[(lat_min, lon_max)]
f_10 = point_values[(lat_max, lon_min)]
f_11 = point_values[(lat_max, lon_max)]

print(f"\n4. TEC VALUES MAPPING:")
print(f"   f_00 (lat_min, lon_min) = ({lat_min:+6.1f}°, {lon_min:+6.1f}°) = {f_00:5.1f}")
print(f"   f_01 (lat_min, lon_max) = ({lat_min:+6.1f}°, {lon_max:+6.1f}°) = {f_01:5.1f}")
print(f"   f_10 (lat_max, lon_min) = ({lat_max:+6.1f}°, {lon_min:+6.1f}°) = {f_10:5.1f}")
print(f"   f_11 (lat_max, lon_max) = ({lat_max:+6.1f}°, {lon_max:+6.1f}°) = {f_11:5.1f}")

t_x = (target_lon - lon_min) / (lon_max - lon_min) if lon_max != lon_min else 0
t_y = (target_lat - lat_min) / (lat_max - lat_min) if lat_max != lat_min else 0

print(f"\n5. INTERPOLATION PARAMETERS:")
print(f"   t_x = (target_lon - lon_min) / (lon_max - lon_min)")
print(f"   t_x = ({target_lon:+6.5f} - ({lon_min:+6.1f})) / ({lon_max:+6.1f} - ({lon_min:+6.1f}))")
print(f"   t_x = {target_lon - lon_min:6.5f} / {lon_max - lon_min:4.1f} = {t_x:.6f}")
print(f"   ")
print(f"   t_y = (target_lat - lat_min) / (lat_max - lat_min)")
print(f"   t_y = ({target_lat:+6.5f} - ({lat_min:+6.1f})) / ({lat_max:+6.1f} - ({lat_min:+6.1f}))")
print(f"   t_y = {target_lat - lat_min:6.5f} / {lat_max - lat_min:4.1f} = {t_y:.6f}")

w_00 = (1 - t_x) * (1 - t_y)
w_01 = t_x * (1 - t_y)
w_10 = (1 - t_x) * t_y
w_11 = t_x * t_y

print(f"\n6. INTERPOLATION WEIGHTS:")
print(f"   w_00 = (1 - t_x) * (1 - t_y) = (1 - {t_x:.6f}) * (1 - {t_y:.6f}) = {w_00:.6f}")
print(f"   w_01 = t_x * (1 - t_y)       = {t_x:.6f} * (1 - {t_y:.6f})       = {w_01:.6f}")
print(f"   w_10 = (1 - t_x) * t_y       = (1 - {t_x:.6f}) * {t_y:.6f}       = {w_10:.6f}")
print(f"   w_11 = t_x * t_y             = {t_x:.6f} * {t_y:.6f}             = {w_11:.6f}")
print(f"   Sum of weights = {w_00 + w_01 + w_10 + w_11:.6f} (should be 1.0)")

interpolated_value = w_00 * f_00 + w_01 * f_01 + w_10 * f_10 + w_11 * f_11

print(f"\n7. FINAL CALCULATION:")
print(f"   Value = w_00*f_00 + w_01*f_01 + w_10*f_10 + w_11*f_11")
print(f"   Value = {w_00:.6f}*{f_00:5.1f} + {w_01:.6f}*{f_01:5.1f} + {w_10:.6f}*{f_10:5.1f} + {w_11:.6f}*{f_11:5.1f}")
print(f"   Value = {w_00*f_00:8.4f} + {w_01*f_01:8.4f} + {w_10*f_10:8.4f} + {w_11*f_11:8.4f}")
print(f"   Value = {interpolated_value:.6f}")

print(f"\n8. TARGET POINT RELATIVE POSITION:")
print(f"   In X direction (longitude): {t_x*100:.2f}% of the way from {lon_min}° to {lon_max}°")
print(f"   In Y direction (latitude):  {t_y*100:.2f}% of the way from {lat_min}° to {lat_max}°")

print(f"\n{'='*60}")
print(f"FINAL RESULT: TEC = {interpolated_value:.4f}")
print(f"{'='*60}")
# Out:
# ============================================================
# DETAILED BILINEAR INTERPOLATION ANALYSIS
# ============================================================
#
# 1. THE 4 CLOSEST POINTS:
#    P1: ( -16.0°,  -48.0°) - Indexes: [128, 124] - TEC: 100.4
#    P2: ( -16.0°,  -47.5°) - Indexes: [128, 125] - TEC: 101.1
#    P3: ( -15.5°,  -48.0°) - Indexes: [129, 124] - TEC: 100.3
#    P4: ( -15.5°,  -47.5°) - Indexes: [129, 125] - TEC:  99.6
#
# 2. TARGET POINT: (-15.94748°, -47.87787°)
#
# 3. INTERPOLATION RECTANGLE BOUNDS:
#    Latitude:   -16.0° to  -15.5° (range:  0.5°)
#    Longitude:  -48.0° to  -47.5° (range:  0.5°)
#
# 4. TEC VALUES MAPPING:
#    f_00 (lat_min, lon_min) = ( -16.0°,  -48.0°) = 100.4
#    f_01 (lat_min, lon_max) = ( -16.0°,  -47.5°) = 101.1
#    f_10 (lat_max, lon_min) = ( -15.5°,  -48.0°) = 100.3
#    f_11 (lat_max, lon_max) = ( -15.5°,  -47.5°) =  99.6
#
# 5. INTERPOLATION PARAMETERS:
#    t_x = (target_lon - lon_min) / (lon_max - lon_min)
#    t_x = (-47.87787 - ( -48.0)) / ( -47.5 - ( -48.0))
#    t_x = 0.12213 /  0.5 = 0.244260
#
#    t_y = (target_lat - lat_min) / (lat_max - lat_min)
#    t_y = (-15.94748 - ( -16.0)) / ( -15.5 - ( -16.0))
#    t_y = 0.05252 /  0.5 = 0.105040
#
# 6. INTERPOLATION WEIGHTS:
#    w_00 = (1 - t_x) * (1 - t_y) = (1 - 0.244260) * (1 - 0.105040) = 0.676357
#    w_01 = t_x * (1 - t_y)       = 0.244260 * (1 - 0.105040)       = 0.218603
#    w_10 = (1 - t_x) * t_y       = (1 - 0.244260) * 0.105040       = 0.079383
#    w_11 = t_x * t_y             = 0.244260 * 0.105040             = 0.025657
#    Sum of weights = 1.000000 (should be 1.0)
#
# 7. FINAL CALCULATION:
#    Value = w_00*f_00 + w_01*f_01 + w_10*f_10 + w_11*f_11
#    Value = 0.676357*100.4 + 0.218603*101.1 + 0.079383*100.3 + 0.025657* 99.6
#    Value =  67.9177 +  22.1029 +   7.9610 +   2.5553
#    Value = 100.536952
#
# 8. TARGET POINT RELATIVE POSITION:
#    In X direction (longitude): 24.43% of the way from -48.0° to -47.5°
#    In Y direction (latitude):  10.50% of the way from -16.0° to -15.5°
#
# ============================================================
# FINAL RESULT: TEC = 100.5370
# ============================================================

# %% [markdown]
# ### 12/18 - 18:20

# %%
import pandas as pd

date = '2024-12-18'
time = '18:20:00'
timestamp_wanted = f'{date} {time}'

result = df_maggia_maps_2024[df_maggia_maps_2024['DATETIME'] == timestamp_wanted]

if result.empty:
    df_temp = df_maggia_maps_2024.copy()
    df_temp['DATETIME'] = pd.to_datetime(df_temp['DATETIME'])
    timestamp_dt = pd.to_datetime(timestamp_wanted)

    df_temp['diff'] = abs((df_temp['DATETIME'] - timestamp_dt).dt.total_seconds())
    idx_nearest = df_temp['diff'].idxmin()

    result = df_maggia_maps_2024.iloc[[idx_nearest]]
    print(f"Exact date not found. Using closest record: {df_maggia_maps_2024.iloc[idx_nearest]['DATETIME']}")

# %%
result
# Out:
#                  DATETIME                                             TECMAP
# 13718 2024-12-18 18:20:00  [[nan, nan, nan, nan, nan, nan, nan, nan, nan,...

# %%
maggia_maps = np.array(result.iloc[:]['TECMAP'])

# %%
np_maggia_maps = []
for i in range(len(maggia_maps)):
    np_maggia_maps.append(maggia_maps[i])
np_maggia_maps = np.array(np_maggia_maps)

# %%
np_maggia_maps
# Out:
# array([[[        nan,         nan,         nan, ...,         nan,
#                  nan,         nan],
#         [        nan,         nan,         nan, ...,         nan,
#                  nan,         nan],
#         [        nan,         nan,         nan, ...,         nan,
#                  nan,         nan],
#         ...,
#         [40.14899826, 40.15000153, 40.18000031, ..., 13.84500027,
#          13.67500019, 13.12800026],
#         [39.97399902, 40.02799988, 40.15399933, ..., 13.75800037,
#          13.67599964, 12.39599991],
#         [39.73500061, 39.83499908, 40.02500153, ..., 13.10700035,
#          12.6239996 , 12.06000042]]])

# %%
np_maggia_maps.shape
# Out:
# (1, 241, 221)

# %%
maggia_tec.tec_map = np_maggia_maps[0]

print("=" * 60)
print("DETAILED BILINEAR INTERPOLATION ANALYSIS")
print("=" * 60)

print("\n1. THE 4 CLOSEST POINTS:")
for i, point in enumerate(maggia_points):
    lat, lon, lat_idx, lon_idx = point
    tec_value = maggia_tec.tec_map[lat_idx, lon_idx]
    print(f"   P{i+1}: ({lat:+6.1f}°, {lon:+6.1f}°) - Indexes: [{lat_idx:2d}, {lon_idx:2d}] - TEC: {tec_value:5.1f}")

target_lat = -15.94748
target_lon = -47.87787

print(f"\n2. TARGET POINT: ({target_lat:+6.5f}°, {target_lon:+6.5f}°)")

values = []
for point in maggia_points:
    lat, lon, lat_idx, lon_idx = point
    values.append(maggia_tec.tec_map[lat_idx, lon_idx])

lats = [p[0] for p in maggia_points]
lons = [p[1] for p in maggia_points]

lat_min, lat_max = min(lats), max(lats)
lon_min, lon_max = min(lons), max(lons)

print(f"\n3. INTERPOLATION RECTANGLE BOUNDS:")
print(f"   Latitude:  {lat_min:+6.1f}° to {lat_max:+6.1f}° (range: {lat_max - lat_min:4.1f}°)")
print(f"   Longitude: {lon_min:+6.1f}° to {lon_max:+6.1f}° (range: {lon_max - lon_min:4.1f}°)")

point_values = {}
for i, point in enumerate(maggia_points):
    point_values[(point[0], point[1])] = values[i]

f_00 = point_values[(lat_min, lon_min)]
f_01 = point_values[(lat_min, lon_max)]
f_10 = point_values[(lat_max, lon_min)]
f_11 = point_values[(lat_max, lon_max)]

print(f"\n4. TEC VALUES MAPPING:")
print(f"   f_00 (lat_min, lon_min) = ({lat_min:+6.1f}°, {lon_min:+6.1f}°) = {f_00:5.1f}")
print(f"   f_01 (lat_min, lon_max) = ({lat_min:+6.1f}°, {lon_max:+6.1f}°) = {f_01:5.1f}")
print(f"   f_10 (lat_max, lon_min) = ({lat_max:+6.1f}°, {lon_min:+6.1f}°) = {f_10:5.1f}")
print(f"   f_11 (lat_max, lon_max) = ({lat_max:+6.1f}°, {lon_max:+6.1f}°) = {f_11:5.1f}")

t_x = (target_lon - lon_min) / (lon_max - lon_min) if lon_max != lon_min else 0
t_y = (target_lat - lat_min) / (lat_max - lat_min) if lat_max != lat_min else 0

print(f"\n5. INTERPOLATION PARAMETERS:")
print(f"   t_x = (target_lon - lon_min) / (lon_max - lon_min)")
print(f"   t_x = ({target_lon:+6.5f} - ({lon_min:+6.1f})) / ({lon_max:+6.1f} - ({lon_min:+6.1f}))")
print(f"   t_x = {target_lon - lon_min:6.5f} / {lon_max - lon_min:4.1f} = {t_x:.6f}")
print(f"   ")
print(f"   t_y = (target_lat - lat_min) / (lat_max - lat_min)")
print(f"   t_y = ({target_lat:+6.5f} - ({lat_min:+6.1f})) / ({lat_max:+6.1f} - ({lat_min:+6.1f}))")
print(f"   t_y = {target_lat - lat_min:6.5f} / {lat_max - lat_min:4.1f} = {t_y:.6f}")

w_00 = (1 - t_x) * (1 - t_y)
w_01 = t_x * (1 - t_y)
w_10 = (1 - t_x) * t_y
w_11 = t_x * t_y

print(f"\n6. INTERPOLATION WEIGHTS:")
print(f"   w_00 = (1 - t_x) * (1 - t_y) = (1 - {t_x:.6f}) * (1 - {t_y:.6f}) = {w_00:.6f}")
print(f"   w_01 = t_x * (1 - t_y)       = {t_x:.6f} * (1 - {t_y:.6f})       = {w_01:.6f}")
print(f"   w_10 = (1 - t_x) * t_y       = (1 - {t_x:.6f}) * {t_y:.6f}       = {w_10:.6f}")
print(f"   w_11 = t_x * t_y             = {t_x:.6f} * {t_y:.6f}             = {w_11:.6f}")
print(f"   Sum of weights = {w_00 + w_01 + w_10 + w_11:.6f} (should be 1.0)")

interpolated_value = w_00 * f_00 + w_01 * f_01 + w_10 * f_10 + w_11 * f_11

print(f"\n7. FINAL CALCULATION:")
print(f"   Value = w_00*f_00 + w_01*f_01 + w_10*f_10 + w_11*f_11")
print(f"   Value = {w_00:.6f}*{f_00:5.1f} + {w_01:.6f}*{f_01:5.1f} + {w_10:.6f}*{f_10:5.1f} + {w_11:.6f}*{f_11:5.1f}")
print(f"   Value = {w_00*f_00:8.4f} + {w_01*f_01:8.4f} + {w_10*f_10:8.4f} + {w_11*f_11:8.4f}")
print(f"   Value = {interpolated_value:.6f}")

print(f"\n8. TARGET POINT RELATIVE POSITION:")
print(f"   In X direction (longitude): {t_x*100:.2f}% of the way from {lon_min}° to {lon_max}°")
print(f"   In Y direction (latitude):  {t_y*100:.2f}% of the way from {lat_min}° to {lat_max}°")

print(f"\n{'='*60}")
print(f"FINAL RESULT: TEC = {interpolated_value:.4f}")
print(f"{'='*60}")
# Out:
# ============================================================
# DETAILED BILINEAR INTERPOLATION ANALYSIS
# ============================================================
#
# 1. THE 4 CLOSEST POINTS:
#    P1: ( -16.0°,  -48.0°) - Indexes: [128, 124] - TEC: 101.5
#    P2: ( -16.0°,  -47.5°) - Indexes: [128, 125] - TEC: 102.8
#    P3: ( -15.5°,  -48.0°) - Indexes: [129, 124] - TEC: 103.5
#    P4: ( -15.5°,  -47.5°) - Indexes: [129, 125] - TEC: 102.8
#
# 2. TARGET POINT: (-15.94748°, -47.87787°)
#
# 3. INTERPOLATION RECTANGLE BOUNDS:
#    Latitude:   -16.0° to  -15.5° (range:  0.5°)
#    Longitude:  -48.0° to  -47.5° (range:  0.5°)
#
# 4. TEC VALUES MAPPING:
#    f_00 (lat_min, lon_min) = ( -16.0°,  -48.0°) = 101.5
#    f_01 (lat_min, lon_max) = ( -16.0°,  -47.5°) = 102.8
#    f_10 (lat_max, lon_min) = ( -15.5°,  -48.0°) = 103.5
#    f_11 (lat_max, lon_max) = ( -15.5°,  -47.5°) = 102.8
#
# 5. INTERPOLATION PARAMETERS:
#    t_x = (target_lon - lon_min) / (lon_max - lon_min)
#    t_x = (-47.87787 - ( -48.0)) / ( -47.5 - ( -48.0))
#    t_x = 0.12213 /  0.5 = 0.244260
#
#    t_y = (target_lat - lat_min) / (lat_max - lat_min)
#    t_y = (-15.94748 - ( -16.0)) / ( -15.5 - ( -16.0))
#    t_y = 0.05252 /  0.5 = 0.105040
#
# 6. INTERPOLATION WEIGHTS:
#    w_00 = (1 - t_x) * (1 - t_y) = (1 - 0.244260) * (1 - 0.105040) = 0.676357
#    w_01 = t_x * (1 - t_y)       = 0.244260 * (1 - 0.105040)       = 0.218603
#    w_10 = (1 - t_x) * t_y       = (1 - 0.244260) * 0.105040       = 0.079383
#    w_11 = t_x * t_y             = 0.244260 * 0.105040             = 0.025657
#    Sum of weights = 1.000000 (should be 1.0)
#
# 7. FINAL CALCULATION:
#    Value = w_00*f_00 + w_01*f_01 + w_10*f_10 + w_11*f_11
#    Value = 0.676357*101.5 + 0.218603*102.8 + 0.079383*103.5 + 0.025657*102.8
#    Value =  68.6543 +  22.4630 +   8.2154 +   2.6364
#    Value = 101.969143
#
# 8. TARGET POINT RELATIVE POSITION:
#    In X direction (longitude): 24.43% of the way from -48.0° to -47.5°
#    In Y direction (latitude):  10.50% of the way from -16.0° to -15.5°
#
# ============================================================
# FINAL RESULT: TEC = 101.9691
# ============================================================

# %% [markdown]
# ### 12/18 - 18:30

# %%
import pandas as pd

date = '2024-12-18'
time = '18:30:00'
timestamp_wanted = f'{date} {time}'

result = df_maggia_maps_2024[df_maggia_maps_2024['DATETIME'] == timestamp_wanted]

if result.empty:
    df_temp = df_maggia_maps_2024.copy()
    df_temp['DATETIME'] = pd.to_datetime(df_temp['DATETIME'])
    timestamp_dt = pd.to_datetime(timestamp_wanted)

    df_temp['diff'] = abs((df_temp['DATETIME'] - timestamp_dt).dt.total_seconds())
    idx_nearest = df_temp['diff'].idxmin()

    result = df_maggia_maps_2024.iloc[[idx_nearest]]
    print(f"Exact date not found. Using closest record: {df_maggia_maps_2024.iloc[idx_nearest]['DATETIME']}")

# %%
result
# Out:
#                  DATETIME                                             TECMAP
# 13719 2024-12-18 18:30:00  [[nan, nan, nan, nan, nan, nan, nan, nan, nan,...

# %%
maggia_maps = np.array(result.iloc[:]['TECMAP'])

# %%
np_maggia_maps = []
for i in range(len(maggia_maps)):
    np_maggia_maps.append(maggia_maps[i])
np_maggia_maps = np.array(np_maggia_maps)

# %%
np_maggia_maps
# Out:
# array([[[        nan,         nan,         nan, ...,         nan,
#                  nan,         nan],
#         [        nan,         nan,         nan, ...,         nan,
#                  nan,         nan],
#         [        nan,         nan,         nan, ...,         nan,
#                  nan,         nan],
#         ...,
#         [41.94900131, 41.94900131, 41.94900131, ..., 11.0880003 ,
#          11.0880003 , 11.0880003 ],
#         [41.94400024, 41.94400024, 41.94499969, ..., 11.0880003 ,
#          11.0880003 , 11.0880003 ],
#         [41.89500046, 41.89799881, 41.90100098, ..., 11.36600018,
#          11.25800037, 11.1960001 ]]])

# %%
np_maggia_maps.shape
# Out:
# (1, 241, 221)

# %%
maggia_tec.tec_map = np_maggia_maps[0]

print("=" * 60)
print("DETAILED BILINEAR INTERPOLATION ANALYSIS")
print("=" * 60)

print("\n1. THE 4 CLOSEST POINTS:")
for i, point in enumerate(maggia_points):
    lat, lon, lat_idx, lon_idx = point
    tec_value = maggia_tec.tec_map[lat_idx, lon_idx]
    print(f"   P{i+1}: ({lat:+6.1f}°, {lon:+6.1f}°) - Indexes: [{lat_idx:2d}, {lon_idx:2d}] - TEC: {tec_value:5.1f}")

target_lat = -15.94748
target_lon = -47.87787

print(f"\n2. TARGET POINT: ({target_lat:+6.5f}°, {target_lon:+6.5f}°)")

values = []
for point in maggia_points:
    lat, lon, lat_idx, lon_idx = point
    values.append(maggia_tec.tec_map[lat_idx, lon_idx])

lats = [p[0] for p in maggia_points]
lons = [p[1] for p in maggia_points]

lat_min, lat_max = min(lats), max(lats)
lon_min, lon_max = min(lons), max(lons)

print(f"\n3. INTERPOLATION RECTANGLE BOUNDS:")
print(f"   Latitude:  {lat_min:+6.1f}° to {lat_max:+6.1f}° (range: {lat_max - lat_min:4.1f}°)")
print(f"   Longitude: {lon_min:+6.1f}° to {lon_max:+6.1f}° (range: {lon_max - lon_min:4.1f}°)")

point_values = {}
for i, point in enumerate(maggia_points):
    point_values[(point[0], point[1])] = values[i]

f_00 = point_values[(lat_min, lon_min)]
f_01 = point_values[(lat_min, lon_max)]
f_10 = point_values[(lat_max, lon_min)]
f_11 = point_values[(lat_max, lon_max)]

print(f"\n4. TEC VALUES MAPPING:")
print(f"   f_00 (lat_min, lon_min) = ({lat_min:+6.1f}°, {lon_min:+6.1f}°) = {f_00:5.1f}")
print(f"   f_01 (lat_min, lon_max) = ({lat_min:+6.1f}°, {lon_max:+6.1f}°) = {f_01:5.1f}")
print(f"   f_10 (lat_max, lon_min) = ({lat_max:+6.1f}°, {lon_min:+6.1f}°) = {f_10:5.1f}")
print(f"   f_11 (lat_max, lon_max) = ({lat_max:+6.1f}°, {lon_max:+6.1f}°) = {f_11:5.1f}")

t_x = (target_lon - lon_min) / (lon_max - lon_min) if lon_max != lon_min else 0
t_y = (target_lat - lat_min) / (lat_max - lat_min) if lat_max != lat_min else 0

print(f"\n5. INTERPOLATION PARAMETERS:")
print(f"   t_x = (target_lon - lon_min) / (lon_max - lon_min)")
print(f"   t_x = ({target_lon:+6.5f} - ({lon_min:+6.1f})) / ({lon_max:+6.1f} - ({lon_min:+6.1f}))")
print(f"   t_x = {target_lon - lon_min:6.5f} / {lon_max - lon_min:4.1f} = {t_x:.6f}")
print(f"   ")
print(f"   t_y = (target_lat - lat_min) / (lat_max - lat_min)")
print(f"   t_y = ({target_lat:+6.5f} - ({lat_min:+6.1f})) / ({lat_max:+6.1f} - ({lat_min:+6.1f}))")
print(f"   t_y = {target_lat - lat_min:6.5f} / {lat_max - lat_min:4.1f} = {t_y:.6f}")

w_00 = (1 - t_x) * (1 - t_y)
w_01 = t_x * (1 - t_y)
w_10 = (1 - t_x) * t_y
w_11 = t_x * t_y

print(f"\n6. INTERPOLATION WEIGHTS:")
print(f"   w_00 = (1 - t_x) * (1 - t_y) = (1 - {t_x:.6f}) * (1 - {t_y:.6f}) = {w_00:.6f}")
print(f"   w_01 = t_x * (1 - t_y)       = {t_x:.6f} * (1 - {t_y:.6f})       = {w_01:.6f}")
print(f"   w_10 = (1 - t_x) * t_y       = (1 - {t_x:.6f}) * {t_y:.6f}       = {w_10:.6f}")
print(f"   w_11 = t_x * t_y             = {t_x:.6f} * {t_y:.6f}             = {w_11:.6f}")
print(f"   Sum of weights = {w_00 + w_01 + w_10 + w_11:.6f} (should be 1.0)")

interpolated_value = w_00 * f_00 + w_01 * f_01 + w_10 * f_10 + w_11 * f_11

print(f"\n7. FINAL CALCULATION:")
print(f"   Value = w_00*f_00 + w_01*f_01 + w_10*f_10 + w_11*f_11")
print(f"   Value = {w_00:.6f}*{f_00:5.1f} + {w_01:.6f}*{f_01:5.1f} + {w_10:.6f}*{f_10:5.1f} + {w_11:.6f}*{f_11:5.1f}")
print(f"   Value = {w_00*f_00:8.4f} + {w_01*f_01:8.4f} + {w_10*f_10:8.4f} + {w_11*f_11:8.4f}")
print(f"   Value = {interpolated_value:.6f}")

print(f"\n8. TARGET POINT RELATIVE POSITION:")
print(f"   In X direction (longitude): {t_x*100:.2f}% of the way from {lon_min}° to {lon_max}°")
print(f"   In Y direction (latitude):  {t_y*100:.2f}% of the way from {lat_min}° to {lat_max}°")

print(f"\n{'='*60}")
print(f"FINAL RESULT: TEC = {interpolated_value:.4f}")
print(f"{'='*60}")
# Out:
# ============================================================
# DETAILED BILINEAR INTERPOLATION ANALYSIS
# ============================================================
#
# 1. THE 4 CLOSEST POINTS:
#    P1: ( -16.0°,  -48.0°) - Indexes: [128, 124] - TEC:  97.8
#    P2: ( -16.0°,  -47.5°) - Indexes: [128, 125] - TEC:  95.6
#    P3: ( -15.5°,  -48.0°) - Indexes: [129, 124] - TEC: 100.8
#    P4: ( -15.5°,  -47.5°) - Indexes: [129, 125] - TEC: 102.0
#
# 2. TARGET POINT: (-15.94748°, -47.87787°)
#
# 3. INTERPOLATION RECTANGLE BOUNDS:
#    Latitude:   -16.0° to  -15.5° (range:  0.5°)
#    Longitude:  -48.0° to  -47.5° (range:  0.5°)
#
# 4. TEC VALUES MAPPING:
#    f_00 (lat_min, lon_min) = ( -16.0°,  -48.0°) =  97.8
#    f_01 (lat_min, lon_max) = ( -16.0°,  -47.5°) =  95.6
#    f_10 (lat_max, lon_min) = ( -15.5°,  -48.0°) = 100.8
#    f_11 (lat_max, lon_max) = ( -15.5°,  -47.5°) = 102.0
#
# 5. INTERPOLATION PARAMETERS:
#    t_x = (target_lon - lon_min) / (lon_max - lon_min)
#    t_x = (-47.87787 - ( -48.0)) / ( -47.5 - ( -48.0))
#    t_x = 0.12213 /  0.5 = 0.244260
#
#    t_y = (target_lat - lat_min) / (lat_max - lat_min)
#    t_y = (-15.94748 - ( -16.0)) / ( -15.5 - ( -16.0))
#    t_y = 0.05252 /  0.5 = 0.105040
#
# 6. INTERPOLATION WEIGHTS:
#    w_00 = (1 - t_x) * (1 - t_y) = (1 - 0.244260) * (1 - 0.105040) = 0.676357
#    w_01 = t_x * (1 - t_y)       = 0.244260 * (1 - 0.105040)       = 0.218603
#    w_10 = (1 - t_x) * t_y       = (1 - 0.244260) * 0.105040       = 0.079383
#    w_11 = t_x * t_y             = 0.244260 * 0.105040             = 0.025657
#    Sum of weights = 1.000000 (should be 1.0)
#
# 7. FINAL CALCULATION:
#    Value = w_00*f_00 + w_01*f_01 + w_10*f_10 + w_11*f_11
#    Value = 0.676357* 97.8 + 0.218603* 95.6 + 0.079383*100.8 + 0.025657*102.0
#    Value =  66.1464 +  20.8958 +   8.0028 +   2.6162
#    Value = 97.661240
#
# 8. TARGET POINT RELATIVE POSITION:
#    In X direction (longitude): 24.43% of the way from -48.0° to -47.5°
#    In Y direction (latitude):  10.50% of the way from -16.0° to -15.5°
#
# ============================================================
# FINAL RESULT: TEC = 97.6612
# ============================================================

# %% [markdown]
# ### 12/19 - 18:00

# %%
import pandas as pd

date = '2024-12-19'
time = '18:00:00'
timestamp_wanted = f'{date} {time}'

result = df_maggia_maps_2024[df_maggia_maps_2024['DATETIME'] == timestamp_wanted]

if result.empty:
    df_temp = df_maggia_maps_2024.copy()
    df_temp['DATETIME'] = pd.to_datetime(df_temp['DATETIME'])
    timestamp_dt = pd.to_datetime(timestamp_wanted)

    df_temp['diff'] = abs((df_temp['DATETIME'] - timestamp_dt).dt.total_seconds())
    idx_nearest = df_temp['diff'].idxmin()

    result = df_maggia_maps_2024.iloc[[idx_nearest]]
    print(f"Exact date not found. Using closest record: {df_maggia_maps_2024.iloc[idx_nearest]['DATETIME']}")

# %%
result
# Out:
#                  DATETIME                                             TECMAP
# 13860 2024-12-19 18:00:00  [[nan, nan, nan, nan, nan, nan, nan, nan, nan,...

# %%
maggia_maps = np.array(result.iloc[:]['TECMAP'])

# %%
np_maggia_maps = []
for i in range(len(maggia_maps)):
    np_maggia_maps.append(maggia_maps[i])
np_maggia_maps = np.array(np_maggia_maps)

# %%
np_maggia_maps
# Out:
# array([[[        nan,         nan,         nan, ...,         nan,
#                  nan,         nan],
#         [        nan,         nan,         nan, ...,         nan,
#                  nan,         nan],
#         [        nan,         nan,         nan, ...,         nan,
#                  nan,         nan],
#         ...,
#         [37.94499969, 38.06100082, 38.13499832, ..., 11.56599998,
#          11.17399979, 10.60200024],
#         [37.7840004 , 37.92599869, 38.02999878, ..., 11.47599983,
#          10.99199963, 10.38300037],
#         [37.63499832, 37.77899933, 37.90499878, ..., 11.36100006,
#          10.8739996 , 10.52200031]]])

# %%
np_maggia_maps.shape
# Out:
# (1, 241, 221)

# %%
maggia_tec.tec_map = np_maggia_maps[0]

print("=" * 60)
print("DETAILED BILINEAR INTERPOLATION ANALYSIS")
print("=" * 60)

print("\n1. THE 4 CLOSEST POINTS:")
for i, point in enumerate(maggia_points):
    lat, lon, lat_idx, lon_idx = point
    tec_value = maggia_tec.tec_map[lat_idx, lon_idx]
    print(f"   P{i+1}: ({lat:+6.1f}°, {lon:+6.1f}°) - Indexes: [{lat_idx:2d}, {lon_idx:2d}] - TEC: {tec_value:5.1f}")

target_lat = -15.94748
target_lon = -47.87787

print(f"\n2. TARGET POINT: ({target_lat:+6.5f}°, {target_lon:+6.5f}°)")

values = []
for point in maggia_points:
    lat, lon, lat_idx, lon_idx = point
    values.append(maggia_tec.tec_map[lat_idx, lon_idx])

lats = [p[0] for p in maggia_points]
lons = [p[1] for p in maggia_points]

lat_min, lat_max = min(lats), max(lats)
lon_min, lon_max = min(lons), max(lons)

print(f"\n3. INTERPOLATION RECTANGLE BOUNDS:")
print(f"   Latitude:  {lat_min:+6.1f}° to {lat_max:+6.1f}° (range: {lat_max - lat_min:4.1f}°)")
print(f"   Longitude: {lon_min:+6.1f}° to {lon_max:+6.1f}° (range: {lon_max - lon_min:4.1f}°)")

point_values = {}
for i, point in enumerate(maggia_points):
    point_values[(point[0], point[1])] = values[i]

f_00 = point_values[(lat_min, lon_min)]
f_01 = point_values[(lat_min, lon_max)]
f_10 = point_values[(lat_max, lon_min)]
f_11 = point_values[(lat_max, lon_max)]

print(f"\n4. TEC VALUES MAPPING:")
print(f"   f_00 (lat_min, lon_min) = ({lat_min:+6.1f}°, {lon_min:+6.1f}°) = {f_00:5.1f}")
print(f"   f_01 (lat_min, lon_max) = ({lat_min:+6.1f}°, {lon_max:+6.1f}°) = {f_01:5.1f}")
print(f"   f_10 (lat_max, lon_min) = ({lat_max:+6.1f}°, {lon_min:+6.1f}°) = {f_10:5.1f}")
print(f"   f_11 (lat_max, lon_max) = ({lat_max:+6.1f}°, {lon_max:+6.1f}°) = {f_11:5.1f}")

t_x = (target_lon - lon_min) / (lon_max - lon_min) if lon_max != lon_min else 0
t_y = (target_lat - lat_min) / (lat_max - lat_min) if lat_max != lat_min else 0

print(f"\n5. INTERPOLATION PARAMETERS:")
print(f"   t_x = (target_lon - lon_min) / (lon_max - lon_min)")
print(f"   t_x = ({target_lon:+6.5f} - ({lon_min:+6.1f})) / ({lon_max:+6.1f} - ({lon_min:+6.1f}))")
print(f"   t_x = {target_lon - lon_min:6.5f} / {lon_max - lon_min:4.1f} = {t_x:.6f}")
print(f"   ")
print(f"   t_y = (target_lat - lat_min) / (lat_max - lat_min)")
print(f"   t_y = ({target_lat:+6.5f} - ({lat_min:+6.1f})) / ({lat_max:+6.1f} - ({lat_min:+6.1f}))")
print(f"   t_y = {target_lat - lat_min:6.5f} / {lat_max - lat_min:4.1f} = {t_y:.6f}")

w_00 = (1 - t_x) * (1 - t_y)
w_01 = t_x * (1 - t_y)
w_10 = (1 - t_x) * t_y
w_11 = t_x * t_y

print(f"\n6. INTERPOLATION WEIGHTS:")
print(f"   w_00 = (1 - t_x) * (1 - t_y) = (1 - {t_x:.6f}) * (1 - {t_y:.6f}) = {w_00:.6f}")
print(f"   w_01 = t_x * (1 - t_y)       = {t_x:.6f} * (1 - {t_y:.6f})       = {w_01:.6f}")
print(f"   w_10 = (1 - t_x) * t_y       = (1 - {t_x:.6f}) * {t_y:.6f}       = {w_10:.6f}")
print(f"   w_11 = t_x * t_y             = {t_x:.6f} * {t_y:.6f}             = {w_11:.6f}")
print(f"   Sum of weights = {w_00 + w_01 + w_10 + w_11:.6f} (should be 1.0)")

interpolated_value = w_00 * f_00 + w_01 * f_01 + w_10 * f_10 + w_11 * f_11

print(f"\n7. FINAL CALCULATION:")
print(f"   Value = w_00*f_00 + w_01*f_01 + w_10*f_10 + w_11*f_11")
print(f"   Value = {w_00:.6f}*{f_00:5.1f} + {w_01:.6f}*{f_01:5.1f} + {w_10:.6f}*{f_10:5.1f} + {w_11:.6f}*{f_11:5.1f}")
print(f"   Value = {w_00*f_00:8.4f} + {w_01*f_01:8.4f} + {w_10*f_10:8.4f} + {w_11*f_11:8.4f}")
print(f"   Value = {interpolated_value:.6f}")

print(f"\n8. TARGET POINT RELATIVE POSITION:")
print(f"   In X direction (longitude): {t_x*100:.2f}% of the way from {lon_min}° to {lon_max}°")
print(f"   In Y direction (latitude):  {t_y*100:.2f}% of the way from {lat_min}° to {lat_max}°")

print(f"\n{'='*60}")
print(f"FINAL RESULT: TEC = {interpolated_value:.4f}")
print(f"{'='*60}")
# Out:
# ============================================================
# DETAILED BILINEAR INTERPOLATION ANALYSIS
# ============================================================
#
# 1. THE 4 CLOSEST POINTS:
#    P1: ( -16.0°,  -48.0°) - Indexes: [128, 124] - TEC:  85.8
#    P2: ( -16.0°,  -47.5°) - Indexes: [128, 125] - TEC:  83.9
#    P3: ( -15.5°,  -48.0°) - Indexes: [129, 124] - TEC:  87.1
#    P4: ( -15.5°,  -47.5°) - Indexes: [129, 125] - TEC:  83.9
#
# 2. TARGET POINT: (-15.94748°, -47.87787°)
#
# 3. INTERPOLATION RECTANGLE BOUNDS:
#    Latitude:   -16.0° to  -15.5° (range:  0.5°)
#    Longitude:  -48.0° to  -47.5° (range:  0.5°)
#
# 4. TEC VALUES MAPPING:
#    f_00 (lat_min, lon_min) = ( -16.0°,  -48.0°) =  85.8
#    f_01 (lat_min, lon_max) = ( -16.0°,  -47.5°) =  83.9
#    f_10 (lat_max, lon_min) = ( -15.5°,  -48.0°) =  87.1
#    f_11 (lat_max, lon_max) = ( -15.5°,  -47.5°) =  83.9
#
# 5. INTERPOLATION PARAMETERS:
#    t_x = (target_lon - lon_min) / (lon_max - lon_min)
#    t_x = (-47.87787 - ( -48.0)) / ( -47.5 - ( -48.0))
#    t_x = 0.12213 /  0.5 = 0.244260
#
#    t_y = (target_lat - lat_min) / (lat_max - lat_min)
#    t_y = (-15.94748 - ( -16.0)) / ( -15.5 - ( -16.0))
#    t_y = 0.05252 /  0.5 = 0.105040
#
# 6. INTERPOLATION WEIGHTS:
#    w_00 = (1 - t_x) * (1 - t_y) = (1 - 0.244260) * (1 - 0.105040) = 0.676357
#    w_01 = t_x * (1 - t_y)       = 0.244260 * (1 - 0.105040)       = 0.218603
#    w_10 = (1 - t_x) * t_y       = (1 - 0.244260) * 0.105040       = 0.079383
#    w_11 = t_x * t_y             = 0.244260 * 0.105040             = 0.025657
#    Sum of weights = 1.000000 (should be 1.0)
#
# 7. FINAL CALCULATION:
#    Value = w_00*f_00 + w_01*f_01 + w_10*f_10 + w_11*f_11
#    Value = 0.676357* 85.8 + 0.218603* 83.9 + 0.079383* 87.1 + 0.025657* 83.9
#    Value =  58.0639 +  18.3329 +   6.9145 +   2.1517
#    Value = 85.463013
#
# 8. TARGET POINT RELATIVE POSITION:
#    In X direction (longitude): 24.43% of the way from -48.0° to -47.5°
#    In Y direction (latitude):  10.50% of the way from -16.0° to -15.5°
#
# ============================================================
# FINAL RESULT: TEC = 85.4630
# ============================================================

# %% [markdown]
# ### 12/22 - 18:00

# %%
import pandas as pd

date = '2024-12-22'
time = '18:00:00'
timestamp_wanted = f'{date} {time}'

result = df_maggia_maps_2024[df_maggia_maps_2024['DATETIME'] == timestamp_wanted]

if result.empty:
    df_temp = df_maggia_maps_2024.copy()
    df_temp['DATETIME'] = pd.to_datetime(df_temp['DATETIME'])
    timestamp_dt = pd.to_datetime(timestamp_wanted)

    df_temp['diff'] = abs((df_temp['DATETIME'] - timestamp_dt).dt.total_seconds())
    idx_nearest = df_temp['diff'].idxmin()

    result = df_maggia_maps_2024.iloc[[idx_nearest]]
    print(f"Exact date not found. Using closest record: {df_maggia_maps_2024.iloc[idx_nearest]['DATETIME']}")

# %%
result
# Out:
#                  DATETIME                                             TECMAP
# 14292 2024-12-22 18:00:00  [[nan, nan, nan, nan, nan, nan, nan, nan, nan,...

# %%
maggia_maps = np.array(result.iloc[:]['TECMAP'])

# %%
np_maggia_maps = []
for i in range(len(maggia_maps)):
    np_maggia_maps.append(maggia_maps[i])
np_maggia_maps = np.array(np_maggia_maps)

# %%
np_maggia_maps
# Out:
# array([[[        nan,         nan,         nan, ...,         nan,
#                  nan,         nan],
#         [        nan,         nan,         nan, ...,         nan,
#                  nan,         nan],
#         [        nan,         nan,         nan, ...,         nan,
#                  nan,         nan],
#         ...,
#         [48.41400146, 48.5379982 , 48.59199905, ..., 19.10899925,
#          17.45599937, 17.45599937],
#         [48.26200104, 48.41799927, 48.52799988, ..., 18.8560009 ,
#          18.24600029, 17.79299927],
#         [48.11100006, 48.27999878, 48.42100143, ..., 19.0890007 ,
#          18.74200058, 18.39999962]]])

# %%
np_maggia_maps.shape
# Out:
# (1, 241, 221)

# %%
maggia_tec.tec_map = np_maggia_maps[0]

print("=" * 60)
print("DETAILED BILINEAR INTERPOLATION ANALYSIS")
print("=" * 60)

print("\n1. THE 4 CLOSEST POINTS:")
for i, point in enumerate(maggia_points):
    lat, lon, lat_idx, lon_idx = point
    tec_value = maggia_tec.tec_map[lat_idx, lon_idx]
    print(f"   P{i+1}: ({lat:+6.1f}°, {lon:+6.1f}°) - Indexes: [{lat_idx:2d}, {lon_idx:2d}] - TEC: {tec_value:5.1f}")

target_lat = -15.94748
target_lon = -47.87787

print(f"\n2. TARGET POINT: ({target_lat:+6.5f}°, {target_lon:+6.5f}°)")

values = []
for point in maggia_points:
    lat, lon, lat_idx, lon_idx = point
    values.append(maggia_tec.tec_map[lat_idx, lon_idx])

lats = [p[0] for p in maggia_points]
lons = [p[1] for p in maggia_points]

lat_min, lat_max = min(lats), max(lats)
lon_min, lon_max = min(lons), max(lons)

print(f"\n3. INTERPOLATION RECTANGLE BOUNDS:")
print(f"   Latitude:  {lat_min:+6.1f}° to {lat_max:+6.1f}° (range: {lat_max - lat_min:4.1f}°)")
print(f"   Longitude: {lon_min:+6.1f}° to {lon_max:+6.1f}° (range: {lon_max - lon_min:4.1f}°)")

point_values = {}
for i, point in enumerate(maggia_points):
    point_values[(point[0], point[1])] = values[i]

f_00 = point_values[(lat_min, lon_min)]
f_01 = point_values[(lat_min, lon_max)]
f_10 = point_values[(lat_max, lon_min)]
f_11 = point_values[(lat_max, lon_max)]

print(f"\n4. TEC VALUES MAPPING:")
print(f"   f_00 (lat_min, lon_min) = ({lat_min:+6.1f}°, {lon_min:+6.1f}°) = {f_00:5.1f}")
print(f"   f_01 (lat_min, lon_max) = ({lat_min:+6.1f}°, {lon_max:+6.1f}°) = {f_01:5.1f}")
print(f"   f_10 (lat_max, lon_min) = ({lat_max:+6.1f}°, {lon_min:+6.1f}°) = {f_10:5.1f}")
print(f"   f_11 (lat_max, lon_max) = ({lat_max:+6.1f}°, {lon_max:+6.1f}°) = {f_11:5.1f}")

t_x = (target_lon - lon_min) / (lon_max - lon_min) if lon_max != lon_min else 0
t_y = (target_lat - lat_min) / (lat_max - lat_min) if lat_max != lat_min else 0

print(f"\n5. INTERPOLATION PARAMETERS:")
print(f"   t_x = (target_lon - lon_min) / (lon_max - lon_min)")
print(f"   t_x = ({target_lon:+6.5f} - ({lon_min:+6.1f})) / ({lon_max:+6.1f} - ({lon_min:+6.1f}))")
print(f"   t_x = {target_lon - lon_min:6.5f} / {lon_max - lon_min:4.1f} = {t_x:.6f}")
print(f"   ")
print(f"   t_y = (target_lat - lat_min) / (lat_max - lat_min)")
print(f"   t_y = ({target_lat:+6.5f} - ({lat_min:+6.1f})) / ({lat_max:+6.1f} - ({lat_min:+6.1f}))")
print(f"   t_y = {target_lat - lat_min:6.5f} / {lat_max - lat_min:4.1f} = {t_y:.6f}")

w_00 = (1 - t_x) * (1 - t_y)
w_01 = t_x * (1 - t_y)
w_10 = (1 - t_x) * t_y
w_11 = t_x * t_y

print(f"\n6. INTERPOLATION WEIGHTS:")
print(f"   w_00 = (1 - t_x) * (1 - t_y) = (1 - {t_x:.6f}) * (1 - {t_y:.6f}) = {w_00:.6f}")
print(f"   w_01 = t_x * (1 - t_y)       = {t_x:.6f} * (1 - {t_y:.6f})       = {w_01:.6f}")
print(f"   w_10 = (1 - t_x) * t_y       = (1 - {t_x:.6f}) * {t_y:.6f}       = {w_10:.6f}")
print(f"   w_11 = t_x * t_y             = {t_x:.6f} * {t_y:.6f}             = {w_11:.6f}")
print(f"   Sum of weights = {w_00 + w_01 + w_10 + w_11:.6f} (should be 1.0)")

interpolated_value = w_00 * f_00 + w_01 * f_01 + w_10 * f_10 + w_11 * f_11

print(f"\n7. FINAL CALCULATION:")
print(f"   Value = w_00*f_00 + w_01*f_01 + w_10*f_10 + w_11*f_11")
print(f"   Value = {w_00:.6f}*{f_00:5.1f} + {w_01:.6f}*{f_01:5.1f} + {w_10:.6f}*{f_10:5.1f} + {w_11:.6f}*{f_11:5.1f}")
print(f"   Value = {w_00*f_00:8.4f} + {w_01*f_01:8.4f} + {w_10*f_10:8.4f} + {w_11*f_11:8.4f}")
print(f"   Value = {interpolated_value:.6f}")

print(f"\n8. TARGET POINT RELATIVE POSITION:")
print(f"   In X direction (longitude): {t_x*100:.2f}% of the way from {lon_min}° to {lon_max}°")
print(f"   In Y direction (latitude):  {t_y*100:.2f}% of the way from {lat_min}° to {lat_max}°")

print(f"\n{'='*60}")
print(f"FINAL RESULT: TEC = {interpolated_value:.4f}")
print(f"{'='*60}")
# Out:
# ============================================================
# DETAILED BILINEAR INTERPOLATION ANALYSIS
# ============================================================
#
# 1. THE 4 CLOSEST POINTS:
#    P1: ( -16.0°,  -48.0°) - Indexes: [128, 124] - TEC:  94.4
#    P2: ( -16.0°,  -47.5°) - Indexes: [128, 125] - TEC:  94.9
#    P3: ( -15.5°,  -48.0°) - Indexes: [129, 124] - TEC:  91.5
#    P4: ( -15.5°,  -47.5°) - Indexes: [129, 125] - TEC:  97.8
#
# 2. TARGET POINT: (-15.94748°, -47.87787°)
#
# 3. INTERPOLATION RECTANGLE BOUNDS:
#    Latitude:   -16.0° to  -15.5° (range:  0.5°)
#    Longitude:  -48.0° to  -47.5° (range:  0.5°)
#
# 4. TEC VALUES MAPPING:
#    f_00 (lat_min, lon_min) = ( -16.0°,  -48.0°) =  94.4
#    f_01 (lat_min, lon_max) = ( -16.0°,  -47.5°) =  94.9
#    f_10 (lat_max, lon_min) = ( -15.5°,  -48.0°) =  91.5
#    f_11 (lat_max, lon_max) = ( -15.5°,  -47.5°) =  97.8
#
# 5. INTERPOLATION PARAMETERS:
#    t_x = (target_lon - lon_min) / (lon_max - lon_min)
#    t_x = (-47.87787 - ( -48.0)) / ( -47.5 - ( -48.0))
#    t_x = 0.12213 /  0.5 = 0.244260
#
#    t_y = (target_lat - lat_min) / (lat_max - lat_min)
#    t_y = (-15.94748 - ( -16.0)) / ( -15.5 - ( -16.0))
#    t_y = 0.05252 /  0.5 = 0.105040
#
# 6. INTERPOLATION WEIGHTS:
#    w_00 = (1 - t_x) * (1 - t_y) = (1 - 0.244260) * (1 - 0.105040) = 0.676357
#    w_01 = t_x * (1 - t_y)       = 0.244260 * (1 - 0.105040)       = 0.218603
#    w_10 = (1 - t_x) * t_y       = (1 - 0.244260) * 0.105040       = 0.079383
#    w_11 = t_x * t_y             = 0.244260 * 0.105040             = 0.025657
#    Sum of weights = 1.000000 (should be 1.0)
#
# 7. FINAL CALCULATION:
#    Value = w_00*f_00 + w_01*f_01 + w_10*f_10 + w_11*f_11
#    Value = 0.676357* 94.4 + 0.218603* 94.9 + 0.079383* 91.5 + 0.025657* 97.8
#    Value =  63.8305 +  20.7500 +   7.2623 +   2.5095
#    Value = 94.352396
#
# 8. TARGET POINT RELATIVE POSITION:
#    In X direction (longitude): 24.43% of the way from -48.0° to -47.5°
#    In Y direction (latitude):  10.50% of the way from -16.0° to -15.5°
#
# ============================================================
# FINAL RESULT: TEC = 94.3524
# ============================================================

# %% [markdown]
# ## Nagoya

# %%
import pandas as pd
import numpy as np

# %%
#Download TF_Nagoya_TEC_maps_intersection_case_study_Dec_2024.pkl from https://doi.org/10.5281/zenodo.15453941

# %%
# !gdown '1CXL-btSyeELqYjLGL-B2oSnMt-QlPFUR'
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1CXL-btSyeELqYjLGL-B2oSnMt-QlPFUR
# From (redirected): https://drive.google.com/uc?id=1CXL-btSyeELqYjLGL-B2oSnMt-QlPFUR&confirm=t&uuid=f6fafaa0-3aa7-46a3-9fd7-ad05449081fc
# To: /content/TF_Nagoya_TEC_maps_intersection_case_study_Dec_2024.pkl
# 100% 4.03G/4.03G [00:26<00:00, 150MB/s]

# %%
df_nagoya_maps_2024 = pd.read_pickle('TF_Nagoya_TEC_maps_intersection_case_study_Dec_2024.pkl')

# %%
df_nagoya_maps_2024
# Out:
#                 DATETIME                                             TECMAP
# 0    2024-12-01 00:00:00  [[18.593109130859375, 19.42150115966797, 19.42...
# 1    2024-12-01 00:05:00  [[18.222612380981445, 18.222612380981445, 18.2...
# 2    2024-12-01 00:10:00  [[18.21422576904297, 18.21422576904297, 18.214...
# 3    2024-12-01 00:15:00  [[18.284513473510742, 18.284513473510742, 18.0...
# 4    2024-12-01 00:20:00  [[18.328298568725586, 18.328298568725586, 18.0...
# ...                  ...                                                ...
# 8347 2024-12-30 23:35:00  [[26.173906326293945, 27.259140014648438, 27.2...
# 8348 2024-12-30 23:40:00  [[27.0389347076416, 27.0389347076416, 27.03893...
# 8349 2024-12-30 23:45:00  [[26.902502059936523, 26.72080421447754, 25.94...
# 8350 2024-12-30 23:50:00  [[27.88735580444336, 27.88735580444336, 27.887...
# 8351 2024-12-30 23:55:00  [[24.682987213134766, 25.294950485229492, 25.2...
#
# [8352 rows x 2 columns]

# %%
class Nagoya(TecMap):
    def __init__(self,
                 extent: Iterable[float] = (-110, 0, -80.4, 40.1),
                 lat_step: float = 0.5,
                 lon_step: float = 0.5):
        super().__init__(extent, lat_step, lon_step)

# %%
nagoya_tec = Nagoya()
nagoya_points = nagoya_tec.find_nearest_points(lat=-15.94748, lon=-47.87787)

# %%
nagoya_points
# Out:
# [(-16.400000000000006, -48.0, 128, 124),
#  (-16.400000000000006, -47.5, 128, 125),
#  (-15.900000000000006, -48.0, 129, 124),
#  (-15.900000000000006, -47.5, 129, 125)]

# %% [markdown]
# ### 12/01 - 18:00

# %%
import pandas as pd

date = '2024-12-01'
time = '18:00:00'
timestamp_wanted = f'{date} {time}'

result = df_nagoya_maps_2024[df_nagoya_maps_2024['DATETIME'] == timestamp_wanted]

if result.empty:
    df_temp = df_nagoya_maps_2024.copy()
    df_temp['DATETIME'] = pd.to_datetime(df_temp['DATETIME'])
    timestamp_dt = pd.to_datetime(timestamp_wanted)

    df_temp['diff'] = abs((df_temp['DATETIME'] - timestamp_dt).dt.total_seconds())
    idx_nearest = df_temp['diff'].idxmin()

    result = df_nagoya_maps_2024.iloc[[idx_nearest]]
    print(f"Exact date not found. Using closest record: {df_nagoya_maps_2024.iloc[idx_nearest]['DATETIME']}")

# %%
result
# Out:
#                DATETIME                                             TECMAP
# 216 2024-12-01 18:00:00  [[5.463457107543945, 5.463457107543945, 5.4634...

# %%
nagoya_maps = np.array(result.iloc[:]['TECMAP'])

# %%
np_nagoya_maps = []
for i in range(len(nagoya_maps)):
    np_nagoya_maps.append(nagoya_maps[i])
np_nagoya_maps = np.array(np_nagoya_maps)

# %%
np_nagoya_maps
# Out:
# array([[[ 5.46345711,  5.46345711,  5.46345711, ...,         nan,
#                  nan,         nan],
#         [ 9.9241066 , 10.95889568, 10.95889568, ...,         nan,
#                  nan,         nan],
#         [14.80212975, 14.80212975, 14.12398911, ...,         nan,
#                  nan,         nan],
#         ...,
#         [43.88991547, 44.48843002, 44.89578247, ..., 21.9361248 ,
#          21.8728199 , 21.43001556],
#         [44.12051773, 44.59725952, 44.77046967, ..., 21.9361248 ,
#          21.76833344, 21.42024994],
#         [44.22133255, 44.64913177, 44.84080887, ..., 21.9361248 ,
#          21.67697716, 21.29607773]]])

# %%
np_nagoya_maps.shape
# Out:
# (1, 242, 221)

# %%
nagoya_tec.tec_map = np_nagoya_maps[0]

print("=" * 60)
print("DETAILED BILINEAR INTERPOLATION ANALYSIS")
print("=" * 60)

print("\n1. THE 4 CLOSEST POINTS:")
for i, point in enumerate(nagoya_points):
    lat, lon, lat_idx, lon_idx = point
    tec_value = nagoya_tec.tec_map[lat_idx, lon_idx]
    print(f"   P{i+1}: ({lat:+6.1f}°, {lon:+6.1f}°) - Indexes: [{lat_idx:2d}, {lon_idx:2d}] - TEC: {tec_value:5.1f}")

target_lat = -15.94748
target_lon = -47.87787

print(f"\n2. TARGET POINT: ({target_lat:+6.5f}°, {target_lon:+6.5f}°)")

values = []
for point in nagoya_points:
    lat, lon, lat_idx, lon_idx = point
    values.append(nagoya_tec.tec_map[lat_idx, lon_idx])

lats = [p[0] for p in nagoya_points]
lons = [p[1] for p in nagoya_points]

lat_min, lat_max = min(lats), max(lats)
lon_min, lon_max = min(lons), max(lons)

print(f"\n3. INTERPOLATION RECTANGLE BOUNDS:")
print(f"   Latitude:  {lat_min:+6.1f}° to {lat_max:+6.1f}° (range: {lat_max - lat_min:4.1f}°)")
print(f"   Longitude: {lon_min:+6.1f}° to {lon_max:+6.1f}° (range: {lon_max - lon_min:4.1f}°)")

# Value mapping
point_values = {}
for i, point in enumerate(nagoya_points):
    point_values[(point[0], point[1])] = values[i]

f_00 = point_values[(lat_min, lon_min)]
f_01 = point_values[(lat_min, lon_max)]
f_10 = point_values[(lat_max, lon_min)]
f_11 = point_values[(lat_max, lon_max)]

print(f"\n4. TEC VALUES MAPPING:")
print(f"   f_00 (lat_min, lon_min) = ({lat_min:+6.1f}°, {lon_min:+6.1f}°) = {f_00:5.1f}")
print(f"   f_01 (lat_min, lon_max) = ({lat_min:+6.1f}°, {lon_max:+6.1f}°) = {f_01:5.1f}")
print(f"   f_10 (lat_max, lon_min) = ({lat_max:+6.1f}°, {lon_min:+6.1f}°) = {f_10:5.1f}")
print(f"   f_11 (lat_max, lon_max) = ({lat_max:+6.1f}°, {lon_max:+6.1f}°) = {f_11:5.1f}")

t_x = (target_lon - lon_min) / (lon_max - lon_min) if lon_max != lon_min else 0
t_y = (target_lat - lat_min) / (lat_max - lat_min) if lat_max != lat_min else 0

print(f"\n5. INTERPOLATION PARAMETERS:")
print(f"   t_x = (target_lon - lon_min) / (lon_max - lon_min)")
print(f"   t_x = ({target_lon:+6.5f} - ({lon_min:+6.1f})) / ({lon_max:+6.1f} - ({lon_min:+6.1f}))")
print(f"   t_x = {target_lon - lon_min:6.5f} / {lon_max - lon_min:4.1f} = {t_x:.6f}")
print(f"   ")
print(f"   t_y = (target_lat - lat_min) / (lat_max - lat_min)")
print(f"   t_y = ({target_lat:+6.5f} - ({lat_min:+6.1f})) / ({lat_max:+6.1f} - ({lat_min:+6.1f}))")
print(f"   t_y = {target_lat - lat_min:6.5f} / {lat_max - lat_min:4.1f} = {t_y:.6f}")

w_00 = (1 - t_x) * (1 - t_y)
w_01 = t_x * (1 - t_y)
w_10 = (1 - t_x) * t_y
w_11 = t_x * t_y

print(f"\n6. INTERPOLATION WEIGHTS:")
print(f"   w_00 = (1 - t_x) * (1 - t_y) = (1 - {t_x:.6f}) * (1 - {t_y:.6f}) = {w_00:.6f}")
print(f"   w_01 = t_x * (1 - t_y)       = {t_x:.6f} * (1 - {t_y:.6f})       = {w_01:.6f}")
print(f"   w_10 = (1 - t_x) * t_y       = (1 - {t_x:.6f}) * {t_y:.6f}       = {w_10:.6f}")
print(f"   w_11 = t_x * t_y             = {t_x:.6f} * {t_y:.6f}             = {w_11:.6f}")
print(f"   Sum of weights = {w_00 + w_01 + w_10 + w_11:.6f} (should be 1.0)")

interpolated_value = w_00 * f_00 + w_01 * f_01 + w_10 * f_10 + w_11 * f_11

print(f"\n7. FINAL CALCULATION:")
print(f"   Value = w_00*f_00 + w_01*f_01 + w_10*f_10 + w_11*f_11")
print(f"   Value = {w_00:.6f}*{f_00:5.1f} + {w_01:.6f}*{f_01:5.1f} + {w_10:.6f}*{f_10:5.1f} + {w_11:.6f}*{f_11:5.1f}")
print(f"   Value = {w_00*f_00:8.4f} + {w_01*f_01:8.4f} + {w_10*f_10:8.4f} + {w_11*f_11:8.4f}")
print(f"   Value = {interpolated_value:.6f}")

print(f"\n8. TARGET POINT RELATIVE POSITION:")
print(f"   In X direction (longitude): {t_x*100:.2f}% of the way from {lon_min}° to {lon_max}°")
print(f"   In Y direction (latitude):  {t_y*100:.2f}% of the way from {lat_min}° to {lat_max}°")

print(f"\n{'='*60}")
print(f"FINAL RESULT: TEC = {interpolated_value:.4f}")
print(f"{'='*60}")
# Out:
# ============================================================
# DETAILED BILINEAR INTERPOLATION ANALYSIS
# ============================================================
#
# 1. THE 4 CLOSEST POINTS:
#    P1: ( -16.4°,  -48.0°) - Indexes: [128, 124] - TEC:  79.8
#    P2: ( -16.4°,  -47.5°) - Indexes: [128, 125] - TEC:  74.8
#    P3: ( -15.9°,  -48.0°) - Indexes: [129, 124] - TEC:  80.3
#    P4: ( -15.9°,  -47.5°) - Indexes: [129, 125] - TEC:  75.4
#
# 2. TARGET POINT: (-15.94748°, -47.87787°)
#
# 3. INTERPOLATION RECTANGLE BOUNDS:
#    Latitude:   -16.4° to  -15.9° (range:  0.5°)
#    Longitude:  -48.0° to  -47.5° (range:  0.5°)
#
# 4. TEC VALUES MAPPING:
#    f_00 (lat_min, lon_min) = ( -16.4°,  -48.0°) =  79.8
#    f_01 (lat_min, lon_max) = ( -16.4°,  -47.5°) =  74.8
#    f_10 (lat_max, lon_min) = ( -15.9°,  -48.0°) =  80.3
#    f_11 (lat_max, lon_max) = ( -15.9°,  -47.5°) =  75.4
#
# 5. INTERPOLATION PARAMETERS:
#    t_x = (target_lon - lon_min) / (lon_max - lon_min)
#    t_x = (-47.87787 - ( -48.0)) / ( -47.5 - ( -48.0))
#    t_x = 0.12213 /  0.5 = 0.244260
#
#    t_y = (target_lat - lat_min) / (lat_max - lat_min)
#    t_y = (-15.94748 - ( -16.4)) / ( -15.9 - ( -16.4))
#    t_y = 0.45252 /  0.5 = 0.905040
#
# 6. INTERPOLATION WEIGHTS:
#    w_00 = (1 - t_x) * (1 - t_y) = (1 - 0.244260) * (1 - 0.905040) = 0.071765
#    w_01 = t_x * (1 - t_y)       = 0.244260 * (1 - 0.905040)       = 0.023195
#    w_10 = (1 - t_x) * t_y       = (1 - 0.244260) * 0.905040       = 0.683975
#    w_11 = t_x * t_y             = 0.244260 * 0.905040             = 0.221065
#    Sum of weights = 1.000000 (should be 1.0)
#
# 7. FINAL CALCULATION:
#    Value = w_00*f_00 + w_01*f_01 + w_10*f_10 + w_11*f_11
#    Value = 0.071765* 79.8 + 0.023195* 74.8 + 0.683975* 80.3 + 0.221065* 75.4
#    Value =   5.7301 +   1.7360 +  54.8969 +  16.6679
#    Value = 79.030915
#
# 8. TARGET POINT RELATIVE POSITION:
#    In X direction (longitude): 24.43% of the way from -48.0° to -47.5°
#    In Y direction (latitude):  90.50% of the way from -16.400000000000006° to -15.900000000000006°
#
# ============================================================
# FINAL RESULT: TEC = 79.0309
# ============================================================

# %% [markdown]
# ### 12/18 - 18:00

# %%
import pandas as pd

date = '2024-12-18'
time = '18:00:00'
timestamp_wanted = f'{date} {time}'

result = df_nagoya_maps_2024[df_nagoya_maps_2024['DATETIME'] == timestamp_wanted]

if result.empty:
    df_temp = df_nagoya_maps_2024.copy()
    df_temp['DATETIME'] = pd.to_datetime(df_temp['DATETIME'])
    timestamp_dt = pd.to_datetime(timestamp_wanted)

    df_temp['diff'] = abs((df_temp['DATETIME'] - timestamp_dt).dt.total_seconds())
    idx_nearest = df_temp['diff'].idxmin()

    result = df_nagoya_maps_2024.iloc[[idx_nearest]]
    print(f"Exact date not found. Using closest record: {df_nagoya_maps_2024.iloc[idx_nearest]['DATETIME']}")

# %%
result
# Out:
#                 DATETIME                                             TECMAP
# 4824 2024-12-18 18:00:00  [[17.569849014282227, 17.569849014282227, 17.6...

# %%
nagoya_maps = np.array(result.iloc[:]['TECMAP'])

# %%
np_nagoya_maps = []
for i in range(len(nagoya_maps)):
    np_nagoya_maps.append(nagoya_maps[i])
np_nagoya_maps = np.array(np_nagoya_maps)

# %%
np_nagoya_maps
# Out:
# array([[[17.56984901, 17.56984901, 17.63764763, ...,         nan,
#                  nan,         nan],
#         [17.83648491, 17.83648491, 17.8645153 , ...,         nan,
#                  nan,         nan],
#         [16.60485077, 16.60485077, 16.60485077, ...,         nan,
#                  nan,         nan],
#         ...,
#         [35.25151062, 35.38899231, 35.7537117 , ..., 14.51318359,
#          13.86343384, 13.80283642],
#         [34.86306763, 34.9417305 , 34.75822449, ..., 14.43698978,
#          13.88199997, 13.79667377],
#         [34.32035065, 34.41825104, 34.44206238, ..., 14.2071352 ,
#          13.66319656, 13.62114334]]])

# %%
np_nagoya_maps.shape
# Out:
# (1, 242, 221)

# %%
nagoya_tec.tec_map = np_nagoya_maps[0]

print("=" * 60)
print("DETAILED BILINEAR INTERPOLATION ANALYSIS")
print("=" * 60)

print("\n1. THE 4 CLOSEST POINTS:")
for i, point in enumerate(nagoya_points):
    lat, lon, lat_idx, lon_idx = point
    tec_value = nagoya_tec.tec_map[lat_idx, lon_idx]
    print(f"   P{i+1}: ({lat:+6.1f}°, {lon:+6.1f}°) - Indexes: [{lat_idx:2d}, {lon_idx:2d}] - TEC: {tec_value:5.1f}")

target_lat = -15.94748
target_lon = -47.87787

print(f"\n2. TARGET POINT: ({target_lat:+6.5f}°, {target_lon:+6.5f}°)")

values = []
for point in nagoya_points:
    lat, lon, lat_idx, lon_idx = point
    values.append(nagoya_tec.tec_map[lat_idx, lon_idx])

lats = [p[0] for p in nagoya_points]
lons = [p[1] for p in nagoya_points]

lat_min, lat_max = min(lats), max(lats)
lon_min, lon_max = min(lons), max(lons)

print(f"\n3. INTERPOLATION RECTANGLE BOUNDS:")
print(f"   Latitude:  {lat_min:+6.1f}° to {lat_max:+6.1f}° (range: {lat_max - lat_min:4.1f}°)")
print(f"   Longitude: {lon_min:+6.1f}° to {lon_max:+6.1f}° (range: {lon_max - lon_min:4.1f}°)")

point_values = {}
for i, point in enumerate(nagoya_points):
    point_values[(point[0], point[1])] = values[i]

f_00 = point_values[(lat_min, lon_min)]
f_01 = point_values[(lat_min, lon_max)]
f_10 = point_values[(lat_max, lon_min)]
f_11 = point_values[(lat_max, lon_max)]

print(f"\n4. TEC VALUES MAPPING:")
print(f"   f_00 (lat_min, lon_min) = ({lat_min:+6.1f}°, {lon_min:+6.1f}°) = {f_00:5.1f}")
print(f"   f_01 (lat_min, lon_max) = ({lat_min:+6.1f}°, {lon_max:+6.1f}°) = {f_01:5.1f}")
print(f"   f_10 (lat_max, lon_min) = ({lat_max:+6.1f}°, {lon_min:+6.1f}°) = {f_10:5.1f}")
print(f"   f_11 (lat_max, lon_max) = ({lat_max:+6.1f}°, {lon_max:+6.1f}°) = {f_11:5.1f}")

t_x = (target_lon - lon_min) / (lon_max - lon_min) if lon_max != lon_min else 0
t_y = (target_lat - lat_min) / (lat_max - lat_min) if lat_max != lat_min else 0

print(f"\n5. INTERPOLATION PARAMETERS:")
print(f"   t_x = (target_lon - lon_min) / (lon_max - lon_min)")
print(f"   t_x = ({target_lon:+6.5f} - ({lon_min:+6.1f})) / ({lon_max:+6.1f} - ({lon_min:+6.1f}))")
print(f"   t_x = {target_lon - lon_min:6.5f} / {lon_max - lon_min:4.1f} = {t_x:.6f}")
print(f"   ")
print(f"   t_y = (target_lat - lat_min) / (lat_max - lat_min)")
print(f"   t_y = ({target_lat:+6.5f} - ({lat_min:+6.1f})) / ({lat_max:+6.1f} - ({lat_min:+6.1f}))")
print(f"   t_y = {target_lat - lat_min:6.5f} / {lat_max - lat_min:4.1f} = {t_y:.6f}")

w_00 = (1 - t_x) * (1 - t_y)
w_01 = t_x * (1 - t_y)
w_10 = (1 - t_x) * t_y
w_11 = t_x * t_y

print(f"\n6. INTERPOLATION WEIGHTS:")
print(f"   w_00 = (1 - t_x) * (1 - t_y) = (1 - {t_x:.6f}) * (1 - {t_y:.6f}) = {w_00:.6f}")
print(f"   w_01 = t_x * (1 - t_y)       = {t_x:.6f} * (1 - {t_y:.6f})       = {w_01:.6f}")
print(f"   w_10 = (1 - t_x) * t_y       = (1 - {t_x:.6f}) * {t_y:.6f}       = {w_10:.6f}")
print(f"   w_11 = t_x * t_y             = {t_x:.6f} * {t_y:.6f}             = {w_11:.6f}")
print(f"   Sum of weights = {w_00 + w_01 + w_10 + w_11:.6f} (should be 1.0)")

interpolated_value = w_00 * f_00 + w_01 * f_01 + w_10 * f_10 + w_11 * f_11

print(f"\n7. FINAL CALCULATION:")
print(f"   Value = w_00*f_00 + w_01*f_01 + w_10*f_10 + w_11*f_11")
print(f"   Value = {w_00:.6f}*{f_00:5.1f} + {w_01:.6f}*{f_01:5.1f} + {w_10:.6f}*{f_10:5.1f} + {w_11:.6f}*{f_11:5.1f}")
print(f"   Value = {w_00*f_00:8.4f} + {w_01*f_01:8.4f} + {w_10*f_10:8.4f} + {w_11*f_11:8.4f}")
print(f"   Value = {interpolated_value:.6f}")

print(f"\n8. TARGET POINT RELATIVE POSITION:")
print(f"   In X direction (longitude): {t_x*100:.2f}% of the way from {lon_min}° to {lon_max}°")
print(f"   In Y direction (latitude):  {t_y*100:.2f}% of the way from {lat_min}° to {lat_max}°")

print(f"\n{'='*60}")
print(f"FINAL RESULT: TEC = {interpolated_value:.4f}")
print(f"{'='*60}")
# Out:
# ============================================================
# DETAILED BILINEAR INTERPOLATION ANALYSIS
# ============================================================
#
# 1. THE 4 CLOSEST POINTS:
#    P1: ( -16.4°,  -48.0°) - Indexes: [128, 124] - TEC:  84.5
#    P2: ( -16.4°,  -47.5°) - Indexes: [128, 125] - TEC:  82.6
#    P3: ( -15.9°,  -48.0°) - Indexes: [129, 124] - TEC:  82.1
#    P4: ( -15.9°,  -47.5°) - Indexes: [129, 125] - TEC:  83.1
#
# 2. TARGET POINT: (-15.94748°, -47.87787°)
#
# 3. INTERPOLATION RECTANGLE BOUNDS:
#    Latitude:   -16.4° to  -15.9° (range:  0.5°)
#    Longitude:  -48.0° to  -47.5° (range:  0.5°)
#
# 4. TEC VALUES MAPPING:
#    f_00 (lat_min, lon_min) = ( -16.4°,  -48.0°) =  84.5
#    f_01 (lat_min, lon_max) = ( -16.4°,  -47.5°) =  82.6
#    f_10 (lat_max, lon_min) = ( -15.9°,  -48.0°) =  82.1
#    f_11 (lat_max, lon_max) = ( -15.9°,  -47.5°) =  83.1
#
# 5. INTERPOLATION PARAMETERS:
#    t_x = (target_lon - lon_min) / (lon_max - lon_min)
#    t_x = (-47.87787 - ( -48.0)) / ( -47.5 - ( -48.0))
#    t_x = 0.12213 /  0.5 = 0.244260
#
#    t_y = (target_lat - lat_min) / (lat_max - lat_min)
#    t_y = (-15.94748 - ( -16.4)) / ( -15.9 - ( -16.4))
#    t_y = 0.45252 /  0.5 = 0.905040
#
# 6. INTERPOLATION WEIGHTS:
#    w_00 = (1 - t_x) * (1 - t_y) = (1 - 0.244260) * (1 - 0.905040) = 0.071765
#    w_01 = t_x * (1 - t_y)       = 0.244260 * (1 - 0.905040)       = 0.023195
#    w_10 = (1 - t_x) * t_y       = (1 - 0.244260) * 0.905040       = 0.683975
#    w_11 = t_x * t_y             = 0.244260 * 0.905040             = 0.221065
#    Sum of weights = 1.000000 (should be 1.0)
#
# 7. FINAL CALCULATION:
#    Value = w_00*f_00 + w_01*f_01 + w_10*f_10 + w_11*f_11
#    Value = 0.071765* 84.5 + 0.023195* 82.6 + 0.683975* 82.1 + 0.221065* 83.1
#    Value =   6.0672 +   1.9163 +  56.1447 +  18.3615
#    Value = 82.489682
#
# 8. TARGET POINT RELATIVE POSITION:
#    In X direction (longitude): 24.43% of the way from -48.0° to -47.5°
#    In Y direction (latitude):  90.50% of the way from -16.400000000000006° to -15.900000000000006°
#
# ============================================================
# FINAL RESULT: TEC = 82.4897
# ============================================================

# %% [markdown]
# ### 12/18 - 18:10

# %%
import pandas as pd

date = '2024-12-18'
time = '18:10:00'
timestamp_wanted = f'{date} {time}'

result = df_nagoya_maps_2024[df_nagoya_maps_2024['DATETIME'] == timestamp_wanted]

if result.empty:
    df_temp = df_nagoya_maps_2024.copy()
    df_temp['DATETIME'] = pd.to_datetime(df_temp['DATETIME'])
    timestamp_dt = pd.to_datetime(timestamp_wanted)

    df_temp['diff'] = abs((df_temp['DATETIME'] - timestamp_dt).dt.total_seconds())
    idx_nearest = df_temp['diff'].idxmin()

    result = df_nagoya_maps_2024.iloc[[idx_nearest]]
    print(f"Exact date not found. Using closest record: {df_nagoya_maps_2024.iloc[idx_nearest]['DATETIME']}")

# %%
result
# Out:
#                 DATETIME                                             TECMAP
# 4826 2024-12-18 18:10:00  [[18.412939071655273, 17.651090621948242, 17.6...

# %%
nagoya_maps = np.array(result.iloc[:]['TECMAP'])

# %%
np_nagoya_maps = []
for i in range(len(nagoya_maps)):
    np_nagoya_maps.append(nagoya_maps[i])
np_nagoya_maps = np.array(np_nagoya_maps)

# %%
np_nagoya_maps
# Out:
# array([[[18.41293907, 17.65109062, 17.65109062, ...,         nan,
#                  nan,         nan],
#         [18.53962135, 17.62540054, 17.62540054, ...,         nan,
#                  nan,         nan],
#         [17.62013054, 17.62013054, 17.62540054, ...,         nan,
#                  nan,         nan],
#         ...,
#         [36.95772552, 37.32144928, 37.6816864 , ..., 14.07102394,
#          13.53792286, 13.37452602],
#         [37.09318542, 37.28800964, 37.65478134, ..., 13.818923  ,
#          13.44021893, 13.28282356],
#         [36.133461  , 36.14941025, 36.71422577, ..., 13.40729332,
#          13.00967979, 13.02010918]]])

# %%
np_nagoya_maps.shape
# Out:
# (1, 242, 221)

# %%
nagoya_tec.tec_map = np_nagoya_maps[0]

print("=" * 60)
print("DETAILED BILINEAR INTERPOLATION ANALYSIS")
print("=" * 60)

print("\n1. THE 4 CLOSEST POINTS:")
for i, point in enumerate(nagoya_points):
    lat, lon, lat_idx, lon_idx = point
    tec_value = nagoya_tec.tec_map[lat_idx, lon_idx]
    print(f"   P{i+1}: ({lat:+6.1f}°, {lon:+6.1f}°) - Indexes: [{lat_idx:2d}, {lon_idx:2d}] - TEC: {tec_value:5.1f}")

target_lat = -15.94748
target_lon = -47.87787

print(f"\n2. TARGET POINT: ({target_lat:+6.5f}°, {target_lon:+6.5f}°)")

values = []
for point in nagoya_points:
    lat, lon, lat_idx, lon_idx = point
    values.append(nagoya_tec.tec_map[lat_idx, lon_idx])

lats = [p[0] for p in nagoya_points]
lons = [p[1] for p in nagoya_points]

lat_min, lat_max = min(lats), max(lats)
lon_min, lon_max = min(lons), max(lons)

print(f"\n3. INTERPOLATION RECTANGLE BOUNDS:")
print(f"   Latitude:  {lat_min:+6.1f}° to {lat_max:+6.1f}° (range: {lat_max - lat_min:4.1f}°)")
print(f"   Longitude: {lon_min:+6.1f}° to {lon_max:+6.1f}° (range: {lon_max - lon_min:4.1f}°)")

point_values = {}
for i, point in enumerate(nagoya_points):
    point_values[(point[0], point[1])] = values[i]

f_00 = point_values[(lat_min, lon_min)]
f_01 = point_values[(lat_min, lon_max)]
f_10 = point_values[(lat_max, lon_min)]
f_11 = point_values[(lat_max, lon_max)]

print(f"\n4. TEC VALUES MAPPING:")
print(f"   f_00 (lat_min, lon_min) = ({lat_min:+6.1f}°, {lon_min:+6.1f}°) = {f_00:5.1f}")
print(f"   f_01 (lat_min, lon_max) = ({lat_min:+6.1f}°, {lon_max:+6.1f}°) = {f_01:5.1f}")
print(f"   f_10 (lat_max, lon_min) = ({lat_max:+6.1f}°, {lon_min:+6.1f}°) = {f_10:5.1f}")
print(f"   f_11 (lat_max, lon_max) = ({lat_max:+6.1f}°, {lon_max:+6.1f}°) = {f_11:5.1f}")

t_x = (target_lon - lon_min) / (lon_max - lon_min) if lon_max != lon_min else 0
t_y = (target_lat - lat_min) / (lat_max - lat_min) if lat_max != lat_min else 0

print(f"\n5. INTERPOLATION PARAMETERS:")
print(f"   t_x = (target_lon - lon_min) / (lon_max - lon_min)")
print(f"   t_x = ({target_lon:+6.5f} - ({lon_min:+6.1f})) / ({lon_max:+6.1f} - ({lon_min:+6.1f}))")
print(f"   t_x = {target_lon - lon_min:6.5f} / {lon_max - lon_min:4.1f} = {t_x:.6f}")
print(f"   ")
print(f"   t_y = (target_lat - lat_min) / (lat_max - lat_min)")
print(f"   t_y = ({target_lat:+6.5f} - ({lat_min:+6.1f})) / ({lat_max:+6.1f} - ({lat_min:+6.1f}))")
print(f"   t_y = {target_lat - lat_min:6.5f} / {lat_max - lat_min:4.1f} = {t_y:.6f}")

w_00 = (1 - t_x) * (1 - t_y)
w_01 = t_x * (1 - t_y)
w_10 = (1 - t_x) * t_y
w_11 = t_x * t_y

print(f"\n6. INTERPOLATION WEIGHTS:")
print(f"   w_00 = (1 - t_x) * (1 - t_y) = (1 - {t_x:.6f}) * (1 - {t_y:.6f}) = {w_00:.6f}")
print(f"   w_01 = t_x * (1 - t_y)       = {t_x:.6f} * (1 - {t_y:.6f})       = {w_01:.6f}")
print(f"   w_10 = (1 - t_x) * t_y       = (1 - {t_x:.6f}) * {t_y:.6f}       = {w_10:.6f}")
print(f"   w_11 = t_x * t_y             = {t_x:.6f} * {t_y:.6f}             = {w_11:.6f}")
print(f"   Sum of weights = {w_00 + w_01 + w_10 + w_11:.6f} (should be 1.0)")

interpolated_value = w_00 * f_00 + w_01 * f_01 + w_10 * f_10 + w_11 * f_11

print(f"\n7. FINAL CALCULATION:")
print(f"   Value = w_00*f_00 + w_01*f_01 + w_10*f_10 + w_11*f_11")
print(f"   Value = {w_00:.6f}*{f_00:5.1f} + {w_01:.6f}*{f_01:5.1f} + {w_10:.6f}*{f_10:5.1f} + {w_11:.6f}*{f_11:5.1f}")
print(f"   Value = {w_00*f_00:8.4f} + {w_01*f_01:8.4f} + {w_10*f_10:8.4f} + {w_11*f_11:8.4f}")
print(f"   Value = {interpolated_value:.6f}")

print(f"\n8. TARGET POINT RELATIVE POSITION:")
print(f"   In X direction (longitude): {t_x*100:.2f}% of the way from {lon_min}° to {lon_max}°")
print(f"   In Y direction (latitude):  {t_y*100:.2f}% of the way from {lat_min}° to {lat_max}°")

print(f"\n{'='*60}")
print(f"FINAL RESULT: TEC = {interpolated_value:.4f}")
print(f"{'='*60}")
# Out:
# ============================================================
# DETAILED BILINEAR INTERPOLATION ANALYSIS
# ============================================================
#
# 1. THE 4 CLOSEST POINTS:
#    P1: ( -16.4°,  -48.0°) - Indexes: [128, 124] - TEC:  87.5
#    P2: ( -16.4°,  -47.5°) - Indexes: [128, 125] - TEC:  91.0
#    P3: ( -15.9°,  -48.0°) - Indexes: [129, 124] - TEC:  75.7
#    P4: ( -15.9°,  -47.5°) - Indexes: [129, 125] - TEC:  78.8
#
# 2. TARGET POINT: (-15.94748°, -47.87787°)
#
# 3. INTERPOLATION RECTANGLE BOUNDS:
#    Latitude:   -16.4° to  -15.9° (range:  0.5°)
#    Longitude:  -48.0° to  -47.5° (range:  0.5°)
#
# 4. TEC VALUES MAPPING:
#    f_00 (lat_min, lon_min) = ( -16.4°,  -48.0°) =  87.5
#    f_01 (lat_min, lon_max) = ( -16.4°,  -47.5°) =  91.0
#    f_10 (lat_max, lon_min) = ( -15.9°,  -48.0°) =  75.7
#    f_11 (lat_max, lon_max) = ( -15.9°,  -47.5°) =  78.8
#
# 5. INTERPOLATION PARAMETERS:
#    t_x = (target_lon - lon_min) / (lon_max - lon_min)
#    t_x = (-47.87787 - ( -48.0)) / ( -47.5 - ( -48.0))
#    t_x = 0.12213 /  0.5 = 0.244260
#
#    t_y = (target_lat - lat_min) / (lat_max - lat_min)
#    t_y = (-15.94748 - ( -16.4)) / ( -15.9 - ( -16.4))
#    t_y = 0.45252 /  0.5 = 0.905040
#
# 6. INTERPOLATION WEIGHTS:
#    w_00 = (1 - t_x) * (1 - t_y) = (1 - 0.244260) * (1 - 0.905040) = 0.071765
#    w_01 = t_x * (1 - t_y)       = 0.244260 * (1 - 0.905040)       = 0.023195
#    w_10 = (1 - t_x) * t_y       = (1 - 0.244260) * 0.905040       = 0.683975
#    w_11 = t_x * t_y             = 0.244260 * 0.905040             = 0.221065
#    Sum of weights = 1.000000 (should be 1.0)
#
# 7. FINAL CALCULATION:
#    Value = w_00*f_00 + w_01*f_01 + w_10*f_10 + w_11*f_11
#    Value = 0.071765* 87.5 + 0.023195* 91.0 + 0.683975* 75.7 + 0.221065* 78.8
#    Value =   6.2816 +   2.1111 +  51.7680 +  17.4171
#    Value = 77.577780
#
# 8. TARGET POINT RELATIVE POSITION:
#    In X direction (longitude): 24.43% of the way from -48.0° to -47.5°
#    In Y direction (latitude):  90.50% of the way from -16.400000000000006° to -15.900000000000006°
#
# ============================================================
# FINAL RESULT: TEC = 77.5778
# ============================================================

# %% [markdown]
# ### 12/18 - 18:20

# %%
import pandas as pd

date = '2024-12-18'
time = '18:20:00'
timestamp_wanted = f'{date} {time}'

result = df_nagoya_maps_2024[df_nagoya_maps_2024['DATETIME'] == timestamp_wanted]

if result.empty:
    df_temp = df_nagoya_maps_2024.copy()
    df_temp['DATETIME'] = pd.to_datetime(df_temp['DATETIME'])
    timestamp_dt = pd.to_datetime(timestamp_wanted)

    df_temp['diff'] = abs((df_temp['DATETIME'] - timestamp_dt).dt.total_seconds())
    idx_nearest = df_temp['diff'].idxmin()

    result = df_nagoya_maps_2024.iloc[[idx_nearest]]
    print(f"Exact date not found. Using closest record: {df_nagoya_maps_2024.iloc[idx_nearest]['DATETIME']}")

# %%
result
# Out:
#                 DATETIME                                             TECMAP
# 4828 2024-12-18 18:20:00  [[18.751976013183594, 18.751976013183594, 18.8...

# %%
nagoya_maps = np.array(result.iloc[:]['TECMAP'])

# %%
np_nagoya_maps = []
for i in range(len(nagoya_maps)):
    np_nagoya_maps.append(nagoya_maps[i])
np_nagoya_maps = np.array(np_nagoya_maps)

# %%
np_nagoya_maps
# Out:
# array([[[18.75197601, 18.75197601, 18.81381989, ...,         nan,
#                  nan,         nan],
#         [18.75197601, 18.75197601, 18.81381989, ...,         nan,
#                  nan,         nan],
#         [18.25943375, 18.13648224, 18.13648224, ...,         nan,
#                  nan,         nan],
#         ...,
#         [38.79235458, 39.10980225, 39.51619339, ..., 13.45065308,
#          13.1072731 , 12.96411705],
#         [38.38473892, 38.68589783, 39.00465393, ..., 13.27555275,
#          12.90675449, 12.72219276],
#         [38.23902512, 38.27802277, 38.43577194, ..., 12.968153  ,
#          12.60940075, 12.51128292]]])

# %%
np_nagoya_maps.shape
# Out:
# (1, 242, 221)

# %%
nagoya_tec.tec_map = np_nagoya_maps[0]

print("=" * 60)
print("DETAILED BILINEAR INTERPOLATION ANALYSIS")
print("=" * 60)

print("\n1. THE 4 CLOSEST POINTS:")
for i, point in enumerate(nagoya_points):
    lat, lon, lat_idx, lon_idx = point
    tec_value = nagoya_tec.tec_map[lat_idx, lon_idx]
    print(f"   P{i+1}: ({lat:+6.1f}°, {lon:+6.1f}°) - Indexes: [{lat_idx:2d}, {lon_idx:2d}] - TEC: {tec_value:5.1f}")

target_lat = -15.94748
target_lon = -47.87787

print(f"\n2. TARGET POINT: ({target_lat:+6.5f}°, {target_lon:+6.5f}°)")

values = []
for point in nagoya_points:
    lat, lon, lat_idx, lon_idx = point
    values.append(nagoya_tec.tec_map[lat_idx, lon_idx])

lats = [p[0] for p in nagoya_points]
lons = [p[1] for p in nagoya_points]

lat_min, lat_max = min(lats), max(lats)
lon_min, lon_max = min(lons), max(lons)

print(f"\n3. INTERPOLATION RECTANGLE BOUNDS:")
print(f"   Latitude:  {lat_min:+6.1f}° to {lat_max:+6.1f}° (range: {lat_max - lat_min:4.1f}°)")
print(f"   Longitude: {lon_min:+6.1f}° to {lon_max:+6.1f}° (range: {lon_max - lon_min:4.1f}°)")

point_values = {}
for i, point in enumerate(nagoya_points):
    point_values[(point[0], point[1])] = values[i]

f_00 = point_values[(lat_min, lon_min)]
f_01 = point_values[(lat_min, lon_max)]
f_10 = point_values[(lat_max, lon_min)]
f_11 = point_values[(lat_max, lon_max)]

print(f"\n4. TEC VALUES MAPPING:")
print(f"   f_00 (lat_min, lon_min) = ({lat_min:+6.1f}°, {lon_min:+6.1f}°) = {f_00:5.1f}")
print(f"   f_01 (lat_min, lon_max) = ({lat_min:+6.1f}°, {lon_max:+6.1f}°) = {f_01:5.1f}")
print(f"   f_10 (lat_max, lon_min) = ({lat_max:+6.1f}°, {lon_min:+6.1f}°) = {f_10:5.1f}")
print(f"   f_11 (lat_max, lon_max) = ({lat_max:+6.1f}°, {lon_max:+6.1f}°) = {f_11:5.1f}")

t_x = (target_lon - lon_min) / (lon_max - lon_min) if lon_max != lon_min else 0
t_y = (target_lat - lat_min) / (lat_max - lat_min) if lat_max != lat_min else 0

print(f"\n5. INTERPOLATION PARAMETERS:")
print(f"   t_x = (target_lon - lon_min) / (lon_max - lon_min)")
print(f"   t_x = ({target_lon:+6.5f} - ({lon_min:+6.1f})) / ({lon_max:+6.1f} - ({lon_min:+6.1f}))")
print(f"   t_x = {target_lon - lon_min:6.5f} / {lon_max - lon_min:4.1f} = {t_x:.6f}")
print(f"   ")
print(f"   t_y = (target_lat - lat_min) / (lat_max - lat_min)")
print(f"   t_y = ({target_lat:+6.5f} - ({lat_min:+6.1f})) / ({lat_max:+6.1f} - ({lat_min:+6.1f}))")
print(f"   t_y = {target_lat - lat_min:6.5f} / {lat_max - lat_min:4.1f} = {t_y:.6f}")

w_00 = (1 - t_x) * (1 - t_y)
w_01 = t_x * (1 - t_y)
w_10 = (1 - t_x) * t_y
w_11 = t_x * t_y

print(f"\n6. INTERPOLATION WEIGHTS:")
print(f"   w_00 = (1 - t_x) * (1 - t_y) = (1 - {t_x:.6f}) * (1 - {t_y:.6f}) = {w_00:.6f}")
print(f"   w_01 = t_x * (1 - t_y)       = {t_x:.6f} * (1 - {t_y:.6f})       = {w_01:.6f}")
print(f"   w_10 = (1 - t_x) * t_y       = (1 - {t_x:.6f}) * {t_y:.6f}       = {w_10:.6f}")
print(f"   w_11 = t_x * t_y             = {t_x:.6f} * {t_y:.6f}             = {w_11:.6f}")
print(f"   Sum of weights = {w_00 + w_01 + w_10 + w_11:.6f} (should be 1.0)")

interpolated_value = w_00 * f_00 + w_01 * f_01 + w_10 * f_10 + w_11 * f_11

print(f"\n7. FINAL CALCULATION:")
print(f"   Value = w_00*f_00 + w_01*f_01 + w_10*f_10 + w_11*f_11")
print(f"   Value = {w_00:.6f}*{f_00:5.1f} + {w_01:.6f}*{f_01:5.1f} + {w_10:.6f}*{f_10:5.1f} + {w_11:.6f}*{f_11:5.1f}")
print(f"   Value = {w_00*f_00:8.4f} + {w_01*f_01:8.4f} + {w_10*f_10:8.4f} + {w_11*f_11:8.4f}")
print(f"   Value = {interpolated_value:.6f}")

print(f"\n8. TARGET POINT RELATIVE POSITION:")
print(f"   In X direction (longitude): {t_x*100:.2f}% of the way from {lon_min}° to {lon_max}°")
print(f"   In Y direction (latitude):  {t_y*100:.2f}% of the way from {lat_min}° to {lat_max}°")

print(f"\n{'='*60}")
print(f"FINAL RESULT: TEC = {interpolated_value:.4f}")
print(f"{'='*60}")
# Out:
# ============================================================
# DETAILED BILINEAR INTERPOLATION ANALYSIS
# ============================================================
#
# 1. THE 4 CLOSEST POINTS:
#    P1: ( -16.4°,  -48.0°) - Indexes: [128, 124] - TEC:  86.1
#    P2: ( -16.4°,  -47.5°) - Indexes: [128, 125] - TEC:  85.8
#    P3: ( -15.9°,  -48.0°) - Indexes: [129, 124] - TEC:  86.5
#    P4: ( -15.9°,  -47.5°) - Indexes: [129, 125] - TEC:  85.8
#
# 2. TARGET POINT: (-15.94748°, -47.87787°)
#
# 3. INTERPOLATION RECTANGLE BOUNDS:
#    Latitude:   -16.4° to  -15.9° (range:  0.5°)
#    Longitude:  -48.0° to  -47.5° (range:  0.5°)
#
# 4. TEC VALUES MAPPING:
#    f_00 (lat_min, lon_min) = ( -16.4°,  -48.0°) =  86.1
#    f_01 (lat_min, lon_max) = ( -16.4°,  -47.5°) =  85.8
#    f_10 (lat_max, lon_min) = ( -15.9°,  -48.0°) =  86.5
#    f_11 (lat_max, lon_max) = ( -15.9°,  -47.5°) =  85.8
#
# 5. INTERPOLATION PARAMETERS:
#    t_x = (target_lon - lon_min) / (lon_max - lon_min)
#    t_x = (-47.87787 - ( -48.0)) / ( -47.5 - ( -48.0))
#    t_x = 0.12213 /  0.5 = 0.244260
#
#    t_y = (target_lat - lat_min) / (lat_max - lat_min)
#    t_y = (-15.94748 - ( -16.4)) / ( -15.9 - ( -16.4))
#    t_y = 0.45252 /  0.5 = 0.905040
#
# 6. INTERPOLATION WEIGHTS:
#    w_00 = (1 - t_x) * (1 - t_y) = (1 - 0.244260) * (1 - 0.905040) = 0.071765
#    w_01 = t_x * (1 - t_y)       = 0.244260 * (1 - 0.905040)       = 0.023195
#    w_10 = (1 - t_x) * t_y       = (1 - 0.244260) * 0.905040       = 0.683975
#    w_11 = t_x * t_y             = 0.244260 * 0.905040             = 0.221065
#    Sum of weights = 1.000000 (should be 1.0)
#
# 7. FINAL CALCULATION:
#    Value = w_00*f_00 + w_01*f_01 + w_10*f_10 + w_11*f_11
#    Value = 0.071765* 86.1 + 0.023195* 85.8 + 0.683975* 86.5 + 0.221065* 85.8
#    Value =   6.1821 +   1.9895 +  59.1901 +  18.9635
#    Value = 86.325173
#
# 8. TARGET POINT RELATIVE POSITION:
#    In X direction (longitude): 24.43% of the way from -48.0° to -47.5°
#    In Y direction (latitude):  90.50% of the way from -16.400000000000006° to -15.900000000000006°
#
# ============================================================
# FINAL RESULT: TEC = 86.3252
# ============================================================

# %% [markdown]
# ### 12/18 - 18:30

# %%
import pandas as pd

date = '2024-12-18'
time = '18:30:00'
timestamp_wanted = f'{date} {time}'

result = df_nagoya_maps_2024[df_nagoya_maps_2024['DATETIME'] == timestamp_wanted]

if result.empty:
    df_temp = df_nagoya_maps_2024.copy()
    df_temp['DATETIME'] = pd.to_datetime(df_temp['DATETIME'])
    timestamp_dt = pd.to_datetime(timestamp_wanted)

    df_temp['diff'] = abs((df_temp['DATETIME'] - timestamp_dt).dt.total_seconds())
    idx_nearest = df_temp['diff'].idxmin()

    result = df_nagoya_maps_2024.iloc[[idx_nearest]]
    print(f"Exact date not found. Using closest record: {df_nagoya_maps_2024.iloc[idx_nearest]['DATETIME']}")

# %%
result
# Out:
#                 DATETIME                                             TECMAP
# 4830 2024-12-18 18:30:00  [[21.299997329711914, 21.299997329711914, 21.2...

# %%
nagoya_maps = np.array(result.iloc[:]['TECMAP'])

# %%
np_nagoya_maps = []
for i in range(len(nagoya_maps)):
    np_nagoya_maps.append(nagoya_maps[i])
np_nagoya_maps = np.array(np_nagoya_maps)

# %%
np_nagoya_maps
# Out:
# array([[[21.29999733, 21.29999733, 21.29999733, ...,         nan,
#                  nan,         nan],
#         [21.29999733, 21.29999733, 21.29999733, ...,         nan,
#                  nan,         nan],
#         [21.28308678, 21.28308678, 21.28308678, ...,         nan,
#                  nan,         nan],
#         ...,
#         [39.65393066, 40.11976624, 40.50592804, ..., 13.14062977,
#          12.80635357, 12.63247967],
#         [39.26050949, 39.7519455 , 40.19271851, ..., 12.65815067,
#          12.54124069, 12.46903992],
#         [39.23273468, 39.40169144, 39.72786331, ..., 12.41631317,
#          12.32884121, 12.25786972]]])

# %%
np_nagoya_maps.shape
# Out:
# (1, 242, 221)

# %%
nagoya_tec.tec_map = np_nagoya_maps[0]

print("=" * 60)
print("DETAILED BILINEAR INTERPOLATION ANALYSIS")
print("=" * 60)

print("\n1. THE 4 CLOSEST POINTS:")
for i, point in enumerate(nagoya_points):
    lat, lon, lat_idx, lon_idx = point
    tec_value = nagoya_tec.tec_map[lat_idx, lon_idx]
    print(f"   P{i+1}: ({lat:+6.1f}°, {lon:+6.1f}°) - Indexes: [{lat_idx:2d}, {lon_idx:2d}] - TEC: {tec_value:5.1f}")

target_lat = -15.94748
target_lon = -47.87787

print(f"\n2. TARGET POINT: ({target_lat:+6.5f}°, {target_lon:+6.5f}°)")

values = []
for point in nagoya_points:
    lat, lon, lat_idx, lon_idx = point
    values.append(nagoya_tec.tec_map[lat_idx, lon_idx])

lats = [p[0] for p in nagoya_points]
lons = [p[1] for p in nagoya_points]

lat_min, lat_max = min(lats), max(lats)
lon_min, lon_max = min(lons), max(lons)

print(f"\n3. INTERPOLATION RECTANGLE BOUNDS:")
print(f"   Latitude:  {lat_min:+6.1f}° to {lat_max:+6.1f}° (range: {lat_max - lat_min:4.1f}°)")
print(f"   Longitude: {lon_min:+6.1f}° to {lon_max:+6.1f}° (range: {lon_max - lon_min:4.1f}°)")

point_values = {}
for i, point in enumerate(nagoya_points):
    point_values[(point[0], point[1])] = values[i]

f_00 = point_values[(lat_min, lon_min)]
f_01 = point_values[(lat_min, lon_max)]
f_10 = point_values[(lat_max, lon_min)]
f_11 = point_values[(lat_max, lon_max)]

print(f"\n4. TEC VALUES MAPPING:")
print(f"   f_00 (lat_min, lon_min) = ({lat_min:+6.1f}°, {lon_min:+6.1f}°) = {f_00:5.1f}")
print(f"   f_01 (lat_min, lon_max) = ({lat_min:+6.1f}°, {lon_max:+6.1f}°) = {f_01:5.1f}")
print(f"   f_10 (lat_max, lon_min) = ({lat_max:+6.1f}°, {lon_min:+6.1f}°) = {f_10:5.1f}")
print(f"   f_11 (lat_max, lon_max) = ({lat_max:+6.1f}°, {lon_max:+6.1f}°) = {f_11:5.1f}")

t_x = (target_lon - lon_min) / (lon_max - lon_min) if lon_max != lon_min else 0
t_y = (target_lat - lat_min) / (lat_max - lat_min) if lat_max != lat_min else 0

print(f"\n5. INTERPOLATION PARAMETERS:")
print(f"   t_x = (target_lon - lon_min) / (lon_max - lon_min)")
print(f"   t_x = ({target_lon:+6.5f} - ({lon_min:+6.1f})) / ({lon_max:+6.1f} - ({lon_min:+6.1f}))")
print(f"   t_x = {target_lon - lon_min:6.5f} / {lon_max - lon_min:4.1f} = {t_x:.6f}")
print(f"   ")
print(f"   t_y = (target_lat - lat_min) / (lat_max - lat_min)")
print(f"   t_y = ({target_lat:+6.5f} - ({lat_min:+6.1f})) / ({lat_max:+6.1f} - ({lat_min:+6.1f}))")
print(f"   t_y = {target_lat - lat_min:6.5f} / {lat_max - lat_min:4.1f} = {t_y:.6f}")

w_00 = (1 - t_x) * (1 - t_y)
w_01 = t_x * (1 - t_y)
w_10 = (1 - t_x) * t_y
w_11 = t_x * t_y

print(f"\n6. INTERPOLATION WEIGHTS:")
print(f"   w_00 = (1 - t_x) * (1 - t_y) = (1 - {t_x:.6f}) * (1 - {t_y:.6f}) = {w_00:.6f}")
print(f"   w_01 = t_x * (1 - t_y)       = {t_x:.6f} * (1 - {t_y:.6f})       = {w_01:.6f}")
print(f"   w_10 = (1 - t_x) * t_y       = (1 - {t_x:.6f}) * {t_y:.6f}       = {w_10:.6f}")
print(f"   w_11 = t_x * t_y             = {t_x:.6f} * {t_y:.6f}             = {w_11:.6f}")
print(f"   Sum of weights = {w_00 + w_01 + w_10 + w_11:.6f} (should be 1.0)")

interpolated_value = w_00 * f_00 + w_01 * f_01 + w_10 * f_10 + w_11 * f_11

print(f"\n7. FINAL CALCULATION:")
print(f"   Value = w_00*f_00 + w_01*f_01 + w_10*f_10 + w_11*f_11")
print(f"   Value = {w_00:.6f}*{f_00:5.1f} + {w_01:.6f}*{f_01:5.1f} + {w_10:.6f}*{f_10:5.1f} + {w_11:.6f}*{f_11:5.1f}")
print(f"   Value = {w_00*f_00:8.4f} + {w_01*f_01:8.4f} + {w_10*f_10:8.4f} + {w_11*f_11:8.4f}")
print(f"   Value = {interpolated_value:.6f}")

print(f"\n8. TARGET POINT RELATIVE POSITION:")
print(f"   In X direction (longitude): {t_x*100:.2f}% of the way from {lon_min}° to {lon_max}°")
print(f"   In Y direction (latitude):  {t_y*100:.2f}% of the way from {lat_min}° to {lat_max}°")

print(f"\n{'='*60}")
print(f"FINAL RESULT: TEC = {interpolated_value:.4f}")
print(f"{'='*60}")
# Out:
# ============================================================
# DETAILED BILINEAR INTERPOLATION ANALYSIS
# ============================================================
#
# 1. THE 4 CLOSEST POINTS:
#    P1: ( -16.4°,  -48.0°) - Indexes: [128, 124] - TEC:  83.6
#    P2: ( -16.4°,  -47.5°) - Indexes: [128, 125] - TEC:  83.0
#    P3: ( -15.9°,  -48.0°) - Indexes: [129, 124] - TEC:  82.7
#    P4: ( -15.9°,  -47.5°) - Indexes: [129, 125] - TEC:  81.3
#
# 2. TARGET POINT: (-15.94748°, -47.87787°)
#
# 3. INTERPOLATION RECTANGLE BOUNDS:
#    Latitude:   -16.4° to  -15.9° (range:  0.5°)
#    Longitude:  -48.0° to  -47.5° (range:  0.5°)
#
# 4. TEC VALUES MAPPING:
#    f_00 (lat_min, lon_min) = ( -16.4°,  -48.0°) =  83.6
#    f_01 (lat_min, lon_max) = ( -16.4°,  -47.5°) =  83.0
#    f_10 (lat_max, lon_min) = ( -15.9°,  -48.0°) =  82.7
#    f_11 (lat_max, lon_max) = ( -15.9°,  -47.5°) =  81.3
#
# 5. INTERPOLATION PARAMETERS:
#    t_x = (target_lon - lon_min) / (lon_max - lon_min)
#    t_x = (-47.87787 - ( -48.0)) / ( -47.5 - ( -48.0))
#    t_x = 0.12213 /  0.5 = 0.244260
#
#    t_y = (target_lat - lat_min) / (lat_max - lat_min)
#    t_y = (-15.94748 - ( -16.4)) / ( -15.9 - ( -16.4))
#    t_y = 0.45252 /  0.5 = 0.905040
#
# 6. INTERPOLATION WEIGHTS:
#    w_00 = (1 - t_x) * (1 - t_y) = (1 - 0.244260) * (1 - 0.905040) = 0.071765
#    w_01 = t_x * (1 - t_y)       = 0.244260 * (1 - 0.905040)       = 0.023195
#    w_10 = (1 - t_x) * t_y       = (1 - 0.244260) * 0.905040       = 0.683975
#    w_11 = t_x * t_y             = 0.244260 * 0.905040             = 0.221065
#    Sum of weights = 1.000000 (should be 1.0)
#
# 7. FINAL CALCULATION:
#    Value = w_00*f_00 + w_01*f_01 + w_10*f_10 + w_11*f_11
#    Value = 0.071765* 83.6 + 0.023195* 83.0 + 0.683975* 82.7 + 0.221065* 81.3
#    Value =   6.0025 +   1.9257 +  56.5953 +  17.9765
#    Value = 82.499926
#
# 8. TARGET POINT RELATIVE POSITION:
#    In X direction (longitude): 24.43% of the way from -48.0° to -47.5°
#    In Y direction (latitude):  90.50% of the way from -16.400000000000006° to -15.900000000000006°
#
# ============================================================
# FINAL RESULT: TEC = 82.4999
# ============================================================

# %% [markdown]
# ### 12/19 - 18:00

# %%
import pandas as pd

date = '2024-12-19'
time = '18:00:00'
timestamp_wanted = f'{date} {time}'

result = df_nagoya_maps_2024[df_nagoya_maps_2024['DATETIME'] == timestamp_wanted]

if result.empty:
    df_temp = df_nagoya_maps_2024.copy()
    df_temp['DATETIME'] = pd.to_datetime(df_temp['DATETIME'])
    timestamp_dt = pd.to_datetime(timestamp_wanted)

    df_temp['diff'] = abs((df_temp['DATETIME'] - timestamp_dt).dt.total_seconds())
    idx_nearest = df_temp['diff'].idxmin()

    result = df_nagoya_maps_2024.iloc[[idx_nearest]]
    print(f"Exact date not found. Using closest record: {df_nagoya_maps_2024.iloc[idx_nearest]['DATETIME']}")

# %%
result
# Out:
#                 DATETIME                                             TECMAP
# 5112 2024-12-19 18:00:00  [[12.639724731445312, 11.565997123718262, 11.5...

# %%
nagoya_maps = np.array(result.iloc[:]['TECMAP'])

# %%
np_nagoya_maps = []
for i in range(len(nagoya_maps)):
    np_nagoya_maps.append(nagoya_maps[i])
np_nagoya_maps = np.array(np_nagoya_maps)

# %%
np_nagoya_maps
# Out:
# array([[[12.63972473, 11.56599712, 11.56599712, ...,         nan,
#                  nan,         nan],
#         [11.71732426, 10.61837482, 10.61837482, ...,         nan,
#                  nan,         nan],
#         [14.18716908, 11.54071808, 10.25730038, ...,         nan,
#                  nan,         nan],
#         ...,
#         [34.01515198, 34.48353958, 34.89712906, ..., 11.77007103,
#          11.27845764, 11.27845764],
#         [33.72997284, 33.06239319, 33.53577042, ..., 11.66871548,
#          11.30887318, 11.18506527],
#         [33.0634613 , 32.32966614, 32.78850937, ..., 11.32422161,
#          11.1510849 , 11.04978752]]])

# %%
np_nagoya_maps.shape
# Out:
# (1, 242, 221)

# %%
nagoya_tec.tec_map = np_nagoya_maps[0]

print("=" * 60)
print("DETAILED BILINEAR INTERPOLATION ANALYSIS")
print("=" * 60)

print("\n1. THE 4 CLOSEST POINTS:")
for i, point in enumerate(nagoya_points):
    lat, lon, lat_idx, lon_idx = point
    tec_value = nagoya_tec.tec_map[lat_idx, lon_idx]
    print(f"   P{i+1}: ({lat:+6.1f}°, {lon:+6.1f}°) - Indexes: [{lat_idx:2d}, {lon_idx:2d}] - TEC: {tec_value:5.1f}")

target_lat = -15.94748
target_lon = -47.87787

print(f"\n2. TARGET POINT: ({target_lat:+6.5f}°, {target_lon:+6.5f}°)")

values = []
for point in nagoya_points:
    lat, lon, lat_idx, lon_idx = point
    values.append(nagoya_tec.tec_map[lat_idx, lon_idx])

lats = [p[0] for p in nagoya_points]
lons = [p[1] for p in nagoya_points]

lat_min, lat_max = min(lats), max(lats)
lon_min, lon_max = min(lons), max(lons)

print(f"\n3. INTERPOLATION RECTANGLE BOUNDS:")
print(f"   Latitude:  {lat_min:+6.1f}° to {lat_max:+6.1f}° (range: {lat_max - lat_min:4.1f}°)")
print(f"   Longitude: {lon_min:+6.1f}° to {lon_max:+6.1f}° (range: {lon_max - lon_min:4.1f}°)")

point_values = {}
for i, point in enumerate(nagoya_points):
    point_values[(point[0], point[1])] = values[i]

f_00 = point_values[(lat_min, lon_min)]
f_01 = point_values[(lat_min, lon_max)]
f_10 = point_values[(lat_max, lon_min)]
f_11 = point_values[(lat_max, lon_max)]

print(f"\n4. TEC VALUES MAPPING:")
print(f"   f_00 (lat_min, lon_min) = ({lat_min:+6.1f}°, {lon_min:+6.1f}°) = {f_00:5.1f}")
print(f"   f_01 (lat_min, lon_max) = ({lat_min:+6.1f}°, {lon_max:+6.1f}°) = {f_01:5.1f}")
print(f"   f_10 (lat_max, lon_min) = ({lat_max:+6.1f}°, {lon_min:+6.1f}°) = {f_10:5.1f}")
print(f"   f_11 (lat_max, lon_max) = ({lat_max:+6.1f}°, {lon_max:+6.1f}°) = {f_11:5.1f}")

t_x = (target_lon - lon_min) / (lon_max - lon_min) if lon_max != lon_min else 0
t_y = (target_lat - lat_min) / (lat_max - lat_min) if lat_max != lat_min else 0

print(f"\n5. INTERPOLATION PARAMETERS:")
print(f"   t_x = (target_lon - lon_min) / (lon_max - lon_min)")
print(f"   t_x = ({target_lon:+6.5f} - ({lon_min:+6.1f})) / ({lon_max:+6.1f} - ({lon_min:+6.1f}))")
print(f"   t_x = {target_lon - lon_min:6.5f} / {lon_max - lon_min:4.1f} = {t_x:.6f}")
print(f"   ")
print(f"   t_y = (target_lat - lat_min) / (lat_max - lat_min)")
print(f"   t_y = ({target_lat:+6.5f} - ({lat_min:+6.1f})) / ({lat_max:+6.1f} - ({lat_min:+6.1f}))")
print(f"   t_y = {target_lat - lat_min:6.5f} / {lat_max - lat_min:4.1f} = {t_y:.6f}")

w_00 = (1 - t_x) * (1 - t_y)
w_01 = t_x * (1 - t_y)
w_10 = (1 - t_x) * t_y
w_11 = t_x * t_y

print(f"\n6. INTERPOLATION WEIGHTS:")
print(f"   w_00 = (1 - t_x) * (1 - t_y) = (1 - {t_x:.6f}) * (1 - {t_y:.6f}) = {w_00:.6f}")
print(f"   w_01 = t_x * (1 - t_y)       = {t_x:.6f} * (1 - {t_y:.6f})       = {w_01:.6f}")
print(f"   w_10 = (1 - t_x) * t_y       = (1 - {t_x:.6f}) * {t_y:.6f}       = {w_10:.6f}")
print(f"   w_11 = t_x * t_y             = {t_x:.6f} * {t_y:.6f}             = {w_11:.6f}")
print(f"   Sum of weights = {w_00 + w_01 + w_10 + w_11:.6f} (should be 1.0)")

interpolated_value = w_00 * f_00 + w_01 * f_01 + w_10 * f_10 + w_11 * f_11

print(f"\n7. FINAL CALCULATION:")
print(f"   Value = w_00*f_00 + w_01*f_01 + w_10*f_10 + w_11*f_11")
print(f"   Value = {w_00:.6f}*{f_00:5.1f} + {w_01:.6f}*{f_01:5.1f} + {w_10:.6f}*{f_10:5.1f} + {w_11:.6f}*{f_11:5.1f}")
print(f"   Value = {w_00*f_00:8.4f} + {w_01*f_01:8.4f} + {w_10*f_10:8.4f} + {w_11*f_11:8.4f}")
print(f"   Value = {interpolated_value:.6f}")

print(f"\n8. TARGET POINT RELATIVE POSITION:")
print(f"   In X direction (longitude): {t_x*100:.2f}% of the way from {lon_min}° to {lon_max}°")
print(f"   In Y direction (latitude):  {t_y*100:.2f}% of the way from {lat_min}° to {lat_max}°")

print(f"\n{'='*60}")
print(f"FINAL RESULT: TEC = {interpolated_value:.4f}")
print(f"{'='*60}")
# Out:
# ============================================================
# DETAILED BILINEAR INTERPOLATION ANALYSIS
# ============================================================
#
# 1. THE 4 CLOSEST POINTS:
#    P1: ( -16.4°,  -48.0°) - Indexes: [128, 124] - TEC:  71.4
#    P2: ( -16.4°,  -47.5°) - Indexes: [128, 125] - TEC:  67.3
#    P3: ( -15.9°,  -48.0°) - Indexes: [129, 124] - TEC:  68.0
#    P4: ( -15.9°,  -47.5°) - Indexes: [129, 125] - TEC:  64.9
#
# 2. TARGET POINT: (-15.94748°, -47.87787°)
#
# 3. INTERPOLATION RECTANGLE BOUNDS:
#    Latitude:   -16.4° to  -15.9° (range:  0.5°)
#    Longitude:  -48.0° to  -47.5° (range:  0.5°)
#
# 4. TEC VALUES MAPPING:
#    f_00 (lat_min, lon_min) = ( -16.4°,  -48.0°) =  71.4
#    f_01 (lat_min, lon_max) = ( -16.4°,  -47.5°) =  67.3
#    f_10 (lat_max, lon_min) = ( -15.9°,  -48.0°) =  68.0
#    f_11 (lat_max, lon_max) = ( -15.9°,  -47.5°) =  64.9
#
# 5. INTERPOLATION PARAMETERS:
#    t_x = (target_lon - lon_min) / (lon_max - lon_min)
#    t_x = (-47.87787 - ( -48.0)) / ( -47.5 - ( -48.0))
#    t_x = 0.12213 /  0.5 = 0.244260
#
#    t_y = (target_lat - lat_min) / (lat_max - lat_min)
#    t_y = (-15.94748 - ( -16.4)) / ( -15.9 - ( -16.4))
#    t_y = 0.45252 /  0.5 = 0.905040
#
# 6. INTERPOLATION WEIGHTS:
#    w_00 = (1 - t_x) * (1 - t_y) = (1 - 0.244260) * (1 - 0.905040) = 0.071765
#    w_01 = t_x * (1 - t_y)       = 0.244260 * (1 - 0.905040)       = 0.023195
#    w_10 = (1 - t_x) * t_y       = (1 - 0.244260) * 0.905040       = 0.683975
#    w_11 = t_x * t_y             = 0.244260 * 0.905040             = 0.221065
#    Sum of weights = 1.000000 (should be 1.0)
#
# 7. FINAL CALCULATION:
#    Value = w_00*f_00 + w_01*f_01 + w_10*f_10 + w_11*f_11
#    Value = 0.071765* 71.4 + 0.023195* 67.3 + 0.683975* 68.0 + 0.221065* 64.9
#    Value =   5.1272 +   1.5602 +  46.4933 +  14.3458
#    Value = 67.526479
#
# 8. TARGET POINT RELATIVE POSITION:
#    In X direction (longitude): 24.43% of the way from -48.0° to -47.5°
#    In Y direction (latitude):  90.50% of the way from -16.400000000000006° to -15.900000000000006°
#
# ============================================================
# FINAL RESULT: TEC = 67.5265
# ============================================================

# %% [markdown]
# ### 12/22 - 18:00

# %%
import pandas as pd

date = '2024-12-22'
time = '18:00:00'
timestamp_wanted = f'{date} {time}'

result = df_nagoya_maps_2024[df_nagoya_maps_2024['DATETIME'] == timestamp_wanted]

if result.empty:
    df_temp = df_nagoya_maps_2024.copy()
    df_temp['DATETIME'] = pd.to_datetime(df_temp['DATETIME'])
    timestamp_dt = pd.to_datetime(timestamp_wanted)

    df_temp['diff'] = abs((df_temp['DATETIME'] - timestamp_dt).dt.total_seconds())
    idx_nearest = df_temp['diff'].idxmin()

    result = df_nagoya_maps_2024.iloc[[idx_nearest]]
    print(f"Exact date not found. Using closest record: {df_nagoya_maps_2024.iloc[idx_nearest]['DATETIME']}")

# %%
result
# Out:
#                 DATETIME                                             TECMAP
# 5976 2024-12-22 18:00:00  [[14.305987358093262, 14.235016822814941, 15.1...

# %%
nagoya_maps = np.array(result.iloc[:]['TECMAP'])

# %%
np_nagoya_maps = []
for i in range(len(nagoya_maps)):
    np_nagoya_maps.append(nagoya_maps[i])
np_nagoya_maps = np.array(np_nagoya_maps)

# %%
np_nagoya_maps
# Out:
# array([[[14.30598736, 14.23501682, 15.19717693, ...,         nan,
#                  nan,         nan],
#         [13.24124527, 13.24124527, 13.24124527, ...,         nan,
#                  nan,         nan],
#         [13.24124527, 13.24124527, 13.24124527, ...,         nan,
#                  nan,         nan],
#         ...,
#         [43.63508224, 43.97467422, 44.23501205, ..., 20.72278595,
#          20.15914345, 19.78045845],
#         [43.53390503, 43.86975861, 44.0747261 , ..., 20.29078865,
#          19.64533615, 19.32730103],
#         [43.54644394, 43.77022934, 43.95893478, ..., 19.72059822,
#          19.0694046 , 18.65716362]]])

# %%
np_nagoya_maps.shape
# Out:
# (1, 242, 221)

# %%
nagoya_tec.tec_map = np_nagoya_maps[0]

print("=" * 60)
print("DETAILED BILINEAR INTERPOLATION ANALYSIS")
print("=" * 60)

print("\n1. THE 4 CLOSEST POINTS:")
for i, point in enumerate(nagoya_points):
    lat, lon, lat_idx, lon_idx = point
    tec_value = nagoya_tec.tec_map[lat_idx, lon_idx]
    print(f"   P{i+1}: ({lat:+6.1f}°, {lon:+6.1f}°) - Indexes: [{lat_idx:2d}, {lon_idx:2d}] - TEC: {tec_value:5.1f}")

target_lat = -15.94748
target_lon = -47.87787

print(f"\n2. TARGET POINT: ({target_lat:+6.5f}°, {target_lon:+6.5f}°)")

values = []
for point in nagoya_points:
    lat, lon, lat_idx, lon_idx = point
    values.append(nagoya_tec.tec_map[lat_idx, lon_idx])

lats = [p[0] for p in nagoya_points]
lons = [p[1] for p in nagoya_points]

lat_min, lat_max = min(lats), max(lats)
lon_min, lon_max = min(lons), max(lons)

print(f"\n3. INTERPOLATION RECTANGLE BOUNDS:")
print(f"   Latitude:  {lat_min:+6.1f}° to {lat_max:+6.1f}° (range: {lat_max - lat_min:4.1f}°)")
print(f"   Longitude: {lon_min:+6.1f}° to {lon_max:+6.1f}° (range: {lon_max - lon_min:4.1f}°)")

point_values = {}
for i, point in enumerate(nagoya_points):
    point_values[(point[0], point[1])] = values[i]

f_00 = point_values[(lat_min, lon_min)]
f_01 = point_values[(lat_min, lon_max)]
f_10 = point_values[(lat_max, lon_min)]
f_11 = point_values[(lat_max, lon_max)]

print(f"\n4. TEC VALUES MAPPING:")
print(f"   f_00 (lat_min, lon_min) = ({lat_min:+6.1f}°, {lon_min:+6.1f}°) = {f_00:5.1f}")
print(f"   f_01 (lat_min, lon_max) = ({lat_min:+6.1f}°, {lon_max:+6.1f}°) = {f_01:5.1f}")
print(f"   f_10 (lat_max, lon_min) = ({lat_max:+6.1f}°, {lon_min:+6.1f}°) = {f_10:5.1f}")
print(f"   f_11 (lat_max, lon_max) = ({lat_max:+6.1f}°, {lon_max:+6.1f}°) = {f_11:5.1f}")

t_x = (target_lon - lon_min) / (lon_max - lon_min) if lon_max != lon_min else 0
t_y = (target_lat - lat_min) / (lat_max - lat_min) if lat_max != lat_min else 0

print(f"\n5. INTERPOLATION PARAMETERS:")
print(f"   t_x = (target_lon - lon_min) / (lon_max - lon_min)")
print(f"   t_x = ({target_lon:+6.5f} - ({lon_min:+6.1f})) / ({lon_max:+6.1f} - ({lon_min:+6.1f}))")
print(f"   t_x = {target_lon - lon_min:6.5f} / {lon_max - lon_min:4.1f} = {t_x:.6f}")
print(f"   ")
print(f"   t_y = (target_lat - lat_min) / (lat_max - lat_min)")
print(f"   t_y = ({target_lat:+6.5f} - ({lat_min:+6.1f})) / ({lat_max:+6.1f} - ({lat_min:+6.1f}))")
print(f"   t_y = {target_lat - lat_min:6.5f} / {lat_max - lat_min:4.1f} = {t_y:.6f}")

w_00 = (1 - t_x) * (1 - t_y)
w_01 = t_x * (1 - t_y)
w_10 = (1 - t_x) * t_y
w_11 = t_x * t_y

print(f"\n6. INTERPOLATION WEIGHTS:")
print(f"   w_00 = (1 - t_x) * (1 - t_y) = (1 - {t_x:.6f}) * (1 - {t_y:.6f}) = {w_00:.6f}")
print(f"   w_01 = t_x * (1 - t_y)       = {t_x:.6f} * (1 - {t_y:.6f})       = {w_01:.6f}")
print(f"   w_10 = (1 - t_x) * t_y       = (1 - {t_x:.6f}) * {t_y:.6f}       = {w_10:.6f}")
print(f"   w_11 = t_x * t_y             = {t_x:.6f} * {t_y:.6f}             = {w_11:.6f}")
print(f"   Sum of weights = {w_00 + w_01 + w_10 + w_11:.6f} (should be 1.0)")

interpolated_value = w_00 * f_00 + w_01 * f_01 + w_10 * f_10 + w_11 * f_11

print(f"\n7. FINAL CALCULATION:")
print(f"   Value = w_00*f_00 + w_01*f_01 + w_10*f_10 + w_11*f_11")
print(f"   Value = {w_00:.6f}*{f_00:5.1f} + {w_01:.6f}*{f_01:5.1f} + {w_10:.6f}*{f_10:5.1f} + {w_11:.6f}*{f_11:5.1f}")
print(f"   Value = {w_00*f_00:8.4f} + {w_01*f_01:8.4f} + {w_10*f_10:8.4f} + {w_11*f_11:8.4f}")
print(f"   Value = {interpolated_value:.6f}")

print(f"\n8. TARGET POINT RELATIVE POSITION:")
print(f"   In X direction (longitude): {t_x*100:.2f}% of the way from {lon_min}° to {lon_max}°")
print(f"   In Y direction (latitude):  {t_y*100:.2f}% of the way from {lat_min}° to {lat_max}°")

print(f"\n{'='*60}")
print(f"FINAL RESULT: TEC = {interpolated_value:.4f}")
print(f"{'='*60}")
# Out:
# ============================================================
# DETAILED BILINEAR INTERPOLATION ANALYSIS
# ============================================================
#
# 1. THE 4 CLOSEST POINTS:
#    P1: ( -16.4°,  -48.0°) - Indexes: [128, 124] - TEC:  84.3
#    P2: ( -16.4°,  -47.5°) - Indexes: [128, 125] - TEC:  82.7
#    P3: ( -15.9°,  -48.0°) - Indexes: [129, 124] - TEC:  74.1
#    P4: ( -15.9°,  -47.5°) - Indexes: [129, 125] - TEC:  76.7
#
# 2. TARGET POINT: (-15.94748°, -47.87787°)
#
# 3. INTERPOLATION RECTANGLE BOUNDS:
#    Latitude:   -16.4° to  -15.9° (range:  0.5°)
#    Longitude:  -48.0° to  -47.5° (range:  0.5°)
#
# 4. TEC VALUES MAPPING:
#    f_00 (lat_min, lon_min) = ( -16.4°,  -48.0°) =  84.3
#    f_01 (lat_min, lon_max) = ( -16.4°,  -47.5°) =  82.7
#    f_10 (lat_max, lon_min) = ( -15.9°,  -48.0°) =  74.1
#    f_11 (lat_max, lon_max) = ( -15.9°,  -47.5°) =  76.7
#
# 5. INTERPOLATION PARAMETERS:
#    t_x = (target_lon - lon_min) / (lon_max - lon_min)
#    t_x = (-47.87787 - ( -48.0)) / ( -47.5 - ( -48.0))
#    t_x = 0.12213 /  0.5 = 0.244260
#
#    t_y = (target_lat - lat_min) / (lat_max - lat_min)
#    t_y = (-15.94748 - ( -16.4)) / ( -15.9 - ( -16.4))
#    t_y = 0.45252 /  0.5 = 0.905040
#
# 6. INTERPOLATION WEIGHTS:
#    w_00 = (1 - t_x) * (1 - t_y) = (1 - 0.244260) * (1 - 0.905040) = 0.071765
#    w_01 = t_x * (1 - t_y)       = 0.244260 * (1 - 0.905040)       = 0.023195
#    w_10 = (1 - t_x) * t_y       = (1 - 0.244260) * 0.905040       = 0.683975
#    w_11 = t_x * t_y             = 0.244260 * 0.905040             = 0.221065
#    Sum of weights = 1.000000 (should be 1.0)
#
# 7. FINAL CALCULATION:
#    Value = w_00*f_00 + w_01*f_01 + w_10*f_10 + w_11*f_11
#    Value = 0.071765* 84.3 + 0.023195* 82.7 + 0.683975* 74.1 + 0.221065* 76.7
#    Value =   6.0472 +   1.9176 +  50.7011 +  16.9634
#    Value = 75.629380
#
# 8. TARGET POINT RELATIVE POSITION:
#    In X direction (longitude): 24.43% of the way from -48.0° to -47.5°
#    In Y direction (latitude):  90.50% of the way from -16.400000000000006° to -15.900000000000006°
#
# ============================================================
# FINAL RESULT: TEC = 75.6294
# ============================================================
