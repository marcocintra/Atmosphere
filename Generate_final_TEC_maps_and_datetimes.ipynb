# %% [markdown]
# <a href="https://colab.research.google.com/github/marcocintra/Atmosphere/blob/master/GENERATE_FINAL_TEC_MAPS_AND_DATETIMES.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # IGS

# %% [markdown]
# ## DF1

# %% [markdown]
# ### 08:00 UTC

# %%
import pandas as pd
import numpy as np

# %%
# df1_mapas_igs_2022_2024_0800.pkl
# !gdown

# %%
df1_mapas_igs_2022_2024_0800 = pd.read_pickle("df1_mapas_igs_2022_2024_0800.pkl")

# %%
df1_mapas_igs_2022_2024_0800

# %%
df1_mapas_igs_2022_2024_0800.index.to_numpy().shape

# %%
df1_mapas_igs_2022_2024_0800.index.to_numpy()[0]

# %%
np.save('mapas1_igs_2022_2024_0800_datetimes.npy', df1_mapas_igs_2022_2024_0800.index.to_numpy())

# %%
mapas1_igs_2022_2024_0800_datetimes = np.load('mapas1_igs_2022_2024_0800_datetimes.npy')

# %%
mapas1_igs_2022_2024_0800_datetimes

# %% [markdown]
# ### 16:00 UTC

# %%
#df1_mapas_igs_2022_2024_1600.pkl
# !gdown

# %%
df1_mapas_igs_2022_2024_1600 = pd.read_pickle("df1_mapas_igs_2022_2024_1600.pkl")

# %%
df1_mapas_igs_2022_2024_1600

# %%
np.save('mapas1_igs_2022_2024_1600_datetimes.npy', df1_mapas_igs_2022_2024_1600.index.to_numpy())

# %%
mapas1_igs_2022_2024_1600_datetimes = np.load('mapas1_igs_2022_2024_1600_datetimes.npy')

# %%
mapas1_igs_2022_2024_1600_datetimes

# %% [markdown]
# ### 20:00 TO 04:00 UTC

# %%
#df1_mapas_igs_2022_2024_2000_2200_0000_0200_0400.pkl
# !gdown

# %%
df1_mapas_igs_2022_2024_2000_2200_0000_0200_0400 = pd.read_pickle("df1_mapas_igs_2022_2024_2000_2200_0000_0200_0400.pkl")

# %%
df1_mapas_igs_2022_2024_2000_2200_0000_0200_0400

# %%
dias_unicos = df1_mapas_igs_2022_2024_2000_2200_0000_0200_0400.index.date
quantidade_dias = len(np.unique(dias_unicos))
print(f"O DataFrame contém {quantidade_dias} dias únicos.")

# %%
np.save('mapas1_igs_2022_2024_2000_2200_0000_0200_0400_datetimes.npy', df1_mapas_igs_2022_2024_2000_2200_0000_0200_0400.index.to_numpy())

# %%
mapas1_igs_2022_2024_2000_2200_0000_0200_0400_datetimes = np.load('mapas1_igs_2022_2024_2000_2200_0000_0200_0400_datetimes.npy')

# %%
mapas1_igs_2022_2024_2000_2200_0000_0200_0400_datetimes

# %% [markdown]
# ## DF2

# %% [markdown]
# ### 08:00 UTC

# %%
import pandas as pd
import numpy as np

# %%
#df2_mapas_igs_2022_2024_0800.pkl
# !gdown

# %%
df2_mapas_igs_2022_2024_0800 = pd.read_pickle("df2_mapas_igs_2022_2024_0800.pkl")

# %%
df2_mapas_igs_2022_2024_0800

# %%
np.save('mapas2_igs_2022_2024_0800_datetimes.npy', df2_mapas_igs_2022_2024_0800.index.to_numpy())

# %%
mapas2_igs_2022_2024_0800_datetimes = np.load('mapas2_igs_2022_2024_0800_datetimes.npy')

# %%
mapas2_igs_2022_2024_0800_datetimes

# %% [markdown]
# ### 16:00 UTC

# %%
#df2_mapas_igs_2022_2024_1600.pkl
# !gdown

# %%
df2_mapas_igs_2022_2024_1600 = pd.read_pickle("df2_mapas_igs_2022_2024_1600.pkl")

# %%
df2_mapas_igs_2022_2024_1600

# %%
np.save('mapas2_igs_2022_2024_1600_datetimes.npy', df2_mapas_igs_2022_2024_1600.index.to_numpy())

# %%
mapas2_igs_2022_2024_1600_datetimes = np.load('mapas2_igs_2022_2024_1600_datetimes.npy')

# %%
mapas2_igs_2022_2024_1600_datetimes

# %% [markdown]
# ### 20:00 TO 04:00 UTC

# %%
#df2_mapas_igs_2022_2024_2000_2200_0000_0200_0400.pkl
# !gdown

# %%
df2_mapas_igs_2022_2024_2000_2200_0000_0200_0400 = pd.read_pickle("df2_mapas_igs_2022_2024_2000_2200_0000_0200_0400.pkl")

# %%
df2_mapas_igs_2022_2024_2000_2200_0000_0200_0400

# %%
dias_unicos = df2_mapas_igs_2022_2024_2000_2200_0000_0200_0400.index.date
quantidade_dias = len(np.unique(dias_unicos))
print(f"O DataFrame contém {quantidade_dias} dias únicos.")

# %%
np.save('mapas2_igs_2022_2024_2000_2200_0000_0200_0400_datetimes.npy', df2_mapas_igs_2022_2024_2000_2200_0000_0200_0400.index.to_numpy())

# %%
mapas2_igs_2022_2024_2000_2200_0000_0200_0400_datetimes = np.load('mapas2_igs_2022_2024_2000_2200_0000_0200_0400_datetimes.npy')

# %%
mapas2_igs_2022_2024_2000_2200_0000_0200_0400_datetimes

# %% [markdown]
# # EMBRACE

# %% [markdown]
# ## DF

# %% [markdown]
# ### 08:00 UTC

# %%
import pandas as pd
import numpy as np

# %%
#df_mapas_embrace_2022_2024_0800.pkl
# !gdown

# %%
df_mapas_embrace_2022_2024_0800 = pd.read_pickle("df_mapas_embrace_2022_2024_0800.pkl")

# %%
df_mapas_embrace_2022_2024_0800

# %%
np.save('mapas_embrace_2022_2024_0800_datetimes.npy', df_mapas_embrace_2022_2024_0800.index.to_numpy())

# %%
mapas_embrace_2022_2024_0800_datetimes = np.load('mapas_embrace_2022_2024_0800_datetimes.npy')

# %%
mapas_embrace_2022_2024_0800_datetimes

# %% [markdown]
# ### 16:00 UTC

# %%
#df_mapas_embrace_2022_2024_1600.pkl
# !gdown

# %%
df_mapas_embrace_2022_2024_1600 = pd.read_pickle("df_mapas_embrace_2022_2024_1600.pkl")

# %%
df_mapas_embrace_2022_2024_1600

# %%
np.save('mapas_embrace_2022_2024_1600_datetimes.npy', df_mapas_embrace_2022_2024_1600.index.to_numpy())

# %%
mapas_embrace_2022_2024_1600_datetimes = np.load('mapas_embrace_2022_2024_1600_datetimes.npy')

# %%
mapas_embrace_2022_2024_1600_datetimes

# %% [markdown]
# ### 20:00 TO 04:00 UTC

# %%
#df_mapas_embrace_2022_2024_2000_2200_0000_0200_0400.pkl
# !gdown

# %%
df_mapas_embrace_2022_2024_2000_2200_0000_0200_0400 = pd.read_pickle("df_mapas_embrace_2022_2024_2000_2200_0000_0200_0400.pkl")

# %%
df_mapas_embrace_2022_2024_2000_2200_0000_0200_0400

# %%
dias_unicos = df_mapas_embrace_2022_2024_2000_2200_0000_0200_0400.index.date
quantidade_dias = len(np.unique(dias_unicos))
print(f"O DataFrame contém {quantidade_dias} dias únicos.")

# %%
np.save('mapas_embrace_2022_2024_2000_2200_0000_0200_0400_datetimes.npy', df_mapas_embrace_2022_2024_2000_2200_0000_0200_0400.index.to_numpy())

# %%
mapas_embrace_2022_2024_2000_2200_0000_0200_0400_datetimes = np.load('mapas_embrace_2022_2024_2000_2200_0000_0200_0400_datetimes.npy')

# %%
mapas_embrace_2022_2024_2000_2200_0000_0200_0400_datetimes

# %% [markdown]
# ## DF3

# %% [markdown]
# ### 08:00 UTC

# %%
import pandas as pd

# %%
import numpy as np

# %%
#df3_mapas_embrace_2024_0800_30m.pkl
# !gdown

# %%
df3_mapas_embrace_2024_0800_30m = pd.read_pickle("df3_mapas_embrace_2024_0800_30m.pkl")

# %%
df3_mapas_embrace_2024_0800_30m

# %%
dias_unicos = df3_mapas_embrace_2024_0800_30m.index.date
quantidade_dias = len(np.unique(dias_unicos))
print(f"O DataFrame contém {quantidade_dias} dias únicos.")

# %%
np.save('mapas3_embrace_2024_0800_30m_datetimes.npy', df3_mapas_embrace_2024_0800_30m.index.to_numpy())

# %%
mapas_embrace_2024_0800_30m_datetimes = np.load('mapas3_embrace_2024_0800_30m_datetimes.npy')

# %%
mapas_embrace_2024_0800_30m_datetimes

# %% [markdown]
# ### 16:00 UTC

# %%
import pandas as pd

# %%
import numpy as np

# %%
#df3_mapas_embrace_2024_1600_30m.pkl
# !gdown

# %%
df3_mapas_embrace_2024_1600_30m = pd.read_pickle("df3_mapas_embrace_2024_1600_30m.pkl")

# %%
df3_mapas_embrace_2024_1600_30m

# %%
dias_unicos = df3_mapas_embrace_2024_1600_30m.index.date
quantidade_dias = len(np.unique(dias_unicos))
print(f"O DataFrame contém {quantidade_dias} dias únicos.")

# %%
np.save('mapas3_embrace_2024_1600_30m_datetimes.npy', df3_mapas_embrace_2024_1600_30m.index.to_numpy())

# %%
mapas_embrace_2024_1600_30m_datetimes = np.load('mapas3_embrace_2024_1600_30m_datetimes.npy')

# %%
mapas_embrace_2024_1600_30m_datetimes

# %% [markdown]
# ### 20:00 TO 04:00 UTC

# %%
import pandas as pd

# %%
import numpy as np

# %%
#df3_mapas_embrace_2024_2000_0400_30m.pkl
# !gdown

# %%
df3_mapas_embrace_2024_2000_0400_30m = pd.read_pickle("df3_mapas_embrace_2024_2000_0400_30m.pkl")

# %%
df3_mapas_embrace_2024_2000_0400_30m

# %%
dias_unicos = df3_mapas_embrace_2024_2000_0400_30m.index.date
quantidade_dias = len(np.unique(dias_unicos))
print(f"O DataFrame contém {quantidade_dias} dias únicos.")

# %%
np.save('mapas3_embrace_2024_2000_0400_30m_datetimes.npy', df3_mapas_embrace_2024_2000_0400_30m.index.to_numpy())

# %%
mapas_embrace_2024_2000_0400_30m_datetimes = np.load('mapas3_embrace_2024_2000_0400_30m_datetimes.npy')

# %%
mapas_embrace_2024_2000_0400_30m_datetimes

# %% [markdown]
# # MAGGIA

# %% [markdown]
# ## DF1

# %% [markdown]
# ### 08:00 UTC

# %%
import pandas as pd
import numpy as np

# %%
#df1_mapas_maggia_2022_2024_0800.pkl
# !gdown

# %%
df1_mapas_maggia_2022_2024_0800 = pd.read_pickle("df1_mapas_maggia_2022_2024_0800.pkl")

# %%
df1_mapas_maggia_2022_2024_0800

# %%
np.save('mapas1_maggia_2022_2024_0800_datetimes.npy', df1_mapas_maggia_2022_2024_0800.index.to_numpy())

# %%
mapas1_maggia_2022_2024_0800_datetimes = np.load('mapas1_maggia_2022_2024_0800_datetimes.npy')

# %%
mapas1_maggia_2022_2024_0800_datetimes

# %% [markdown]
# ### 16:00 UTC

# %%
#df1_mapas_maggia_2022_2024_1600.pkl
# !gdown

# %%
df1_mapas_maggia_2022_2024_1600 = pd.read_pickle("df1_mapas_maggia_2022_2024_1600.pkl")

# %%
df1_mapas_maggia_2022_2024_1600

# %%
df1_mapas_maggia_2022_2024_1600.index

# %%
np.save('mapas1_maggia_2022_2024_1600_datetimes.npy', df1_mapas_maggia_2022_2024_1600.index.to_numpy())

# %%
mapas1_maggia_2022_2024_1600_datetimes = np.load('mapas1_maggia_2022_2024_1600_datetimes.npy')

# %%
mapas1_maggia_2022_2024_1600_datetimes

# %% [markdown]
# ### 20:00 TO 04:00 UTC

# %%
#df1_mapas_maggia_2022_2024_2000_2200_0000_0200_0400.pkl
# !gdown

# %%
df1_mapas_maggia_2022_2024_2000_2200_0000_0200_0400 = pd.read_pickle("df1_mapas_maggia_2022_2024_2000_2200_0000_0200_0400.pkl")

# %%
df1_mapas_maggia_2022_2024_2000_2200_0000_0200_0400

# %%
dias_unicos = df1_mapas_maggia_2022_2024_2000_2200_0000_0200_0400.index.date
quantidade_dias = len(np.unique(dias_unicos))
print(f"O DataFrame contém {quantidade_dias} dias únicos.")

# %%
np.save('mapas1_maggia_2022_2024_2000_2200_0000_0200_0400_datetimes.npy', df1_mapas_maggia_2022_2024_2000_2200_0000_0200_0400.index.to_numpy())

# %%
mapas1_maggia_2022_2024_2000_2200_0000_0200_0400_datetimes = np.load('mapas1_maggia_2022_2024_2000_2200_0000_0200_0400_datetimes.npy')

# %%
mapas1_maggia_2022_2024_2000_2200_0000_0200_0400_datetimes

# %% [markdown]
# ## DF2

# %% [markdown]
# ### 08:00 UTC

# %%
import pandas as pd
import numpy as np

# %%
#df2_mapas_maggia_2022_2024_0800.pkl
# !gdown

# %%
df2_mapas_maggia_2022_2024_0800 = pd.read_pickle("df2_mapas_maggia_2022_2024_0800.pkl")

# %%
df2_mapas_maggia_2022_2024_0800

# %%
np.save('mapas2_maggia_2022_2024_0800_datetimes.npy', df2_mapas_maggia_2022_2024_0800.index.to_numpy())

# %%
mapas2_maggia_2022_2024_0800_datetimes = np.load('mapas2_maggia_2022_2024_0800_datetimes.npy')

# %%
mapas2_maggia_2022_2024_0800_datetimes

# %% [markdown]
# ### 16:00 UTC

# %%
#df2_mapas_maggia_2022_2024_1600.pkl
# !gdown

# %%
df2_mapas_maggia_2022_2024_1600 = pd.read_pickle("df2_mapas_maggia_2022_2024_1600.pkl")

# %%
df2_mapas_maggia_2022_2024_1600

# %%
np.save('mapas2_maggia_2022_2024_1600_datetimes.npy', df2_mapas_maggia_2022_2024_1600.index.to_numpy())

# %%
mapas2_maggia_2022_2024_1600_datetimes = np.load('mapas2_maggia_2022_2024_1600_datetimes.npy')

# %%
mapas2_maggia_2022_2024_1600_datetimes

# %% [markdown]
# ### 20:00 TO 04:00 UTC

# %%
#df2_mapas_maggia_2022_2024_2000_2200_0000_0200_0400.pkl
# !gdown

# %%
df2_mapas_maggia_2022_2024_2000_2200_0000_0200_0400 = pd.read_pickle("df2_mapas_maggia_2022_2024_2000_2200_0000_0200_0400.pkl")

# %%
df2_mapas_maggia_2022_2024_2000_2200_0000_0200_0400

# %%
dias_unicos = df2_mapas_maggia_2022_2024_2000_2200_0000_0200_0400.index.date
quantidade_dias = len(np.unique(dias_unicos))
print(f"O DataFrame contém {quantidade_dias} dias únicos.")

# %%
np.save('mapas2_maggia_2022_2024_2000_2200_0000_0200_0400_datetimes.npy', df2_mapas_maggia_2022_2024_2000_2200_0000_0200_0400.index.to_numpy())

# %%
mapas2_maggia_2022_2024_2000_2200_0000_0200_0400_datetimes = np.load('mapas2_maggia_2022_2024_2000_2200_0000_0200_0400_datetimes.npy')

# %%
mapas2_maggia_2022_2024_2000_2200_0000_0200_0400_datetimes

# %% [markdown]
# ## DF3

# %% [markdown]
# ### 08:00 UTC

# %%
import pandas as pd

# %%
import numpy as np

# %%
#df3_mapas_maggia_2024_0800_30m.pkl
# !gdown

# %%
df3_mapas_maggia_2024_0800_30m = pd.read_pickle("df3_mapas_maggia_2024_0800_30m.pkl")

# %%
df3_mapas_maggia_2024_0800_30m

# %%
dias_unicos = df3_mapas_maggia_2024_0800_30m.index.date
quantidade_dias = len(np.unique(dias_unicos))
print(f"O DataFrame contém {quantidade_dias} dias únicos.")

# %%
np.save('mapas3_maggia_2024_0800_30m_datetimes.npy', df3_mapas_maggia_2024_0800_30m.index.to_numpy())

# %%
mapas_maggia_2024_0800_30m_datetimes = np.load('mapas3_maggia_2024_0800_30m_datetimes.npy')

# %%
mapas_maggia_2024_0800_30m_datetimes

# %% [markdown]
# ### 16:00 UTC

# %%
import pandas as pd

# %%
import numpy as np

# %%
#df3_mapas_maggia_2024_1600_30m.pkl
# !gdown

# %%
df3_mapas_maggia_2024_1600_30m = pd.read_pickle("df3_mapas_maggia_2024_1600_30m.pkl")

# %%
df3_mapas_maggia_2024_1600_30m

# %%
dias_unicos = df3_mapas_maggia_2024_1600_30m.index.date
quantidade_dias = len(np.unique(dias_unicos))
print(f"O DataFrame contém {quantidade_dias} dias únicos.")

# %%
np.save('mapas3_maggia_2024_1600_30m_datetimes.npy', df3_mapas_maggia_2024_1600_30m.index.to_numpy())

# %%
mapas_maggia_2024_1600_30m_datetimes = np.load('mapas3_maggia_2024_1600_30m_datetimes.npy')

# %%
mapas_maggia_2024_1600_30m_datetimes

# %% [markdown]
# ### 20:00 TO 04:00 UTC

# %%
import pandas as pd

# %%
import numpy as np

# %%
#df3_mapas_maggia_2024_2000_0400_30m.pkl
# !gdown

# %%
df3_mapas_maggia_2024_2000_0400_30m = pd.read_pickle("df3_mapas_maggia_2024_2000_0400_30m.pkl")

# %%
df3_mapas_maggia_2024_2000_0400_30m

# %%
dias_unicos = df3_mapas_maggia_2024_2000_0400_30m.index.date
quantidade_dias = len(np.unique(dias_unicos))
print(f"O DataFrame contém {quantidade_dias} dias únicos.")

# %%
np.save('mapas3_maggia_2024_2000_0400_30m_datetimes.npy', df3_mapas_maggia_2024_2000_0400_30m.index.to_numpy())

# %%
mapas3_maggia_2024_2000_0400_30m_datetimes = np.load('mapas3_maggia_2024_2000_0400_30m_datetimes.npy')

# %%
mapas3_maggia_2024_2000_0400_30m_datetimes

# %% [markdown]
# # NAGOYA

# %% [markdown]
# ## DF1

# %% [markdown]
# ### 08:00 UTC

# %%
import pandas as pd
import numpy as np

# %%
#df1_mapas_nagoya_2022_2024_0800.pkl
# !gdown

# %%
df1_mapas_nagoya_2022_2024_0800 = pd.read_pickle("df1_mapas_nagoya_2022_2024_0800.pkl")

# %%
df1_mapas_nagoya_2022_2024_0800

# %%
np.save('mapas1_nagoya_2022_2024_0800_datetimes.npy', df1_mapas_nagoya_2022_2024_0800.index.to_numpy())

# %%
mapas1_nagoya_2022_2024_0800_datetimes = np.load('mapas1_nagoya_2022_2024_0800_datetimes.npy')

# %%
mapas1_nagoya_2022_2024_0800_datetimes

# %% [markdown]
# ### 16:00 UTC

# %%
#df1_mapas_nagoya_2022_2024_1600.pkl
# !gdown

# %%
df1_mapas_nagoya_2022_2024_1600 = pd.read_pickle("df1_mapas_nagoya_2022_2024_1600.pkl")

# %%
df1_mapas_nagoya_2022_2024_1600

# %%
dias_unicos = df1_mapas_nagoya_2022_2024_1600.index.date
quantidade_dias = len(np.unique(dias_unicos))
print(f"O DataFrame contém {quantidade_dias} dias únicos.")

# %%
df1_mapas_nagoya_2022_2024_1600.index

# %%
np.save('mapas1_nagoya_2022_2024_1600_datetimes.npy', df1_mapas_nagoya_2022_2024_1600.index.to_numpy())

# %%
mapas1_nagoya_2022_2024_1600_datetimes = np.load('mapas1_nagoya_2022_2024_1600_datetimes.npy')

# %%
mapas1_nagoya_2022_2024_1600_datetimes

# %% [markdown]
# ### 20:00 TO 04:00 UTC

# %%
#df1_mapas_nagoya_2022_2024_2000_2200_0000_0200_0400.pkl
# !gdown

# %%
df1_mapas_nagoya_2022_2024_2000_2200_0000_0200_0400 = pd.read_pickle("df1_mapas_nagoya_2022_2024_2000_2200_0000_0200_0400.pkl")

# %%
df1_mapas_nagoya_2022_2024_2000_2200_0000_0200_0400

# %%
dias_unicos = df1_mapas_nagoya_2022_2024_2000_2200_0000_0200_0400.index.date
quantidade_dias = len(np.unique(dias_unicos))
print(f"O DataFrame contém {quantidade_dias} dias únicos.")

# %%
np.save('mapas1_nagoya_2022_2024_2000_2200_0000_0200_0400_datetimes.npy', df1_mapas_nagoya_2022_2024_2000_2200_0000_0200_0400.index.to_numpy())

# %%
mapas1_nagoya_2022_2024_2000_2200_0000_0200_0400_datetimes = np.load('mapas1_nagoya_2022_2024_2000_2200_0000_0200_0400_datetimes.npy')

# %%
mapas1_nagoya_2022_2024_2000_2200_0000_0200_0400_datetimes

# %% [markdown]
# ## DF2

# %% [markdown]
# ### 08:00 UTC

# %%
import pandas as pd
import numpy as np

# %%
#df2_mapas_nagoya_2022_2024_0800.pkl
# !gdown

# %%
df2_mapas_nagoya_2022_2024_0800 = pd.read_pickle("df2_mapas_nagoya_2022_2024_0800.pkl")

# %%
df2_mapas_nagoya_2022_2024_0800

# %%
np.save('mapas2_nagoya_2022_2024_0800_datetimes.npy', df2_mapas_nagoya_2022_2024_0800.index.to_numpy())

# %%
mapas2_nagoya_2022_2024_0800_datetimes = np.load('mapas2_nagoya_2022_2024_0800_datetimes.npy')

# %%
mapas2_nagoya_2022_2024_0800_datetimes

# %% [markdown]
# ### 16:00 UTC

# %%
#df2_mapas_nagoya_2022_2024_1600.pkl
# !gdown

# %%
df2_mapas_nagoya_2022_2024_1600 = pd.read_pickle("df2_mapas_nagoya_2022_2024_1600.pkl")

# %%
df2_mapas_nagoya_2022_2024_1600

# %%
np.save('mapas2_nagoya_2022_2024_1600_datetimes.npy', df2_mapas_nagoya_2022_2024_1600.index.to_numpy())

# %%
mapas2_nagoya_2022_2024_1600_datetimes = np.load('mapas2_nagoya_2022_2024_1600_datetimes.npy')

# %%
mapas2_nagoya_2022_2024_1600_datetimes

# %% [markdown]
# ### 20:00 TO 04:00 UTC

# %%
#df2_mapas_nagoya_2022_2024_2000_2200_0000_0200_0400.pkl
# !gdown

# %%
df2_mapas_nagoya_2022_2024_2000_2200_0000_0200_0400 = pd.read_pickle("df2_mapas_nagoya_2022_2024_2000_2200_0000_0200_0400.pkl")

# %%
df2_mapas_nagoya_2022_2024_2000_2200_0000_0200_0400

# %%
dias_unicos = df2_mapas_nagoya_2022_2024_2000_2200_0000_0200_0400.index.date
quantidade_dias = len(np.unique(dias_unicos))
print(f"O DataFrame contém {quantidade_dias} dias únicos.")

# %%
np.save('mapas2_nagoya_2022_2024_2000_2200_0000_0200_0400_datetimes.npy', df2_mapas_nagoya_2022_2024_2000_2200_0000_0200_0400.index.to_numpy())

# %%
mapas2_nagoya_2022_2024_2000_2200_0000_0200_0400_datetimes = np.load('mapas2_nagoya_2022_2024_2000_2200_0000_0200_0400_datetimes.npy')

# %%
mapas2_nagoya_2022_2024_2000_2200_0000_0200_0400_datetimes

# %% [markdown]
# ## DF3

# %% [markdown]
# ### 08:00 UTC

# %%
import pandas as pd

# %%
import numpy as np

# %%
#df3_mapas_nagoya_2024_0800_30m.pkl
# !gdown

# %%
df3_mapas_nagoya_2024_0800_30m = pd.read_pickle("df3_mapas_nagoya_2024_0800_30m.pkl")

# %%
df3_mapas_nagoya_2024_0800_30m

# %%
dias_unicos = df3_mapas_nagoya_2024_0800_30m.index.date
quantidade_dias = len(np.unique(dias_unicos))
print(f"O DataFrame contém {quantidade_dias} dias únicos.")

# %%
np.save('mapas3_nagoya_2024_0800_30m_datetimes.npy', df3_mapas_nagoya_2024_0800_30m.index.to_numpy())

# %%
mapas_nagoya_2024_0800_30m_datetimes = np.load('mapas3_nagoya_2024_0800_30m_datetimes.npy')

# %%
mapas_nagoya_2024_0800_30m_datetimes

# %% [markdown]
# ### 16:00 UTC

# %%
import pandas as pd

# %%
import numpy as np

# %%
#df3_mapas_nagoya_2024_1600_30m.pkl
# !gdown

# %%
df3_mapas_nagoya_2024_1600_30m = pd.read_pickle("df3_mapas_nagoya_2024_1600_30m.pkl")

# %%
df3_mapas_nagoya_2024_1600_30m

# %%
dias_unicos = df3_mapas_nagoya_2024_1600_30m.index.date
quantidade_dias = len(np.unique(dias_unicos))
print(f"O DataFrame contém {quantidade_dias} dias únicos.")

# %%
np.save('mapas3_nagoya_2024_1600_30m_datetimes.npy', df3_mapas_nagoya_2024_1600_30m.index.to_numpy())

# %%
mapas_nagoya_2024_1600_30m_datetimes = np.load('mapas3_nagoya_2024_1600_30m_datetimes.npy')

# %%
mapas_nagoya_2024_1600_30m_datetimes

# %% [markdown]
# ### 20:00 TO 04:00 UTC

# %%
import pandas as pd

# %%
import numpy as np

# %%
#df3_mapas_nagoya_2024_2000_0400_30m.pkl
# !gdown

# %%
df3_mapas_nagoya_2024_2000_0400_30m = pd.read_pickle("df3_mapas_nagoya_2024_2000_0400_30m.pkl")

# %%
df3_mapas_nagoya_2024_2000_0400_30m

# %%
dias_unicos = df3_mapas_nagoya_2024_2000_0400_30m.index.date
quantidade_dias = len(np.unique(dias_unicos))
print(f"O DataFrame contém {quantidade_dias} dias únicos.")

# %%
np.save('mapas3_nagoya_2024_2000_0400_30m_datetimes.npy', df3_mapas_nagoya_2024_2000_0400_30m.index.to_numpy())

# %%
mapas3_nagoya_2024_2000_0400_30m_datetimes = np.load('mapas3_nagoya_2024_2000_0400_30m_datetimes.npy')

# %%
mapas3_nagoya_2024_2000_0400_30m_datetimes

# %% [markdown]
# # CASE STUDY - ORIGINAL TEMPORAL RESOLUTION

# %% [markdown]
# ## SEPTEMBER AND DECEMBER

# %% [markdown]
# ### MAGGIA

# %%
import pandas as pd
import numpy as np

# %%
#df_mapas_maggia_sept_05_2024_beyond.pkl
#gdown

# %%
df_mapas_maggia_2024 = pd.read_pickle('/content/df_mapas_maggia_sept_05_2024_beyond.pkl')

# %%
df_mapas_maggia_2024

# %%
df_mapas_maggia_2024.set_index('DATETIME', inplace=True)

# %%
df_mapas_maggia_2024

# %%
np.save('mapas_maggia_sept_05_2024_beyond_datetimes.npy', df_mapas_maggia_2024.index.to_numpy())

# %%
mapas_maggia_2024_datetimes = np.load('mapas_maggia_sept_05_2024_beyond_datetimes.npy')

# %%
mapas_maggia_2024_datetimes

# %%
len(mapas_maggia_2024_datetimes)

# %%
dias_unicos = df_mapas_maggia_2024.index.date
quantidade_dias = len(np.unique(dias_unicos))
print(f"O DataFrame contém {quantidade_dias} dias únicos.")

# %% [markdown]
# ### EMBRACE

# %%
import pandas as pd
import numpy as np

# %%
#df_mapas_embrace_sept_05_2024_beyond.pkl
#gdown

# %%
df_mapas_embrace_2024 = pd.read_pickle("/content/df_mapas_embrace_sept_05_2024_beyond.pkl")

# %%
df_mapas_embrace_2024

# %%
np.save('mapas_embrace_sept_05_2024_beyond_datetimes.npy', df_mapas_embrace_2024.index.to_numpy())

# %%
mapas_embrace_2024_datetimes = np.load('mapas_embrace_sept_05_2024_beyond_datetimes.npy')

# %%
mapas_embrace_2024_datetimes

# %%
dias_unicos = df_mapas_embrace_2024.index.date
quantidade_dias = len(np.unique(dias_unicos))
print(f"O DataFrame contém {quantidade_dias} dias únicos.")

# %% [markdown]
# ## DECEMBER

# %% [markdown]
# ### NAGOYA

# %%
import pandas as pd
import numpy as np

# %%
#df_mapas_nagoya_dec_2024.pkl
#gdown

# %%
df_mapas_nagoya_2024 = pd.read_pickle('/content/df_mapas_nagoya_dec_2024.pkl')

# %%
df_mapas_nagoya_2024

# %%
df_mapas_nagoya_2024.set_index('DATETIME', inplace=True)

# %%
df_mapas_nagoya_2024

# %%
np.save('mapas_nagoya_dec_2024_datetimes.npy', df_mapas_nagoya_2024.index.to_numpy())

# %%
mapas_nagoya_2024_datetimes = np.load('mapas_nagoya_dec_2024_datetimes.npy')

# %%
mapas_nagoya_2024_datetimes

# %%
len(mapas_nagoya_2024_datetimes)

# %%
dias_unicos = df_mapas_nagoya_2024.index.date
quantidade_dias = len(np.unique(dias_unicos))
print(f"O DataFrame contém {quantidade_dias} dias únicos.")

# %% [markdown]
# ### IGS

# %%
import pandas as pd
import numpy as np

# %%
#df_mapas_igs_dec_2024.pkl
#gdown

# %%
df_mapas_igs_2024 = pd.read_pickle('/content/df_mapas_igs_dec_2024.pkl')

# %%
df_mapas_igs_2024

# %%
df_mapas_igs_2024.set_index('DATETIME', inplace=True)

# %%
df_mapas_igs_2024

# %%
np.save('mapas_igs_dec_2024_datetimes.npy', df_mapas_igs_2024.index.to_numpy())

# %%
mapas_igs_2024_datetimes = np.load('mapas_igs_dec_2024_datetimes.npy')

# %%
mapas_igs_2024_datetimes

# %%
len(mapas_igs_2024_datetimes)

# %%
dias_unicos = df_mapas_igs_2024.index.date
quantidade_dias = len(np.unique(dias_unicos))
print(f"O DataFrame contém {quantidade_dias} dias únicos.")

# %% [markdown]
# ## SEPTEMBER

# %% [markdown]
# ### NAGOYA

# %%
import pandas as pd
import numpy as np

# %%
#df_mapas_nagoya_sept_20_2024_to_end_sept_2024.pkl
#gdown

# %%
df_mapas_nagoya_2024 = pd.read_pickle('/content/df_mapas_nagoya_sept_20_2024_to_end_sept_2024.pkl')

# %%
df_mapas_nagoya_2024

# %%
df_mapas_nagoya_2024.set_index('DATETIME', inplace=True)

# %%
df_mapas_nagoya_2024

# %%
np.save('mapas_nagoya_sept_20_2024_to_end_sept_2024_datetimes.npy', df_mapas_nagoya_2024.index.to_numpy())

# %%
mapas_nagoya_2024_datetimes = np.load('mapas_nagoya_sept_20_2024_to_end_sept_2024_datetimes.npy')

# %%
mapas_nagoya_2024_datetimes

# %%
len(mapas_nagoya_2024_datetimes)

# %%
dias_unicos = df_mapas_nagoya_2024.index.date
quantidade_dias = len(np.unique(dias_unicos))
print(f"O DataFrame contém {quantidade_dias} dias únicos.")

# %%
filtered_df = df_mapas_nagoya_2024.loc['2024-09-26':'2024-09-27']

# %%
filtered_df

# %%
mapas_nagoya_2024 = np.array(filtered_df.iloc[:]['TECMAP'])

# %%
mapas_nagoya_2024.shape

# %%
filtered_df.index.to_numpy()

# %%
filtered_df.index.to_numpy().shape

# %%
np.save('mapas_nagoya_26_09_24_27_09_24_datetimes.npy', filtered_df.index.to_numpy())

# %%
np.save('mapas_nagoya_26_09_24_27_09_24.npy', mapas_nagoya_2024)
