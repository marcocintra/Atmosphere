# %% [markdown]
# # Zip files adjusts

# %%
# Download MAGGIA_TEC_maps_intersection_raw_files_2022_2024.zip from https://doi.org/10.5281/zenodo.15453941

# %%
# !gdown '1xJJ9V8lM7GYhbNNHvXSDgB0AiyfrZvFC'
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1xJJ9V8lM7GYhbNNHvXSDgB0AiyfrZvFC
# From (redirected): https://drive.google.com/uc?id=1xJJ9V8lM7GYhbNNHvXSDgB0AiyfrZvFC&confirm=t&uuid=b9744c7f-2dc5-4fc2-a771-9deef0bbe728
# To: /content/MAGGIA_TEC_maps_intersection_raw_files_2022_2024.zip
# 100% 2.77G/2.77G [00:09<00:00, 277MB/s]

# %%
# %pwd
# Out:
# '/content'

# %%
# !ls

# %%
# !unzip -q 'MAGGIA_TEC_maps_intersection_raw_files_2022_2024.zip'

# %% [markdown]
# # Data files adjusts

# %% [markdown]
# ## 2022

# %%
# %pwd
# Out:
# '/content'

# %%
# %rm *.npy
# Out:
# rm: cannot remove '*.npy': No such file or directory

# %%
# !ls
# Out:
# MAGGIA_TEC_maps_intersection_raw_files_2022_2024.zip  magn20232692100.nc
# magn20220600000.nc				      magn20232692115.nc
# magn20220600015.nc				      magn20232692130.nc
# magn20220600030.nc				      magn20232692145.nc
# magn20220600045.nc				      magn20232692200.nc
# magn20220600100.nc				      magn20232692215.nc
# magn20220600115.nc				      magn20232692230.nc
# magn20220600130.nc				      magn20232692245.nc
# magn20220600145.nc				      magn20232692300.nc
# magn20220600200.nc				      magn20232692315.nc
# magn20220600215.nc				      magn20232692330.nc
# magn20220600230.nc				      magn20232692345.nc
# magn20220600245.nc				      magn20232700000.nc
# magn20220600300.nc				      magn20232700015.nc
# magn20220600315.nc				      magn20232700030.nc
# magn20220600330.nc				      magn20232700045.nc
# magn20220600345.nc				      magn20232700100.nc
# magn20220600400.nc				      magn20232700115.nc
# magn20220600415.nc				      magn20232700130.nc
# ...

# %%
import os
import glob
from collections import defaultdict

base_path = './'

file_pattern = os.path.join(base_path, '**', 'magn2022*.nc')
file_list = sorted(glob.glob(file_pattern, recursive=True))

file_count_by_day = defaultdict(int)

for file_name in file_list:

    day_dir = os.path.basename(os.path.dirname(file_name))
    file_count_by_day[day_dir] += 1

print("\nDays with less than 96 files:")

for day, count in sorted(file_count_by_day.items()):
    if count < 96:
        print(f"Dia {day}: {count} arquivos")
# Out:
# Days with less than 96 files:

# %%
# !pip install netCDF4
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.3/9.3 MB 42.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 35.6 MB/s eta 0:00:00
# ...

# %%
# !pip install xarray
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 11.5 MB/s eta 0:00:00
# ...

# %%
import numpy as np
import xarray as xr
import os
import re
import glob

file_list = glob.glob("./magn2022*.nc")

file_list.sort()

tec_by_doy = {}

pattern = re.compile(r'magn2022(\d{3})')

for file_name in file_list:
    try:

        match = pattern.search(file_name)
        if match:
            doy = match.group(1)

            print(f"Processing file: {file_name}, DOY: {doy}")

            ds_disk = xr.open_dataset(file_name)
            tec = ds_disk['z'][:, :].values

            if doy not in tec_by_doy:
                tec_by_doy[doy] = []

            tec_by_doy[doy].append(tec)

            ds_disk.close()

    except Exception as e:
        print(f"Error processing file {file_name}: {e}")

print("\nSaving NPY files per day...")
for doy, tec_list in tec_by_doy.items():

    tec_array = np.array(tec_list)

    output_file = f"magn2022{doy}.npy"
    np.save(output_file, tec_array)

    print(f"File {output_file} saved successfully! Shape: {tec_array.shape}")

print("\Processing completed!")
# Out:
# <>:47: SyntaxWarning: invalid escape sequence '\P'
# <>:47: SyntaxWarning: invalid escape sequence '\P'
# /tmp/ipython-input-3900763946.py:47: SyntaxWarning: invalid escape sequence '\P'
#   print("\Processing completed!")
# A saída de streaming foi truncada nas últimas 5000 linhas.
# Processing file: ./magn20221712245.nc, DOY: 171
# Processing file: ./magn20221712300.nc, DOY: 171
# Processing file: ./magn20221712315.nc, DOY: 171
# Processing file: ./magn20221712330.nc, DOY: 171
# Processing file: ./magn20221712345.nc, DOY: 171
# Processing file: ./magn20221720000.nc, DOY: 172
# Processing file: ./magn20221720015.nc, DOY: 172
# Processing file: ./magn20221720030.nc, DOY: 172
# Processing file: ./magn20221720045.nc, DOY: 172
# Processing file: ./magn20221720100.nc, DOY: 172
# Processing file: ./magn20221720115.nc, DOY: 172
# Processing file: ./magn20221720130.nc, DOY: 172
# Processing file: ./magn20221720145.nc, DOY: 172
# Processing file: ./magn20221720200.nc, DOY: 172
# ...

# %%
# !ls -lR ./*.npy | wc -l
# Out:
# 96

# %%
import numpy as np
import glob
import re

npy_files = glob.glob("magn2022*.npy")

def extract_doy(filename):
    match = re.search(r'magn2022(\d{3})\.npy', filename)
    if match:
        return int(match.group(1))
    return 0

npy_files.sort(key=extract_doy)

print(f"Found {len(npy_files)} NPY files to process.")

all_data = []

for i, file in enumerate(npy_files):
    doy = extract_doy(file)
    print(f"Processing {file} (DOY {doy}) - {i+1}/{len(npy_files)}")

    data = np.load(file)

    all_data.append(data)

    print(f"  Shape: {data.shape}")

combined_data = np.concatenate(all_data, axis=0)

print(f"\nCombined data. Final shape: {combined_data.shape}")

output_file = "MAGGIA_TEC_maps_intersection_2022.npy"
np.save(output_file, combined_data)

print(f"\nFile {output_file} saved successfully!")
print(f"File size: {combined_data.nbytes / (1024**2):.2f} MB")
# Out:
# Found 96 NPY files to process.
# Processing magn2022060.npy (DOY 60) - 1/96
#   Shape: (96, 241, 221)
# Processing magn2022061.npy (DOY 61) - 2/96
#   Shape: (96, 241, 221)
# Processing magn2022062.npy (DOY 62) - 3/96
#   Shape: (96, 241, 221)
# Processing magn2022063.npy (DOY 63) - 4/96
#   Shape: (96, 241, 221)
# Processing magn2022064.npy (DOY 64) - 5/96
#   Shape: (96, 241, 221)
# Processing magn2022065.npy (DOY 65) - 6/96
#   Shape: (96, 241, 221)
# Processing magn2022066.npy (DOY 66) - 7/96
#   Shape: (96, 241, 221)
# Processing magn2022067.npy (DOY 67) - 8/96
#   Shape: (96, 241, 221)
# Processing magn2022069.npy (DOY 69) - 9/96
#   Shape: (96, 241, 221)
# Processing magn2022070.npy (DOY 70) - 10/96
#   Shape: (96, 241, 221)
# Processing magn2022071.npy (DOY 71) - 11/96
#   Shape: (96, 241, 221)
# Processing magn2022073.npy (DOY 73) - 12/96
#   Shape: (96, 241, 221)
# Processing magn2022074.npy (DOY 74) - 13/96
#   Shape: (96, 241, 221)
# ...

# %% [markdown]
# ## 2024

# %%
# %pwd
# Out:
# '/content'

# %%
# %rm *.npy

# %%
# !ls

# %%
import os
import glob
from collections import defaultdict

base_path = './'

file_pattern = os.path.join(base_path, '**', 'magn2024*.nc')
file_list = sorted(glob.glob(file_pattern, recursive=True))

file_count_by_day = defaultdict(int)

for file_name in file_list:

    day_dir = os.path.basename(os.path.dirname(file_name))
    file_count_by_day[day_dir] += 1

print("\nDays with less than 96 files:")

for day, count in sorted(file_count_by_day.items()):
    if count < 96:
        print(f"Dia {day}: {count} arquivos")
# Out:
# Days with less than 96 files:

# %%
import numpy as np
import xarray as xr
import os
import re
import glob

file_list = glob.glob("./magn2024*.nc")

file_list.sort()

tec_by_doy = {}

pattern = re.compile(r'magn2024(\d{3})')

for file_name in file_list:
    try:

        match = pattern.search(file_name)
        if match:
            doy = match.group(1)

            print(f"Processing file: {file_name}, DOY: {doy}")

            ds_disk = xr.open_dataset(file_name)
            tec = ds_disk['z'][:, :].values

            if doy not in tec_by_doy:
                tec_by_doy[doy] = []

            tec_by_doy[doy].append(tec)

            ds_disk.close()

    except Exception as e:
        print(f"Error processing file {file_name}: {e}")

print("\nSaving NPY files per day...")
for doy, tec_list in tec_by_doy.items():

    tec_array = np.array(tec_list)

    output_file = f"magn2024{doy}.npy"
    np.save(output_file, tec_array)

    print(f"File {output_file} saved successfully! Shape: {tec_array.shape}")

print("\Processing completed!")
# Out:
# Processing file: ./magn20240610000.nc, DOY: 061
# Processing file: ./magn20240610015.nc, DOY: 061
# Processing file: ./magn20240610030.nc, DOY: 061
# Processing file: ./magn20240610045.nc, DOY: 061
# Processing file: ./magn20240610100.nc, DOY: 061
# Processing file: ./magn20240610115.nc, DOY: 061
# Processing file: ./magn20240610130.nc, DOY: 061
# Processing file: ./magn20240610145.nc, DOY: 061
# Processing file: ./magn20240610200.nc, DOY: 061
# Processing file: ./magn20240610215.nc, DOY: 061
# Processing file: ./magn20240610230.nc, DOY: 061
# Processing file: ./magn20240610245.nc, DOY: 061
# Processing file: ./magn20240610300.nc, DOY: 061
# Processing file: ./magn20240610315.nc, DOY: 061
# Processing file: ./magn20240610330.nc, DOY: 061
# Processing file: ./magn20240610345.nc, DOY: 061
# Processing file: ./magn20240610400.nc, DOY: 061
# Processing file: ./magn20240610415.nc, DOY: 061
# Processing file: ./magn20240610430.nc, DOY: 061
# Processing file: ./magn20240610445.nc, DOY: 061
# ...

# %%
# ls *.npy

# %%
# !ls -lR ./*.npy | wc -l

# %%
import numpy as np
import glob
import re

npy_files = glob.glob("magn2024*.npy")

def extract_doy(filename):
    match = re.search(r'magn2024(\d{3})\.npy', filename)
    if match:
        return int(match.group(1))
    return 0

npy_files.sort(key=extract_doy)

print(f"Found {len(npy_files)} NPY files to process.")

all_data = []

for i, file in enumerate(npy_files):
    doy = extract_doy(file)
    print(f"Processing {file} (DOY {doy}) - {i+1}/{len(npy_files)}")

    data = np.load(file)

    all_data.append(data)

    print(f"  Shape: {data.shape}")

combined_data = np.concatenate(all_data, axis=0)

print(f"\nCombined data. Final shape: {combined_data.shape}")

output_file = "MAGGIA_TEC_maps_intersection_2024.npy"
np.save(output_file, combined_data)

print(f"\nFile {output_file} saved successfully!")
print(f"File size: {combined_data.nbytes / (1024**2):.2f} MB")
# Out:
# Found 106 NPY files to process.
# Processing magn2024061.npy (DOY 61) - 1/106
#   Shape: (96, 241, 221)
# Processing magn2024062.npy (DOY 62) - 2/106
#   Shape: (96, 241, 221)
# Processing magn2024063.npy (DOY 63) - 3/106
#   Shape: (96, 241, 221)
# Processing magn2024064.npy (DOY 64) - 4/106
#   Shape: (96, 241, 221)
# Processing magn2024065.npy (DOY 65) - 5/106
#   Shape: (96, 241, 221)
# Processing magn2024066.npy (DOY 66) - 6/106
#   Shape: (96, 241, 221)
# Processing magn2024067.npy (DOY 67) - 7/106
#   Shape: (96, 241, 221)
# Processing magn2024068.npy (DOY 68) - 8/106
#   Shape: (96, 241, 221)
# Processing magn2024069.npy (DOY 69) - 9/106
#   Shape: (96, 241, 221)
# Processing magn2024070.npy (DOY 70) - 10/106
#   Shape: (96, 241, 221)
# Processing magn2024071.npy (DOY 71) - 11/106
#   Shape: (96, 241, 221)
# Processing magn2024072.npy (DOY 72) - 12/106
#   Shape: (96, 241, 221)
# Processing magn2024073.npy (DOY 73) - 13/106
#   Shape: (96, 241, 221)
# ...

# %% [markdown]
# # 5D array - merge 2022-2024 data

# %%
# %cd './'
# Out:
# /content

# %%
import numpy as np

# %%
# !ls *.npy
# Out:
# MAGGIA_TEC_maps_intersection_2022.npy  magn2022262.npy	magn2024165.npy
# MAGGIA_TEC_maps_intersection_2024.npy  magn2022264.npy	magn2024166.npy
# magn2022060.npy			       magn2022265.npy	magn2024167.npy
# magn2022061.npy			       magn2022266.npy	magn2024168.npy
# magn2022062.npy			       magn2022267.npy	magn2024169.npy
# magn2022063.npy			       magn2022268.npy	magn2024170.npy
# magn2022064.npy			       magn2022269.npy	magn2024171.npy
# magn2022065.npy			       magn2022270.npy	magn2024173.npy
# magn2022066.npy			       magn2022271.npy	magn2024174.npy
# magn2022067.npy			       magn2022272.npy	magn2024175.npy
# magn2022069.npy			       magn2022273.npy	magn2024176.npy
# magn2022070.npy			       magn2022338.npy	magn2024177.npy
# magn2022071.npy			       magn2022339.npy	magn2024180.npy
# magn2022073.npy			       magn2022340.npy	magn2024181.npy
# magn2022074.npy			       magn2022348.npy	magn2024247.npy
# magn2022075.npy			       magn2022349.npy	magn2024248.npy
# ...

# %%
# %pwd
# Out:
# '/content'

# %%
# !ls
# Out:
# MAGGIA_TEC_maps_intersection_2022.npy		      magn20232692200.nc
# MAGGIA_TEC_maps_intersection_2024.npy		      magn20232692215.nc
# MAGGIA_TEC_maps_intersection_raw_files_2022_2024.zip  magn20232692230.nc
# magn20220600000.nc				      magn20232692245.nc
# magn20220600015.nc				      magn20232692300.nc
# magn20220600030.nc				      magn20232692315.nc
# magn20220600045.nc				      magn20232692330.nc
# magn20220600100.nc				      magn20232692345.nc
# magn20220600115.nc				      magn20232700000.nc
# magn20220600130.nc				      magn20232700015.nc
# magn20220600145.nc				      magn20232700030.nc
# magn20220600200.nc				      magn20232700045.nc
# magn20220600215.nc				      magn20232700100.nc
# magn20220600230.nc				      magn20232700115.nc
# magn20220600245.nc				      magn20232700130.nc
# magn20220600300.nc				      magn20232700145.nc
# magn20220600315.nc				      magn20232700200.nc
# magn20220600330.nc				      magn20232700215.nc
# magn20220600345.nc				      magn20232700230.nc
# ...

# %%
# %pwd
# Out:
# '/content'

# %%
# !ls *.npy
# Out:
# MAGGIA_TEC_maps_intersection_2022.npy  magn2022262.npy	magn2024165.npy
# MAGGIA_TEC_maps_intersection_2024.npy  magn2022264.npy	magn2024166.npy
# magn2022060.npy			       magn2022265.npy	magn2024167.npy
# magn2022061.npy			       magn2022266.npy	magn2024168.npy
# magn2022062.npy			       magn2022267.npy	magn2024169.npy
# magn2022063.npy			       magn2022268.npy	magn2024170.npy
# magn2022064.npy			       magn2022269.npy	magn2024171.npy
# magn2022065.npy			       magn2022270.npy	magn2024173.npy
# magn2022066.npy			       magn2022271.npy	magn2024174.npy
# magn2022067.npy			       magn2022272.npy	magn2024175.npy
# magn2022069.npy			       magn2022273.npy	magn2024176.npy
# magn2022070.npy			       magn2022338.npy	magn2024177.npy
# magn2022071.npy			       magn2022339.npy	magn2024180.npy
# magn2022073.npy			       magn2022340.npy	magn2024181.npy
# magn2022074.npy			       magn2022348.npy	magn2024247.npy
# magn2022075.npy			       magn2022349.npy	magn2024248.npy
# ...

# %%
maggia_2022 = np.load('MAGGIA_TEC_maps_intersection_2022.npy')
print(np.shape(maggia_2022))
print(type(maggia_2022))
print(type(maggia_2022[0]))
print(type(maggia_2022[0][0]))
print(type(maggia_2022[0][0][0]))
# Out:
# (9216, 241, 221)
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.float32'>

# %%
for i in range(len(maggia_2022)):
    print(np.shape(maggia_2022[i]))
# Out:
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# ...

# %%
np.shape(maggia_2022)
# Out:
# (9216, 241, 221)

# %%
has_nan = np.any(np.isnan(maggia_2022))
print(has_nan)

count_nan = np.sum(np.isnan(maggia_2022))
print(count_nan)
# Out:
# True
# 174265624

# %%
maggia_2022.shape
# Out:
# (9216, 241, 221)

# %%
np.set_printoptions(threshold=np.inf)

# %%
print(maggia_2022[0][0])
# Out:
# [nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan]

# %%
print(maggia_2022[0][-1])
# Out:
# [17.788412  17.755325  17.722652  17.688313  17.65265   17.620007
#  17.595892  17.567413  17.543629  17.529224  17.512714  17.505653
#  17.497473  17.497871  17.502499  17.512209  17.538767  17.567375
#  17.608377  17.65319   17.699726  17.754261  17.823154  17.905228
#  17.993402  18.087454  18.190685  18.302395  18.418121  18.534784
#  18.649996  18.760876  18.875555  18.991348  19.097591  19.191473
#  19.285069  19.371471  19.441626  19.498102  19.5466    19.575624
#  19.591415  19.594072  19.58052   19.552345  19.514132  19.460115
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
# ...

# %%
# del maggia_2022

# %%
maggia_2024 = np.load('MAGGIA_TEC_maps_intersection_2024.npy')
print(np.shape(maggia_2024))
print(type(maggia_2024))
print(type(maggia_2024[0]))
print(type(maggia_2024[0][0]))
print(type(maggia_2024[0][0][0]))
# Out:
# (12744, 241, 221)
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.float32'>

# %%
for i in range(len(maggia_2024)):
    print(np.shape(maggia_2024[i]))
# Out:
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# ...

# %%
np.shape(maggia_2024)
# Out:
# (12744, 241, 221)

# %%
has_nan = np.any(np.isnan(maggia_2024))
print(has_nan)

count_nan = np.sum(np.isnan(maggia_2024))
print(count_nan)
# Out:
# True
# 297383688

# %%
maggia_2024.shape
# Out:
# (12744, 241, 221)

# %%
np.set_printoptions(threshold=np.inf)

# %%
print(maggia_2024[0][0])
# Out:
# [      nan       nan       nan       nan       nan       nan       nan
#        nan       nan       nan       nan       nan       nan       nan
#        nan       nan       nan       nan       nan       nan       nan
#        nan       nan       nan       nan       nan       nan       nan
#        nan       nan       nan       nan       nan       nan       nan
#        nan       nan       nan       nan       nan       nan       nan
#        nan       nan       nan       nan       nan       nan       nan
#        nan       nan       nan       nan       nan       nan       nan
#        nan       nan       nan       nan       nan       nan       nan
#        nan       nan       nan       nan       nan       nan       nan
#        nan       nan       nan       nan       nan       nan       nan
#        nan       nan 29.192455 29.162899 29.132933 29.102135 29.070847
#  29.039406 29.008446 28.977596 28.947266 28.916576 28.8842   28.851604
# ...

# %%
print(maggia_2024[0][-1])
# Out:
# [39.41671   39.26682   39.108894  38.944115  38.763126  38.577763
#  38.379105  38.17472   37.952423  37.721645  37.48399   37.24049
#  37.002926  36.763454  36.525036  36.292767  36.06174   35.837265
#  35.622192  35.40941   35.213593  35.01287   34.8202    34.637413
#  34.44743   34.272167  34.10503   33.936024  33.77426   33.621197
#  33.46703   33.323605  33.186466  33.04637   32.903618  32.768536
#  32.631     32.492046  32.344532  32.19713   32.04554   31.892933
#  31.740366  31.577015  31.410427  31.239164  31.062418  30.883389
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
# ...

# %%
# del maggia_2024

# %%
maggia_2022_2024 = np.concatenate([maggia_2022, maggia_2024], axis=0)
print(maggia_2022_2024.shape)
# Out:
# (21960, 241, 221)

# %%
print(type(maggia_2022_2024))
print(type(maggia_2022_2024[0]))
print(type(maggia_2022_2024[0][0]))
print(type(maggia_2022_2024[0][0][0]))
# Out:
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.float32'>

# %%
for i in range(len(maggia_2022_2024)):
    print(np.shape(maggia_2022_2024[i]))
# Out:
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# (241, 221)
# ...

# %%
np.shape(maggia_2022_2024)
# Out:
# (21960, 241, 221)

# %%
has_nan = np.any(np.isnan(maggia_2022_2024))
print(has_nan)

count_nan = np.sum(np.isnan(maggia_2022_2024))
print(count_nan)
# Out:
# True
# 471649312

# %%
np.set_printoptions(threshold=np.inf)

# %%
print(maggia_2022_2024[0][0])
# Out:
# [nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan]

# %%
print(maggia_2022_2024[0][-1])
# Out:
# [17.788412  17.755325  17.722652  17.688313  17.65265   17.620007
#  17.595892  17.567413  17.543629  17.529224  17.512714  17.505653
#  17.497473  17.497871  17.502499  17.512209  17.538767  17.567375
#  17.608377  17.65319   17.699726  17.754261  17.823154  17.905228
#  17.993402  18.087454  18.190685  18.302395  18.418121  18.534784
#  18.649996  18.760876  18.875555  18.991348  19.097591  19.191473
#  19.285069  19.371471  19.441626  19.498102  19.5466    19.575624
#  19.591415  19.594072  19.58052   19.552345  19.514132  19.460115
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
# ...

# %% [markdown]
# # Dates adjusts

# %%
import numpy as np
from datetime import datetime, timedelta

def doy_to_date(year, doy):
    return datetime(year, 1, 1) + timedelta(days=doy - 1)

doys = {
    2022: {
        3: [60, 61, 62, 63, 64, 65, 66, 67, 69, 70,
            71, 73, 74, 75, 76, 77, 78, 79, 80, 81,
            82, 83, 84, 85, 86, 90],
        6: [152, 153, 154, 156, 157, 158, 159, 160,
            161, 162, 163, 164, 165, 166, 167, 168,
            169, 170, 171, 172, 173, 174, 176, 178,
            181],
        9: [245, 246, 247, 248, 249, 250, 251, 252,
            253, 254, 255, 256, 258, 260, 261, 262,
            264, 265, 266, 267, 268, 269, 270, 271,
            272, 273],
        12: [338, 339, 340, 348, 349, 350, 351, 352,
             353, 354, 356, 357, 358, 359, 360, 362,
             363, 364, 365]
    },
    2024: {
        3: [61, 62, 63, 64, 65, 66, 67, 68, 69, 70,
            71, 72, 73, 74, 75, 76, 77, 78, 79, 80,
            81, 86, 87, 88, 89, 91],
        6: [153, 154, 155, 156, 157, 158, 159, 160, 161, 162,
            163, 164, 165, 166, 167, 168, 169, 170, 171, 173,
            174, 175, 176, 177, 180, 181],
        9: [247, 248, 249, 250, 251, 252, 253, 254, 255, 256,
            257, 258, 261, 262, 263, 264, 265, 266, 267, 268,
            269, 270, 271, 272, 274],
        12: [336, 337, 338, 339, 340, 341, 342, 343, 344, 345,
             346, 347, 349, 350, 351, 352, 353, 354, 355,
             356, 357, 358, 359, 360, 361, 362, 363, 364, 365]
    }
}

doy249_times = [
    "0000", "0010", "0015", "0020", "0030", "0040", "0045", "0050",
    "0100", "0110", "0115", "0120", "0130", "0140", "0145", "0150",
    "0200", "0210", "0215", "0220", "0230", "0240", "0245", "0250",
    "0300", "0310", "0315", "0320", "0330", "0340", "0345", "0350",
    "0400", "0410", "0415", "0420", "0430", "0440", "0445", "0450",
    "0500", "0510", "0515", "0520", "0530", "0540", "0545", "0550",
    "0600", "0610", "0615", "0620", "0630", "0640", "0645", "0650",
    "0700", "0710", "0715", "0720", "0730", "0740", "0745", "0750",
    "0800", "0810", "0815", "0820", "0830", "0840", "0845", "0850",
    "0900", "0910", "0915", "0920", "0930", "0940", "0945", "0950",
    "1000", "1010", "1015", "1020", "1030", "1040", "1045", "1050",
    "1100", "1110", "1115", "1120", "1130", "1140", "1145", "1150",
    "1200", "1210", "1215", "1220", "1230", "1240", "1245", "1250",
    "1300", "1310", "1315", "1320", "1330", "1340", "1345", "1350",
    "1400", "1410", "1415", "1420", "1430", "1440", "1445", "1450",
    "1500", "1510", "1515", "1520", "1530", "1540", "1545", "1550",
    "1600", "1610", "1615", "1620", "1630", "1640", "1645", "1650",
    "1700", "1710", "1715", "1720", "1730", "1740", "1745", "1750",
    "1800", "1810", "1815", "1820", "1830", "1840", "1845", "1850",
    "1900", "1910", "1915", "1920", "1930", "1940", "1945", "1950",
    "2000", "2010", "2015", "2020", "2030", "2040", "2045", "2050",
    "2100", "2110", "2115", "2120", "2130", "2140", "2145", "2150",
    "2200", "2210", "2215", "2220", "2230", "2240", "2245", "2250",
    "2300", "2310", "2315", "2320", "2330", "2340", "2345", "2350"
]

doy250_times = [
    "0000", "0010", "0015", "0020", "0030", "0040", "0045", "0050",
    "0100", "0110", "0115", "0120", "0130", "0140", "0145", "0150",
    "0200", "0210", "0215", "0220", "0230", "0240", "0245", "0250",
    "0300", "0310", "0315", "0320", "0330", "0340", "0345", "0350",
    "0400", "0410", "0415", "0420", "0430", "0440", "0445", "0450",
    "0500", "0510", "0515", "0520", "0530", "0540", "0545", "0550",
    "0600", "0610", "0615", "0620", "0630", "0640", "0645", "0650",
    "0700", "0710", "0715", "0720", "0730", "0740", "0745", "0750",
    "0800", "0810", "0815", "0820", "0830", "0840", "0845", "0850",
    "0900", "0910", "0915", "0920", "0930", "0940", "0945", "0950",
    "1000", "1010", "1015", "1020", "1030", "1040", "1045", "1050",
    "1100", "1110", "1115", "1120", "1130", "1140", "1145", "1150",
    "1200", "1210", "1220", "1230", "1240", "1250", "1300", "1310",
    "1320", "1330", "1340", "1350", "1400", "1410", "1420", "1430",
    "1440", "1450", "1500", "1510", "1520", "1530", "1540", "1550",
    "1600", "1610", "1620", "1630", "1640", "1650", "1700", "1710",
    "1720", "1730", "1740", "1750", "1800", "1810", "1820", "1830",
    "1840", "1850", "1900", "1910", "1920", "1930", "1940", "1950",
    "2000", "2010", "2020", "2030", "2040", "2050", "2100", "2110",
    "2120", "2130", "2140", "2150", "2200", "2210", "2220", "2230",
    "2240", "2250", "2300", "2310", "2320", "2330", "2340", "2350"
]

datetime_list = []

for year in doys.keys():
    for month in doys[year].keys():
        for doy in doys[year][month]:
            base_date = doy_to_date(year, doy)

            if year == 2024 and doy == 249:
                for time_str in doy249_times:
                    hours = int(time_str[:2])
                    minutes = int(time_str[2:])
                    dt = base_date + timedelta(hours=hours, minutes=minutes)
                    datetime_list.append(dt)

            elif year == 2024 and doy == 250:
                for time_str in doy250_times:
                    hours = int(time_str[:2])
                    minutes = int(time_str[2:])
                    dt = base_date + timedelta(hours=hours, minutes=minutes)
                    datetime_list.append(dt)

            elif year == 2024 and doy >= 251:
                for minute in range(0, 24 * 60, 10):
                    dt = base_date + timedelta(minutes=minute)
                    datetime_list.append(dt)

            else:
                for minute in range(0, 24 * 60, 15):
                    dt = base_date + timedelta(minutes=minute)
                    datetime_list.append(dt)

maggia_datetimes_2022_2024 = np.array(datetime_list, dtype='datetime64[s]')

print(f"Total number of datetime points: {len(maggia_datetimes_2022_2024)}")
print(f"First datetime: {maggia_datetimes_2022_2024[0]}")
print(f"Last datetime: {maggia_datetimes_2022_2024[-1]}")

print("\nSample of first 10 datetime entries:")
for dt in maggia_datetimes_2022_2024[:10]:
    print(dt)

print("\nSample of last 10 datetime entries:")
for dt in maggia_datetimes_2022_2024[-10:]:
    print(dt)
# Out:
# Total number of datetime points: 21960
# First datetime: 2022-03-01T00:00:00
# Last datetime: 2024-12-30T23:50:00
#
# Sample of first 10 datetime entries:
# 2022-03-01T00:00:00
# 2022-03-01T00:15:00
# 2022-03-01T00:30:00
# 2022-03-01T00:45:00
# 2022-03-01T01:00:00
# 2022-03-01T01:15:00
# 2022-03-01T01:30:00
# 2022-03-01T01:45:00
# 2022-03-01T02:00:00
# 2022-03-01T02:15:00
#
# Sample of last 10 datetime entries:
# 2024-12-30T22:20:00
# 2024-12-30T22:30:00
# 2024-12-30T22:40:00
# 2024-12-30T22:50:00
# 2024-12-30T23:00:00
# 2024-12-30T23:10:00
# 2024-12-30T23:20:00
# 2024-12-30T23:30:00
# 2024-12-30T23:40:00
# 2024-12-30T23:50:00

# %%
maggia_datetimes_2022_2024.shape
# Out:
# (21960,)

# %%
maggia_datetimes_2022_2024
# Out:
# array(['2022-03-01T00:00:00', '2022-03-01T00:15:00',
#        '2022-03-01T00:30:00', '2022-03-01T00:45:00',
#        '2022-03-01T01:00:00', '2022-03-01T01:15:00',
#        '2022-03-01T01:30:00', '2022-03-01T01:45:00',
#        '2022-03-01T02:00:00', '2022-03-01T02:15:00',
#        '2022-03-01T02:30:00', '2022-03-01T02:45:00',
#        '2022-03-01T03:00:00', '2022-03-01T03:15:00',
#        '2022-03-01T03:30:00', '2022-03-01T03:45:00',
#        '2022-03-01T04:00:00', '2022-03-01T04:15:00',
#        '2022-03-01T04:30:00', '2022-03-01T04:45:00',
#        '2022-03-01T05:00:00', '2022-03-01T05:15:00',
#        '2022-03-01T05:30:00', '2022-03-01T05:45:00',
#        '2022-03-01T06:00:00', '2022-03-01T06:15:00',
#        '2022-03-01T06:30:00', '2022-03-01T06:45:00',
#        '2022-03-01T07:00:00', '2022-03-01T07:15:00',
#        '2022-03-01T07:30:00', '2022-03-01T07:45:00',
#        '2022-03-01T08:00:00', '2022-03-01T08:15:00',
#        '2022-03-01T08:30:00', '2022-03-01T08:45:00',
# ...

# %%
maggia_2022_2024.shape
# Out:
# (21960, 241, 221)

# %%
print(len(maggia_2022_2024.tolist()))
print(len(maggia_2022_2024[0].tolist()))
print(len(maggia_2022_2024[0][0].tolist()))
# Out:
# 21960
# 241
# 221

# %%
maggia_2022.shape
# Out:
# (9216, 241, 221)

# %%
maggia_2024.shape
# Out:
# (12744, 241, 221)

# %%
maggia_datetimes_2022 = np.array([d for d in maggia_datetimes_2022_2024 if d.astype(object).year == 2022])

# %%
len(maggia_datetimes_2022)
# Out:
# 9216

# %%
maggia_datetimes_2024 = np.array([d for d in maggia_datetimes_2022_2024 if d.astype(object).year == 2024])

# %%
len(maggia_datetimes_2024)
# Out:
# 12744

# %%
maggia_datetimes_2022_2024[0:12]
# Out:
# array(['2022-03-01T00:00:00', '2022-03-01T00:15:00',
#        '2022-03-01T00:30:00', '2022-03-01T00:45:00',
#        '2022-03-01T01:00:00', '2022-03-01T01:15:00',
#        '2022-03-01T01:30:00', '2022-03-01T01:45:00',
#        '2022-03-01T02:00:00', '2022-03-01T02:15:00',
#        '2022-03-01T02:30:00', '2022-03-01T02:45:00'],
#       dtype='datetime64[s]')

# %%
len(maggia_datetimes_2022_2024[0:12])
# Out:
# 12

# %%
len(maggia_2022_2024[0:12])
# Out:
# 12

# %%
maggia_2022_2024_shaped = np.reshape(maggia_2022_2024, (-1, 241, 221))

# %%
np.shape(maggia_2022_2024_shaped)
# Out:
# (21960, 241, 221)

# %%
np.shape(maggia_2022_2024_shaped.tolist())
# Out:
# (21960, 241, 221)

# %%
maggia_datetimes_2022_2024.shape
# Out:
# (21960,)

# %% [markdown]
# ## Create dataframe

# %%
import pandas as pd

data = {
    'DATETIME': maggia_datetimes_2022_2024,
    'TECMAP': maggia_2022_2024_shaped.tolist()
}

df_maggia_maps_2022_2024 = pd.DataFrame(data)

df_maggia_maps_2022_2024
# Out:
#                  DATETIME                                             TECMAP
# 0     2022-03-01 00:00:00  [[nan, nan, nan, nan, nan, nan, nan, nan, nan,...
# 1     2022-03-01 00:15:00  [[nan, nan, nan, nan, nan, nan, nan, nan, nan,...
# 2     2022-03-01 00:30:00  [[nan, nan, nan, nan, nan, nan, nan, nan, nan,...
# 3     2022-03-01 00:45:00  [[nan, nan, nan, nan, nan, nan, nan, nan, nan,...
# 4     2022-03-01 01:00:00  [[nan, nan, nan, nan, nan, nan, nan, nan, nan,...
# ...                   ...                                                ...
# 21955 2024-12-30 23:10:00  [[nan, nan, nan, nan, nan, nan, nan, nan, nan,...
# 21956 2024-12-30 23:20:00  [[nan, nan, nan, nan, nan, nan, nan, nan, nan,...
# 21957 2024-12-30 23:30:00  [[nan, nan, nan, nan, nan, nan, nan, nan, nan,...
# 21958 2024-12-30 23:40:00  [[nan, nan, nan, nan, nan, nan, nan, nan, nan,...
# 21959 2024-12-30 23:50:00  [[nan, nan, nan, nan, nan, nan, nan, nan, nan,...
#
# [21960 rows x 2 columns]

# %%
df_maggia_maps_2022_2024['DATETIME'] = pd.to_datetime(df_maggia_maps_2022_2024['DATETIME'])

df_maggia_maps_2022_2024.set_index('DATETIME', inplace=True)

# %%
# df_maggia_maps_2022_2024.to_pickle("./df_maggia_maps_2022_2024.pkl")

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
# %cp df_maggia_maps_2022_2024.pkl /content/drive/MyDrive/df_maggia_maps_2022_2024.pkl

# %%
df_maggia_maps_2022_2024 = df_maggia_maps_2022_2024[(df_maggia_maps_2022_2024.index.minute == 0) & (df_maggia_maps_2022_2024.index.hour % 2 == 0)]

df120 = df_maggia_maps_2022_2024[
    ((df_maggia_maps_2022_2024.index.year == 2022) & (df_maggia_maps_2022_2024.index.month.isin([3, 6, 9]))) |
    ((df_maggia_maps_2022_2024.index.year == 2024) & (df_maggia_maps_2022_2024.index.month.isin([3, 6, 9, 12])))
]

df30 = pd.DataFrame(data)

df30['DATETIME'] = pd.to_datetime(df30['DATETIME'])

df30.set_index('DATETIME', inplace=True)

df30 = df30[
    ((df30.index.year == 2024) & (df30.index.month.isin([3, 6, 9, 12])))
]

df30 = df30[df30.index.minute % 30 == 0]

print("DF 120:")
print(df120)

print("DF 30:")
print(df30)
# Out:
# DF 120:
#                                                                 TECMAP
# DATETIME
# 2022-03-01 00:00:00  [[nan, nan, nan, nan, nan, nan, nan, nan, nan,...
# 2022-03-01 02:00:00  [[nan, nan, nan, nan, nan, nan, nan, nan, nan,...
# 2022-03-01 04:00:00  [[nan, nan, nan, nan, nan, nan, nan, nan, nan,...
# 2022-03-01 06:00:00  [[nan, nan, nan, nan, nan, nan, nan, nan, nan,...
# 2022-03-01 08:00:00  [[nan, nan, nan, nan, nan, nan, nan, nan, nan,...
# ...                                                                ...
# 2024-12-30 14:00:00  [[nan, nan, nan, nan, nan, nan, nan, nan, nan,...
# 2024-12-30 16:00:00  [[nan, nan, nan, nan, nan, nan, nan, nan, nan,...
# 2024-12-30 18:00:00  [[nan, nan, nan, nan, nan, nan, nan, nan, nan,...
# 2024-12-30 20:00:00  [[nan, nan, nan, nan, nan, nan, nan, nan, nan,...
# 2024-12-30 22:00:00  [[nan, nan, nan, nan, nan, nan, nan, nan, nan,...
#
# [2196 rows x 1 columns]
# DF 30:
# ...

# %%
df_maggia_maps_2022_2024 = df_maggia_maps_2022_2024[(df_maggia_maps_2022_2024.index.minute == 0) & (df_maggia_maps_2022_2024.index.hour % 2 == 0)]

# %%
np.array(df_maggia_maps_2022_2024.iloc[0]['TECMAP'])
# Out:
# array([[        nan,         nan,         nan,         nan,         nan,
#                 nan,         nan,         nan,         nan,         nan,
#                 nan,         nan,         nan,         nan,         nan,
#                 nan,         nan,         nan,         nan,         nan,
#                 nan,         nan,         nan,         nan,         nan,
#                 nan,         nan,         nan,         nan,         nan,
#                 nan,         nan,         nan,         nan,         nan,
#                 nan,         nan,         nan,         nan,         nan,
#                 nan,         nan,         nan,         nan,         nan,
#                 nan,         nan,         nan,         nan,         nan,
#                 nan,         nan,         nan,         nan,         nan,
#                 nan,         nan,         nan,         nan,         nan,
#                 nan,         nan,         nan,         nan,         nan,
# ...

# %%
np.array(df_maggia_maps_2022_2024.iloc[0]['TECMAP']).shape
# Out:
# (241, 221)

# %%
maps = np.array(df_maggia_maps_2022_2024.iloc[:]['TECMAP'])

# %%
np.shape(df_maggia_maps_2022_2024)
# Out:
# (2424, 1)

# %%
np_maps = []
for i in range(len(maps)):
    np_maps.append(maps[i])
np_maps = np.array(np_maps)

# %%
np.shape(np_maps)
# Out:
# (2424, 241, 221)

# %%
type(np_maps)
# Out:
# numpy.ndarray

# %%
df_maggia_maps_2022_2024_0800 = df_maggia_maps_2022_2024.between_time('08:00', '08:00')

df_maggia_maps_2022_2024_1600 = df_maggia_maps_2022_2024.between_time('16:00', '16:00')

df_maggia_maps_2022_2024_2000_2200_0000_0200_0400 = pd.concat([
    df_maggia_maps_2022_2024.between_time('20:00', '20:00'),
    df_maggia_maps_2022_2024.between_time('22:00', '22:00'),
    df_maggia_maps_2022_2024.between_time('00:00', '00:00'),
    df_maggia_maps_2022_2024.between_time('02:00', '02:00'),
    df_maggia_maps_2022_2024.between_time('04:00', '04:00')
])

print("Data from 08:00:")
print(df_maggia_maps_2022_2024_0800)

print("\nData from 16:00:")
print(df_maggia_maps_2022_2024_1600)

print("\nData from 20:00 to 04:00:")
print(df_maggia_maps_2022_2024_2000_2200_0000_0200_0400)
# Out:
# Data from 08:00:
#                                                                 TECMAP
# DATETIME
# 2022-03-01 08:00:00  [[nan, nan, nan, nan, nan, nan, nan, nan, nan,...
# 2022-03-02 08:00:00  [[nan, nan, nan, nan, nan, nan, nan, nan, nan,...
# 2022-03-03 08:00:00  [[nan, nan, nan, nan, nan, nan, nan, nan, nan,...
# 2022-03-04 08:00:00  [[nan, nan, nan, nan, nan, nan, nan, nan, nan,...
# 2022-03-05 08:00:00  [[nan, nan, nan, nan, nan, nan, nan, nan, nan,...
# ...                                                                ...
# 2024-12-26 08:00:00  [[nan, nan, nan, nan, nan, nan, nan, nan, nan,...
# 2024-12-27 08:00:00  [[nan, nan, nan, nan, nan, nan, nan, nan, nan,...
# 2024-12-28 08:00:00  [[nan, nan, nan, nan, nan, nan, nan, nan, nan,...
# 2024-12-29 08:00:00  [[nan, nan, nan, nan, nan, nan, nan, nan, nan,...
# 2024-12-30 08:00:00  [[nan, nan, nan, nan, nan, nan, nan, nan, nan,...
#
# [202 rows x 1 columns]
#
# Data from 16:00:
# ...

# %%
np.shape(np.array(df_maggia_maps_2022_2024_0800.iloc[:]['TECMAP']))
# Out:
# (202,)

# %%
maggia_maps_2022_2024_0800 = np.array(df_maggia_maps_2022_2024_0800.iloc[:]['TECMAP'])

# %%
np.shape(maggia_maps_2022_2024_0800)
# Out:
# (202,)

# %%
np_maggia_maps_2022_2024_0800 = []
for i in range(len(maggia_maps_2022_2024_0800)):
    np_maggia_maps_2022_2024_0800.append(maggia_maps_2022_2024_0800[i])
np_maggia_maps_2022_2024_0800 = np.array(np_maggia_maps_2022_2024_0800)

# %%
np.shape(np_maggia_maps_2022_2024_0800)
# Out:
# (202, 241, 221)

# %%
type(np_maggia_maps_2022_2024_0800)
# Out:
# numpy.ndarray

# %%
maggia_maps_2022_2024_1600 = np.array(df_maggia_maps_2022_2024_1600.iloc[:]['TECMAP'])

# %%
np.shape(maggia_maps_2022_2024_1600)
# Out:
# (202,)

# %%
np_maggia_maps_2022_2024_1600 = []
for i in range(len(maggia_maps_2022_2024_1600)):
    np_maggia_maps_2022_2024_1600.append(maggia_maps_2022_2024_1600[i])
np_maggia_maps_2022_2024_1600 = np.array(np_maggia_maps_2022_2024_1600)

# %%
np.shape(np_maggia_maps_2022_2024_1600)
# Out:
# (202, 241, 221)

# %%
type(np_maggia_maps_2022_2024_1600)
# Out:
# numpy.ndarray

# %%
maggia_maps_2022_2024_2000_2200_0000_0200_0400 = np.array(df_maggia_maps_2022_2024_2000_2200_0000_0200_0400.iloc[:]['TECMAP'])

# %%
np.shape(maggia_maps_2022_2024_2000_2200_0000_0200_0400)
# Out:
# (1010,)

# %%
np.shape(maggia_maps_2022_2024_2000_2200_0000_0200_0400[0])
# Out:
# (241, 221)

# %%
np_maggia_maps_2022_2024_2000_2200_0000_0200_0400 = []
for i in range(len(maggia_maps_2022_2024_2000_2200_0000_0200_0400)):
    np_maggia_maps_2022_2024_2000_2200_0000_0200_0400.append(maggia_maps_2022_2024_2000_2200_0000_0200_0400[i])
np_maggia_maps_2022_2024_2000_2200_0000_0200_0400 = np.array(np_maggia_maps_2022_2024_2000_2200_0000_0200_0400)

# %%
np.shape(np_maggia_maps_2022_2024_2000_2200_0000_0200_0400)
# Out:
# (1010, 241, 221)

# %%
type(np_maggia_maps_2022_2024_2000_2200_0000_0200_0400)
# Out:
# numpy.ndarray

# %% [markdown]
# # TF-120 adjusts

# %% [markdown]
# ## Continuous

# %%
np.array(df120.iloc[0]['TECMAP'])
# Out:
# array([[        nan,         nan,         nan,         nan,         nan,
#                 nan,         nan,         nan,         nan,         nan,
#                 nan,         nan,         nan,         nan,         nan,
#                 nan,         nan,         nan,         nan,         nan,
#                 nan,         nan,         nan,         nan,         nan,
#                 nan,         nan,         nan,         nan,         nan,
#                 nan,         nan,         nan,         nan,         nan,
#                 nan,         nan,         nan,         nan,         nan,
#                 nan,         nan,         nan,         nan,         nan,
#                 nan,         nan,         nan,         nan,         nan,
#                 nan,         nan,         nan,         nan,         nan,
#                 nan,         nan,         nan,         nan,         nan,
#                 nan,         nan,         nan,         nan,         nan,
# ...

# %%
np.array(df120.iloc[0]['TECMAP']).shape
# Out:
# (241, 221)

# %%
df120_0800 = df120.between_time('08:00', '08:00')

df120_1600 = df120.between_time('16:00', '16:00')

df120_2000_2200_0000_0200_0400 = pd.concat([
    df120.between_time('20:00', '20:00'),
    df120.between_time('22:00', '22:00'),
    df120.between_time('00:00', '00:00'),
    df120.between_time('02:00', '02:00'),
    df120.between_time('04:00', '04:00')
])

df120_2000_2200_0000_0200_0400.sort_index(inplace=True)

print("Data from 08:00:")
print(df120_0800)

print("\nData from 16:00:")
print(df120_1600)

print("\nData from 20:00 to 04:00:")
print(df120_2000_2200_0000_0200_0400)
# Out:
# Data from 08:00:
#                                                                 TECMAP
# DATETIME
# 2022-03-01 08:00:00  [[nan, nan, nan, nan, nan, nan, nan, nan, nan,...
# 2022-03-02 08:00:00  [[nan, nan, nan, nan, nan, nan, nan, nan, nan,...
# 2022-03-03 08:00:00  [[nan, nan, nan, nan, nan, nan, nan, nan, nan,...
# 2022-03-04 08:00:00  [[nan, nan, nan, nan, nan, nan, nan, nan, nan,...
# 2022-03-05 08:00:00  [[nan, nan, nan, nan, nan, nan, nan, nan, nan,...
# ...                                                                ...
# 2024-12-26 08:00:00  [[nan, nan, nan, nan, nan, nan, nan, nan, nan,...
# 2024-12-27 08:00:00  [[nan, nan, nan, nan, nan, nan, nan, nan, nan,...
# 2024-12-28 08:00:00  [[nan, nan, nan, nan, nan, nan, nan, nan, nan,...
# 2024-12-29 08:00:00  [[nan, nan, nan, nan, nan, nan, nan, nan, nan,...
# 2024-12-30 08:00:00  [[nan, nan, nan, nan, nan, nan, nan, nan, nan,...
#
# [183 rows x 1 columns]
#
# Data from 16:00:
# ...

# %%
np.shape(np.array(df120.iloc[:]['TECMAP']))
# Out:
# (2196,)

# %%
maps120 = np.array(df120.iloc[:]['TECMAP'])

# %%
np.shape(df120)
# Out:
# (2196, 1)

# %%
np_maps120 = []
for i in range(len(maps120)):
    np_maps120.append(maps120[i])
np_maps120 = np.array(np_maps120)

# %%
np.shape(np_maps120)
# Out:
# (2196, 241, 221)

# %%
type(np_maps120)
# Out:
# numpy.ndarray

# %% [markdown]
# ## 08:00 UT

# %%
# df120_0800.to_pickle("./TF_120_MAGGIA_TEC_maps_0800.pkl")

# %%
df120_0800
# Out:
#                                                                 TECMAP
# DATETIME
# 2022-03-01 08:00:00  [[nan, nan, nan, nan, nan, nan, nan, nan, nan,...
# 2022-03-02 08:00:00  [[nan, nan, nan, nan, nan, nan, nan, nan, nan,...
# 2022-03-03 08:00:00  [[nan, nan, nan, nan, nan, nan, nan, nan, nan,...
# 2022-03-04 08:00:00  [[nan, nan, nan, nan, nan, nan, nan, nan, nan,...
# 2022-03-05 08:00:00  [[nan, nan, nan, nan, nan, nan, nan, nan, nan,...
# ...                                                                ...
# 2024-12-26 08:00:00  [[nan, nan, nan, nan, nan, nan, nan, nan, nan,...
# 2024-12-27 08:00:00  [[nan, nan, nan, nan, nan, nan, nan, nan, nan,...
# 2024-12-28 08:00:00  [[nan, nan, nan, nan, nan, nan, nan, nan, nan,...
# 2024-12-29 08:00:00  [[nan, nan, nan, nan, nan, nan, nan, nan, nan,...
# 2024-12-30 08:00:00  [[nan, nan, nan, nan, nan, nan, nan, nan, nan,...
#
# [183 rows x 1 columns]

# %%
np.shape(np.array(df120_0800.iloc[:]['TECMAP']))
# Out:
# (183,)

# %%
maps120_0800 = np.array(df120_0800.iloc[:]['TECMAP'])

# %%
np.shape(df120_0800)
# Out:
# (183, 1)

# %%
np_maps120_0800 = []
for i in range(len(maps120_0800)):
    np_maps120_0800.append(maps120_0800[i])
np_maps120_0800 = np.array(np_maps120_0800)

# %%
np.shape(np_maps120_0800)
# Out:
# (183, 241, 221)

# %%
type(np_maps120_0800)
# Out:
# numpy.ndarray

# %%
np.save('TF_120_MAGGIA_TEC_maps_0800.npy', np_maps120_0800)

# %% [markdown]
# ## 16:00 UT

# %%
# df120_1600.to_pickle("./TF_120_MAGGIA_TEC_maps_1600.pkl")

# %%
df120_1600
# Out:
#                                                                 TECMAP
# DATETIME
# 2022-03-01 16:00:00  [[nan, nan, nan, nan, nan, nan, nan, nan, nan,...
# 2022-03-02 16:00:00  [[nan, nan, nan, nan, nan, nan, nan, nan, nan,...
# 2022-03-03 16:00:00  [[nan, nan, nan, nan, nan, nan, nan, nan, nan,...
# 2022-03-04 16:00:00  [[nan, nan, nan, nan, nan, nan, nan, nan, nan,...
# 2022-03-05 16:00:00  [[nan, nan, nan, nan, nan, nan, nan, nan, nan,...
# ...                                                                ...
# 2024-12-26 16:00:00  [[nan, nan, nan, nan, nan, nan, nan, nan, nan,...
# 2024-12-27 16:00:00  [[nan, nan, nan, nan, nan, nan, nan, nan, nan,...
# 2024-12-28 16:00:00  [[nan, nan, nan, nan, nan, nan, nan, nan, nan,...
# 2024-12-29 16:00:00  [[nan, nan, nan, nan, nan, nan, nan, nan, nan,...
# 2024-12-30 16:00:00  [[nan, nan, nan, nan, nan, nan, nan, nan, nan,...
#
# [183 rows x 1 columns]

# %%
maps120_1600 = np.array(df120_1600.iloc[:]['TECMAP'])

# %%
np.shape(maps120_1600)
# Out:
# (183,)

# %%
np_maps120_1600 = []
for i in range(len(maps120_1600)):
    np_maps120_1600.append(maps120_1600[i])
np_maps120_1600 = np.array(np_maps120_1600)

# %%
np.shape(np_maps120_1600)
# Out:
# (183, 241, 221)

# %%
type(np_maps120_1600)
# Out:
# numpy.ndarray

# %%
np.save('TF_120_MAGGIA_TEC_maps_1600.npy', np_maps120_1600)

# %% [markdown]
# ## 20:00 to 04:00 UT

# %%
# df120_2000_2200_0000_0200_0400.to_pickle("./TF_120_MAGGIA_TEC_maps_2000_0400.pkl")

# %%
df120_2000_2200_0000_0200_0400
# Out:
#                                                                 TECMAP
# DATETIME
# 2022-03-01 00:00:00  [[nan, nan, nan, nan, nan, nan, nan, nan, nan,...
# 2022-03-01 02:00:00  [[nan, nan, nan, nan, nan, nan, nan, nan, nan,...
# 2022-03-01 04:00:00  [[nan, nan, nan, nan, nan, nan, nan, nan, nan,...
# 2022-03-01 20:00:00  [[nan, nan, nan, nan, nan, nan, nan, nan, nan,...
# 2022-03-01 22:00:00  [[nan, nan, nan, nan, nan, nan, nan, nan, nan,...
# ...                                                                ...
# 2024-12-30 00:00:00  [[nan, nan, nan, nan, nan, nan, nan, nan, nan,...
# 2024-12-30 02:00:00  [[nan, nan, nan, nan, nan, nan, nan, nan, nan,...
# 2024-12-30 04:00:00  [[nan, nan, nan, nan, nan, nan, nan, nan, nan,...
# 2024-12-30 20:00:00  [[nan, nan, nan, nan, nan, nan, nan, nan, nan,...
# 2024-12-30 22:00:00  [[nan, nan, nan, nan, nan, nan, nan, nan, nan,...
#
# [915 rows x 1 columns]

# %%
maps120_2000_2200_0000_0200_0400 = np.array(df120_2000_2200_0000_0200_0400.iloc[:]['TECMAP'])

# %%
np.shape(maps120_2000_2200_0000_0200_0400)
# Out:
# (915,)

# %%
np_maps120_2000_2200_0000_0200_0400 = []
for i in range(len(maps120_2000_2200_0000_0200_0400)):
    np_maps120_2000_2200_0000_0200_0400.append(maps120_2000_2200_0000_0200_0400[i])
np_maps120_2000_2200_0000_0200_0400 = np.array(np_maps120_2000_2200_0000_0200_0400)

# %%
np.shape(np_maps120_2000_2200_0000_0200_0400)
# Out:
# (915, 241, 221)

# %%
type(np_maps120_2000_2200_0000_0200_0400)
# Out:
# numpy.ndarray

# %%
np.save('TF_120_MAGGIA_TEC_maps_2000_0400.npy', np_maps120_2000_2200_0000_0200_0400)

# %% [markdown]
# # TF-30 adjusts

# %% [markdown]
# ## Continuous

# %%
np.array(df30.iloc[0]['TECMAP'])
# Out:
# array([[        nan,         nan,         nan,         nan,         nan,
#                 nan,         nan,         nan,         nan,         nan,
#                 nan,         nan,         nan,         nan,         nan,
#                 nan,         nan,         nan,         nan,         nan,
#                 nan,         nan,         nan,         nan,         nan,
#                 nan,         nan,         nan,         nan,         nan,
#                 nan,         nan,         nan,         nan,         nan,
#                 nan,         nan,         nan,         nan,         nan,
#                 nan,         nan,         nan,         nan,         nan,
#                 nan,         nan,         nan,         nan,         nan,
#                 nan,         nan,         nan,         nan,         nan,
#                 nan,         nan,         nan,         nan,         nan,
#                 nan,         nan,         nan,         nan,         nan,
# ...

# %%
np.array(df30.iloc[0]['TECMAP']).shape
# Out:
# (241, 221)

# %%
df30_0800 = df30.between_time('08:00', '08:00')

df30_1600 = df30.between_time('16:00', '16:00')

df30_2000_0400 = pd.concat([
    df30.between_time('20:00', '20:00'),
    df30.between_time('20:30', '20:30'),
    df30.between_time('21:00', '21:00'),
    df30.between_time('21:30', '21:30'),
    df30.between_time('22:00', '22:00'),
    df30.between_time('22:30', '22:30'),
    df30.between_time('23:00', '23:00'),
    df30.between_time('23:30', '23:30'),
    df30.between_time('00:00', '00:00'),
    df30.between_time('00:30', '00:30'),
    df30.between_time('01:00', '01:00'),
    df30.between_time('01:30', '01:30'),
    df30.between_time('02:00', '02:00'),
    df30.between_time('02:30', '02:30'),
    df30.between_time('03:00', '03:00'),
    df30.between_time('03:30', '03:30'),
    df30.between_time('04:00', '04:00')
])

df30_2000_0400.sort_index(inplace=True)

print("Data from 08:00:")
print(df30_0800)

print("\nData from 16:00:")
print(df30_1600)

print("\nData from 20:00 to 04:00:")
print(df30_2000_0400)
# Out:
# Data from 08:00:
#                                                                 TECMAP
# DATETIME
# 2024-03-01 08:00:00  [[nan, nan, nan, nan, nan, nan, nan, nan, nan,...
# 2024-03-02 08:00:00  [[nan, nan, nan, nan, nan, nan, nan, nan, nan,...
# 2024-03-03 08:00:00  [[nan, nan, nan, nan, nan, nan, nan, nan, nan,...
# 2024-03-04 08:00:00  [[nan, nan, nan, nan, nan, nan, nan, nan, nan,...
# 2024-03-05 08:00:00  [[nan, nan, nan, nan, nan, nan, nan, nan, nan,...
# ...                                                                ...
# 2024-12-26 08:00:00  [[nan, nan, nan, nan, nan, nan, nan, nan, nan,...
# 2024-12-27 08:00:00  [[nan, nan, nan, nan, nan, nan, nan, nan, nan,...
# 2024-12-28 08:00:00  [[nan, nan, nan, nan, nan, nan, nan, nan, nan,...
# 2024-12-29 08:00:00  [[nan, nan, nan, nan, nan, nan, nan, nan, nan,...
# 2024-12-30 08:00:00  [[nan, nan, nan, nan, nan, nan, nan, nan, nan,...
#
# [106 rows x 1 columns]
#
# Data from 16:00:
# ...

# %%
np.shape(np.array(df30.iloc[:]['TECMAP']))
# Out:
# (5088,)

# %%
maps30 = np.array(df30.iloc[:]['TECMAP'])

# %%
np.shape(df30)
# Out:
# (5088, 1)

# %%
np_maps30 = []
for i in range(len(maps30)):
    np_maps30.append(maps30[i])
np_maps30 = np.array(np_maps30)

# %%
np.shape(np_maps30)
# Out:
# (5088, 241, 221)

# %%
type(np_maps30)
# Out:
# numpy.ndarray

# %% [markdown]
# ## 08:00 UT

# %%
# df30_0800.to_pickle("./TF_30_MAGGIA_TEC_maps_2024_0800.pkl")

# %%
df30_0800
# Out:
#                                                                 TECMAP
# DATETIME
# 2024-03-01 08:00:00  [[nan, nan, nan, nan, nan, nan, nan, nan, nan,...
# 2024-03-02 08:00:00  [[nan, nan, nan, nan, nan, nan, nan, nan, nan,...
# 2024-03-03 08:00:00  [[nan, nan, nan, nan, nan, nan, nan, nan, nan,...
# 2024-03-04 08:00:00  [[nan, nan, nan, nan, nan, nan, nan, nan, nan,...
# 2024-03-05 08:00:00  [[nan, nan, nan, nan, nan, nan, nan, nan, nan,...
# ...                                                                ...
# 2024-12-26 08:00:00  [[nan, nan, nan, nan, nan, nan, nan, nan, nan,...
# 2024-12-27 08:00:00  [[nan, nan, nan, nan, nan, nan, nan, nan, nan,...
# 2024-12-28 08:00:00  [[nan, nan, nan, nan, nan, nan, nan, nan, nan,...
# 2024-12-29 08:00:00  [[nan, nan, nan, nan, nan, nan, nan, nan, nan,...
# 2024-12-30 08:00:00  [[nan, nan, nan, nan, nan, nan, nan, nan, nan,...
#
# [106 rows x 1 columns]

# %%
np.shape(np.array(df30_0800.iloc[:]['TECMAP']))
# Out:
# (106,)

# %%
maps30_0800 = np.array(df30_0800.iloc[:]['TECMAP'])

# %%
np.shape(df30_0800)
# Out:
# (106, 1)

# %%
np_maps30_0800 = []
for i in range(len(maps30_0800)):
    np_maps30_0800.append(maps30_0800[i])
np_maps30_0800 = np.array(np_maps30_0800)

# %%
np.shape(np_maps30_0800)
# Out:
# (106, 241, 221)

# %%
type(np_maps30_0800)
# Out:
# numpy.ndarray

# %%
# np.save('TF_30_MAGGIA_TEC_maps_2024_0800.npy', np_maps30_0800)

# %% [markdown]
# ## 16:00 UT

# %%
# df30_1600.to_pickle("./TF_30_MAGGIA_TEC_maps_2024_1600.pkl")

# %%
df30_1600
# Out:
#                                                                 TECMAP
# DATETIME
# 2024-03-01 16:00:00  [[nan, nan, nan, nan, nan, nan, nan, nan, nan,...
# 2024-03-02 16:00:00  [[nan, nan, nan, nan, nan, nan, nan, nan, nan,...
# 2024-03-03 16:00:00  [[nan, nan, nan, nan, nan, nan, nan, nan, nan,...
# 2024-03-04 16:00:00  [[nan, nan, nan, nan, nan, nan, nan, nan, nan,...
# 2024-03-05 16:00:00  [[nan, nan, nan, nan, nan, nan, nan, nan, nan,...
# ...                                                                ...
# 2024-12-26 16:00:00  [[nan, nan, nan, nan, nan, nan, nan, nan, nan,...
# 2024-12-27 16:00:00  [[nan, nan, nan, nan, nan, nan, nan, nan, nan,...
# 2024-12-28 16:00:00  [[nan, nan, nan, nan, nan, nan, nan, nan, nan,...
# 2024-12-29 16:00:00  [[nan, nan, nan, nan, nan, nan, nan, nan, nan,...
# 2024-12-30 16:00:00  [[nan, nan, nan, nan, nan, nan, nan, nan, nan,...
#
# [106 rows x 1 columns]

# %%
maps30_1600 = np.array(df30_1600.iloc[:]['TECMAP'])

# %%
np.shape(maps30_1600)
# Out:
# (106,)

# %%
np_maps30_1600 = []
for i in range(len(maps30_1600)):
    np_maps30_1600.append(maps30_1600[i])
np_maps30_1600 = np.array(np_maps30_1600)

# %%
np.shape(np_maps30_1600)
# Out:
# (106, 241, 221)

# %%
type(np_maps30_1600)
# Out:
# numpy.ndarray

# %%
# np.save('TF_30_MAGGIA_TEC_maps_2024_1600.npy', np_maps30_1600)

# %% [markdown]
# ## 20:00 to 04:00 UT

# %%
# df30_2000_0400.to_pickle("./TF_30_MAGGIA_TEC_maps_2024_2000_0400.pkl")

# %%
df30_2000_0400
# Out:
#                                                                 TECMAP
# DATETIME
# 2024-03-01 00:00:00  [[nan, nan, nan, nan, nan, nan, nan, nan, nan,...
# 2024-03-01 00:30:00  [[nan, nan, nan, nan, nan, nan, nan, nan, nan,...
# 2024-03-01 01:00:00  [[nan, nan, nan, nan, nan, nan, nan, nan, nan,...
# 2024-03-01 01:30:00  [[nan, nan, nan, nan, nan, nan, nan, nan, nan,...
# 2024-03-01 02:00:00  [[nan, nan, nan, nan, nan, nan, nan, nan, nan,...
# ...                                                                ...
# 2024-12-30 21:30:00  [[nan, nan, nan, nan, nan, nan, nan, nan, nan,...
# 2024-12-30 22:00:00  [[nan, nan, nan, nan, nan, nan, nan, nan, nan,...
# 2024-12-30 22:30:00  [[nan, nan, nan, nan, nan, nan, nan, nan, nan,...
# 2024-12-30 23:00:00  [[nan, nan, nan, nan, nan, nan, nan, nan, nan,...
# 2024-12-30 23:30:00  [[nan, nan, nan, nan, nan, nan, nan, nan, nan,...
#
# [1802 rows x 1 columns]

# %%
maps30_2000_0400 = np.array(df30_2000_0400.iloc[:]['TECMAP'])

# %%
np.shape(maps30_2000_0400)
# Out:
# (1802,)

# %%
np_maps30_2000_0400 = []
for i in range(len(maps30_2000_0400)):
    np_maps30_2000_0400.append(maps30_2000_0400[i])
np_maps30_2000_0400 = np.array(np_maps30_2000_0400)

# %%
np.shape(np_maps30_2000_0400)
# Out:
# (1802, 241, 221)

# %%
type(np_maps30_2000_0400)
# Out:
# numpy.ndarray

# %%
np.save('TF_30_MAGGIA_TEC_maps_2024_2000_0400.npy', np_maps30_2000_0400)

# %% [markdown]
# # Download outputs

# %%
from google.colab import files

# %%
# %pwd
# Out:
# '/content'

# %%
# !ls df*
# Out:
# ls: cannot access 'df*': No such file or directory

# %%
# !ls maggia*
# Out:
# ls: cannot access 'maggia*': No such file or directory

# %%
# !ls -lh maggia*
# Out:
# ls: cannot access 'maggia*': No such file or directory

# %%
# !ls -lh maps*.npy
# Out:
# ls: cannot access 'maps*.npy': No such file or directory

# %%
# files.download('./TF_120_MAGGIA_TEC_maps_0800.pkl')

# %%
# files.download('./TF_120_MAGGIA_TEC_maps_1600.pkl')

# %%
# files.download('./TF_120_MAGGIA_TEC_maps_2000_0400.pkl')

# %%
# files.download('./TF_30_MAGGIA_TEC_maps_0800.pkl')

# %%
# files.download('./TF_30_MAGGIA_TEC_maps_1600.pkl')

# %%
# files.download('./TF_30_MAGGIA_TEC_maps_2000_0400.pkl')

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
# !ls -lh df30*
# Out:
# ls: cannot access 'df30*': No such file or directory

# %%
# %cp TF_30_MAGGIA_TEC_maps_0800.pkl /content/drive/MyDrive/TF_30_MAGGIA_TEC_maps_0800.pkl

# %%
# %cp TF_30_MAGGIA_TEC_maps_1600.pkl /content/drive/MyDrive/TF_30_MAGGIA_TEC_maps_1600.pkl

# %%
# %cp TF_30_MAGGIA_TEC_maps_2000_0400.pkl /content/drive/MyDrive/TF_30_MAGGIA_TEC_maps_2000_0400.pkl

# %%
# !ls -lh maps30*
# Out:
# ls: cannot access 'maps30*': No such file or directory

# %%
# %cp TF_30_MAGGIA_TEC_maps_0800.npy /content/drive/MyDrive/TF_30_MAGGIA_TEC_maps_0800.npy

# %%
# %cp TF_30_MAGGIA_TEC_maps_1600.npy /content/drive/MyDrive/TF_30_MAGGIA_TEC_maps_1600.npy

# %%
# %cp TF_30_MAGGIA_TEC_maps_2000_0400.npy /content/drive/MyDrive/TF_30_MAGGIA_TEC_maps_2000_0400.npy
